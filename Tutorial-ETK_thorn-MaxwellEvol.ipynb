# %% [markdown]
# # MaxwellEvol: Solving Maxwell's Equations in the Einstein Toolkit with the Method of Lines
#
# ### NRPy+ Source Code for this module: [Maxwell/MaxwellCartesian_Evol.py](../edit/Maxwell/MaxwellCartesian_Evol.py), which is fully documented in the [previous NRPy+ tutorial module](Tutorial-MaxwellCartesian.ipynb) on using NRPy+ to construct Maxwell's equations and initial data as SymPy expressions.

# %% [markdown]
# This module focuses on using the equations developed in the [last tutorial](Tutorial-MaxwellCartesian.ipynb) to build an Einstein Toolkit (ETK) thorn to solve Maxwell's equations in Cartesian coordinates. This tutorial will focus on implementing the time evolution aspects; the next will construct the thorn that will set up the initial data to be evolved.
#
# When interfaced properly with the ETK, this module will propagate the initial data for $E_i$, $A_i$, and $\psi$ ( and $\Gamma$, if we so choose), defined in the next tutorial, forward in time by integrating the equations for $\partial_t E_i$, $\partial_t A_i$ and $\partial_t \psi$ (and possibly $\partial_t \Gamma$) subject to spatial boundary conditions. The time evolution itself is handled by the $\text{MoL}$ (Method of Lines) thorn in the $\text{CactusNumerical}$ arrangement, and the boundary conditions by the $\text{Boundary}$ thorn in the $\text{CactusBase}$ arrangement.
#
# Similar to the Maxwell initial data module, we will construct the WaveToyNRPy module in two steps.
#
# 1. Call on NRPy+ to convert the SymPy expressions for the evolution equations into one C-code kernel.
# 1. Write the C code and linkages to the Einstein Toolkit infrastructure (i.e., the .ccl files) to complete this Einstein Toolkit module.

# %%
# Step 1a: Import needed NRPy+ core modules:
import NRPy_param_funcs as par
import indexedexp as ixp
import grid as gri
import finite_difference as fin
from outputC import *
import loop


# Step 1b: This is an Einstein Toolkit (ETK) thorn. Here we
#          tell NRPy+ that gridfunction memory access will 
#          therefore be in the "ETK" style.
par.set_parval_from_str("grid::GridFuncMemAccess","ETK")
#Set the spatial dimension parameter to 3.
par.set_parval_from_str("grid::DIM", 3)
DIM = par.parval_from_str("grid::DIM")
par.set_parval_from_str("outputC::outCverbose",False) # To prevent absurdly large output files.

# Step 1c: Call the MaxwellCartesian_Evol() function from within the
#          Maxwell/MaxwellCartesian_Evol.py module.
import Maxwell.MaxwellCartesian_Evol as mwrhs
par.set_parval_from_str("System_to_use","System_I")
mwrhs.MaxwellCartesian_Evol()
par.set_parval_from_str("finite_difference::FD_CENTDERIVS_ORDER",2)

# Step 2: Register gridfunctions so they can be written to by NRPy.
# System I:
AIrhsD = ixp.register_gridfunctions_for_single_rank1("EVOL","AIrhsD")
EIrhsD = ixp.register_gridfunctions_for_single_rank1("EVOL","EIrhsD")
psiIrhs = gri.register_gridfunctions("EVOL","psiIrhs")

# Step 3: Set the rhs gridfunctions to their variables 
#         defined by MaxwellEvol().
for i in range(DIM):
    AIrhsD[i] = mwrhs.ArhsD[i]
    EIrhsD[i] = mwrhs.ErhsD[i]
psiIrhs = mwrhs.psi_rhs
Maxwell_Evol_to_printI = [\
                         lhrh(lhs=gri.gfaccess("out_gfs","AIrhsD0"),rhs=AIrhsD[0]),\
                         lhrh(lhs=gri.gfaccess("out_gfs","AIrhsD1"),rhs=AIrhsD[1]),\
                         lhrh(lhs=gri.gfaccess("out_gfs","AIrhsD2"),rhs=AIrhsD[2]),\
                         lhrh(lhs=gri.gfaccess("out_gfs","EIrhsD0"),rhs=EIrhsD[0]),\
                         lhrh(lhs=gri.gfaccess("out_gfs","EIrhsD1"),rhs=EIrhsD[1]),\
                         lhrh(lhs=gri.gfaccess("out_gfs","EIrhsD2"),rhs=EIrhsD[2]),\
                         lhrh(lhs=gri.gfaccess("out_gfs","psiIrhs"),rhs=psiIrhs)]
Maxwell_Evol_CcodeKernelI = fin.FD_outputC("returnstring",Maxwell_Evol_to_printI).replace("AD","AID")\
                                                                                 .replace("ED","EID")\
                                                                                 .replace("psi","psiI")
fin.FD_outputC("stdout",Maxwell_Evol_to_printI)
gri.glb_gridfcs_list = []
# Step 1c: Call the MaxwellCartesian_Evol() function from within the
#          Maxwell/MaxwellCartesian_Evol.py module.
par.set_parval_from_str("System_to_use","System_II")
mwrhs.MaxwellCartesian_Evol()
par.set_parval_from_str("finite_difference::FD_CENTDERIVS_ORDER",2)

# Step 2: Register gridfunctions so they can be written to by NRPy.
# System II:
AIIrhsD = ixp.register_gridfunctions_for_single_rank1("EVOL","AIIrhsD")
EIIrhsD = ixp.register_gridfunctions_for_single_rank1("EVOL","EIIrhsD")
psiIIrhs = gri.register_gridfunctions("EVOL","psiIIrhs")
Gammarhs = gri.register_gridfunctions("EVOL","Gammarhs")
# Step 3: Set the rhs gridfunctions to their variables 
#         defined by MaxwellEvol().

for i in range(DIM):
    AIIrhsD[i] = mwrhs.ArhsD[i]
    EIIrhsD[i] = mwrhs.ErhsD[i]
psiIIrhs = mwrhs.psi_rhs
Gammarhs = mwrhs.Gamma_rhs

# Step 4: Create the C code output kernel.
Maxwell_Evol_to_printII = [\
                          lhrh(lhs=gri.gfaccess("out_gfs","AIIrhsD0"),rhs=AIIrhsD[0]),\
                          lhrh(lhs=gri.gfaccess("out_gfs","AIIrhsD1"),rhs=AIIrhsD[1]),\
                          lhrh(lhs=gri.gfaccess("out_gfs","AIIrhsD2"),rhs=AIIrhsD[2]),\
                          lhrh(lhs=gri.gfaccess("out_gfs","EIIrhsD0"),rhs=EIIrhsD[0]),\
                          lhrh(lhs=gri.gfaccess("out_gfs","EIIrhsD1"),rhs=EIIrhsD[1]),\
                          lhrh(lhs=gri.gfaccess("out_gfs","EIIrhsD2"),rhs=EIIrhsD[2]),\
                          lhrh(lhs=gri.gfaccess("out_gfs","psiIIrhs"),rhs=psiIIrhs),\
                          lhrh(lhs=gri.gfaccess("out_gfs","Gammarhs"),rhs=Gammarhs)]
Maxwell_Evol_CcodeKernelII = fin.FD_outputC("returnstring",Maxwell_Evol_to_printII).replace("AD","AIID")\
                                                                                   .replace("ED","EIID")\
                                                                                   .replace("psiGF","psiIIGF")

Maxwell_Evol_looped = loop.loop(["i2","i1","i0"],["cctk_nghostzones[2]","cctk_nghostzones[1]","cctk_nghostzones[0]"],\
                               ["cctk_lsh[2]-cctk_nghostzones[2]","cctk_lsh[1]-cctk_nghostzones[1]",\
                                "cctk_lsh[0]-cctk_nghostzones[0]"],\
                               ["1","1","1"],["#pragma omp parallel for","",""],"",\
                               (Maxwell_Evol_CcodeKernelI+Maxwell_Evol_CcodeKernelII).replace("time","cctk_time"))

# Step 5: Create directories for the thorn if they don't exist.
# !mkdir MaxwellEvol     2>/dev/null # 2>/dev/null: Don't throw an error if the directory already exists.
# !mkdir MaxwellEvol/src 2>/dev/null # 2>/dev/null: Don't throw an error if the directory already exists.

# Step 6: Write the C code kernel to file.
with open("MaxwellEvol/src/Maxwell_Evol.h", "w") as file:
    file.write(str(Maxwell_Evol_looped))

with open("MaxwellEvol/src/NRPy_params.h", "w") as file:
    file.write("#define FD_CENTDERIVS_ORDER "+str(par.parval_from_str("finite_difference::FD_CENTDERIVS_ORDER"))+"\n")
    
# Step 7: Create a C code kernel to evaluate the constraint violation
Cviola_CcodeKernel = fin.FD_outputC("returnstring",[lhrh(lhs=gri.gfaccess("out_gfs","Cviola"),rhs=mwrhs.Cviola)])
Cviola_CcodeKernel_geminated = (Cviola_CcodeKernel.replace("ED","EID").replace("Cviola","CviolaI") + \
                                Cviola_CcodeKernel.replace("ED","EIID").replace("Cviola","CviolaII"))
Cviola_CcodeKernel_looped = loop.loop(["i2","i1","i0"],["1","1","1"],["cctk_lsh[2]-1","cctk_lsh[1]-1","cctk_lsh[0]-1"],\
                                     ["1","1","1"],["#pragma omp parallel for","",""],"",\
                                     Cviola_CcodeKernel_geminated.replace("time","cctk_time"))
with open("MaxwellEvol/src/Constraint_violation.h", "w") as file:
    file.write(str(Cviola_CcodeKernel_looped))
# Out:
# Warning: System I is less stable!
# {
#     /*
#      * Step 1 of 2: Read from main memory and compute finite difference stencils (if any):
#      */
#     const double psi_i0_i1_i2m1 = psiGF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double psi_i0_i1m1_i2 = psiGF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double psi_i0m1_i1_i2 = psiGF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double psi_i0p1_i1_i2 = psiGF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double psi_i0_i1p1_i2 = psiGF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double psi_i0_i1_i2p1 = psiGF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double ED0 = ED0GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double ED1 = ED1GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double ED2 = ED2GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double AD0_i0_i1m1_i2m1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2-1)];
#     const double AD0_i0m1_i1_i2m1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2-1)];
#     const double AD0_i0_i1_i2m1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double AD0_i0p1_i1_i2m1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2-1)];
#     const double AD0_i0_i1p1_i2m1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2-1)];
#     const double AD0_i0m1_i1m1_i2 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1-1,i2)];
#     const double AD0_i0_i1m1_i2 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double AD0_i0p1_i1m1_i2 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1-1,i2)];
#     const double AD0_i0m1_i1_i2 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double AD0 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double AD0_i0p1_i1_i2 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double AD0_i0m1_i1p1_i2 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1+1,i2)];
#     const double AD0_i0_i1p1_i2 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double AD0_i0p1_i1p1_i2 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1+1,i2)];
#     const double AD0_i0_i1m1_i2p1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2+1)];
#     const double AD0_i0m1_i1_i2p1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2+1)];
#     const double AD0_i0_i1_i2p1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double AD0_i0p1_i1_i2p1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2+1)];
#     const double AD0_i0_i1p1_i2p1 = AD0GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2+1)];
#     const double AD1_i0_i1m1_i2m1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2-1)];
#     const double AD1_i0m1_i1_i2m1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2-1)];
#     const double AD1_i0_i1_i2m1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double AD1_i0p1_i1_i2m1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2-1)];
#     const double AD1_i0_i1p1_i2m1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2-1)];
#     const double AD1_i0m1_i1m1_i2 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1-1,i2)];
#     const double AD1_i0_i1m1_i2 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double AD1_i0p1_i1m1_i2 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1-1,i2)];
#     const double AD1_i0m1_i1_i2 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double AD1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double AD1_i0p1_i1_i2 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double AD1_i0m1_i1p1_i2 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1+1,i2)];
#     const double AD1_i0_i1p1_i2 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double AD1_i0p1_i1p1_i2 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1+1,i2)];
#     const double AD1_i0_i1m1_i2p1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2+1)];
#     const double AD1_i0m1_i1_i2p1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2+1)];
#     const double AD1_i0_i1_i2p1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double AD1_i0p1_i1_i2p1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2+1)];
#     const double AD1_i0_i1p1_i2p1 = AD1GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2+1)];
#     const double AD2_i0_i1m1_i2m1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2-1)];
#     const double AD2_i0m1_i1_i2m1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2-1)];
#     const double AD2_i0_i1_i2m1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double AD2_i0p1_i1_i2m1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2-1)];
#     const double AD2_i0_i1p1_i2m1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2-1)];
#     const double AD2_i0m1_i1m1_i2 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1-1,i2)];
#     const double AD2_i0_i1m1_i2 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double AD2_i0p1_i1m1_i2 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1-1,i2)];
#     const double AD2_i0m1_i1_i2 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double AD2 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double AD2_i0p1_i1_i2 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double AD2_i0m1_i1p1_i2 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1+1,i2)];
#     const double AD2_i0_i1p1_i2 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double AD2_i0p1_i1p1_i2 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1+1,i2)];
#     const double AD2_i0_i1m1_i2p1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2+1)];
#     const double AD2_i0m1_i1_i2p1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2+1)];
#     const double AD2_i0_i1_i2p1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double AD2_i0p1_i1_i2p1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2+1)];
#     const double AD2_i0_i1p1_i2p1 = AD2GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2+1)];
#     const double gammaDD00_i0_i1m1_i2m1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2-1)];
#     const double gammaDD00_i0m1_i1_i2m1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2-1)];
#     const double gammaDD00_i0_i1_i2m1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double gammaDD00_i0p1_i1_i2m1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2-1)];
#     const double gammaDD00_i0_i1p1_i2m1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2-1)];
#     const double gammaDD00_i0m1_i1m1_i2 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1-1,i2)];
#     const double gammaDD00_i0_i1m1_i2 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double gammaDD00_i0p1_i1m1_i2 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1-1,i2)];
#     const double gammaDD00_i0m1_i1_i2 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double gammaDD00 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double gammaDD00_i0p1_i1_i2 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double gammaDD00_i0m1_i1p1_i2 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1+1,i2)];
#     const double gammaDD00_i0_i1p1_i2 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double gammaDD00_i0p1_i1p1_i2 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1+1,i2)];
#     const double gammaDD00_i0_i1m1_i2p1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2+1)];
#     const double gammaDD00_i0m1_i1_i2p1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2+1)];
#     const double gammaDD00_i0_i1_i2p1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double gammaDD00_i0p1_i1_i2p1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2+1)];
#     const double gammaDD00_i0_i1p1_i2p1 = gammaDD00GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2+1)];
#     const double gammaDD01_i0_i1m1_i2m1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2-1)];
#     const double gammaDD01_i0m1_i1_i2m1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2-1)];
#     const double gammaDD01_i0_i1_i2m1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double gammaDD01_i0p1_i1_i2m1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2-1)];
#     const double gammaDD01_i0_i1p1_i2m1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2-1)];
#     const double gammaDD01_i0_i1m1_i2 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double gammaDD01_i0m1_i1_i2 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double gammaDD01 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double gammaDD01_i0p1_i1_i2 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double gammaDD01_i0_i1p1_i2 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double gammaDD01_i0_i1m1_i2p1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2+1)];
#     const double gammaDD01_i0m1_i1_i2p1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2+1)];
#     const double gammaDD01_i0_i1_i2p1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double gammaDD01_i0p1_i1_i2p1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2+1)];
#     const double gammaDD01_i0_i1p1_i2p1 = gammaDD01GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2+1)];
#     const double gammaDD02_i0_i1m1_i2m1 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2-1)];
#     const double gammaDD02_i0_i1_i2m1 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double gammaDD02_i0_i1p1_i2m1 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2-1)];
#     const double gammaDD02_i0m1_i1m1_i2 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1-1,i2)];
#     const double gammaDD02_i0_i1m1_i2 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double gammaDD02_i0p1_i1m1_i2 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1-1,i2)];
#     const double gammaDD02_i0m1_i1_i2 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double gammaDD02 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double gammaDD02_i0p1_i1_i2 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double gammaDD02_i0m1_i1p1_i2 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1+1,i2)];
#     const double gammaDD02_i0_i1p1_i2 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double gammaDD02_i0p1_i1p1_i2 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1+1,i2)];
#     const double gammaDD02_i0_i1m1_i2p1 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2+1)];
#     const double gammaDD02_i0_i1_i2p1 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double gammaDD02_i0_i1p1_i2p1 = gammaDD02GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2+1)];
#     const double gammaDD11_i0_i1m1_i2m1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2-1)];
#     const double gammaDD11_i0m1_i1_i2m1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2-1)];
#     const double gammaDD11_i0_i1_i2m1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double gammaDD11_i0p1_i1_i2m1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2-1)];
#     const double gammaDD11_i0_i1p1_i2m1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2-1)];
#     const double gammaDD11_i0m1_i1m1_i2 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1-1,i2)];
#     const double gammaDD11_i0_i1m1_i2 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double gammaDD11_i0p1_i1m1_i2 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1-1,i2)];
#     const double gammaDD11_i0m1_i1_i2 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double gammaDD11 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double gammaDD11_i0p1_i1_i2 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double gammaDD11_i0m1_i1p1_i2 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1+1,i2)];
#     const double gammaDD11_i0_i1p1_i2 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double gammaDD11_i0p1_i1p1_i2 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1+1,i2)];
#     const double gammaDD11_i0_i1m1_i2p1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2+1)];
#     const double gammaDD11_i0m1_i1_i2p1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2+1)];
#     const double gammaDD11_i0_i1_i2p1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double gammaDD11_i0p1_i1_i2p1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2+1)];
#     const double gammaDD11_i0_i1p1_i2p1 = gammaDD11GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2+1)];
#     const double gammaDD12_i0m1_i1_i2m1 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2-1)];
#     const double gammaDD12_i0_i1_i2m1 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double gammaDD12_i0p1_i1_i2m1 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2-1)];
#     const double gammaDD12_i0m1_i1m1_i2 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1-1,i2)];
#     const double gammaDD12_i0_i1m1_i2 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double gammaDD12_i0p1_i1m1_i2 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1-1,i2)];
#     const double gammaDD12_i0m1_i1_i2 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double gammaDD12 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double gammaDD12_i0p1_i1_i2 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double gammaDD12_i0m1_i1p1_i2 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1+1,i2)];
#     const double gammaDD12_i0_i1p1_i2 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double gammaDD12_i0p1_i1p1_i2 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1+1,i2)];
#     const double gammaDD12_i0m1_i1_i2p1 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2+1)];
#     const double gammaDD12_i0_i1_i2p1 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double gammaDD12_i0p1_i1_i2p1 = gammaDD12GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2+1)];
#     const double gammaDD22_i0_i1m1_i2m1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2-1)];
#     const double gammaDD22_i0m1_i1_i2m1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2-1)];
#     const double gammaDD22_i0_i1_i2m1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2-1)];
#     const double gammaDD22_i0p1_i1_i2m1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2-1)];
#     const double gammaDD22_i0_i1p1_i2m1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2-1)];
#     const double gammaDD22_i0m1_i1m1_i2 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1-1,i2)];
#     const double gammaDD22_i0_i1m1_i2 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2)];
#     const double gammaDD22_i0p1_i1m1_i2 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1-1,i2)];
#     const double gammaDD22_i0m1_i1_i2 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2)];
#     const double gammaDD22 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2)];
#     const double gammaDD22_i0p1_i1_i2 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2)];
#     const double gammaDD22_i0m1_i1p1_i2 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1+1,i2)];
#     const double gammaDD22_i0_i1p1_i2 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2)];
#     const double gammaDD22_i0p1_i1p1_i2 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1+1,i2)];
#     const double gammaDD22_i0_i1m1_i2p1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0,i1-1,i2+1)];
#     const double gammaDD22_i0m1_i1_i2p1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0-1,i1,i2+1)];
#     const double gammaDD22_i0_i1_i2p1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0,i1,i2+1)];
#     const double gammaDD22_i0p1_i1_i2p1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0+1,i1,i2+1)];
#     const double gammaDD22_i0_i1p1_i2p1 = gammaDD22GF[CCTK_GFINDEX3D(cctkGH, i0,i1+1,i2+1)];
#     const double tmpFD0 = invdx0*invdx1;
#     const double tmpFD1 = invdx0*invdx2;
#     const double tmpFD2 = pow(invdx1, 2);
#     const double tmpFD3 = -2*AD0;
#     const double tmpFD4 = invdx1*invdx2;
#     const double tmpFD5 = pow(invdx2, 2);
#     const double tmpFD6 = pow(invdx0, 2);
#     const double tmpFD7 = -2*AD1;
#     const double tmpFD8 = -2*AD2;
#     const double tmpFD9 = -2*gammaDD00;
#     const double tmpFD10 = -2*gammaDD11;
#     const double tmpFD11 = -2*gammaDD22;
#     const double AD_dD00 = invdx0*(-1.0/2.0*AD0_i0m1_i1_i2 + (1.0/2.0)*AD0_i0p1_i1_i2);
#     const double AD_dD01 = invdx1*(-1.0/2.0*AD0_i0_i1m1_i2 + (1.0/2.0)*AD0_i0_i1p1_i2);
#     const double AD_dD02 = invdx2*(-1.0/2.0*AD0_i0_i1_i2m1 + (1.0/2.0)*AD0_i0_i1_i2p1);
#     const double AD_dD10 = invdx0*(-1.0/2.0*AD1_i0m1_i1_i2 + (1.0/2.0)*AD1_i0p1_i1_i2);
#     const double AD_dD11 = invdx1*(-1.0/2.0*AD1_i0_i1m1_i2 + (1.0/2.0)*AD1_i0_i1p1_i2);
#     const double AD_dD12 = invdx2*(-1.0/2.0*AD1_i0_i1_i2m1 + (1.0/2.0)*AD1_i0_i1_i2p1);
#     const double AD_dD20 = invdx0*(-1.0/2.0*AD2_i0m1_i1_i2 + (1.0/2.0)*AD2_i0p1_i1_i2);
#     const double AD_dD21 = invdx1*(-1.0/2.0*AD2_i0_i1m1_i2 + (1.0/2.0)*AD2_i0_i1p1_i2);
#     const double AD_dD22 = invdx2*(-1.0/2.0*AD2_i0_i1_i2m1 + (1.0/2.0)*AD2_i0_i1_i2p1);
#     const double AD_dDD001 = tmpFD0*((1.0/4.0)*AD0_i0m1_i1m1_i2 - 1.0/4.0*AD0_i0m1_i1p1_i2 - 1.0/4.0*AD0_i0p1_i1m1_i2 + (1.0/4.0)*AD0_i0p1_i1p1_i2);
#     const double AD_dDD002 = tmpFD1*((1.0/4.0)*AD0_i0m1_i1_i2m1 - 1.0/4.0*AD0_i0m1_i1_i2p1 - 1.0/4.0*AD0_i0p1_i1_i2m1 + (1.0/4.0)*AD0_i0p1_i1_i2p1);
#     const double AD_dDD011 = tmpFD2*(AD0_i0_i1m1_i2 + AD0_i0_i1p1_i2 + tmpFD3);
#     const double AD_dDD012 = tmpFD4*((1.0/4.0)*AD0_i0_i1m1_i2m1 - 1.0/4.0*AD0_i0_i1m1_i2p1 - 1.0/4.0*AD0_i0_i1p1_i2m1 + (1.0/4.0)*AD0_i0_i1p1_i2p1);
#     const double AD_dDD022 = tmpFD5*(AD0_i0_i1_i2m1 + AD0_i0_i1_i2p1 + tmpFD3);
#     const double AD_dDD100 = tmpFD6*(AD1_i0m1_i1_i2 + AD1_i0p1_i1_i2 + tmpFD7);
#     const double AD_dDD101 = tmpFD0*((1.0/4.0)*AD1_i0m1_i1m1_i2 - 1.0/4.0*AD1_i0m1_i1p1_i2 - 1.0/4.0*AD1_i0p1_i1m1_i2 + (1.0/4.0)*AD1_i0p1_i1p1_i2);
#     const double AD_dDD102 = tmpFD1*((1.0/4.0)*AD1_i0m1_i1_i2m1 - 1.0/4.0*AD1_i0m1_i1_i2p1 - 1.0/4.0*AD1_i0p1_i1_i2m1 + (1.0/4.0)*AD1_i0p1_i1_i2p1);
#     const double AD_dDD112 = tmpFD4*((1.0/4.0)*AD1_i0_i1m1_i2m1 - 1.0/4.0*AD1_i0_i1m1_i2p1 - 1.0/4.0*AD1_i0_i1p1_i2m1 + (1.0/4.0)*AD1_i0_i1p1_i2p1);
#     const double AD_dDD122 = tmpFD5*(AD1_i0_i1_i2m1 + AD1_i0_i1_i2p1 + tmpFD7);
#     const double AD_dDD200 = tmpFD6*(AD2_i0m1_i1_i2 + AD2_i0p1_i1_i2 + tmpFD8);
#     const double AD_dDD201 = tmpFD0*((1.0/4.0)*AD2_i0m1_i1m1_i2 - 1.0/4.0*AD2_i0m1_i1p1_i2 - 1.0/4.0*AD2_i0p1_i1m1_i2 + (1.0/4.0)*AD2_i0p1_i1p1_i2);
#     const double AD_dDD202 = tmpFD1*((1.0/4.0)*AD2_i0m1_i1_i2m1 - 1.0/4.0*AD2_i0m1_i1_i2p1 - 1.0/4.0*AD2_i0p1_i1_i2m1 + (1.0/4.0)*AD2_i0p1_i1_i2p1);
#     const double AD_dDD211 = tmpFD2*(AD2_i0_i1m1_i2 + AD2_i0_i1p1_i2 + tmpFD8);
#     const double AD_dDD212 = tmpFD4*((1.0/4.0)*AD2_i0_i1m1_i2m1 - 1.0/4.0*AD2_i0_i1m1_i2p1 - 1.0/4.0*AD2_i0_i1p1_i2m1 + (1.0/4.0)*AD2_i0_i1p1_i2p1);
#     const double gammaDD_dD000 = invdx0*(-1.0/2.0*gammaDD00_i0m1_i1_i2 + (1.0/2.0)*gammaDD00_i0p1_i1_i2);
#     const double gammaDD_dD001 = invdx1*(-1.0/2.0*gammaDD00_i0_i1m1_i2 + (1.0/2.0)*gammaDD00_i0_i1p1_i2);
#     const double gammaDD_dD002 = invdx2*(-1.0/2.0*gammaDD00_i0_i1_i2m1 + (1.0/2.0)*gammaDD00_i0_i1_i2p1);
#     const double gammaDD_dD010 = invdx0*(-1.0/2.0*gammaDD01_i0m1_i1_i2 + (1.0/2.0)*gammaDD01_i0p1_i1_i2);
#     const double gammaDD_dD011 = invdx1*(-1.0/2.0*gammaDD01_i0_i1m1_i2 + (1.0/2.0)*gammaDD01_i0_i1p1_i2);
#     const double gammaDD_dD012 = invdx2*(-1.0/2.0*gammaDD01_i0_i1_i2m1 + (1.0/2.0)*gammaDD01_i0_i1_i2p1);
#     const double gammaDD_dD020 = invdx0*(-1.0/2.0*gammaDD02_i0m1_i1_i2 + (1.0/2.0)*gammaDD02_i0p1_i1_i2);
#     const double gammaDD_dD021 = invdx1*(-1.0/2.0*gammaDD02_i0_i1m1_i2 + (1.0/2.0)*gammaDD02_i0_i1p1_i2);
#     const double gammaDD_dD022 = invdx2*(-1.0/2.0*gammaDD02_i0_i1_i2m1 + (1.0/2.0)*gammaDD02_i0_i1_i2p1);
#     const double gammaDD_dD110 = invdx0*(-1.0/2.0*gammaDD11_i0m1_i1_i2 + (1.0/2.0)*gammaDD11_i0p1_i1_i2);
#     const double gammaDD_dD111 = invdx1*(-1.0/2.0*gammaDD11_i0_i1m1_i2 + (1.0/2.0)*gammaDD11_i0_i1p1_i2);
#     const double gammaDD_dD112 = invdx2*(-1.0/2.0*gammaDD11_i0_i1_i2m1 + (1.0/2.0)*gammaDD11_i0_i1_i2p1);
#     const double gammaDD_dD120 = invdx0*(-1.0/2.0*gammaDD12_i0m1_i1_i2 + (1.0/2.0)*gammaDD12_i0p1_i1_i2);
#     const double gammaDD_dD121 = invdx1*(-1.0/2.0*gammaDD12_i0_i1m1_i2 + (1.0/2.0)*gammaDD12_i0_i1p1_i2);
#     const double gammaDD_dD122 = invdx2*(-1.0/2.0*gammaDD12_i0_i1_i2m1 + (1.0/2.0)*gammaDD12_i0_i1_i2p1);
#     const double gammaDD_dD220 = invdx0*(-1.0/2.0*gammaDD22_i0m1_i1_i2 + (1.0/2.0)*gammaDD22_i0p1_i1_i2);
#     const double gammaDD_dD221 = invdx1*(-1.0/2.0*gammaDD22_i0_i1m1_i2 + (1.0/2.0)*gammaDD22_i0_i1p1_i2);
#     const double gammaDD_dD222 = invdx2*(-1.0/2.0*gammaDD22_i0_i1_i2m1 + (1.0/2.0)*gammaDD22_i0_i1_i2p1);
#     const double gammaDD_dDD0001 = tmpFD0*((1.0/4.0)*gammaDD00_i0m1_i1m1_i2 - 1.0/4.0*gammaDD00_i0m1_i1p1_i2 - 1.0/4.0*gammaDD00_i0p1_i1m1_i2 + (1.0/4.0)*gammaDD00_i0p1_i1p1_i2);
#     const double gammaDD_dDD0002 = tmpFD1*((1.0/4.0)*gammaDD00_i0m1_i1_i2m1 - 1.0/4.0*gammaDD00_i0m1_i1_i2p1 - 1.0/4.0*gammaDD00_i0p1_i1_i2m1 + (1.0/4.0)*gammaDD00_i0p1_i1_i2p1);
#     const double gammaDD_dDD0011 = tmpFD2*(gammaDD00_i0_i1m1_i2 + gammaDD00_i0_i1p1_i2 + tmpFD9);
#     const double gammaDD_dDD0012 = tmpFD4*((1.0/4.0)*gammaDD00_i0_i1m1_i2m1 - 1.0/4.0*gammaDD00_i0_i1m1_i2p1 - 1.0/4.0*gammaDD00_i0_i1p1_i2m1 + (1.0/4.0)*gammaDD00_i0_i1p1_i2p1);
#     const double gammaDD_dDD0022 = tmpFD5*(gammaDD00_i0_i1_i2m1 + gammaDD00_i0_i1_i2p1 + tmpFD9);
#     const double gammaDD_dDD0102 = tmpFD1*((1.0/4.0)*gammaDD01_i0m1_i1_i2m1 - 1.0/4.0*gammaDD01_i0m1_i1_i2p1 - 1.0/4.0*gammaDD01_i0p1_i1_i2m1 + (1.0/4.0)*gammaDD01_i0p1_i1_i2p1);
#     const double gammaDD_dDD0112 = tmpFD4*((1.0/4.0)*gammaDD01_i0_i1m1_i2m1 - 1.0/4.0*gammaDD01_i0_i1m1_i2p1 - 1.0/4.0*gammaDD01_i0_i1p1_i2m1 + (1.0/4.0)*gammaDD01_i0_i1p1_i2p1);
#     const double gammaDD_dDD0122 = tmpFD5*(-2*gammaDD01 + gammaDD01_i0_i1_i2m1 + gammaDD01_i0_i1_i2p1);
#     const double gammaDD_dDD0201 = tmpFD0*((1.0/4.0)*gammaDD02_i0m1_i1m1_i2 - 1.0/4.0*gammaDD02_i0m1_i1p1_i2 - 1.0/4.0*gammaDD02_i0p1_i1m1_i2 + (1.0/4.0)*gammaDD02_i0p1_i1p1_i2);
#     const double gammaDD_dDD0211 = tmpFD2*(-2*gammaDD02 + gammaDD02_i0_i1m1_i2 + gammaDD02_i0_i1p1_i2);
#     const double gammaDD_dDD0212 = tmpFD4*((1.0/4.0)*gammaDD02_i0_i1m1_i2m1 - 1.0/4.0*gammaDD02_i0_i1m1_i2p1 - 1.0/4.0*gammaDD02_i0_i1p1_i2m1 + (1.0/4.0)*gammaDD02_i0_i1p1_i2p1);
#     const double gammaDD_dDD1100 = tmpFD6*(gammaDD11_i0m1_i1_i2 + gammaDD11_i0p1_i1_i2 + tmpFD10);
#     const double gammaDD_dDD1101 = tmpFD0*((1.0/4.0)*gammaDD11_i0m1_i1m1_i2 - 1.0/4.0*gammaDD11_i0m1_i1p1_i2 - 1.0/4.0*gammaDD11_i0p1_i1m1_i2 + (1.0/4.0)*gammaDD11_i0p1_i1p1_i2);
#     const double gammaDD_dDD1102 = tmpFD1*((1.0/4.0)*gammaDD11_i0m1_i1_i2m1 - 1.0/4.0*gammaDD11_i0m1_i1_i2p1 - 1.0/4.0*gammaDD11_i0p1_i1_i2m1 + (1.0/4.0)*gammaDD11_i0p1_i1_i2p1);
#     const double gammaDD_dDD1112 = tmpFD4*((1.0/4.0)*gammaDD11_i0_i1m1_i2m1 - 1.0/4.0*gammaDD11_i0_i1m1_i2p1 - 1.0/4.0*gammaDD11_i0_i1p1_i2m1 + (1.0/4.0)*gammaDD11_i0_i1p1_i2p1);
#     const double gammaDD_dDD1122 = tmpFD5*(gammaDD11_i0_i1_i2m1 + gammaDD11_i0_i1_i2p1 + tmpFD10);
#     const double gammaDD_dDD1200 = tmpFD6*(-2*gammaDD12 + gammaDD12_i0m1_i1_i2 + gammaDD12_i0p1_i1_i2);
#     const double gammaDD_dDD1201 = tmpFD0*((1.0/4.0)*gammaDD12_i0m1_i1m1_i2 - 1.0/4.0*gammaDD12_i0m1_i1p1_i2 - 1.0/4.0*gammaDD12_i0p1_i1m1_i2 + (1.0/4.0)*gammaDD12_i0p1_i1p1_i2);
#     const double gammaDD_dDD1202 = tmpFD1*((1.0/4.0)*gammaDD12_i0m1_i1_i2m1 - 1.0/4.0*gammaDD12_i0m1_i1_i2p1 - 1.0/4.0*gammaDD12_i0p1_i1_i2m1 + (1.0/4.0)*gammaDD12_i0p1_i1_i2p1);
#     const double gammaDD_dDD2200 = tmpFD6*(gammaDD22_i0m1_i1_i2 + gammaDD22_i0p1_i1_i2 + tmpFD11);
#     const double gammaDD_dDD2201 = tmpFD0*((1.0/4.0)*gammaDD22_i0m1_i1m1_i2 - 1.0/4.0*gammaDD22_i0m1_i1p1_i2 - 1.0/4.0*gammaDD22_i0p1_i1m1_i2 + (1.0/4.0)*gammaDD22_i0p1_i1p1_i2);
#     const double gammaDD_dDD2202 = tmpFD1*((1.0/4.0)*gammaDD22_i0m1_i1_i2m1 - 1.0/4.0*gammaDD22_i0m1_i1_i2p1 - 1.0/4.0*gammaDD22_i0p1_i1_i2m1 + (1.0/4.0)*gammaDD22_i0p1_i1_i2p1);
#     const double gammaDD_dDD2211 = tmpFD2*(gammaDD22_i0_i1m1_i2 + gammaDD22_i0_i1p1_i2 + tmpFD11);
#     const double gammaDD_dDD2212 = tmpFD4*((1.0/4.0)*gammaDD22_i0_i1m1_i2m1 - 1.0/4.0*gammaDD22_i0_i1m1_i2p1 - 1.0/4.0*gammaDD22_i0_i1p1_i2m1 + (1.0/4.0)*gammaDD22_i0_i1p1_i2p1);
#     const double psi_dD0 = invdx0*(-1.0/2.0*psi_i0m1_i1_i2 + (1.0/2.0)*psi_i0p1_i1_i2);
#     const double psi_dD1 = invdx1*(-1.0/2.0*psi_i0_i1m1_i2 + (1.0/2.0)*psi_i0_i1p1_i2);
#     const double psi_dD2 = invdx2*(-1.0/2.0*psi_i0_i1_i2m1 + (1.0/2.0)*psi_i0_i1_i2p1);
#     /*
#      * Step 2 of 2: Evaluate SymPy expressions and write to main memory:
#      */
#     const double tmp0 = gammaDD00*gammaDD11;
#     const double tmp1 = gammaDD01*gammaDD12;
#     const double tmp2 = pow(gammaDD12, 2);
#     const double tmp3 = pow(gammaDD01, 2);
#     const double tmp4 = pow(gammaDD02, 2);
#     const double tmp5 = 1.0/(-gammaDD00*tmp2 + 2*gammaDD02*tmp1 - gammaDD11*tmp4 + gammaDD22*tmp0 - gammaDD22*tmp3);
#     const double tmp6 = -gammaDD01*gammaDD22 + gammaDD02*gammaDD12;
#     const double tmp7 = tmp5*tmp6;
#     const double tmp8 = (1.0/2.0)*tmp7;
#     const double tmp9 = -gammaDD00*gammaDD12 + gammaDD01*gammaDD02;
#     const double tmp10 = tmp5*tmp9;
#     const double tmp11 = (1.0/2.0)*gammaDD_dD220;
#     const double tmp12 = gammaDD00*gammaDD22 - tmp4;
#     const double tmp13 = tmp12*tmp5;
#     const double tmp14 = gammaDD_dD012 - gammaDD_dD021 + gammaDD_dD120;
#     const double tmp15 = (1.0/2.0)*tmp14;
#     const double tmp16 = gammaDD_dD002*tmp8 + tmp10*tmp11 + tmp13*tmp15;
#     const double tmp17 = gammaDD11*gammaDD22 - tmp2;
#     const double tmp18 = tmp17*tmp5;
#     const double tmp19 = (1.0/2.0)*tmp18;
#     const double tmp20 = -gammaDD_dD001 + 2*gammaDD_dD010;
#     const double tmp21 = -gammaDD_dD002 + 2*gammaDD_dD020;
#     const double tmp22 = -gammaDD02*gammaDD11 + tmp1;
#     const double tmp23 = tmp22*tmp5;
#     const double tmp24 = (1.0/2.0)*tmp23;
#     const double tmp25 = gammaDD_dD000*tmp19 + tmp20*tmp8 + tmp21*tmp24;
#     const double tmp26 = tmp0 - tmp3;
#     const double tmp27 = tmp26*tmp5;
#     const double tmp28 = gammaDD_dD002*tmp24 + tmp10*tmp15 + tmp11*tmp27;
#     const double tmp29 = (1.0/2.0)*tmp10;
#     const double tmp30 = (1.0/2.0)*tmp13;
#     const double tmp31 = gammaDD_dD000*tmp8 + tmp20*tmp30 + tmp21*tmp29;
#     const double tmp32 = gammaDD_dD002*tmp19 + gammaDD_dD220*tmp24 + tmp14*tmp8;
#     const double tmp33 = (1.0/2.0)*tmp27;
#     const double tmp34 = gammaDD_dD000*tmp24 + tmp20*tmp29 + tmp21*tmp33;
#     const double tmp35 = 2*gammaDD_dD122 - gammaDD_dD221;
#     const double tmp36 = 2*gammaDD_dD022 - gammaDD_dD220;
#     const double tmp37 = gammaDD_dD222*tmp24 + tmp19*tmp36 + tmp35*tmp8;
#     const double tmp38 = AD0*tmp37;
#     const double tmp39 = gammaDD_dD012 + gammaDD_dD021 - gammaDD_dD120;
#     const double tmp40 = gammaDD_dD112*tmp8 + gammaDD_dD221*tmp24 + tmp19*tmp39;
#     const double tmp41 = AD0*tmp40;
#     const double tmp42 = -gammaDD_dD012 + gammaDD_dD021 + gammaDD_dD120;
#     const double tmp43 = gammaDD_dD001*tmp19 + gammaDD_dD110*tmp8 + tmp24*tmp42;
#     const double tmp44 = AD0*tmp43;
#     const double tmp45 = AD0*tmp32;
#     const double tmp46 = AD1*tmp16;
#     const double tmp47 = (1.0/2.0)*gammaDD_dD222;
#     const double tmp48 = (1.0/2.0)*tmp35;
#     const double tmp49 = tmp10*tmp47 + tmp13*tmp48 + tmp36*tmp8;
#     const double tmp50 = AD1*tmp49;
#     const double tmp51 = AD1*tmp31;
#     const double tmp52 = gammaDD_dD112*tmp30 + gammaDD_dD221*tmp29 + tmp39*tmp8;
#     const double tmp53 = gammaDD_dD001*tmp8 + gammaDD_dD110*tmp30 + tmp29*tmp42;
#     const double tmp54 = AD2*tmp28;
#     const double tmp55 = AD2*tmp34;
#     const double tmp56 = tmp10*tmp48 + tmp24*tmp36 + tmp27*tmp47;
#     const double tmp57 = AD2*tmp56;
#     const double tmp58 = gammaDD_dD112*tmp29 + gammaDD_dD221*tmp33 + tmp24*tmp39;
#     const double tmp59 = AD2*tmp58;
#     const double tmp60 = gammaDD_dD001*tmp24 + gammaDD_dD110*tmp29 + tmp33*tmp42;
#     const double tmp61 = AD2*tmp60;
#     const double tmp62 = AD_dD00*tmp5;
#     const double tmp63 = AD0*gammaDD_dD000 + tmp17*tmp62;
#     const double tmp64 = gammaDD02*tmp28;
#     const double tmp65 = AD1*gammaDD_dD010 + AD_dD10*tmp7;
#     const double tmp66 = AD2*gammaDD_dD020 + AD_dD20*tmp23;
#     const double tmp67 = AD0*gammaDD_dD010 + tmp6*tmp62;
#     const double tmp68 = gammaDD12*tmp28;
#     const double tmp69 = AD1*gammaDD_dD110 + AD_dD10*tmp13;
#     const double tmp70 = AD2*gammaDD_dD120 + AD_dD20*tmp10;
#     const double tmp71 = AD0*gammaDD_dD020 + tmp22*tmp62;
#     const double tmp72 = gammaDD22*tmp28;
#     const double tmp73 = AD1*gammaDD_dD120 + AD_dD10*tmp10;
#     const double tmp74 = AD2*gammaDD_dD220 + AD_dD20*tmp27;
#     const double tmp75 = AD0*tmp25;
#     const double tmp76 = 2*tmp75;
#     const double tmp77 = AD2*tmp23;
#     const double tmp78 = AD2*tmp27;
#     const double tmp79 = AD2*tmp10;
#     const double tmp80 = AD2*pow(tmp28, 2) - AD_dD00*tmp32 - AD_dD22*tmp34 - gammaDD_dDD0002*tmp77 - gammaDD_dDD2200*tmp78 + tmp16*tmp44 + tmp16*tmp61 + tmp25*tmp46 + tmp25*tmp54 + tmp28*tmp45 + tmp28*tmp46 + tmp31*tmp41 + tmp31*tmp59 + tmp32*tmp51 + tmp32*tmp55 + tmp32*tmp76 + tmp34*tmp38 + tmp34*tmp50 + tmp34*tmp57 + tmp46*tmp53 + tmp51*tmp52 + tmp63*tmp64 + tmp64*tmp65 + tmp64*tmp66 + tmp67*tmp68 + tmp68*tmp69 + tmp68*tmp70 + tmp71*tmp72 + tmp72*tmp73 + tmp72*tmp74 - tmp79*(gammaDD_dDD0102 - gammaDD_dDD0201 + gammaDD_dDD1200);
#     const double tmp81 = -AD_dD10*tmp16 - AD_dD20*tmp25 - AD_dD20*tmp28 - AD_dD21*tmp31 + AD_dDD200 + tmp80;
#     const double tmp82 = -gammaDD_dD112 + 2*gammaDD_dD121;
#     const double tmp83 = 2*gammaDD_dD011 - gammaDD_dD110;
#     const double tmp84 = gammaDD_dD111*tmp8 + tmp19*tmp83 + tmp24*tmp82;
#     const double tmp85 = AD0*tmp84;
#     const double tmp86 = AD1*tmp53;
#     const double tmp87 = AD1*tmp52;
#     const double tmp88 = gammaDD_dD111*tmp30 + tmp29*tmp82 + tmp8*tmp83;
#     const double tmp89 = AD1*tmp88;
#     const double tmp90 = gammaDD_dD111*tmp29 + tmp24*tmp83 + tmp33*tmp82;
#     const double tmp91 = AD2*tmp90;
#     const double tmp92 = gammaDD02*tmp60;
#     const double tmp93 = gammaDD12*tmp60;
#     const double tmp94 = gammaDD22*tmp60;
#     const double tmp95 = AD1*pow(tmp53, 2) - AD_dD00*tmp43 - AD_dD11*tmp31 - gammaDD_dDD0001*tmp77 - gammaDD_dDD1100*tmp79 + tmp25*tmp61 + tmp25*tmp86 + tmp31*tmp85 + tmp31*tmp89 + tmp31*tmp91 + tmp34*tmp41 + tmp34*tmp87 + tmp43*tmp51 + tmp43*tmp55 + tmp43*tmp76 + tmp44*tmp53 + tmp45*tmp60 + tmp46*tmp60 + tmp53*tmp61 + tmp54*tmp60 + tmp55*tmp58 + tmp63*tmp92 + tmp65*tmp92 + tmp66*tmp92 + tmp67*tmp93 + tmp69*tmp93 + tmp70*tmp93 + tmp71*tmp94 + tmp73*tmp94 + tmp74*tmp94 - tmp78*(-gammaDD_dDD0102 + gammaDD_dDD0201 + gammaDD_dDD1200);
#     const double tmp96 = -AD_dD10*tmp25 - AD_dD10*tmp53 - AD_dD12*tmp34 - AD_dD20*tmp60 + AD_dDD100 + tmp95;
#     const double tmp97 = AD_dD02*tmp5;
#     const double tmp98 = AD0*gammaDD_dD002 + tmp17*tmp97;
#     const double tmp99 = AD_dD12*tmp5;
#     const double tmp100 = AD1*gammaDD_dD012 + tmp6*tmp99;
#     const double tmp101 = AD_dD22*tmp5;
#     const double tmp102 = AD2*gammaDD_dD022 + tmp101*tmp22;
#     const double tmp103 = AD0*gammaDD_dD012 + tmp6*tmp97;
#     const double tmp104 = AD1*gammaDD_dD112 + tmp12*tmp99;
#     const double tmp105 = AD2*gammaDD_dD122 + tmp101*tmp9;
#     const double tmp106 = AD0*gammaDD_dD022 + tmp22*tmp97;
#     const double tmp107 = AD1*gammaDD_dD122 + tmp9*tmp99;
#     const double tmp108 = AD2*gammaDD_dD222 + tmp101*tmp26;
#     const double tmp109 = 2*tmp57;
#     const double tmp110 = AD0*pow(tmp32, 2) - AD_dD00*tmp37 - AD_dD22*tmp28 - gammaDD_dDD0022*tmp77 - gammaDD_dDD2202*tmp78 + tmp100*tmp64 + tmp102*tmp64 + tmp103*tmp68 + tmp104*tmp68 + tmp105*tmp68 + tmp106*tmp72 + tmp107*tmp72 + tmp108*tmp72 + tmp109*tmp28 + tmp16*tmp41 + tmp16*tmp59 + tmp16*tmp87 + tmp25*tmp38 + tmp28*tmp38 + tmp28*tmp50 + tmp32*tmp46 + tmp32*tmp54 + tmp37*tmp51 + tmp37*tmp55 + tmp44*tmp49 + tmp45*tmp56 + tmp46*tmp56 + tmp49*tmp61 + tmp50*tmp53 + tmp64*tmp98 - tmp79*(gammaDD_dDD0122 - gammaDD_dDD0212 + gammaDD_dDD1202);
#     const double tmp111 = -AD_dD10*tmp49 - AD_dD20*tmp32 - AD_dD20*tmp56 - AD_dD21*tmp16 + AD_dDD202 + tmp110;
#     const double tmp112 = AD_dD01*tmp5;
#     const double tmp113 = AD0*gammaDD_dD001 + tmp112*tmp17;
#     const double tmp114 = AD_dD11*tmp5;
#     const double tmp115 = AD1*gammaDD_dD011 + tmp114*tmp6;
#     const double tmp116 = AD_dD21*tmp5;
#     const double tmp117 = AD2*gammaDD_dD021 + tmp116*tmp22;
#     const double tmp118 = AD0*gammaDD_dD011 + tmp112*tmp6;
#     const double tmp119 = AD1*gammaDD_dD111 + tmp114*tmp12;
#     const double tmp120 = AD2*gammaDD_dD121 + tmp116*tmp9;
#     const double tmp121 = AD0*gammaDD_dD021 + tmp112*tmp22;
#     const double tmp122 = AD1*gammaDD_dD121 + tmp114*tmp9;
#     const double tmp123 = AD2*gammaDD_dD221 + AD_dD21*tmp27;
#     const double tmp124 = 2*tmp89;
#     const double tmp125 = AD0*pow(tmp43, 2) - AD_dD00*tmp84 - AD_dD11*tmp53 - gammaDD_dDD0011*tmp77 - gammaDD_dDD1101*tmp79 + tmp113*tmp92 + tmp115*tmp92 + tmp117*tmp92 + tmp118*tmp93 + tmp119*tmp93 + tmp120*tmp93 + tmp121*tmp94 + tmp122*tmp94 + tmp123*tmp94 + tmp124*tmp53 + tmp25*tmp85 + tmp28*tmp91 + tmp41*tmp60 + tmp43*tmp61 + tmp43*tmp86 + tmp44*tmp88 + tmp45*tmp90 + tmp46*tmp90 + tmp51*tmp84 + tmp53*tmp85 + tmp53*tmp91 + tmp55*tmp84 + tmp59*tmp60 + tmp60*tmp87 + tmp61*tmp88 - tmp78*(-gammaDD_dDD0112 + gammaDD_dDD0211 + gammaDD_dDD1201);
#     const double tmp126 = -AD_dD10*tmp43 - AD_dD10*tmp88 - AD_dD12*tmp60 - AD_dD20*tmp90 + AD_dDD101 + tmp125;
#     const double tmp127 = -AD_dD01*tmp16 - AD_dD02*tmp25 - AD_dD02*tmp28 - AD_dD12*tmp31 + AD_dDD002 + tmp80;
#     const double tmp128 = -AD_dD01*tmp25 - AD_dD01*tmp53 - AD_dD02*tmp60 - AD_dD21*tmp34 + AD_dDD001 + tmp95;
#     const double tmp129 = -AD_dD01*tmp49 - AD_dD02*tmp32 - AD_dD02*tmp56 - AD_dD12*tmp16 + AD_dDD022 + tmp110;
#     const double tmp130 = -AD_dD01*tmp43 - AD_dD01*tmp88 - AD_dD02*tmp90 - AD_dD21*tmp60 + AD_dDD011 + tmp125;
#     const double tmp131 = tmp43*tmp45;
#     const double tmp132 = -AD_dD00*tmp40 - gammaDD_dDD0012*tmp77 + tmp131 + tmp40*tmp51 + tmp40*tmp55 + tmp40*tmp75 + tmp44*tmp52 + tmp45*tmp58 + tmp46*tmp58 + tmp52*tmp61;
#     const double tmp133 = -AD_dD10*tmp52 - AD_dD20*tmp58 + tmp132;
#     const double tmp134 = tmp28*tmp59;
#     const double tmp135 = -AD_dD22*tmp60 - gammaDD_dDD2201*tmp78 + tmp134 + tmp38*tmp60 + tmp41*tmp53 + tmp43*tmp46 + tmp43*tmp54 + tmp50*tmp60 + tmp53*tmp59 + tmp57*tmp60;
#     const double tmp136 = -AD_dD20*tmp43 - AD_dD21*tmp53 + AD_dDD201 + tmp135;
#     const double tmp137 = tmp53*tmp87;
#     const double tmp138 = tmp113*tmp64 + tmp115*tmp64 + tmp117*tmp64 + tmp118*tmp68 + tmp119*tmp68 + tmp120*tmp68 + tmp121*tmp72 + tmp122*tmp72 + tmp123*tmp72 + 2*tmp137 - tmp79*(gammaDD_dDD0112 - gammaDD_dDD0211 + gammaDD_dDD1201);
#     const double tmp139 = tmp133 + tmp136 + tmp138;
#     const double tmp140 = -AD_dD11*tmp16 - gammaDD_dDD1102*tmp79 + tmp137 + tmp16*tmp85 + tmp16*tmp89 + tmp16*tmp91 + tmp28*tmp41 + tmp28*tmp87 + tmp32*tmp61 + tmp32*tmp86;
#     const double tmp141 = -AD_dD10*tmp32 - AD_dD12*tmp28 + AD_dDD102 + tmp140;
#     const double tmp142 = tmp100*tmp92 + tmp102*tmp92 + tmp103*tmp93 + tmp104*tmp93 + tmp105*tmp93 + tmp106*tmp94 + tmp107*tmp94 + tmp108*tmp94 + 2*tmp134 - tmp78*(-gammaDD_dDD0122 + gammaDD_dDD0212 + gammaDD_dDD1202) + tmp92*tmp98;
#     const double tmp143 = tmp133 + tmp141 + tmp142;
#     const double tmp144 = -AD_dD01*tmp52 - AD_dD02*tmp58 + AD_dDD012 + tmp132;
#     const double tmp145 = -AD_dD02*tmp43 - AD_dD12*tmp53 + tmp135;
#     const double tmp146 = tmp138 + tmp144 + tmp145;
#     const double tmp147 = -AD_dD01*tmp32 - AD_dD21*tmp28 + tmp140;
#     const double tmp148 = tmp142 + tmp144 + tmp147;
#     const double tmp149 = gammaDD02*tmp58;
#     const double tmp150 = gammaDD12*tmp58;
#     const double tmp151 = gammaDD22*tmp58;
#     const double tmp152 = AD2*pow(tmp58, 2) - AD_dD11*tmp52 - AD_dD22*tmp90 - gammaDD_dDD1112*tmp79 - gammaDD_dDD2211*tmp78 + tmp113*tmp149 + tmp115*tmp149 + tmp117*tmp149 + tmp118*tmp150 + tmp119*tmp150 + tmp120*tmp150 + tmp121*tmp151 + tmp122*tmp151 + tmp123*tmp151 + tmp124*tmp52 + tmp32*tmp85 + tmp38*tmp90 + tmp40*tmp61 + tmp40*tmp86 + tmp41*tmp43 + tmp41*tmp58 + tmp41*tmp88 + tmp46*tmp84 + tmp50*tmp90 + tmp52*tmp85 + tmp52*tmp91 + tmp54*tmp84 + tmp57*tmp90 + tmp58*tmp87 + tmp59*tmp88 - tmp77*(gammaDD_dDD0112 + gammaDD_dDD0211 - gammaDD_dDD1201);
#     const double tmp153 = -AD_dD01*tmp40 - AD_dD20*tmp84 - AD_dD21*tmp58 - AD_dD21*tmp88 + AD_dDD211 + tmp152;
#     const double tmp154 = AD1*pow(tmp52, 2) - AD_dD11*tmp49 - AD_dD22*tmp58 - gammaDD_dDD1122*tmp79 - gammaDD_dDD2212*tmp78 + tmp100*tmp149 + tmp102*tmp149 + tmp103*tmp150 + tmp104*tmp150 + tmp105*tmp150 + tmp106*tmp151 + tmp107*tmp151 + tmp108*tmp151 + tmp109*tmp58 + tmp149*tmp98 + tmp32*tmp41 + tmp37*tmp61 + tmp37*tmp86 + tmp38*tmp43 + tmp38*tmp58 + tmp40*tmp46 + tmp40*tmp54 + tmp41*tmp52 + tmp41*tmp56 + tmp49*tmp85 + tmp49*tmp91 + tmp50*tmp58 + tmp50*tmp88 + tmp52*tmp59 + tmp56*tmp87 - tmp77*(gammaDD_dDD0122 + gammaDD_dDD0212 - gammaDD_dDD1202);
#     const double tmp155 = -AD_dD01*tmp37 - AD_dD20*tmp40 - AD_dD21*tmp52 - AD_dD21*tmp56 + AD_dDD212 + tmp154;
#     const double tmp156 = -AD_dD02*tmp84 - AD_dD10*tmp40 - AD_dD12*tmp58 - AD_dD12*tmp88 + AD_dDD112 + tmp152;
#     const double tmp157 = -AD_dD02*tmp40 - AD_dD10*tmp37 - AD_dD12*tmp52 - AD_dD12*tmp56 + AD_dDD122 + tmp154;
#     const double tmp158 = 2*tmp131 + tmp149*tmp63 + tmp149*tmp65 + tmp149*tmp66 + tmp150*tmp67 + tmp150*tmp69 + tmp150*tmp70 + tmp151*tmp71 + tmp151*tmp73 + tmp151*tmp74 - tmp77*(gammaDD_dDD0102 + gammaDD_dDD0201 - gammaDD_dDD1200);
#     const double tmp159 = tmp136 + tmp147 + tmp158;
#     const double tmp160 = tmp141 + tmp145 + tmp158;
#     const double tmp161 = -tmp41 - tmp59 - tmp87;
#     const double tmp162 = -tmp45 - tmp46 - tmp54;
#     const double tmp163 = -tmp44 - tmp61 - tmp86;
#     AIrhsD0GF[CCTK_GFINDEX3D(cctkGH, i0, i1, i2)] = -ED0 - psi_dD0;
#     AIrhsD1GF[CCTK_GFINDEX3D(cctkGH, i0, i1, i2)] = -ED1 - psi_dD1;
#     AIrhsD2GF[CCTK_GFINDEX3D(cctkGH, i0, i1, i2)] = -ED2 - psi_dD2;
#     EIrhsD0GF[CCTK_GFINDEX3D(cctkGH, i0, i1, i2)] = tmp10*tmp139 + tmp10*tmp143 - tmp10*tmp146 - tmp10*tmp148 + tmp111*tmp27 + tmp126*tmp13 - tmp127*tmp23 - tmp128*tmp7 - tmp129*tmp27 - tmp13*tmp130 + tmp23*tmp81 + tmp7*tmp96;
#     EIrhsD1GF[CCTK_GFINDEX3D(cctkGH, i0, i1, i2)] = tmp10*tmp153 - tmp10*tmp156 - tmp126*tmp7 + tmp128*tmp18 + tmp130*tmp7 - tmp143*tmp23 + tmp148*tmp23 + tmp155*tmp27 - tmp157*tmp27 + tmp159*tmp23 - tmp160*tmp23 - tmp18*tmp96;
#     EIrhsD2GF[CCTK_GFINDEX3D(cctkGH, i0, i1, i2)] = -tmp10*tmp155 + tmp10*tmp157 - tmp111*tmp23 + tmp127*tmp18 + tmp129*tmp23 - tmp13*tmp153 + tmp13*tmp156 - tmp139*tmp7 + tmp146*tmp7 - tmp159*tmp7 + tmp160*tmp7 - tmp18*tmp81;
#     psiIrhsGF[CCTK_GFINDEX3D(cctkGH, i0, i1, i2)] = -tmp10*(AD_dD12 + tmp161) - tmp10*(AD_dD21 + tmp161) - tmp13*(AD_dD11 - tmp85 - tmp89 - tmp91) - tmp18*(AD_dD00 - tmp51 - tmp55 - tmp75) - tmp23*(AD_dD02 + tmp162) - tmp23*(AD_dD20 + tmp162) - tmp27*(AD_dD22 - tmp38 - tmp50 - tmp57) - tmp7*(AD_dD01 + tmp163) - tmp7*(AD_dD10 + tmp163);
# }

# %% [markdown]
# ### Step 2: Interfacing with the Einstein Toolkit
#
# #### Step 2a: Constructing the Einstein Toolkit C-code calling functions that include the C code kernels.
#
# Now that we have generated the C code kernel *ScalarWave_RHSs.h* and the parameters file *NRPy_params.h*, we will need to write C code to make use of these files. To do this, we can simply follow the example within the [IDScalarWaveNRPy tutorial module](Tutorial-ETK_thorn-IDScalarWaveNRPy.ipynb). Functions defined by these files will be called by the Einstein Toolkit scheduler (specified in schedule.ccl below).

# %%
# %%writefile MaxwellEvol/src/MaxwellEvol.c
# #include <math.h>
# #include <stdio.h>
#
# #include "cctk.h"
# #include "cctk_Arguments.h"
# #include "cctk_Parameters.h"
# #include "Symmetry.h"
#
# #include "NRPy_params.h"
#
# void MaxwellEvol_calc_constraint_violation(CCTK_ARGUMENTS) {
#   DECLARE_CCTK_ARGUMENTS;
#   DECLARE_CCTK_PARAMETERS;
#
#   const CCTK_REAL invdx0 = 1.0 / (CCTK_DELTA_SPACE(0));
#   const CCTK_REAL invdx1 = 1.0 / (CCTK_DELTA_SPACE(1));
#   const CCTK_REAL invdx2 = 1.0 / (CCTK_DELTA_SPACE(2));
#   const CCTK_REAL *gammaDD00GF = gxx;
#   const CCTK_REAL *gammaDD01GF = gxy;
#   const CCTK_REAL *gammaDD02GF = gxz;
#   const CCTK_REAL *gammaDD11GF = gyy;
#   const CCTK_REAL *gammaDD12GF = gyz;
#   const CCTK_REAL *gammaDD22GF = gzz;
#
#     #include "Constraint_violation.h"
# }
#
# void MaxwellEvol_set_rhs(CCTK_ARGUMENTS) {
#   DECLARE_CCTK_ARGUMENTS;
#   DECLARE_CCTK_PARAMETERS;
#
#   const CCTK_REAL invdx0 = 1.0 / (CCTK_DELTA_SPACE(0));
#   const CCTK_REAL invdx1 = 1.0 / (CCTK_DELTA_SPACE(1));
#   const CCTK_REAL invdx2 = 1.0 / (CCTK_DELTA_SPACE(2));
#   const CCTK_REAL *gammaDD00GF = gxx;
#   const CCTK_REAL *gammaDD01GF = gxy;
#   const CCTK_REAL *gammaDD02GF = gxz;
#   const CCTK_REAL *gammaDD11GF = gyy;
#   const CCTK_REAL *gammaDD12GF = gyz;
#   const CCTK_REAL *gammaDD22GF = gzz;
#
# #include "Maxwell_Evol.h"
# }
#
# /* Boundary Condition code adapted from WaveToyC thorn in ETK, implementing built-in
#  * ETK BC functionality
#  */
# void MaxwellEvol_SelectBCs(CCTK_ARGUMENTS)
# {
#   DECLARE_CCTK_ARGUMENTS;
#   DECLARE_CCTK_PARAMETERS;
#
#   const char *bctype;
#
#
#   bctype = NULL;
#   if (CCTK_EQUALS(bound,"flat") || CCTK_EQUALS(bound,"static") ||
#       CCTK_EQUALS(bound,"radiation") || CCTK_EQUALS(bound,"robin") ||
#       CCTK_EQUALS(bound,"none"))
#   {
#     bctype = bound;
#   }
#   else if (CCTK_EQUALS(bound,"zero"))
#   {
#     bctype = "scalar";
#   }
#
#   /* Uses all default arguments, so invalid table handle -1 can be passed */
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::AID0GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::AID1GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::AID2GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::EID0GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::EID1GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::EID2GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::psiIGF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::AIID0GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::AIID1GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::AIID2GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::EIID0GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::EIID1GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::EIID2GF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::psiIIGF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
#   if (bctype && Boundary_SelectVarForBC (cctkGH, CCTK_ALL_FACES, 1, -1,
#                                          "MaxwellEvol::GammaGF", bctype) < 0)
#   {
#     CCTK_WARN (0, "MaxwellEvol_Boundaries: Error selecting boundary condition");
#   }
# }
#
# void MaxwellEvol_InitSymBound(CCTK_ARGUMENTS)
# {
#   DECLARE_CCTK_ARGUMENTS;
#
#   int sym[3];
#
#   sym[0] = 1;
#   sym[1] = 1;
#   sym[2] = 1;
#
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::AID0GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::AID1GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::AID2GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::EID0GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::EID1GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::EID2GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::psiIGF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::CviolaIGF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::AIID0GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::AIID1GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::AIID2GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::EIID0GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::EIID1GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::EIID2GF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::psiIIGF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::GammaGF");
#   SetCartSymVN(cctkGH, sym,"MaxwellEvol::CviolaIIGF");
#
#   return;
# }
#
# void MaxwellEvol_RegisterVars(CCTK_ARGUMENTS)
# {
#   DECLARE_CCTK_ARGUMENTS;
#   DECLARE_CCTK_PARAMETERS;
#
#   CCTK_INT ierr CCTK_ATTRIBUTE_UNUSED = 0;
#   /* Register all the evolved grid functions with MoL */
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::AID0GF"),  CCTK_VarIndex("MaxwellEvol::AIrhsD0GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::AID1GF"),  CCTK_VarIndex("MaxwellEvol::AIrhsD1GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::AID2GF"),  CCTK_VarIndex("MaxwellEvol::AIrhsD2GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::EID0GF"),  CCTK_VarIndex("MaxwellEvol::EIrhsD0GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::EID1GF"),  CCTK_VarIndex("MaxwellEvol::EIrhsD1GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::EID2GF"),  CCTK_VarIndex("MaxwellEvol::EIrhsD2GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::psiIGF"),  CCTK_VarIndex("MaxwellEvol::psiIrhsGF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::AIID0GF"),  CCTK_VarIndex("MaxwellEvol::AIIrhsD0GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::AIID1GF"),  CCTK_VarIndex("MaxwellEvol::AIIrhsD1GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::AIID2GF"),  CCTK_VarIndex("MaxwellEvol::AIIrhsD2GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::EIID0GF"),  CCTK_VarIndex("MaxwellEvol::EIIrhsD0GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::EIID1GF"),  CCTK_VarIndex("MaxwellEvol::EIIrhsD1GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::EIID2GF"),  CCTK_VarIndex("MaxwellEvol::EIIrhsD2GF"));
#   ierr += MoLRegisterEvolved(CCTK_VarIndex("MaxwellEvol::psiIIGF"),  CCTK_VarIndex("MaxwellEvol::psiIIrhsGF"));
#   /* Register all the evolved Array functions with MoL */
#   return;
# }
# Out:
# Overwriting MaxwellEvol/src/MaxwellEvol.c

# %% [markdown]
# #### Step 2b: CCL files - Define how this module interacts and interfaces with the larger Einstein Toolkit infrastructure
#
# Writing a module ("thorn") within the Einstein Toolkit requires that three "ccl" files be constructed, all in the root directory of the thorn:
#
# 1. $\text{interface.ccl}$: defines the gridfunction groups needed, and provides keywords denoting what this thorn provides and what it should inherit from other thorns. This file governs the interaction between this thorn and others; more information can be found in the [official Einstein Toolkit documentation](http://cactuscode.org/documentation/referencemanual/ReferenceManualch8.html#x12-260000C2.2).
# With "implements", we give our thorn its unique name. By "inheriting" other thorns, we tell the Toolkit that we will rely on variables that exist within those functions. Then, we tell the toolkit that we want the gridfunctions $A_i$, $E_i$, $\psi$, and $\Gamma$ to be visible to other thorns by using the keyword "public".

# %%
# %%writefile MaxwellEvol/interface.ccl
# implements: MaxwellEvol
#
# inherits: admbase Boundary grid
#
# USES INCLUDE: loopcontrol.h
# USES INCLUDE: Symmetry.h
# USES INCLUDE: Boundary.h
#
# CCTK_INT FUNCTION MoLRegisterEvolved(CCTK_INT IN EvolvedIndex, CCTK_INT IN RHSIndex)
# USES FUNCTION MoLRegisterEvolved
#
# CCTK_INT FUNCTION GetBoundarySpecification(CCTK_INT IN size, CCTK_INT OUT ARRAY nboundaryzones, CCTK_INT OUT ARRAY is_internal, CCTK_INT OUT ARRAY is_staggered, CCTK_INT OUT ARRAY shiftout)
# USES FUNCTION GetBoundarySpecification
#
# CCTK_INT FUNCTION SymmetryTableHandleForGrid(CCTK_POINTER_TO_CONST IN cctkGH)
# USES FUNCTION SymmetryTableHandleForGrid
#
# CCTK_INT FUNCTION Boundary_SelectGroupForBC(CCTK_POINTER_TO_CONST IN GH, CCTK_INT IN faces, CCTK_INT IN boundary_width, CCTK_INT IN table_handle, CCTK_STRING IN group_name, CCTK_STRING IN bc_name)
# USES FUNCTION Boundary_SelectGroupForBC
#
# CCTK_INT FUNCTION Boundary_SelectVarForBC(CCTK_POINTER_TO_CONST IN GH, CCTK_INT IN faces, CCTK_INT IN boundary_width, CCTK_INT IN table_handle, CCTK_STRING IN var_name, CCTK_STRING IN bc_name)
# USES FUNCTION Boundary_SelectVarForBC
#
# public:
# cctk_real system_I_rhs type = GF Timelevels=3 tags='tensortypealias="Scalar"'
# {
#   AIrhsD0GF,AIrhsD1GF,AIrhsD2GF,EIrhsD0GF,EIrhsD1GF,EIrhsD2GF,psiIrhsGF
# } "The evolved scalar fields"
#
# public:
# cctk_real system_II_rhs type = GF Timelevels=3 tags='tensortypealias="Scalar"'
# {
#   AIIrhsD0GF,AIIrhsD1GF,AIIrhsD2GF,EIIrhsD0GF,EIIrhsD1GF,EIIrhsD2GF,psiIIrhsGF,GammarhsGF
# } "The evolved scalar fields"
#
# public:
# cctk_real system_I type = GF Timelevels=3 tags='tensortypealias="Scalar"'
# {
#   AID0GF,AID1GF,AID2GF,EID0GF,EID1GF,EID2GF,psiIGF
# } "The evolved scalar fields"
#
# public:
# cctk_real system_II type = GF Timelevels=3 tags='tensortypealias="Scalar"'
# {
#   AIID0GF,AIID1GF,AIID2GF,EIID0GF,EIID1GF,EIID2GF,psiIIGF,GammaGF
# } "The evolved scalar fields"
#
# public:
# cctk_real system_I_constraint_violation type = GF Timelevels=3 tags='tensortypealias="Scalar"'
# {
#   CviolaIGF
# } "The constraint violation for system I"
#
# public:
# cctk_real system_II_constraint_violation type = GF Timelevels=3 tags='tensortypealias="Scalar"'
# {
#   CviolaIIGF
# } "The constraint violation for system II"
# Out:
# Overwriting MaxwellEvol/interface.ccl

# %% [markdown]
# 2. $\text{param.ccl}$: specifies free parameters within the thorn, enabling them to be set at runtime. It is required to provide allowed ranges and default values for each parameter. More information on this file's syntax can be found in the [official Einstein Toolkit documentation](http://cactuscode.org/documentation/referencemanual/ReferenceManualch8.html#x12-265000C2.3). A number of parameters are defined, and more parameters can be easily added in later versions. We also set the number of timelevels we will store in memory.

# %%
# %%writefile MaxwellEvol/param.ccl
# shares: MethodOfLines
#
# USES CCTK_INT MoL_Num_Evolved_Vars
# USES CCTK_INT MoL_Num_ArrayEvolved_Vars
#
# restricted:
# CCTK_INT MaxwellEvol_MaxNumEvolvedVars "Number of evolved variables used by this thorn" ACCUMULATOR-BASE=MethodofLines::MoL_Num_Evolved_Vars STEERABLE=RECOVER
# {
#   15:15 :: "Number of evolved variables used by this thorn"
# } 15
#
# restricted:
# CCTK_INT SimpleWave_MaxNumArrayEvolvedVars "Number of Array evolved variables used by this thorn" ACCUMULATOR-BASE=MethodofLines::MoL_Num_ArrayEvolved_Vars STEERABLE=RECOVER
# {
#   0:0 :: "Number of Array evolved variables used by this thorn"
# } 0
#
# restricted:
# KEYWORD bound "Type of boundary condition to use"
# {
#   "flat"      :: "Flat (von Neumann, n grad phi = 0) boundary condition"
#   "static"    :: "Static (Dirichlet, dphi/dt=0) boundary condition"
#   "radiation" :: "Radiation boundary condition"
#   "robin"     :: "Robin (phi(r) = C/r) boundary condition"
#   "zero"      :: "Zero (Dirichlet, phi=0) boundary condition"
#   "none"      :: "Apply no boundary condition"
# } "static"
#
# restricted:
# CCTK_INT timelevels "Number of active timelevels" STEERABLE=RECOVER
# {
#   0:3 :: ""
# } 3
#
# restricted:
# CCTK_REAL amp "The amplitude of the wavepacket"
# {
#  *:* :: "The amplitude of the wavepacket"
# } 1.0
#
# restricted:
# CCTK_REAL lam "The size lambda of the wavepacket"
# {
#  *:* :: "The size lambda of the wavepacket"
# } 1.0
# Out:
# Overwriting MaxwellEvol/param.ccl

# %% [markdown]
# 3. $\text{schedule.ccl}$: allocates storage for gridfunctions, defines how the thorn's functions should be scheduled in a broader simulation, and specifies the regions of memory written to or read from gridfunctions. $\text{schedule.ccl}$'s official documentation may be found [here](http://cactuscode.org/documentation/referencemanual/ReferenceManualch8.html#x12-268000C2.4).
#
# We first assign storage for both scalar gridfunctions, and then specify the standardized ETK "scheduling bins" in which we want each of our thorn's functions to run.

# %%
# %%writefile MaxwellEvol/schedule.ccl
# STORAGE: system_I_rhs[timelevels]
# STORAGE: system_I[timelevels]
# STORAGE: system_II_rhs[timelevels]
# STORAGE: system_II[timelevels]
# STORAGE: system_I_constraint_violation[timelevels]
# STORAGE: system_II_constraint_violation[timelevels]
#
# schedule MaxwellEvol_InitSymBound at BASEGRID
# {
#   LANG: C
#   OPTIONS: global
# } "Schedule symmetries"
#
# schedule MaxwellEvol_calc_constraint_violation IN CCTK_ANALYSIS
# {
#   LANG: C
#   READS: admbase::gxx(Everywhere)
#   READS: admbase::gxy(Everywhere)
#   READS: admbase::gxz(Everywhere)
#   READS: admbase::gyy(Everywhere)
#   READS: admbase::gyz(Everywhere)
#   READS: admbase::gzz(Everywhere)
#   READS: EID0GF(Everywhere)
#   READS: EID1GF(Everywhere)
#   READS: EID2GF(Everywhere)
#   READS: EIID0GF(Everywhere)
#   READS: EIID1GF(Everywhere)
#   READS: EIID2GF(Everywhere)
#   WRITES: CviolaIGF(Interior)
#   WRITES: CviolaIIGF(Interior)
# }"Calculate the contraint violation of the simulation"
#
# schedule MaxwellEvol_set_rhs as WaveToy_Evolution IN MoL_CalcRHS
# {
#   LANG: C
#   READS: admbase::gxx(Everywhere)
#   READS: admbase::gxy(Everywhere)
#   READS: admbase::gxz(Everywhere)
#   READS: admbase::gyy(Everywhere)
#   READS: admbase::gyz(Everywhere)
#   READS: admbase::gzz(Everywhere)
#   READS: AID0GF(Everywhere)
#   READS: AID1GF(Everywhere)
#   READS: AID2GF(Everywhere)
#   READS: EID0GF(Everywhere)
#   READS: EID1GF(Everywhere)
#   READS: EID2GF(Everywhere)
#   READS: psiIGF(Everywhere)
#   READS: AIID0GF(Everywhere)
#   READS: AIID1GF(Everywhere)
#   READS: AIID2GF(Everywhere)
#   READS: EIID0GF(Everywhere)
#   READS: EIID1GF(Everywhere)
#   READS: EIID2GF(Everywhere)
#   READS: psiIIGF(Everywhere)
#   READS: GammaGF(Everywhere)
#   WRITES: AIrhsD0GF(Interior)
#   WRITES: AIrhsD1GF(Interior)
#   WRITES: AIrhsD2GF(Interior)
#   WRITES: EIrhsD0GF(Interior)
#   WRITES: EIrhsD1GF(Interior)
#   WRITES: EIrhsD2GF(Interior)
#   WRITES: psiIrhsGF(Interior)
#   WRITES: AIIrhsD0GF(Interior)
#   WRITES: AIIrhsD1GF(Interior)
#   WRITES: AIIrhsD2GF(Interior)
#   WRITES: EIIrhsD0GF(Interior)
#   WRITES: EIIrhsD1GF(Interior)
#   WRITES: EIIrhsD2GF(Interior)
#   WRITES: psiIIrhsGF(Interior)
#   WRITES: GammarhsGF(Interior)
# } "Evolution of Maxwell's equations"
#
# schedule MaxwellEvol_SelectBCs in MoL_PostStep
# {
#   LANG: C
#   OPTIONS: level
#   SYNC: system_I
#   SYNC: system_II
# } "Boundaries of Maxwell's equations"
#
# schedule GROUP ApplyBCs as MaxwellEvol_ApplyBCs in MoL_PostStep after MaxwellEvol_SelectBCs
# {
# } "Apply boundary conditions"
#
#
# schedule GROUP ApplyBCs as MaxwellEvol_ApplyBCs at POSTRESTRICT
# {
# } "Apply boundary conditions"
#
# schedule MaxwellEvol_RegisterVars in MoL_Register
# {
#   LANG: C
#   OPTIONS: meta
# } "Register Variables for MoL"
# Out:
# Overwriting MaxwellEvol/schedule.ccl

# %% [markdown]
# #### Step 2c: Add the C file to Einstein Toolkit compilation list.
#
# We will also need $\text{make.code.defn}$, which indicates the list of files that need to be compiled. This thorn only has the one C file to compile.

# %%
# %%writefile MaxwellEvol/src/make.code.defn
# SRCS = MaxwellEvol.c
# Out:
# Overwriting MaxwellEvol/src/make.code.defn

# %% [markdown]
# ### Code Validation
# (To be performed)
