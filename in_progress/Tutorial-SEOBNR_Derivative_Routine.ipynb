# %% [markdown]
# # Symbolic Partial Derivative Routine
#
# ## Authors: Zach Etienne & Tyler Knowles
#
# ## This module contains a routine for computing partial derivatives of a mathematical expression that is written as several subexpressions.
#
# **Notebook Status:** <font color='red'><b> In progress </b></font>
#
# **TODO:**
# 1. Edit location of NRPy+ tutorial
# 1. Edit location of v3 Hamiltonian notebook (in introduction)
# 1. Include validation cell
#
# **Validation Notes:** This tutorial notebook has been confirmed to be self-consistent with its corresponding NRPy+ module, as documented [below](#code_validation). Additionally, this notebook has been validated by checking that results are consistent with exact derivative expressions in [LALSuite](https://git.ligo.org/lscsoft/lalsuite).
#
# ### NRPy+ Source Code for this module: [SEOBNR_Derivative_Routine.py](../../edit/in_progress/SEOBNR/SEOBNR_Derivative_Routine.py)
#
# ## Introduction
# $$\label{intro}$$
#
# This notebook documents the symbolic partial derivative routine used to generate analytic derivatives of the [SEOBNRv3](https://git.ligo.org/lscsoft/lalsuite) Hamiltonian (documented [here](../Tutorial-SEOBNR_v3_Hamiltonian.ipynb)) and described in [this article](https://arxiv.org/abs/1803.06346).  In general, this notebook takes as input a file of inter-dependent mathematical expressions (in SymPy syntax), a file listing the names of values within those expressions, and a file listing all variables with which to take partial derivatives of each expression.  The output is a text file containing the original expression and those for each partial derivative computation.  The intention is to perform CSE on these expressions to create efficient partial derivative code!

# %% [markdown]
# <a id='toc'></a>
#
# # Table of Contents
# $$\label{toc}$$
#
# This notebook is organized as follows
#
# 1. [Step 1](#initializenrpy): Initialize core Python/NRPy+ modules
# 1. [Step 2:](#step2) Read in expressions
# 1. [Step 3:](#step3) Read in constants and variables
# 1. [Step 4:](#step4) List free symbols
# 1. [Step 5:](#step5) Convert expressions to function notation
# 1. [Step 6:](#step6) Differentiate with respect to xx
# 1. [Step 7:](#step7) Simplify derivative expressions
# 1. [Step 8:](#step8) Differentiate with respect to a specific free variable
# 1. [Step 9:](#step9) Output result
# 1. [Step 10:](#code_validation) Code Validation against `SEOBNR_Derivative_Routine` NRPy+ module
# 1. [Step 11:](#latex_pdf_output) Output this notebook to $\LaTeX$-formatted PDF file

# %% [markdown]
# <a id='initializenrpy'></a>
#
# # Step 1: Initialize core Python/NRPy+ modules \[Back to [top](#toc)\]
# $$\label{initializenrpy}$$
#
# Let's start by importing all the needed modules from Python/NRPy+:

# %%
# Step 1.a: import all needed modules from Python/NRPy+:
import sympy as sp                # SymPy: The Python computer algebra package upon which NRPy+ depends
import os, sys                    # Standard Python modules for multiplatform OS-level functions

# Step 1.?: check system path so can use outputC; #TylerK: remove and put outputC back with other imports
nrpy_dir_path = os.path.join("..")
if nrpy_dir_path not in sys.path:
    sys.path.append(nrpy_dir_path)

from outputC import superfast_uniq, lhrh      # Remove duplicate entries from a Python array; store left- and right-
                                              #   hand sides of mathematical expressions

# %% [markdown]
# <a id='step2'></a>
#
# # Step 2: Read in expressions \[Back to [top](#toc)\]
# $$\label{step2}$$
#
# We read in the expressions of which we will compute partial derivatives in a single large string before splitting the string by line (carriage return) and by "=".  Doing so allows us to manipulate the right- and left-hand sides of the expressions appropriately.  We store the left- and right-hand sides in the array $\texttt{lr}$, which consists of $\texttt{lhrh}$ arrays with left-hand sides $\texttt{lhs}$ and right-hand sides $\texttt{rhs}$.  Note that $\texttt{Lambda}$ is a protected keyword in Python, so the variable $\Lambda$ in the Hamiltonian is renamed $\texttt{Lamb}$.

# %%
# Step 2.a: Read in expressions as a (single) string
with open('SEOBNR/Hamstring.txt', 'r') as file:
    expressions_as_lines = file.readlines()

# Step 2.b: Create and populate the "lr" array, which separates each line into left- and right-hand sides
#   Each entry is a string of the form lhrh(lhs='',rhs='')
lr = []

for i in range(len(expressions_as_lines)):
    # Ignore lines with 2 or fewer characters and those starting with #
    if len(expressions_as_lines[i]) > 2 and expressions_as_lines[i][0] != "#":
        # Split each line by its equals sign
        split_line = expressions_as_lines[i].split("=")
        # Append the line to "lr", removing spaces, "sp." prefixes, and replacing Lambda->Lamb
        #   (Lambda is a protected keyword):
        lr.append(lhrh(lhs=split_line[0].replace(" ","").replace("Lambda","Lamb"),
                       rhs=split_line[1].replace(" ","").replace("sp.","").replace("Lambda","Lamb")))

# Step 2.c: Separate and sympify right- and left-hand sides into separate arrays
lhss = []
rhss = []
for i in range(len(lr)):
    lhss.append(sp.sympify(lr[i].lhs))
    rhss.append(sp.sympify(lr[i].rhs))

# %% [markdown]
# <a id='step3'></a>
#
# # Step 3: Read in constants and variables \[Back to [top](#toc)\]
# $$\label{step3}$$
#
# We read in and declare as SymPy symbols the constant values; derivatives with respect to these variables will be set to zero.  We then read in the variables with respect to which we want to take derivatives and declare those as SymPy variables as well.

# %%
# Step 3.a: Read in constants as a (single) string
with open('SEOBNR/Hamstring_constants.txt', 'r') as file:
    constants_as_lines = file.readlines()

# Step 3.b: Create "input_constants" array and populate with SymPy constants
input_constants = []
for constant in constants_as_lines:
    constant = sp.symbols(constant,real=True)
    input_constants.append(constant)

# Step 3.c: Read in variables with which to take derivatives
with open('SEOBNR/Hamstring_variables.txt', 'r') as file:
    variables_as_lines = file.readlines()

#Step 3.d: Create "dynamic_variables" array and populate with SymPy symbols
dynamic_variables = []
for variable in variables_as_lines:
    variable = sp.symbols(variable,real=True)
    dynamic_variables.append(variable)

# %% [markdown]
# <a id='step4'></a>
#
# # Step 4: List free symbols \[Back to [top](#toc)\]
# $$\label{step4}$$
#
# By ''free symbols'' we mean the variables in the right-hand sides.  We first create a list of all such terms (using SymPy's built-in free_symbol attribute), including duplicates, and then strip the duplicates.  We then remove input constants from the symbol list.

# %%
# Step 4.a: Prepare array of "free symbols" in the right-hand side expressions
full_symbol_list_with_dups = []
for i in range(len(lr)):
    for variable in rhss[i].free_symbols:
        full_symbol_list_with_dups.append(variable)

# Step 4.b: Remove duplicate free symbols
full_symbol_list = superfast_uniq(full_symbol_list_with_dups)

# Step 4.c: Remove input constants from symbol list
for inputconst in input_constants:
    for symbol in full_symbol_list:
        if str(symbol) == str(inputconst):
            full_symbol_list.remove(symbol)

# %% [markdown]
# <a id='step5'></a>
#
# # Step 5: Convert expressions to function notation \[Back to [top](#toc)\]
# $$\label{step5}$$
#
# In order to compute the partial derivative of each right-hand side, we mark each variable (left-hand side) and each free symbol (in right-hand sides) as a function with argument $\texttt{xx}$.

# %%
# Step 5.a: Convert each left-hand side to function notation
#   while separating and simplifying left- and right-hand sides
xx = sp.Symbol('xx',real=True)
func = []
for i in range(len(lr)):
    func.append(sp.sympify(sp.Function(lr[i].lhs)(xx)))

# Step 5.b: Mark each free variable as a function with argument xx
full_function_list = []
for symb in full_symbol_list:
    func = sp.sympify(sp.Function(str(symb))(xx))
    full_function_list.append(func)
    for i in range(len(rhss)):
        for var in rhss[i].free_symbols:
            if str(var) == str(symb):
                rhss[i] = rhss[i].subs(var,func)

# %% [markdown]
# <a id='step6'></a>
#
# # Step 6: Differentiate with respect to xx \[Back to [top](#toc)\]
# $$\label{step6}$$
#
# Now we differentiate the right-hand expressions with respect to $\textrm{xx}$.  We use the SymPy $\texttt{diff}$ command, differentiating with respect to $\texttt{xx}$.  After so doing, we remove $\texttt{(xx)}$ and "Derivative" (which is output by $\texttt{diff}$), and use "prm" suffix to denote the derivative with respect to $\texttt{xx}$.

# %%
print(lhss[130],rhss[130])
# Zach says: Notice that the tortoise constant is being converted into a function:
print(str(sp.diff(rhss[130],xx)).replace("(xx)","").replace(", xx","prm").replace("Derivative",""))
# Out:
# csi2 (1/2 - 0.5*sign(1.5 - tortoise(xx)))*(csi(xx) - 1) + 1
# (1/2 - 0.5*sign(1.5 - tortoise))*(csiprm) - 0.5*(csi - 1)*(sign(1.5 - tortoise)prm)

# %%
# Step 6: Use SymPy's diff function to differentiate right-hand sides with respect to xx
#   and append "prm" notation to left-hand sides
lhss_deriv = []
rhss_deriv = []
for i in range(len(rhss)):
    lhss_deriv.append(sp.sympify(str(lhss[i])+"prm"))
    print(i,lhss[i],rhss[i])
    print(sp.diff(rhss[i],xx))
    newrhs = sp.sympify(str(sp.diff(rhss[i],xx)).replace("(xx)","").replace(", xx","prm").replace("Derivative",""))
    rhss_deriv.append(newrhs)
# Out:
# 0 sigmaKerr0 s1x(xx) + s2x(xx)
# Derivative(s1x(xx), xx) + Derivative(s2x(xx), xx)
# 1 sigmaKerr1 s1y(xx) + s2y(xx)
# Derivative(s1y(xx), xx) + Derivative(s2y(xx), xx)
# 2 sigmaKerr2 s1z(xx) + s2z(xx)
# Derivative(s1z(xx), xx) + Derivative(s2z(xx), xx)
# 3 invm1m2 1/(m1(xx)*m2(xx))
# -Derivative(m2(xx), xx)/(m1(xx)*m2(xx)**2) - Derivative(m1(xx), xx)/(m1(xx)**2*m2(xx))
# 4 m2overm1 invm1m2(xx)*m2(xx)**2
# 2*invm1m2(xx)*m2(xx)*Derivative(m2(xx), xx) + m2(xx)**2*Derivative(invm1m2(xx), xx)
# 5 m1overm2 invm1m2(xx)*m1(xx)**2
# 2*invm1m2(xx)*m1(xx)*Derivative(m1(xx), xx) + m1(xx)**2*Derivative(invm1m2(xx), xx)
# 6 sigmaStar0 m1overm2(xx)*s2x(xx) + m2overm1(xx)*s1x(xx)
# m1overm2(xx)*Derivative(s2x(xx), xx) + m2overm1(xx)*Derivative(s1x(xx), xx) + s1x(xx)*Derivative(m2overm1(xx), xx) + s2x(xx)*Derivative(m1overm2(xx), xx)
# 7 sigmaStar1 m1overm2(xx)*s2y(xx) + m2overm1(xx)*s1y(xx)
# m1overm2(xx)*Derivative(s2y(xx), xx) + m2overm1(xx)*Derivative(s1y(xx), xx) + s1y(xx)*Derivative(m2overm1(xx), xx) + s2y(xx)*Derivative(m1overm2(xx), xx)
# 8 sigmaStar2 m1overm2(xx)*s2z(xx) + m2overm1(xx)*s1z(xx)
# m1overm2(xx)*Derivative(s2z(xx), xx) + m2overm1(xx)*Derivative(s1z(xx), xx) + s1z(xx)*Derivative(m2overm1(xx), xx) + s2z(xx)*Derivative(m1overm2(xx), xx)
# 9 s1dots1 s1x(xx)**2 + s1y(xx)**2 + s1z(xx)**2
# 2*s1x(xx)*Derivative(s1x(xx), xx) + 2*s1y(xx)*Derivative(s1y(xx), xx) + 2*s1z(xx)*Derivative(s1z(xx), xx)
# 10 s2dots2 s2x(xx)**2 + s2y(xx)**2 + s2z(xx)**2
# 2*s2x(xx)*Derivative(s2x(xx), xx) + 2*s2y(xx)*Derivative(s2y(xx), xx) + 2*s2z(xx)*Derivative(s2z(xx), xx)
# 11 r2 x(xx)**2 + y(xx)**2 + z(xx)**2
# 2*x(xx)*Derivative(x(xx), xx) + 2*y(xx)*Derivative(y(xx), xx) + 2*z(xx)*Derivative(z(xx), xx)
# 12 r sqrt(r2(xx))
# Derivative(r2(xx), xx)/(2*sqrt(r2(xx)))
# 13 u 1/r(xx)
# -Derivative(r(xx), xx)/r(xx)**2
# 14 u2 u(xx)**2
# 2*u(xx)*Derivative(u(xx), xx)
# 15 u3 u(xx)*u2(xx)
# u(xx)*Derivative(u2(xx), xx) + u2(xx)*Derivative(u(xx), xx)
# 16 u4 u2(xx)**2
# 2*u2(xx)*Derivative(u2(xx), xx)
# 17 u5 u(xx)*u4(xx)
# u(xx)*Derivative(u4(xx), xx) + u4(xx)*Derivative(u(xx), xx)
# 18 etau3 eta(xx)*u3(xx)
# eta(xx)*Derivative(u3(xx), xx) + u3(xx)*Derivative(eta(xx), xx)
# 19 etau4 eta(xx)*u4(xx)
# eta(xx)*Derivative(u4(xx), xx) + u4(xx)*Derivative(eta(xx), xx)
# 20 nx u(xx)*x(xx)
# u(xx)*Derivative(x(xx), xx) + x(xx)*Derivative(u(xx), xx)
# 21 ny u(xx)*y(xx)
# u(xx)*Derivative(y(xx), xx) + y(xx)*Derivative(u(xx), xx)
# 22 nz u(xx)*z(xx)
# u(xx)*Derivative(z(xx), xx) + z(xx)*Derivative(u(xx), xx)
# 23 sKerrUSCOREx sigmaKerr0(xx)
# Derivative(sigmaKerr0(xx), xx)
# 24 sKerrUSCOREy sigmaKerr1(xx)
# Derivative(sigmaKerr1(xx), xx)
# 25 sKerrUSCOREz sigmaKerr2(xx)
# Derivative(sigmaKerr2(xx), xx)
# 26 sStarUSCOREx sigmaStar0(xx)
# Derivative(sigmaStar0(xx), xx)
# 27 sStarUSCOREy sigmaStar1(xx)
# Derivative(sigmaStar1(xx), xx)
# 28 sStarUSCOREz sigmaStar2(xx)
# Derivative(sigmaStar2(xx), xx)
# 29 a2 sKerrUSCOREx(xx)**2 + sKerrUSCOREy(xx)**2 + sKerrUSCOREz(xx)**2
# 2*sKerrUSCOREx(xx)*Derivative(sKerrUSCOREx(xx), xx) + 2*sKerrUSCOREy(xx)*Derivative(sKerrUSCOREy(xx), xx) + 2*sKerrUSCOREz(xx)*Derivative(sKerrUSCOREz(xx), xx)
# 30 a4 a2(xx)**2
# 2*a2(xx)*Derivative(a2(xx), xx)
# 31 a sqrt(a2(xx))
# Derivative(a2(xx), xx)/(2*sqrt(a2(xx)))
# 32 inva 1/a(xx)
# -Derivative(a(xx), xx)/a(xx)**2
# 33 m1PlusetaKK KK(xx)*eta(xx) - 1
# KK(xx)*Derivative(eta(xx), xx) + eta(xx)*Derivative(KK(xx), xx)
# 34 m1PlusetaKKsq m1PlusetaKK(xx)**2
# 2*m1PlusetaKK(xx)*Derivative(m1PlusetaKK(xx), xx)
# 35 invm1PlusetaKK 1/m1PlusetaKK(xx)
# -Derivative(m1PlusetaKK(xx), xx)/m1PlusetaKK(xx)**2
# 36 k1sq k1(xx)**2
# 2*k1(xx)*Derivative(k1(xx), xx)
# 37 k1cu k1(xx)*k1sq(xx)
# k1(xx)*Derivative(k1sq(xx), xx) + k1sq(xx)*Derivative(k1(xx), xx)
# 38 k1ft k1(xx)*k1cu(xx)
# k1(xx)*Derivative(k1cu(xx), xx) + k1cu(xx)*Derivative(k1(xx), xx)
# 39 k2 0.5*(k1(xx) - 4.0*m1PlusetaKK(xx))*k1(xx) - a2(xx)*k0(xx)*m1PlusetaKKsq(xx)
# (0.5*k1(xx) - 2.0*m1PlusetaKK(xx))*Derivative(k1(xx), xx) + (0.5*Derivative(k1(xx), xx) - 2.0*Derivative(m1PlusetaKK(xx), xx))*k1(xx) - a2(xx)*k0(xx)*Derivative(m1PlusetaKKsq(xx), xx) - a2(xx)*m1PlusetaKKsq(xx)*Derivative(k0(xx), xx) - k0(xx)*m1PlusetaKKsq(xx)*Derivative(a2(xx), xx)
# 40 k2sq k2(xx)**2
# 2*k2(xx)*Derivative(k2(xx), xx)
# 41 k3 -(2.0*k2(xx) - 2.0*m1PlusetaKK(xx))*m1PlusetaKK(xx) - a2(xx)*k1(xx)*m1PlusetaKKsq(xx) + k1(xx)*k2(xx) - 0.333333333333333*k1cu(xx) + k1sq(xx)*m1PlusetaKK(xx)
# (-2.0*k2(xx) + 2.0*m1PlusetaKK(xx))*Derivative(m1PlusetaKK(xx), xx) + (-2.0*Derivative(k2(xx), xx) + 2.0*Derivative(m1PlusetaKK(xx), xx))*m1PlusetaKK(xx) - a2(xx)*k1(xx)*Derivative(m1PlusetaKKsq(xx), xx) - a2(xx)*m1PlusetaKKsq(xx)*Derivative(k1(xx), xx) - k1(xx)*m1PlusetaKKsq(xx)*Derivative(a2(xx), xx) + k1(xx)*Derivative(k2(xx), xx) + k1sq(xx)*Derivative(m1PlusetaKK(xx), xx) + k2(xx)*Derivative(k1(xx), xx) + m1PlusetaKK(xx)*Derivative(k1sq(xx), xx) - 0.333333333333333*Derivative(k1cu(xx), xx)
# 42 k4 0.0833333333333333*(24*k2(xx)*m1PlusetaKK(xx) + 12*k3(xx))*k1(xx) + 0.5*(k1sq(xx) - 2*k2(xx))*a2(xx)*m1PlusetaKKsq(xx) - 0.666666666666667*k1cu(xx)*m1PlusetaKK(xx) + 0.25*k1ft(xx) - 1.0*k1sq(xx)*k2(xx) + 0.5*k2(xx)**2 - 2.0*k3(xx)*m1PlusetaKK(xx) + 0.0833333333333333*(376.0 - 15.375*pi**2)*m1PlusetaKKsq(xx)
# (2.0*k2(xx)*m1PlusetaKK(xx) + 1.0*k3(xx))*Derivative(k1(xx), xx) + (0.5*k1sq(xx) - 1.0*k2(xx))*a2(xx)*Derivative(m1PlusetaKKsq(xx), xx) + (0.5*k1sq(xx) - 1.0*k2(xx))*m1PlusetaKKsq(xx)*Derivative(a2(xx), xx) + (0.5*Derivative(k1sq(xx), xx) - 1.0*Derivative(k2(xx), xx))*a2(xx)*m1PlusetaKKsq(xx) + (2.0*k2(xx)*Derivative(m1PlusetaKK(xx), xx) + 2.0*m1PlusetaKK(xx)*Derivative(k2(xx), xx) + 1.0*Derivative(k3(xx), xx))*k1(xx) - 0.666666666666667*k1cu(xx)*Derivative(m1PlusetaKK(xx), xx) - 1.0*k1sq(xx)*Derivative(k2(xx), xx) - 1.0*k2(xx)*Derivative(k1sq(xx), xx) + 1.0*k2(xx)*Derivative(k2(xx), xx) - 2.0*k3(xx)*Derivative(m1PlusetaKK(xx), xx) - 0.666666666666667*m1PlusetaKK(xx)*Derivative(k1cu(xx), xx) - 2.0*m1PlusetaKK(xx)*Derivative(k3(xx), xx) + 0.25*Derivative(k1ft(xx), xx) + (31.3333333333333 - 1.28125*pi**2)*Derivative(m1PlusetaKKsq(xx), xx)
# 43 k5 (-0.333333333333333*(-3.0*k1(xx)*k2(xx) + k1cu(xx) + 3.0*k3(xx))*a2(xx) + (4.0*k1(xx)*k3(xx) + k1ft(xx) - 4.0*k1sq(xx)*k2(xx) + 2.0*k2sq(xx) - 4.0*k4(xx))/(2*m1PlusetaKK(xx)) - 0.2*(k1(xx)*k1ft(xx) + 5.0*k1(xx)*k2sq(xx) - 5.0*k1(xx)*k4(xx) - 5.0*k1cu(xx)*k2(xx) + 5.0*k1sq(xx)*k3(xx) - 5.0*k2(xx)*k3(xx))/m1PlusetaKKsq(xx) + 25.6*EMgamma(xx) - 70.6166666666667 + 51.2*log(2) + 4.443359375*pi**2)*m1PlusetaKKsq(xx)
# (-0.333333333333333*(-3.0*k1(xx)*k2(xx) + k1cu(xx) + 3.0*k3(xx))*a2(xx) + (4.0*k1(xx)*k3(xx) + k1ft(xx) - 4.0*k1sq(xx)*k2(xx) + 2.0*k2sq(xx) - 4.0*k4(xx))/(2*m1PlusetaKK(xx)) - 0.2*(k1(xx)*k1ft(xx) + 5.0*k1(xx)*k2sq(xx) - 5.0*k1(xx)*k4(xx) - 5.0*k1cu(xx)*k2(xx) + 5.0*k1sq(xx)*k3(xx) - 5.0*k2(xx)*k3(xx))/m1PlusetaKKsq(xx) + 25.6*EMgamma(xx) - 70.6166666666667 + 51.2*log(2) + 4.443359375*pi**2)*Derivative(m1PlusetaKKsq(xx), xx) + ((1.0*k1(xx)*k2(xx) - 0.333333333333333*k1cu(xx) - 1.0*k3(xx))*Derivative(a2(xx), xx) + (1.0*k1(xx)*Derivative(k2(xx), xx) + 1.0*k2(xx)*Derivative(k1(xx), xx) - 0.333333333333333*Derivative(k1cu(xx), xx) - 1.0*Derivative(k3(xx), xx))*a2(xx) - (4.0*k1(xx)*k3(xx) + k1ft(xx) - 4.0*k1sq(xx)*k2(xx) + 2.0*k2sq(xx) - 4.0*k4(xx))*Derivative(m1PlusetaKK(xx), xx)/(2*m1PlusetaKK(xx)**2) + 0.2*(k1(xx)*k1ft(xx) + 5.0*k1(xx)*k2sq(xx) - 5.0*k1(xx)*k4(xx) - 5.0*k1cu(xx)*k2(xx) + 5.0*k1sq(xx)*k3(xx) - 5.0*k2(xx)*k3(xx))*Derivative(m1PlusetaKKsq(xx), xx)/m1PlusetaKKsq(xx)**2 + (4.0*k1(xx)*Derivative(k3(xx), xx) - 4.0*k1sq(xx)*Derivative(k2(xx), xx) - 4.0*k2(xx)*Derivative(k1sq(xx), xx) + 4.0*k3(xx)*Derivative(k1(xx), xx) + Derivative(k1ft(xx), xx) + 2.0*Derivative(k2sq(xx), xx) - 4.0*Derivative(k4(xx), xx))/(2*m1PlusetaKK(xx)) - 0.2*(k1(xx)*Derivative(k1ft(xx), xx) + 5.0*k1(xx)*Derivative(k2sq(xx), xx) - 5.0*k1(xx)*Derivative(k4(xx), xx) - 5.0*k1cu(xx)*Derivative(k2(xx), xx) + k1ft(xx)*Derivative(k1(xx), xx) + 5.0*k1sq(xx)*Derivative(k3(xx), xx) - 5.0*k2(xx)*Derivative(k1cu(xx), xx) - 5.0*k2(xx)*Derivative(k3(xx), xx) + 5.0*k2sq(xx)*Derivative(k1(xx), xx) + 5.0*k3(xx)*Derivative(k1sq(xx), xx) - 5.0*k3(xx)*Derivative(k2(xx), xx) - 5.0*k4(xx)*Derivative(k1(xx), xx))/m1PlusetaKKsq(xx) + 25.6*Derivative(EMgamma(xx), xx))*m1PlusetaKKsq(xx)
# 44 k5l 12.8*m1PlusetaKKsq(xx)
# 12.8*Derivative(m1PlusetaKKsq(xx), xx)
# 45 e3USCOREx inva(xx)*sKerrUSCOREx(xx)
# inva(xx)*Derivative(sKerrUSCOREx(xx), xx) + sKerrUSCOREx(xx)*Derivative(inva(xx), xx)
# 46 e3USCOREy inva(xx)*sKerrUSCOREy(xx)
# inva(xx)*Derivative(sKerrUSCOREy(xx), xx) + sKerrUSCOREy(xx)*Derivative(inva(xx), xx)
# 47 e3USCOREz inva(xx)*sKerrUSCOREz(xx)
# inva(xx)*Derivative(sKerrUSCOREz(xx), xx) + sKerrUSCOREz(xx)*Derivative(inva(xx), xx)
# 48 costheta e3USCOREx(xx)*nx(xx) + e3USCOREy(xx)*ny(xx) + e3USCOREz(xx)*nz(xx)
# e3USCOREx(xx)*Derivative(nx(xx), xx) + e3USCOREy(xx)*Derivative(ny(xx), xx) + e3USCOREz(xx)*Derivative(nz(xx), xx) + nx(xx)*Derivative(e3USCOREx(xx), xx) + ny(xx)*Derivative(e3USCOREy(xx), xx) + nz(xx)*Derivative(e3USCOREz(xx), xx)
# 49 xi2 1 - costheta(xx)**2
# -2*costheta(xx)*Derivative(costheta(xx), xx)
# 50 xiUSCOREx e3USCOREy(xx)*nz(xx) - e3USCOREz(xx)*ny(xx)
# e3USCOREy(xx)*Derivative(nz(xx), xx) - e3USCOREz(xx)*Derivative(ny(xx), xx) - ny(xx)*Derivative(e3USCOREz(xx), xx) + nz(xx)*Derivative(e3USCOREy(xx), xx)
# 51 xiUSCOREy -e3USCOREx(xx)*nz(xx) + e3USCOREz(xx)*nx(xx)
# -e3USCOREx(xx)*Derivative(nz(xx), xx) + e3USCOREz(xx)*Derivative(nx(xx), xx) + nx(xx)*Derivative(e3USCOREz(xx), xx) - nz(xx)*Derivative(e3USCOREx(xx), xx)
# 52 xiUSCOREz e3USCOREx(xx)*ny(xx) - e3USCOREy(xx)*nx(xx)
# e3USCOREx(xx)*Derivative(ny(xx), xx) - e3USCOREy(xx)*Derivative(nx(xx), xx) - nx(xx)*Derivative(e3USCOREy(xx), xx) + ny(xx)*Derivative(e3USCOREx(xx), xx)
# 53 vx ny(xx)*xiUSCOREz(xx) - nz(xx)*xiUSCOREy(xx)
# ny(xx)*Derivative(xiUSCOREz(xx), xx) - nz(xx)*Derivative(xiUSCOREy(xx), xx) - xiUSCOREy(xx)*Derivative(nz(xx), xx) + xiUSCOREz(xx)*Derivative(ny(xx), xx)
# 54 vy -nx(xx)*xiUSCOREz(xx) + nz(xx)*xiUSCOREx(xx)
# -nx(xx)*Derivative(xiUSCOREz(xx), xx) + nz(xx)*Derivative(xiUSCOREx(xx), xx) + xiUSCOREx(xx)*Derivative(nz(xx), xx) - xiUSCOREz(xx)*Derivative(nx(xx), xx)
# 55 vz nx(xx)*xiUSCOREy(xx) - ny(xx)*xiUSCOREx(xx)
# nx(xx)*Derivative(xiUSCOREy(xx), xx) - ny(xx)*Derivative(xiUSCOREx(xx), xx) - xiUSCOREx(xx)*Derivative(ny(xx), xx) + xiUSCOREy(xx)*Derivative(nx(xx), xx)
# 56 w2 a2(xx) + r2(xx)
# Derivative(a2(xx), xx) + Derivative(r2(xx), xx)
# 57 rho2 a2(xx)*costheta(xx)**2 + r2(xx)
# 2*a2(xx)*costheta(xx)*Derivative(costheta(xx), xx) + costheta(xx)**2*Derivative(a2(xx), xx) + Derivative(r2(xx), xx)
# 58 bulk (invm1PlusetaKK(xx) + 2*u(xx))*invm1PlusetaKK(xx) + a2(xx)*u2(xx)
# (invm1PlusetaKK(xx) + 2*u(xx))*Derivative(invm1PlusetaKK(xx), xx) + (Derivative(invm1PlusetaKK(xx), xx) + 2*Derivative(u(xx), xx))*invm1PlusetaKK(xx) + a2(xx)*Derivative(u2(xx), xx) + u2(xx)*Derivative(a2(xx), xx)
# 59 logu log(u(xx))
# Derivative(u(xx), xx)/u(xx)
# 60 logarg k1(xx)*u(xx) + k2(xx)*u2(xx) + k3(xx)*u3(xx) + k4(xx)*u4(xx) + k5(xx)*u5(xx) + k5l(xx)*logu(xx)*u5(xx)
# k1(xx)*Derivative(u(xx), xx) + k2(xx)*Derivative(u2(xx), xx) + k3(xx)*Derivative(u3(xx), xx) + k4(xx)*Derivative(u4(xx), xx) + k5(xx)*Derivative(u5(xx), xx) + k5l(xx)*logu(xx)*Derivative(u5(xx), xx) + k5l(xx)*u5(xx)*Derivative(logu(xx), xx) + logu(xx)*u5(xx)*Derivative(k5l(xx), xx) + u(xx)*Derivative(k1(xx), xx) + u2(xx)*Derivative(k2(xx), xx) + u3(xx)*Derivative(k3(xx), xx) + u4(xx)*Derivative(k4(xx), xx) + u5(xx)*Derivative(k5(xx), xx)
# 61 onepluslogarg logarg(xx) + 1
# Derivative(logarg(xx), xx)
# 62 invonepluslogarg 1/onepluslogarg(xx)
# -Derivative(onepluslogarg(xx), xx)/onepluslogarg(xx)**2
# 63 logTerms eta(xx)*k0(xx) + eta(xx)*log(onepluslogarg(xx)) + 1
# eta(xx)*Derivative(k0(xx), xx) + eta(xx)*Derivative(onepluslogarg(xx), xx)/onepluslogarg(xx) + k0(xx)*Derivative(eta(xx), xx) + log(onepluslogarg(xx))*Derivative(eta(xx), xx)
# 64 deltaU bulk(xx)*logTerms(xx)
# bulk(xx)*Derivative(logTerms(xx), xx) + logTerms(xx)*Derivative(bulk(xx), xx)
# 65 deltaT deltaU(xx)*r2(xx)
# deltaU(xx)*Derivative(r2(xx), xx) + r2(xx)*Derivative(deltaU(xx), xx)
# 66 deltaUUSCOREupt7 k5(xx) + k5l(xx)*logu(xx)
# k5l(xx)*Derivative(logu(xx), xx) + logu(xx)*Derivative(k5l(xx), xx) + Derivative(k5(xx), xx)
# 67 deltaUUSCOREupt6 5*deltaUUSCOREupt7(xx)*u(xx) + 4*k4(xx)
# 5*deltaUUSCOREupt7(xx)*Derivative(u(xx), xx) + 5*u(xx)*Derivative(deltaUUSCOREupt7(xx), xx) + 4*Derivative(k4(xx), xx)
# 68 deltaUUSCOREupt5 deltaUUSCOREupt6(xx)*u(xx) + 3*k3(xx)
# deltaUUSCOREupt6(xx)*Derivative(u(xx), xx) + u(xx)*Derivative(deltaUUSCOREupt6(xx), xx) + 3*Derivative(k3(xx), xx)
# 69 deltaUUSCOREupt4 deltaUUSCOREupt5(xx)*u(xx) + 2*k2(xx)
# deltaUUSCOREupt5(xx)*Derivative(u(xx), xx) + u(xx)*Derivative(deltaUUSCOREupt5(xx), xx) + 2*Derivative(k2(xx), xx)
# 70 deltaUUSCOREupt3 deltaUUSCOREupt4(xx)*u(xx) + k1(xx)
# deltaUUSCOREupt4(xx)*Derivative(u(xx), xx) + u(xx)*Derivative(deltaUUSCOREupt4(xx), xx) + Derivative(k1(xx), xx)
# 71 deltaUUSCOREupt2 a2(xx)*u(xx) + invm1PlusetaKK(xx)
# a2(xx)*Derivative(u(xx), xx) + u(xx)*Derivative(a2(xx), xx) + Derivative(invm1PlusetaKK(xx), xx)
# 72 deltaUUSCOREupt1 bulk(xx)*deltaUUSCOREupt3(xx)*eta(xx)
# bulk(xx)*deltaUUSCOREupt3(xx)*Derivative(eta(xx), xx) + bulk(xx)*eta(xx)*Derivative(deltaUUSCOREupt3(xx), xx) + deltaUUSCOREupt3(xx)*eta(xx)*Derivative(bulk(xx), xx)
# 73 deltaUUSCOREu deltaUUSCOREupt1(xx)*invonepluslogarg(xx) + 2*deltaUUSCOREupt2(xx)*logTerms(xx)
# deltaUUSCOREupt1(xx)*Derivative(invonepluslogarg(xx), xx) + 2*deltaUUSCOREupt2(xx)*Derivative(logTerms(xx), xx) + invonepluslogarg(xx)*Derivative(deltaUUSCOREupt1(xx), xx) + 2*logTerms(xx)*Derivative(deltaUUSCOREupt2(xx), xx)
# 74 deltaTUSCOREr 2*deltaU(xx)*r(xx) - deltaUUSCOREu(xx)
# 2*deltaU(xx)*Derivative(r(xx), xx) + 2*r(xx)*Derivative(deltaU(xx), xx) - Derivative(deltaUUSCOREu(xx), xx)
# 75 Lamb -a2(xx)*deltaT(xx)*xi2(xx) + w2(xx)**2
# -a2(xx)*deltaT(xx)*Derivative(xi2(xx), xx) - a2(xx)*xi2(xx)*Derivative(deltaT(xx), xx) - deltaT(xx)*xi2(xx)*Derivative(a2(xx), xx) + 2*w2(xx)*Derivative(w2(xx), xx)
# 76 rho2xi2Lamb Lamb(xx)*rho2(xx)*xi2(xx)
# Lamb(xx)*rho2(xx)*Derivative(xi2(xx), xx) + Lamb(xx)*xi2(xx)*Derivative(rho2(xx), xx) + rho2(xx)*xi2(xx)*Derivative(Lamb(xx), xx)
# 77 invrho2xi2Lamb 1/rho2xi2Lamb(xx)
# -Derivative(rho2xi2Lamb(xx), xx)/rho2xi2Lamb(xx)**2
# 78 invrho2 1/rho2(xx)
# -Derivative(rho2(xx), xx)/rho2(xx)**2
# 79 invxi2 1/xi2(xx)
# -Derivative(xi2(xx), xx)/xi2(xx)**2
# 80 invLamb 1/Lamb(xx)
# -Derivative(Lamb(xx), xx)/Lamb(xx)**2
# 81 invLambsq invLamb(xx)**2
# 2*invLamb(xx)*Derivative(invLamb(xx), xx)
# 82 rho2invLamb invLamb(xx)*rho2(xx)
# invLamb(xx)*Derivative(rho2(xx), xx) + rho2(xx)*Derivative(invLamb(xx), xx)
# 83 expnu sqrt(deltaT(xx)*rho2invLamb(xx))
# sqrt(deltaT(xx)*rho2invLamb(xx))*(deltaT(xx)*Derivative(rho2invLamb(xx), xx)/2 + rho2invLamb(xx)*Derivative(deltaT(xx), xx)/2)/(deltaT(xx)*rho2invLamb(xx))
# 84 expMU sqrt(rho2(xx))
# Derivative(rho2(xx), xx)/(2*sqrt(rho2(xx)))
# 85 expMUexpnu expMU(xx)*expnu(xx)
# expMU(xx)*Derivative(expnu(xx), xx) + expnu(xx)*Derivative(expMU(xx), xx)
# 86 expMUsq expMU(xx)**2
# 2*expMU(xx)*Derivative(expMU(xx), xx)
# 87 expnusq expnu(xx)**2
# 2*expnu(xx)*Derivative(expnu(xx), xx)
# 88 expMUsqexpnusq expMUsq(xx)*expnusq(xx)
# expMUsq(xx)*Derivative(expnusq(xx), xx) + expnusq(xx)*Derivative(expMUsq(xx), xx)
# 89 invexpnuexpMU 1/expMUexpnu(xx)
# -Derivative(expMUexpnu(xx), xx)/expMUexpnu(xx)**2
# 90 invexpMU expnu(xx)*invexpnuexpMU(xx)
# expnu(xx)*Derivative(invexpnuexpMU(xx), xx) + invexpnuexpMU(xx)*Derivative(expnu(xx), xx)
# 91 invexpMUsq invexpMU(xx)**2
# 2*invexpMU(xx)*Derivative(invexpMU(xx), xx)
# 92 expnuinvexpMU2 expnu(xx)*invexpMUsq(xx)
# expnu(xx)*Derivative(invexpMUsq(xx), xx) + invexpMUsq(xx)*Derivative(expnu(xx), xx)
# 93 invexpMUcubinvexpnu invexpMUsq(xx)*invexpnuexpMU(xx)
# invexpMUsq(xx)*Derivative(invexpnuexpMU(xx), xx) + invexpnuexpMU(xx)*Derivative(invexpMUsq(xx), xx)
# 94 DD log((52 - 6*eta(xx))*etau3(xx) + 6*eta(xx)*u2(xx) + 1) + 1
# ((52 - 6*eta(xx))*Derivative(etau3(xx), xx) + 6*eta(xx)*Derivative(u2(xx), xx) - 6*etau3(xx)*Derivative(eta(xx), xx) + 6*u2(xx)*Derivative(eta(xx), xx))/((52 - 6*eta(xx))*etau3(xx) + 6*eta(xx)*u2(xx) + 1)
# 95 deltaR DD(xx)*deltaT(xx)
# DD(xx)*Derivative(deltaT(xx), xx) + deltaT(xx)*Derivative(DD(xx), xx)
# 96 qq 2*(4 - 3*eta(xx))*eta(xx)
# (8 - 6*eta(xx))*Derivative(eta(xx), xx) - 6*eta(xx)*Derivative(eta(xx), xx)
# 97 b3 0
# 0
# 98 bb3 0
# 0
# 99 ww a(xx)*a2(xx)*b3(xx)*eta(xx)*u(xx) + a(xx)*bb3(xx)*eta(xx)*u(xx) + 2*a(xx)*r(xx)
# a(xx)*a2(xx)*b3(xx)*eta(xx)*Derivative(u(xx), xx) + a(xx)*a2(xx)*b3(xx)*u(xx)*Derivative(eta(xx), xx) + a(xx)*a2(xx)*eta(xx)*u(xx)*Derivative(b3(xx), xx) + a(xx)*b3(xx)*eta(xx)*u(xx)*Derivative(a2(xx), xx) + a(xx)*bb3(xx)*eta(xx)*Derivative(u(xx), xx) + a(xx)*bb3(xx)*u(xx)*Derivative(eta(xx), xx) + a(xx)*eta(xx)*u(xx)*Derivative(bb3(xx), xx) + 2*a(xx)*Derivative(r(xx), xx) + a2(xx)*b3(xx)*eta(xx)*u(xx)*Derivative(a(xx), xx) + bb3(xx)*eta(xx)*u(xx)*Derivative(a(xx), xx) + 2*r(xx)*Derivative(a(xx), xx)
# 100 B sqrt(deltaT(xx))
# Derivative(deltaT(xx), xx)/(2*sqrt(deltaT(xx)))
# 101 sqrtdeltaT B(xx)
# Derivative(B(xx), xx)
# 102 sqrtdeltaR sqrt(deltaR(xx))
# Derivative(deltaR(xx), xx)/(2*sqrt(deltaR(xx)))
# 103 deltaTsqrtdeltaR deltaT(xx)*sqrtdeltaR(xx)
# deltaT(xx)*Derivative(sqrtdeltaR(xx), xx) + sqrtdeltaR(xx)*Derivative(deltaT(xx), xx)
# 104 sqrtdeltaTdeltaTsqrtdeltaR deltaTsqrtdeltaR(xx)*sqrtdeltaT(xx)
# deltaTsqrtdeltaR(xx)*Derivative(sqrtdeltaT(xx), xx) + sqrtdeltaT(xx)*Derivative(deltaTsqrtdeltaR(xx), xx)
# 105 invdeltaTsqrtdeltaTsqrtdeltaR 1.0/sqrtdeltaTdeltaTsqrtdeltaR(xx)
# -1.0*Derivative(sqrtdeltaTdeltaTsqrtdeltaR(xx), xx)/sqrtdeltaTdeltaTsqrtdeltaR(xx)**2
# 106 invdeltaT invdeltaTsqrtdeltaTsqrtdeltaR(xx)*sqrtdeltaR(xx)*sqrtdeltaT(xx)
# invdeltaTsqrtdeltaTsqrtdeltaR(xx)*sqrtdeltaR(xx)*Derivative(sqrtdeltaT(xx), xx) + invdeltaTsqrtdeltaTsqrtdeltaR(xx)*sqrtdeltaT(xx)*Derivative(sqrtdeltaR(xx), xx) + sqrtdeltaR(xx)*sqrtdeltaT(xx)*Derivative(invdeltaTsqrtdeltaTsqrtdeltaR(xx), xx)
# 107 invsqrtdeltaT deltaTsqrtdeltaR(xx)*invdeltaTsqrtdeltaTsqrtdeltaR(xx)
# deltaTsqrtdeltaR(xx)*Derivative(invdeltaTsqrtdeltaTsqrtdeltaR(xx), xx) + invdeltaTsqrtdeltaTsqrtdeltaR(xx)*Derivative(deltaTsqrtdeltaR(xx), xx)
# 108 invsqrtdeltaR deltaT(xx)*invdeltaTsqrtdeltaTsqrtdeltaR(xx)*sqrtdeltaT(xx)
# deltaT(xx)*invdeltaTsqrtdeltaTsqrtdeltaR(xx)*Derivative(sqrtdeltaT(xx), xx) + deltaT(xx)*sqrtdeltaT(xx)*Derivative(invdeltaTsqrtdeltaTsqrtdeltaR(xx), xx) + invdeltaTsqrtdeltaTsqrtdeltaR(xx)*sqrtdeltaT(xx)*Derivative(deltaT(xx), xx)
# 109 w invLamb(xx)*ww(xx)
# invLamb(xx)*Derivative(ww(xx), xx) + ww(xx)*Derivative(invLamb(xx), xx)
# 110 LambUSCOREr -a2(xx)*deltaTUSCOREr(xx)*xi2(xx) + 4*r(xx)*w2(xx)
# -a2(xx)*deltaTUSCOREr(xx)*Derivative(xi2(xx), xx) - a2(xx)*xi2(xx)*Derivative(deltaTUSCOREr(xx), xx) - deltaTUSCOREr(xx)*xi2(xx)*Derivative(a2(xx), xx) + 4*r(xx)*Derivative(w2(xx), xx) + 4*w2(xx)*Derivative(r(xx), xx)
# 111 wwUSCOREr -a(xx)*a2(xx)*b3(xx)*eta(xx)*u2(xx) - a(xx)*bb3(xx)*eta(xx)*u2(xx) + 2*a(xx)
# -a(xx)*a2(xx)*b3(xx)*eta(xx)*Derivative(u2(xx), xx) - a(xx)*a2(xx)*b3(xx)*u2(xx)*Derivative(eta(xx), xx) - a(xx)*a2(xx)*eta(xx)*u2(xx)*Derivative(b3(xx), xx) - a(xx)*b3(xx)*eta(xx)*u2(xx)*Derivative(a2(xx), xx) - a(xx)*bb3(xx)*eta(xx)*Derivative(u2(xx), xx) - a(xx)*bb3(xx)*u2(xx)*Derivative(eta(xx), xx) - a(xx)*eta(xx)*u2(xx)*Derivative(bb3(xx), xx) - a2(xx)*b3(xx)*eta(xx)*u2(xx)*Derivative(a(xx), xx) - bb3(xx)*eta(xx)*u2(xx)*Derivative(a(xx), xx) + 2*Derivative(a(xx), xx)
# 112 BR (-deltaT(xx)*invsqrtdeltaR(xx) + deltaTUSCOREr(xx)/2)*invsqrtdeltaT(xx)
# (-deltaT(xx)*invsqrtdeltaR(xx) + deltaTUSCOREr(xx)/2)*Derivative(invsqrtdeltaT(xx), xx) + (-deltaT(xx)*Derivative(invsqrtdeltaR(xx), xx) - invsqrtdeltaR(xx)*Derivative(deltaT(xx), xx) + Derivative(deltaTUSCOREr(xx), xx)/2)*invsqrtdeltaT(xx)
# 113 wr (Lamb(xx)*wwUSCOREr(xx) - LambUSCOREr(xx)*ww(xx))*invLambsq(xx)
# (Lamb(xx)*wwUSCOREr(xx) - LambUSCOREr(xx)*ww(xx))*Derivative(invLambsq(xx), xx) + (Lamb(xx)*Derivative(wwUSCOREr(xx), xx) - LambUSCOREr(xx)*Derivative(ww(xx), xx) - ww(xx)*Derivative(LambUSCOREr(xx), xx) + wwUSCOREr(xx)*Derivative(Lamb(xx), xx))*invLambsq(xx)
# 114 nurpt2 (-4.0*deltaT(xx)*r(xx) + deltaTUSCOREr(xx)*w2(xx))*w2(xx)
# (-4.0*deltaT(xx)*r(xx) + deltaTUSCOREr(xx)*w2(xx))*Derivative(w2(xx), xx) + (-4.0*deltaT(xx)*Derivative(r(xx), xx) + deltaTUSCOREr(xx)*Derivative(w2(xx), xx) - 4.0*r(xx)*Derivative(deltaT(xx), xx) + w2(xx)*Derivative(deltaTUSCOREr(xx), xx))*w2(xx)
# 115 nurpt1 invdeltaT(xx)*nurpt2(xx)
# invdeltaT(xx)*Derivative(nurpt2(xx), xx) + nurpt2(xx)*Derivative(invdeltaT(xx), xx)
# 116 nur invLamb(xx)*nurpt1(xx)/2 + invrho2(xx)*r(xx)
# invLamb(xx)*Derivative(nurpt1(xx), xx)/2 + invrho2(xx)*Derivative(r(xx), xx) + nurpt1(xx)*Derivative(invLamb(xx), xx)/2 + r(xx)*Derivative(invrho2(xx), xx)
# 117 mur invrho2(xx)*r(xx) - invsqrtdeltaR(xx)
# invrho2(xx)*Derivative(r(xx), xx) + r(xx)*Derivative(invrho2(xx), xx) - Derivative(invsqrtdeltaR(xx), xx)
# 118 a2costheta a2(xx)*costheta(xx)
# a2(xx)*Derivative(costheta(xx), xx) + costheta(xx)*Derivative(a2(xx), xx)
# 119 wcospt2 deltaT(xx)*ww(xx)
# deltaT(xx)*Derivative(ww(xx), xx) + ww(xx)*Derivative(deltaT(xx), xx)
# 120 wcospt1 invLambsq(xx)*wcospt2(xx)
# invLambsq(xx)*Derivative(wcospt2(xx), xx) + wcospt2(xx)*Derivative(invLambsq(xx), xx)
# 121 wcos -2*a2costheta(xx)*wcospt1(xx)
# -2*a2costheta(xx)*Derivative(wcospt1(xx), xx) - 2*wcospt1(xx)*Derivative(a2costheta(xx), xx)
# 122 nucospt3 invLamb(xx)*invrho2(xx)
# invLamb(xx)*Derivative(invrho2(xx), xx) + invrho2(xx)*Derivative(invLamb(xx), xx)
# 123 nucospt2 nucospt3(xx)*w2(xx)
# nucospt3(xx)*Derivative(w2(xx), xx) + w2(xx)*Derivative(nucospt3(xx), xx)
# 124 nucospt1 a2costheta(xx)*nucospt2(xx)
# a2costheta(xx)*Derivative(nucospt2(xx), xx) + nucospt2(xx)*Derivative(a2costheta(xx), xx)
# 125 nucos (-deltaT(xx) + w2(xx))*nucospt1(xx)
# (-deltaT(xx) + w2(xx))*Derivative(nucospt1(xx), xx) + (-Derivative(deltaT(xx), xx) + Derivative(w2(xx), xx))*nucospt1(xx)
# 126 mucos a2costheta(xx)*invrho2(xx)
# a2costheta(xx)*Derivative(invrho2(xx), xx) + invrho2(xx)*Derivative(a2costheta(xx), xx)
# 127 etaover12r eta(xx)*u(xx)/12
# eta(xx)*Derivative(u(xx), xx)/12 + u(xx)*Derivative(eta(xx), xx)/12
# 128 csi sqrt(deltaR(xx)*deltaT(xx))/w2(xx)
# sqrt(deltaR(xx)*deltaT(xx))*(deltaR(xx)*Derivative(deltaT(xx), xx)/2 + deltaT(xx)*Derivative(deltaR(xx), xx)/2)/(deltaR(xx)*deltaT(xx)*w2(xx)) - sqrt(deltaR(xx)*deltaT(xx))*Derivative(w2(xx), xx)/w2(xx)**2
# 129 csi1 (1 - Abs(tortoise(xx) - 1))*(csi(xx) - 1) + 1
# (1 - Abs(tortoise(xx) - 1))*Derivative(csi(xx), xx) - ((re(tortoise(xx)) - 1)*re(Derivative(tortoise(xx), xx)) + im(tortoise(xx))*im(Derivative(tortoise(xx), xx)))*(csi(xx) - 1)*sign(tortoise(xx) - 1)/(tortoise(xx) - 1)
# 130 csi2 (1/2 - 0.5*sign(1.5 - tortoise(xx)))*(csi(xx) - 1) + 1
# (1/2 - 0.5*sign(1.5 - tortoise(xx)))*Derivative(csi(xx), xx) - 0.5*(csi(xx) - 1)*Derivative(sign(1.5 - tortoise(xx)), xx)
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~/jup38/lib/python3.8/site-packages/sympy/core/sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     405         a = a.replace('\n', '')
# --> 406         expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     407     except (TokenError, SyntaxError) as exc:
#
# ~/jup38/lib/python3.8/site-packages/sympy/parsing/sympy_parser.py in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1007
# -> 1008     return eval_expr(code, local_dict, global_dict)
#    1009
#
# ~/jup38/lib/python3.8/site-packages/sympy/parsing/sympy_parser.py in eval_expr(code, local_dict, global_dict)
#     901     """
# --> 902     expr = eval(
#     903         code, global_dict, local_dict)  # take local objects in preference
#
# SyntaxError: invalid syntax (<string>, line 1)
#
# During handling of the above exception, another exception occurred:
#
# SympifyError                              Traceback (most recent call last)
# <ipython-input-7-8d559d67b427> in <module>
#       7     print(i,lhss[i],rhss[i])
#       8     print(sp.diff(rhss[i],xx))
# ----> 9     newrhs = sp.sympify(str(sp.diff(rhss[i],xx)).replace("(xx)","").replace(", xx","prm").replace("Derivative",""))
#      10     rhss_deriv.append(newrhs)
#
# ~/jup38/lib/python3.8/site-packages/sympy/core/sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     406         expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     407     except (TokenError, SyntaxError) as exc:
# --> 408         raise SympifyError('could not parse %r' % a, exc)
#     409
#     410     return expr
#
# SympifyError: Sympify of expression 'could not parse '(1/2 - 0.5*sign(1.5 - tortoise))*(csiprm) - 0.5*(csi - 1)*(sign(1.5 - tortoise)prm)'' failed, because of exception being raised:
# SyntaxError: invalid syntax (<string>, line 1)

# %% [markdown]
# <a id='step7'></a>
#
# # Step 7: Simplify derivative expressions \[Back to [top](#toc)\]
# $$\label{step7}$$
#
# We declare a function to simply the derivative expressions.  In particular, we want to remove terms equal to zero.

# %%
# Step 7.a: Define derivative simplification function
def simplify_deriv(lhss_deriv,rhss_deriv):
    # Copy expressions into another array
    lhss_deriv_simp = []
    rhss_deriv_simp = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_simp.append(lhss_deriv[i])
        rhss_deriv_simp.append(rhss_deriv[i])
    # If a right-hand side is 0, substitute value 0 for the corresponding left-hand side in later terms
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == 0:
            for j in range(i+1,len(rhss_deriv_simp)):
                for var in rhss_deriv_simp[j].free_symbols:
                    if str(var) == str(lhss_deriv_simp[i]):
                        rhss_deriv_simp[j] = rhss_deriv_simp[j].subs(var,0)
    zero_elements_to_remove = []
    # Create array of indices for expressions that are zero
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == sp.sympify(0):
            zero_elements_to_remove.append(i)

    # When removing terms that are zero, we need to take into account their new index (after each removal)
    count = 0
    for i in range(len(zero_elements_to_remove)):
        del lhss_deriv_simp[zero_elements_to_remove[i]+count]
        del rhss_deriv_simp[zero_elements_to_remove[i]+count]
        count -= 1
    return lhss_deriv_simp,rhss_deriv_simp

# Step 7.b: Call the simplication function and then copy results
lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv,rhss_deriv)
lhss_deriv = lhss_deriv_simp
rhss_deriv = rhss_deriv_simp

# %% [markdown]
# <a id='step8'></a>
#
# # Step 8: Differentiate with respect to a specific free variable \[Back to [top](#toc)\]
# $$\label{step8}$$
#
# In [Step 6](#step6) we took a generic derivative of each term, assuming it is a function of the varible $\textrm{xx}$.  We now define a function that will select a specific free variable for differentiation.

# %%
# Step 8.a: Define onevar derivative function
def deriv_onevar(lhss_deriv,rhss_deriv,variable_list,index):
    # Denote each variable with prm
    variableprm_list = []
    for variable in variable_list:
        variableprm_list.append(str(variable)+"prm")

    # Copy expressions into another array
    lhss_deriv_new = []
    rhss_deriv_new = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_new.append(lhss_deriv[i])
        rhss_deriv_new.append(rhss_deriv[i])
    # For each free symbol's derivative, replace it with:
    #   1, if we are differentiating with respect to the variable, or
    #   0, if we are note differentiating with respect to that variable
    for i in range(len(rhss_deriv_new)):
        for var in variableprm_list:
            if variableprm_list.index(str(var))==index:
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,1)
            else:
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,0)
    # Simplify derivative expressions again
    lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv_new,rhss_deriv_new)
    return lhss_deriv_simp,rhss_deriv_simp

# Step 8.b: Call the derivative function and populate dictionaries with the result
lhss_derivative = {}
rhss_derivative = {}
for index in range(len(dynamic_variables)):
    lhss_temp,rhss_temp = deriv_onevar(lhss_deriv,rhss_deriv,dynamic_variables,index)
    lhss_derivative[dynamic_variables[index]] = lhss_temp
    rhss_derivative[dynamic_variables[index]] = rhss_temp

# %% [markdown]
# <a id='step9'></a>
#
# # Step 9: Output result \[Back to [top](#toc)\]
# $$\label{step9}$$
#
# We write the resulting derivatives in SymPy syntax.  Each partial derivative is output in its own file, in a similar format to the input expressions.

# %%
# Step 9: Output original expression and each partial derivative expression in SymPy snytax
with open("partial_derivatives.txt", "w") as output:
    for i in range(len(lr)):
        right_side = lr[i].rhs
        right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(")
        output.write(str(lr[i].lhs)+" = "+right_side_in_sp)
    for var in dynamic_variables:
        for i in range(len(lhss_derivative[var])):
            right_side = str(rhss_derivative[var][i])
            right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(").replace("prm",
                                                "prm_"+str(var))
            output.write(str(lhss_derivative[var][i]).replace("prm","prm_"+str(var))+" = "+right_side_in_sp+"\n")

# %% [markdown]
# <a id='code_validation'></a>
#
# # Step 10: Code Validation against `SEOBNR_Derivative_Routine` NRPy+ module \[Back to [top](#toc)\]
# $$\label{code_validation}$$

# %% [markdown]
# <a id='latex_pdf_output'></a>
#
# # Step 11: Output this notebook to $\LaTeX$-formatted PDF file \[Back to [top](#toc)\]
# $$\label{latex_pdf_output}$$
#
# The following code cell converts this Jupyter notebook into a proper, clickable $\LaTeX$-formatted PDF file. After the cell is successfully run, the generated PDF may be found in the root NRPy+ tutorial directory, with filename
# [Tutorial-SEOBNR_Derivative_Routine.pdf](Tutorial-SEOBNR_Derivative_Routine.pdf) (Note that clicking on this link may not work; you may need to open the PDF file through another means.)

# %%
import os,sys                    # Standard Python modules for multiplatform OS-level functions
nrpy_dir_path = os.path.join("..")
if nrpy_dir_path not in sys.path:
    sys.path.append(nrpy_dir_path)
import cmdline_helper as cmd    # NRPy+: Multi-platform Python command-line interface
cmd.output_Jupyter_notebook_to_LaTeXed_PDF("NRPyPN_shortcuts",location_of_template_file=os.path.join(".."))
