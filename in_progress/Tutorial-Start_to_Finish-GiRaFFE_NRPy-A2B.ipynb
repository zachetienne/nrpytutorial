# %% [markdown]
# # Unit Testing `GiRaFFE_NRPy`: $A_k$ to $B^i$
#
# ### Author: Patrick Nelson
#
# This notebook validates our A-to-B solver for use in `GiRaFFE_NRPy`. Because the original `GiRaFFE` used staggered grids and we do not, we can not trivially do a direct comparison to the old code. Instead, we will compare the numerical results with the expected analytic results.
#
# **Module Status:** <font color=red><b> In-Progress </b></font>
#
# **Validation Notes:** This module will validate the routines in [Tutorial-GiRaFFE_HO_C_code_library-A2B](../Tutorial-GiRaFFE_HO_C_code_library-A2B.ipynb).
#
# It is, in general, good coding practice to unit test functions individually to verify that they produce the expected and intended output. Here, we expect our functions to produce the correct cross product in an arbitrary spacetime. To that end, we will choose functions that are easy to differentiate, but lack the symmetries that would trivialize the finite-difference algorithm. Higher-order polynomials are one such type of function.
#
# We will start with the simplest case - testing the second-order solver. In second-order finite-differencing, we use a three-point stencil that can exactly differentiate polynomials up to quadratic. So, we will use cubic functions three variables. For instance,
#
# \begin{align}
# A_x &= ax^3 + by^3 + cz^3 + dy^2 + ez^2 + f \\
# A_y &= gx^3 + hy^3 + lz^3 + mx^2 + nz^2 + p \\
# A_z &= px^3 + qy^3 + rz^3 + sx^2 + ty^2 + u. \\
# \end{align}
#
# It will be much simpler to let NRPy+ handle most of this work. So, we will import the core functionality of NRPy+, build the expressions, and then output them using `outputC()`.

# %%
import shutil, os, sys           # Standard Python modules for multiplatform OS-level functions
# First, we'll add the parent directory to the list of directories Python will check for modules.
nrpy_dir_path = os.path.join("..")
if nrpy_dir_path not in sys.path:
    sys.path.append(nrpy_dir_path)
nrpy_dir_path = os.path.join("..","..")
if nrpy_dir_path not in sys.path:
    sys.path.append(nrpy_dir_path)

from outputC import *            # NRPy+: Core C code output module
import finite_difference as fin  # NRPy+: Finite difference C code generation module
import NRPy_param_funcs as par   # NRPy+: Parameter interface
import grid as gri               # NRPy+: Functions having to do with numerical grids
import loop as lp                # NRPy+: Generate C code loops
import indexedexp as ixp         # NRPy+: Symbolic indexed expression (e.g., tensors, vectors, etc.) support
import reference_metric as rfm   # NRPy+: Reference metric support
import cmdline_helper as cmd     # NRPy+: Multi-platform Python command-line interface

out_dir = "Validation/"
cmd.mkdir(out_dir)

thismodule = "Unit_Test_GiRaFFE_NRPy_Ccode_library_A2B"
a,b,c,d,e,f,g,h,l,m,n,o,p,q,r,s,t,u = par.Cparameters("REAL",thismodule,["a","b","c","d","e","f","g","h","l","m","n","o","p","q","r","s","t","u"],10.0)
gammadet = gri.register_gridfunctions("AUXEVOL","gammadet")

DIM = 3
par.set_parval_from_str("grid::DIM",DIM)

par.set_parval_from_str("reference_metric::CoordSystem","Cartesian")
rfm.reference_metric()
x = rfm.xxCart[0]
y = rfm.xxCart[1]
z = rfm.xxCart[2]

AD = ixp.register_gridfunctions_for_single_rank1("EVOL","AD")
AD[0] = a*x**3 + b*y**3 + c*z**3 + d*y**2 + e*z**2 + f
AD[1] = g*x**3 + h*y**3 + l*z**3 + m*x**2 + n*z**2 + o
AD[2] = p*x**3 + q*y**3 + r*z**3 + s*x**2 + t*y**2 + u

# %% [markdown]
# We also need to create the files that interact with NRPy's C parameter interface. (This is for the newer version of the A2B routine, as we replace the old with it in this unit test.)

# %%
# Step 3.d.i: Generate declare_Cparameters_struct.h, set_Cparameters_default.h, and set_Cparameters[-SIMD].h
par.generate_Cparameters_Ccodes(os.path.join(out_dir))

# Step 3.d.ii: Set free_parameters.h
with open(os.path.join(out_dir,"free_parameters.h"),"w") as file:
    file.write("""
// Override parameter defaults with values based on command line arguments and NGHOSTS.
// We'll use this grid. It has one point and one ghost zone.
params.Nxx0 = atoi(argv[1]);
params.Nxx1 = atoi(argv[2]);
params.Nxx2 = atoi(argv[3]);
params.Nxx_plus_2NGHOSTS0 = params.Nxx0 + 2*NGHOSTS;
params.Nxx_plus_2NGHOSTS1 = params.Nxx1 + 2*NGHOSTS;
params.Nxx_plus_2NGHOSTS2 = params.Nxx2 + 2*NGHOSTS;
// Step 0d: Set up space and time coordinates
// Step 0d.i: Declare \Delta x^i=dxx{0,1,2} and invdxx{0,1,2}, as well as xxmin[3] and xxmax[3]:
const REAL xxmin[3] = {-0.01,-0.01,-0.01};
const REAL xxmax[3] = { 0.01, 0.01, 0.01};

params.dxx0 = (xxmax[0] - xxmin[0]) / ((REAL)params.Nxx0);
params.dxx1 = (xxmax[1] - xxmin[1]) / ((REAL)params.Nxx1);
params.dxx2 = (xxmax[2] - xxmin[2]) / ((REAL)params.Nxx2);
params.invdx0 = 1.0 / params.dxx0;
params.invdx1 = 1.0 / params.dxx1;
params.invdx2 = 1.0 / params.dxx2;
\n""")

# Generates declare_Cparameters_struct.h, set_Cparameters_default.h, and set_Cparameters[-SIMD].h
par.generate_Cparameters_Ccodes(os.path.join(out_dir))

# %% [markdown]
# Next, we'll let NRPy+ compute derivatives analytically according to $$B^i = \frac{[ijk]}{\sqrt{\gamma}} \partial_j A_k.$$ Then we can carry out two separate tests to verify the numerical derivatives. First, we will verify that when we let the cubic terms be zero, the two calculations of $B^i$ agree to roundoff error. Second, we will verify that when we set the cubic terms, our error is dominated by trunction error that converges to zero at the expected rate.

# %%
import WeylScal4NRPy.WeylScalars_Cartesian as weyl
LeviCivitaDDD = weyl.define_LeviCivitaSymbol_rank3()
LeviCivitaUUU = ixp.zerorank3()
for i in range(DIM):
    for j in range(DIM):
        for k in range(DIM):
            LeviCivitaUUU[i][j][k] = LeviCivitaDDD[i][j][k] / sp.sqrt(gammadet)
            
B_analyticU = ixp.register_gridfunctions_for_single_rank1("AUXEVOL","B_analyticU")
for i in range(DIM):
    B_analyticU[i] = 0
    for j in range(DIM):
        for k in range(DIM):
            B_analyticU[i] += LeviCivitaUUU[i][j][k] * sp.diff(AD[k],rfm.xxCart[j])

# %% [markdown]
# Now that we have our vector potential and analytic magnetic field to compare against, we will start writing our unit test. We'll also import common C functionality, define `REAL`, the number of ghost zones, and the faces, and set the standard macros for NRPy+ style memory access.

# %%
# %%writefile $out_dir/A2B_unit_test.C
# // These are common packages that we are likely to need.
# #include "stdio.h"
# #include "stdlib.h"
# #include "math.h"
# #include "string.h" // Needed for strncmp, etc.
# #include "stdint.h" // Needed for Windows GCC 6.x compatibility
# #include <time.h>   // Needed to set a random seed.
#
# #define REAL double
# #include "declare_Cparameters_struct.h"
#
# const int MAXFACE = -1;
# const int NUL     = +0;
# const int MINFACE = +1;
# const int NGHOSTS = 1;
#
# // Standard NRPy+ memory access:
# #define IDX4(g,i,j,k) \
# ( (i) + Nxx_plus_2NGHOSTS[0] * ( (j) + Nxx_plus_2NGHOSTS[1] * ( (k) + Nxx_plus_2NGHOSTS[2] * (g) ) ) )
# #define IDX3(i,j,k) ( (i) + Nxx_plus_2NGHOSTS[0] * ( (j) + Nxx_plus_2NGHOSTS[1] * (k) ) )
# // Assuming idx = IDX3(i,j,k). Much faster if idx can be reused over and over:
# #define IDX4pt(g,idx)   ( (idx) + (Nxx_plus_2NGHOSTS[0]*Nxx_plus_2NGHOSTS[1]*Nxx_plus_2NGHOSTS[2]) * (g) )
# #define IDX4S(g,i,j,k) \
# ( (i) + Nxx_plus_2NGHOSTS0 * ( (j) + Nxx_plus_2NGHOSTS1 * ( (k) + Nxx_plus_2NGHOSTS2 * (g) ) ) )
# Out:
# Overwriting Validation//A2B_unit_test.C

# %% [markdown]
# We'll now define the gridfunction names.

# %%
# %%writefile -a $out_dir/A2B_unit_test.C
# // Let's also #define the NRPy+ gridfunctions
# #define AD0GF 0
# #define AD1GF 1
# #define AD2GF 2
# #define NUM_EVOL_GFS 3
#
# #define GAMMADETGF 0
# #define B_ANALYTICU0GF 1
# #define B_ANALYTICU1GF 2
# #define B_ANALYTICU2GF 3
# #define BU0GF 4
# #define BU1GF 5
# #define BU2GF 6
# #define NUM_AUXEVOL_GFS 7
# Out:
# Appending to Validation//A2B_unit_test.C

# %% [markdown]
# Now, we'll handle the different A2B codes. There are several things to do here. First, we'll add `#include`s to the C code so that we have access to the functions we want to test. We must also create a directory and copy the files to that directory. We will choose to do this in the subfolder `A2B` relative to this tutorial.

# %%
# %%writefile $out_dir/A2B_unit_test.C
# #include "../A2B/driver_AtoB_new.c" // This file contains both functions we need.
#
# REAL a,b,c,d,e,f,g,h,l,m,n,o,p,q,r,s,t,u;
#
# void calculate_exact_BU(const int Nxx_plus_2NGHOSTS[3],REAL *xx[3],double *auxevol_gfs) {
#     for(int i2=0;i2<Nxx_plus_2NGHOSTS[2];i2++) for(int i1=0;i1<Nxx_plus_2NGHOSTS[1];i1++) for(int i0=0;i0<Nxx_plus_2NGHOSTS[0];i0++) {
# Out:
# Overwriting Validation//A2B_unit_test.C

# %% [markdown]
# We also should write a function that will use the analytic formulae for $B^i$. Then, we'll need to call the function from the module `GiRaFFE_HO_A2B` to generate the different header files. Also, we will declare the parameters for the vector potential functions.

# %%
B_analyticU_to_print = [\
                           lhrh(lhs=gri.gfaccess("out_gfs","B_analyticU0"),rhs=B_analyticU[0]),\
                           lhrh(lhs=gri.gfaccess("out_gfs","B_analyticU1"),rhs=B_analyticU[1]),\
                           lhrh(lhs=gri.gfaccess("out_gfs","B_analyticU2"),rhs=B_analyticU[2]),\
                          ]

desc = "Calculate the exact magnetic field"
name = "calculate_exact_BU"
B_analytic_Ccode = outCfunction(
    outfile  = "returnstring", desc=desc, name=name,
    params   ="const paramstruct *restrict params,REAL *restrict in_gfs,REAL *restrict out_gfs",
    preloop  ="""
        REAL xx0 = xx[0][i0];
        REAL xx1 = xx[1][i1];
        REAL xx2 = xx[2][i2];
""",
    body     = fin.FD_outputC("returnstring",B_analyticU_to_print,params="outCverbose=False").replace("IDX4","IDX4S"),
    loopopts="AllPoints")

with open(os.path.join(out_dir,"A2B_unit_test.C"),"w") as file:
    file.write(B_analytic_Ccode)

gri.glb_gridfcs_list = []
cmd.mkdir(os.path.join("A2B/"))
import GiRaFFE_NRPy.GiRaFFE_NRPy_A2B as A2B
# We'll generate these into the A2B subdirectory since that's where the functions
# we're testing expect them to be.
A2B.GiRaFFE_NRPy_A2B("A2B/")

# %% [markdown]
# We'll now write a function to set the vector potential $A_k$. This simply uses NRPy+ to generte most of the code from the expressions we wrote at the beginning.

# %%
AD_to_print = [\
               lhrh(lhs=gri.gfaccess("out_gfs","AD0"),rhs=AD[0]),\
               lhrh(lhs=gri.gfaccess("out_gfs","AD1"),rhs=AD[1]),\
               lhrh(lhs=gri.gfaccess("out_gfs","AD2"),rhs=AD[2]),\
              ]

desc = "Calculate the vector potential"
name = "calculate_AD"
A_Ccode = outCfunction(
    outfile  = "returnstring", desc=desc, name=name,
    params   ="const paramstruct *restrict params,REAL *restrict in_gfs,REAL *restrict out_gfs",
    preloop  ="""
        REAL xx0 = xx[0][i0];
        REAL xx1 = xx[1][i1];
        REAL xx2 = xx[2][i2];
""",
    body     = fin.FD_outputC("returnstring",AD_to_print,params="outCverbose=False").replace("IDX4","IDX4S"),
    loopopts="AllPoints")

with open(os.path.join(out_dir,"A2B_unit_test.C"),"w") as file:
    file.write(A_Ccode)

# %% [markdown]
# Now, we'll write the main method. First, we'll set up the grid. In this test, we cannot use only one point. As we are testing a three-point stencil, we can get away with a minimal $3 \times 3 \times 3$ grid. Then, we'll write the A fields. After that, we'll calculate the magnetic field two ways.

# %%
# %%writefile -a $out_dir/A2B_unit_test.C
# main(int argc, const char *argv[]) {
# #include "set_Cparameters_default.h"
#
#     // Let the first argument be the test we're doing. 1 = coarser grid, 0 = finer grid.
#     int do_quadratic_test = atoi(argv[4]);
#
#     // Step 0c: Set free parameters, overwriting Cparameters defaults
#     //          by hand or with command-line input, as desired.
# #include "free_parameters.h"
# #include "set_Cparameters-nopointer.h"
#
#     // We'll define our grid slightly different from how we normally would. We let our outermost
#     // ghostzones coincide with xxmin and xxmax instead of the interior of the grid. This means
#     // that the ghostzone points will have identical positions so we can do convergence tests of them.    // Step 0d.ii: Set up uniform coordinate grids
#     REAL *xx[3];
#     for(int i=0;i<3;i++) {
#         xx[i] = (REAL *)malloc(sizeof(REAL)*Nxx_plus_2NGHOSTS[i]);
#         for(int j=0;j<Nxx_plus_2NGHOSTS[i];j++) {
#             xx[i][j] = xxmin[i] + ((REAL)(j))*dxx[i]; // Face-centered grid.
#         }
#     }
#     //for(int i=0;i<Nxx_plus_2NGHOSTS[0];i++) printf("xx[0][%d] = %.15e\\n",i,xx[0][i]);
#
#     // This is the array to which we'll write the NRPy+ variables.
#     REAL *auxevol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_AUXEVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#     REAL *evol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_EVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#
#     for(int i2=0;i2<Nxx_plus_2NGHOSTS[2];i2++) for(int i1=0;i1<Nxx_plus_2NGHOSTS[1];i1++) for(int i0=0;i0<Nxx_plus_2NGHOSTS[0];i0++) {
#         //auxevol_gfs[IDX4(GAMMADETGF,i0,i1,i2)] = 1.0; // Flat Space
#         auxevol_gfs[IDX4(GAMMADETGF,i0,i1,i2)] = 1.0 - 1.0/(2.0+xx[0][i0]*xx[0][i0]+xx[1][i1]*xx[1][i1]+xx[2][i2]*xx[2][i2]);
#     }
#
#     // We now want to set up the vector potential. First, we must set the coefficients.
#     // We will use random integers between -10 and 10. For the first test, we let the
#     // Cubic coefficients remain zero. Those are a,b,c,g,h,l,p,q, and r.
#     d = (double)(rand()%20-10);
#     e = (double)(rand()%20-10);
#     f = (double)(rand()%20-10);
#     m = (double)(rand()%20-10);
#     n = (double)(rand()%20-10);
#     o = (double)(rand()%20-10);
#     s = (double)(rand()%20-10);
#     t = (double)(rand()%20-10);
#     u = (double)(rand()%20-10);
#
#     if(do_quadratic_test) {
#         calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#
#         // We'll also calculate the exact solution for B^i
#         calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#
#         // And now for the numerical derivatives:
#         driver_A_to_B(&params,evol_gfs,auxevol_gfs);
#
#         printf("This test uses quadratic vector potentials, so the magnetic fields should agree to roundoff error.\\n");
#         printf("Below, each row represents one point. Each column represents a component of the magnetic field.\\n");
#         printf("Shown is the number of Significant Digits of Agreement, at least 13 is good, higher is better:\\n\\n");
#         //Two variables for inside the loop:
#         int ghost_zone_overlap;int indices[3];
#         for(int i2=0;i2<Nxx_plus_2NGHOSTS[2];i2++) for(int i1=0;i1<Nxx_plus_2NGHOSTS[1];i1++) for(int i0=0;i0<Nxx_plus_2NGHOSTS[0];i0++) {
#             // Are we on an edge/vertex? This algorithm can probably be improved.
#             ghost_zone_overlap = 0;
#             indices[0] = i0;
#             indices[1] = i1;
#             indices[2] = i2;
#             for(int dim=0;dim<3;dim++) {
#                 if(indices[dim]%(Nxx[dim]+NGHOSTS)<NGHOSTS) {
#                     ghost_zone_overlap++;
#                 }
#             }
#             if (ghost_zone_overlap < 2) {
#                 // Don't print if we're on an edge or vertex
#                 printf("SDA: %.3f, %.3f, %.3f\\n",
#                        1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                        1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])+1.e-15)),
#                        1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])+1.e-15))
#                        );
#             }
#         }
#     }
#
#     // Now, we'll set the cubic coefficients:
#     a = (double)(rand()%20-10);
#     b = (double)(rand()%20-10);
#     c = (double)(rand()%20-10);
#     g = (double)(rand()%20-10);
#     h = (double)(rand()%20-10);
#     l = (double)(rand()%20-10);
#     p = (double)(rand()%20-10);
#     q = (double)(rand()%20-10);
#     r = (double)(rand()%20-10);
#
#     // And recalculate on our initial grid:
#     calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#
#     // We'll also calculate the exact solution for B^i
#     calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#
#     // And now for the numerical derivatives:
#     driver_A_to_B(&params,evol_gfs,auxevol_gfs);
#
#     // Some variables needed for the loop:
#     int ghost_zone_overlap; int indices[3];
#
#     char filename[100];
#     sprintf(filename,"out%d-numer.txt",Nxx[0]);
#     FILE *out2D = fopen(filename, "w");
#     if(do_quadratic_test) {
#         for(int i2=0;i2<Nxx_plus_2NGHOSTS[2];i2++) for(int i1=0;i1<Nxx_plus_2NGHOSTS[1];i1++) for(int i0=0;i0<Nxx_plus_2NGHOSTS[0];i0++) {
#             ghost_zone_overlap = 0;
#             indices[0] = i0;
#             indices[1] = i1;
#             indices[2] = i2;
#             for(int dim=0;dim<3;dim++) {
#                 if(indices[dim]%(Nxx[dim]+NGHOSTS)<NGHOSTS) {
#                     ghost_zone_overlap++;
#                 }
#             }
#             if (ghost_zone_overlap < 2) {
#                 // We print the difference between approximate and exact numbers.
#                 fprintf(out2D,"%.16e\t%.16e\t%.16e\\n",
#                         auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                         auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                         auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                         );
#             }
#         }
#     }
#     else {
#         for(int i2=0;i2<Nxx_plus_2NGHOSTS[2];i2++) for(int i1=0;i1<Nxx_plus_2NGHOSTS[1];i1++) for(int i0=0;i0<Nxx_plus_2NGHOSTS[0];i0++) {
#             ghost_zone_overlap = 0;
#             indices[0] = i0;
#             indices[1] = i1;
#             indices[2] = i2;
#             for(int dim=0;dim<3;dim++) {
#                 if(indices[dim]%(Nxx[dim]+NGHOSTS)<NGHOSTS) {
#                     ghost_zone_overlap++;
#                 }
#             }
#             // Don't print on the edges or corners
#             if (ghost_zone_overlap < 2) {
#                 // Only print points shared between the grids
#                 if (i0%2==0 && i1%2==0 && i2%2==0) {
#                     // We print the difference between approximate and exact numbers.
#                     fprintf(out2D,"%.16e\t%.16e\t%.16e\\n",
#                             auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                             auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                             auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                             );
#                 }
#             }
#         }
#
#     }
#     fclose(out2D);
# }
# Out:
# Appending to Validation//A2B_unit_test.C

# %% [markdown]
# Now that we have our file, we can compile it and run the executable.

# %%
import time

print("Now compiling, should take ~2 seconds...\n")
start = time.time()
cmd.C_compile(os.path.join(out_dir,"A2B_unit_test.C"), os.path.join(out_dir,"A2B_unit_test"))
end = time.time()
print("Finished in "+str(end-start)+" seconds.\n\n")

# os.chdir(out_dir)
print("Now running...\n")
start = time.time()
# cmd.Execute(os.path.join("Stilde_flux_unit_test"))
# !./Validation/A2B_unit_test 1 1 1 1
# To do a convergence test, we'll also need a second grid with twice the resolution.
# !./Validation/A2B_unit_test 3 3 3 0
end = time.time()
print("Finished in "+str(end-start)+" seconds.\n\n")
# os.chdir(os.path.join("../"))
# Out:
# Now compiling, should take ~2 seconds...
#
# Compiling executable...
# Executing `gcc -Ofast -fopenmp -march=native -funroll-loops Validation/A2B_unit_test.C -o Validation/A2B_unit_test -lm`...
# Validation/A2B_unit_test.C:4:25: error: ‘paramstruct’ does not name a type; did you mean ‘struct’?
#  void calculate_AD(const paramstruct *restrict params,REAL *restrict in_gfs,REAL *restrict out_gfs) {
#                          ^~~~~~~~~~~
#                          struct
# Validation/A2B_unit_test.C:4:47: error: expected ‘,’ or ‘...’ before ‘params’
#  void calculate_AD(const paramstruct *restrict params,REAL *restrict in_gfs,REAL *restrict out_gfs) {
#                                                ^~~~~~
# In file included from Validation/A2B_unit_test.C:5:0:
# Validation/set_Cparameters.h: In function ‘void calculate_AD(const int*)’:
# Validation/set_Cparameters.h:1:18: error: ‘params’ was not declared in this scope
#  const int Nxx0 = params->Nxx0;
#                   ^~~~~~
# Validation/set_Cparameters.h:7:7: error: ‘REAL’ does not name a type
#  const REAL dxx0 = params->dxx0;
#        ^~~~
# Validation/set_Cparameters.h:8:7: error: ‘REAL’ does not name a type
#  const REAL dxx1 = params->dxx1;
#        ^~~~
# Validation/set_Cparameters.h:9:7: error: ‘REAL’ does not name a type
#  const REAL dxx2 = params->dxx2;
#        ^~~~
# Validation/set_Cparameters.h:10:7: error: ‘REAL’ does not name a type
#  const REAL invdx0 = params->invdx0;
#        ^~~~
# Validation/set_Cparameters.h:11:7: error: ‘REAL’ does not name a type
#  const REAL invdx1 = params->invdx1;
#        ^~~~
# Validation/set_Cparameters.h:12:7: error: ‘REAL’ does not name a type
#  const REAL invdx2 = params->invdx2;
#        ^~~~
# Validation/set_Cparameters.h:13:7: error: ‘REAL’ does not name a type
#  const REAL a = params->a;
#        ^~~~
# Validation/set_Cparameters.h:14:7: error: ‘REAL’ does not name a type
#  const REAL b = params->b;
#        ^~~~
# Validation/set_Cparameters.h:15:7: error: ‘REAL’ does not name a type
#  const REAL c = params->c;
#        ^~~~
# Validation/set_Cparameters.h:16:7: error: ‘REAL’ does not name a type
#  const REAL d = params->d;
#        ^~~~
# Validation/set_Cparameters.h:17:7: error: ‘REAL’ does not name a type
#  const REAL e = params->e;
#        ^~~~
# Validation/set_Cparameters.h:18:7: error: ‘REAL’ does not name a type
#  const REAL f = params->f;
#        ^~~~
# Validation/set_Cparameters.h:19:7: error: ‘REAL’ does not name a type
#  const REAL g = params->g;
#        ^~~~
# Validation/set_Cparameters.h:20:7: error: ‘REAL’ does not name a type
#  const REAL h = params->h;
#        ^~~~
# Validation/set_Cparameters.h:21:7: error: ‘REAL’ does not name a type
#  const REAL l = params->l;
#        ^~~~
# Validation/set_Cparameters.h:22:7: error: ‘REAL’ does not name a type
#  const REAL m = params->m;
#        ^~~~
# Validation/set_Cparameters.h:23:7: error: ‘REAL’ does not name a type
#  const REAL n = params->n;
#        ^~~~
# Validation/set_Cparameters.h:24:7: error: ‘REAL’ does not name a type
#  const REAL o = params->o;
#        ^~~~
# Validation/set_Cparameters.h:25:7: error: ‘REAL’ does not name a type
#  const REAL p = params->p;
#        ^~~~
# Validation/set_Cparameters.h:26:7: error: ‘REAL’ does not name a type
#  const REAL q = params->q;
#        ^~~~
# Validation/set_Cparameters.h:27:7: error: ‘REAL’ does not name a type
#  const REAL r = params->r;
#        ^~~~
# Validation/set_Cparameters.h:28:7: error: ‘REAL’ does not name a type
#  const REAL s = params->s;
#        ^~~~
# Validation/set_Cparameters.h:29:7: error: ‘REAL’ does not name a type
#  const REAL t = params->t;
#        ^~~~
# Validation/set_Cparameters.h:30:7: error: ‘REAL’ does not name a type
#  const REAL u = params->u;
#        ^~~~
# Validation/set_Cparameters.h:31:7: error: ‘REAL’ does not name a type
#  const REAL xmin = params->xmin;
#        ^~~~
# Validation/set_Cparameters.h:32:7: error: ‘REAL’ does not name a type
#  const REAL xmax = params->xmax;
#        ^~~~
# Validation/set_Cparameters.h:33:7: error: ‘REAL’ does not name a type
#  const REAL ymin = params->ymin;
#        ^~~~
# Validation/set_Cparameters.h:34:7: error: ‘REAL’ does not name a type
#  const REAL ymax = params->ymax;
#        ^~~~
# Validation/set_Cparameters.h:35:7: error: ‘REAL’ does not name a type
#  const REAL zmin = params->zmin;
#        ^~~~
# Validation/set_Cparameters.h:36:7: error: ‘REAL’ does not name a type
#  const REAL zmax = params->zmax;
#        ^~~~
# Validation/A2B_unit_test.C:7:9: error: ‘REAL’ was not declared in this scope
#          REAL xx0 = xx[0][i0];
#          ^~~~
# Validation/A2B_unit_test.C:8:14: error: expected ‘;’ before ‘xx1’
#          REAL xx1 = xx[1][i1];
#               ^~~
# Validation/A2B_unit_test.C:9:14: error: expected ‘;’ before ‘xx2’
#          REAL xx2 = xx[2][i2];
#               ^~~
# Validation/A2B_unit_test.C:20:42: error: ‘xx0’ was not declared in this scope
#                     const double tmp0 = ((xx0)*(xx0)*(xx0));
#                                           ^~~
# Validation/A2B_unit_test.C:20:42: note: suggested alternative: ‘Nxx0’
#                     const double tmp0 = ((xx0)*(xx0)*(xx0));
#                                           ^~~
#                                           Nxx0
# Validation/A2B_unit_test.C:21:42: error: ‘xx1’ was not declared in this scope
#                     const double tmp1 = ((xx1)*(xx1)*(xx1));
#                                           ^~~
# Validation/A2B_unit_test.C:21:42: note: suggested alternative: ‘Nxx1’
#                     const double tmp1 = ((xx1)*(xx1)*(xx1));
#                                           ^~~
#                                           Nxx1
# Validation/A2B_unit_test.C:22:42: error: ‘xx2’ was not declared in this scope
#                     const double tmp2 = ((xx2)*(xx2)*(xx2));
#                                           ^~~
# Validation/A2B_unit_test.C:22:42: note: suggested alternative: ‘Nxx2’
#                     const double tmp2 = ((xx2)*(xx2)*(xx2));
#                                           ^~~
#                                           Nxx2
# Validation/A2B_unit_test.C:26:20: error: ‘out_gfs’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                     ^~~~~~~
# Validation/A2B_unit_test.C:26:34: error: ‘AD0GF’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                   ^~~~~
# Validation/A2B_unit_test.C:26:28: error: ‘IDX4S’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                             ^~~~~
# Validation/A2B_unit_test.C:26:56: error: ‘a’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                         ^
# Validation/A2B_unit_test.C:26:65: error: ‘b’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                  ^
# Validation/A2B_unit_test.C:26:74: error: ‘c’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                           ^
# Validation/A2B_unit_test.C:26:83: error: ‘d’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                                    ^
# Validation/A2B_unit_test.C:26:92: error: ‘e’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                                             ^
# Validation/A2B_unit_test.C:26:101: error: ‘f’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                                                      ^
# Validation/A2B_unit_test.C:27:34: error: ‘AD1GF’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                   ^~~~~
# Validation/A2B_unit_test.C:27:56: error: ‘g’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                         ^
# Validation/A2B_unit_test.C:27:65: error: ‘h’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                  ^
# Validation/A2B_unit_test.C:27:74: error: ‘l’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                           ^
# Validation/A2B_unit_test.C:27:83: error: ‘m’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                                    ^
# Validation/A2B_unit_test.C:27:92: error: ‘n’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                                             ^
# Validation/A2B_unit_test.C:27:101: error: ‘o’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                                                      ^
# Validation/A2B_unit_test.C:28:34: error: ‘AD2GF’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                   ^~~~~
# Validation/A2B_unit_test.C:28:56: error: ‘p’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                         ^
# Validation/A2B_unit_test.C:28:65: error: ‘q’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                  ^
# Validation/A2B_unit_test.C:28:74: error: ‘r’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                           ^
# Validation/A2B_unit_test.C:28:83: error: ‘s’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                                    ^
# Validation/A2B_unit_test.C:28:92: error: ‘t’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                                             ^
# Validation/A2B_unit_test.C:28:101: error: ‘u’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                                                      ^
# Validation/A2B_unit_test.C:12:5: error: invalid controlling predicate
#      for(int i2=0; i2<Nxx_plus_2NGHOSTS2; i2++) {
#      ^~~
# In file included from Validation/A2B_unit_test.C:37:0:
# Validation/set_Cparameters_default.h: In function ‘int main(int, const char**)’:
# Validation/set_Cparameters_default.h:1:1: error: ‘params’ was not declared in this scope
#  params.Nxx0 = 64;
#  ^~~~~~
# Validation/A2B_unit_test.C:40:29: error: ‘atoi’ was not declared in this scope
#      int do_quadratic_test = atoi(argv[4]);
#                              ^~~~
# Validation/A2B_unit_test.C:40:29: note: suggested alternative: ‘auto’
#      int do_quadratic_test = atoi(argv[4]);
#                              ^~~~
#                              auto
# In file included from Validation/A2B_unit_test.C:44:0:
# Validation/free_parameters.h:7:45: error: ‘NGHOSTS’ was not declared in this scope
#  params.Nxx_plus_2NGHOSTS0 = params.Nxx0 + 2*NGHOSTS;
#                                              ^~~~~~~
# Validation/free_parameters.h:12:7: error: ‘REAL’ does not name a type
#  const REAL xxmin[3] = {-0.01,-0.01,-0.01};
#        ^~~~
# Validation/free_parameters.h:13:7: error: ‘REAL’ does not name a type
#  const REAL xxmax[3] = { 0.01, 0.01, 0.01};
#        ^~~~
# Validation/free_parameters.h:15:16: error: ‘xxmax’ was not declared in this scope
#  params.dxx0 = (xxmax[0] - xxmin[0]) / ((REAL)params.Nxx0);
#                 ^~~~~
# Validation/free_parameters.h:15:27: error: ‘xxmin’ was not declared in this scope
#  params.dxx0 = (xxmax[0] - xxmin[0]) / ((REAL)params.Nxx0);
#                            ^~~~~
# Validation/free_parameters.h:15:41: error: ‘REAL’ was not declared in this scope
#  params.dxx0 = (xxmax[0] - xxmin[0]) / ((REAL)params.Nxx0);
#                                          ^~~~
# Validation/free_parameters.h:15:46: error: expected ‘)’ before ‘params’
#  params.dxx0 = (xxmax[0] - xxmin[0]) / ((REAL)params.Nxx0);
#                                               ^~~~~~
# Validation/free_parameters.h:16:46: error: expected ‘)’ before ‘params’
#  params.dxx1 = (xxmax[1] - xxmin[1]) / ((REAL)params.Nxx1);
#                                               ^~~~~~
# Validation/free_parameters.h:17:46: error: expected ‘)’ before ‘params’
#  params.dxx2 = (xxmax[2] - xxmin[2]) / ((REAL)params.Nxx2);
#                                               ^~~~~~
# In file included from Validation/A2B_unit_test.C:45:0:
# Validation/set_Cparameters-nopointer.h:7:7: error: ‘REAL’ does not name a type
#  const REAL dxx0 = params.dxx0;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:8:7: error: ‘REAL’ does not name a type
#  const REAL dxx1 = params.dxx1;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:9:7: error: ‘REAL’ does not name a type
#  const REAL dxx2 = params.dxx2;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:10:7: error: ‘REAL’ does not name a type
#  const REAL invdx0 = params.invdx0;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:11:7: error: ‘REAL’ does not name a type
#  const REAL invdx1 = params.invdx1;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:12:7: error: ‘REAL’ does not name a type
#  const REAL invdx2 = params.invdx2;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:13:7: error: ‘REAL’ does not name a type
#  const REAL a = params.a;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:14:7: error: ‘REAL’ does not name a type
#  const REAL b = params.b;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:15:7: error: ‘REAL’ does not name a type
#  const REAL c = params.c;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:16:7: error: ‘REAL’ does not name a type
#  const REAL d = params.d;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:17:7: error: ‘REAL’ does not name a type
#  const REAL e = params.e;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:18:7: error: ‘REAL’ does not name a type
#  const REAL f = params.f;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:19:7: error: ‘REAL’ does not name a type
#  const REAL g = params.g;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:20:7: error: ‘REAL’ does not name a type
#  const REAL h = params.h;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:21:7: error: ‘REAL’ does not name a type
#  const REAL l = params.l;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:22:7: error: ‘REAL’ does not name a type
#  const REAL m = params.m;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:23:7: error: ‘REAL’ does not name a type
#  const REAL n = params.n;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:24:7: error: ‘REAL’ does not name a type
#  const REAL o = params.o;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:25:7: error: ‘REAL’ does not name a type
#  const REAL p = params.p;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:26:7: error: ‘REAL’ does not name a type
#  const REAL q = params.q;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:27:7: error: ‘REAL’ does not name a type
#  const REAL r = params.r;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:28:7: error: ‘REAL’ does not name a type
#  const REAL s = params.s;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:29:7: error: ‘REAL’ does not name a type
#  const REAL t = params.t;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:30:7: error: ‘REAL’ does not name a type
#  const REAL u = params.u;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:31:7: error: ‘REAL’ does not name a type
#  const REAL xmin = params.xmin;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:32:7: error: ‘REAL’ does not name a type
#  const REAL xmax = params.xmax;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:33:7: error: ‘REAL’ does not name a type
#  const REAL ymin = params.ymin;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:34:7: error: ‘REAL’ does not name a type
#  const REAL ymax = params.ymax;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:35:7: error: ‘REAL’ does not name a type
#  const REAL zmin = params.zmin;
#        ^~~~
# Validation/set_Cparameters-nopointer.h:36:7: error: ‘REAL’ does not name a type
#  const REAL zmax = params.zmax;
#        ^~~~
# Validation/A2B_unit_test.C:50:11: error: ‘xx’ was not declared in this scope
#      REAL *xx[3];
#            ^~
# Validation/A2B_unit_test.C:50:11: note: suggested alternative: ‘Nxx2’
#      REAL *xx[3];
#            ^~
#            Nxx2
# Validation/A2B_unit_test.C:52:24: error: expected primary-expression before ‘)’ token
#          xx[i] = (REAL *)malloc(sizeof(REAL)*Nxx_plus_2NGHOSTS[i]);
#                         ^
# Validation/A2B_unit_test.C:53:23: error: ‘Nxx_plus_2NGHOSTS’ was not declared in this scope
#          for(int j=0;j<Nxx_plus_2NGHOSTS[i];j++) {
#                        ^~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:53:23: note: suggested alternative: ‘Nxx_plus_2NGHOSTS2’
#          for(int j=0;j<Nxx_plus_2NGHOSTS[i];j++) {
#                        ^~~~~~~~~~~~~~~~~
#                        Nxx_plus_2NGHOSTS2
# Validation/A2B_unit_test.C:54:47: error: ‘dxx’ was not declared in this scope
#              xx[i][j] = xxmin[i] + ((REAL)(j))*dxx[i]; // Face-centered grid.
#                                                ^~~
# Validation/A2B_unit_test.C:54:47: note: suggested alternative: ‘Nxx2’
#              xx[i][j] = xxmin[i] + ((REAL)(j))*dxx[i]; // Face-centered grid.
#                                                ^~~
#                                                Nxx2
# Validation/A2B_unit_test.C:60:11: error: ‘auxevol_gfs’ was not declared in this scope
#      REAL *auxevol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_AUXEVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#            ^~~~~~~~~~~
# Validation/A2B_unit_test.C:60:33: error: expected primary-expression before ‘)’ token
#      REAL *auxevol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_AUXEVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#                                  ^
# Validation/A2B_unit_test.C:61:11: error: ‘evol_gfs’ was not declared in this scope
#      REAL *evol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_EVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#            ^~~~~~~~
# Validation/A2B_unit_test.C:61:30: error: expected primary-expression before ‘)’ token
#      REAL *evol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_EVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#                               ^
# Validation/A2B_unit_test.C:63:21: error: ‘Nxx_plus_2NGHOSTS’ was not declared in this scope
#      for(int i2=0;i2<Nxx_plus_2NGHOSTS[2];i2++) for(int i1=0;i1<Nxx_plus_2NGHOSTS[1];i1++) for(int i0=0;i0<Nxx_plus_2NGHOSTS[0];i0++) {
#                      ^~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:63:21: note: suggested alternative: ‘Nxx_plus_2NGHOSTS2’
#      for(int i2=0;i2<Nxx_plus_2NGHOSTS[2];i2++) for(int i1=0;i1<Nxx_plus_2NGHOSTS[1];i1++) for(int i0=0;i0<Nxx_plus_2NGHOSTS[0];i0++) {
#                      ^~~~~~~~~~~~~~~~~
#                      Nxx_plus_2NGHOSTS2
# Validation/A2B_unit_test.C:65:26: error: ‘GAMMADETGF’ was not declared in this scope
#          auxevol_gfs[IDX4(GAMMADETGF,i0,i1,i2)] = 1.0 - 1.0/(2.0+xx[0][i0]*xx[0][i0]+xx[1][i1]*xx[1][i1]+xx[2][i2]*xx[2][i2]);
#                           ^~~~~~~~~~
# Validation/A2B_unit_test.C:65:21: error: ‘IDX4’ was not declared in this scope
#          auxevol_gfs[IDX4(GAMMADETGF,i0,i1,i2)] = 1.0 - 1.0/(2.0+xx[0][i0]*xx[0][i0]+xx[1][i1]*xx[1][i1]+xx[2][i2]*xx[2][i2]);
#                      ^~~~
# Validation/A2B_unit_test.C:71:5: error: ‘d’ was not declared in this scope
#      d = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:71:18: error: ‘rand’ was not declared in this scope
#      d = (double)(rand()%20-10);
#                   ^~~~
# Validation/A2B_unit_test.C:72:5: error: ‘e’ was not declared in this scope
#      e = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:73:5: error: ‘f’ was not declared in this scope
#      f = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:74:5: error: ‘m’ was not declared in this scope
#      m = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:75:5: error: ‘n’ was not declared in this scope
#      n = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:76:5: error: ‘o’ was not declared in this scope
#      o = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:77:5: error: ‘s’ was not declared in this scope
#      s = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:78:5: error: ‘t’ was not declared in this scope
#      t = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:79:5: error: ‘u’ was not declared in this scope
#      u = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:82:22: error: ‘Nxx_plus_2NGHOSTS’ was not declared in this scope
#          calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#                       ^~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:82:22: note: suggested alternative: ‘Nxx_plus_2NGHOSTS2’
#          calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#                       ^~~~~~~~~~~~~~~~~
#                       Nxx_plus_2NGHOSTS2
# Validation/A2B_unit_test.C:85:9: error: ‘calculate_exact_BU’ was not declared in this scope
#          calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#          ^~~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:85:9: note: suggested alternative: ‘calculate_AD’
#          calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#          ^~~~~~~~~~~~~~~~~~
#          calculate_AD
# Validation/A2B_unit_test.C:88:9: error: ‘driver_A_to_B’ was not declared in this scope
#          driver_A_to_B(&params,evol_gfs,auxevol_gfs);
#          ^~~~~~~~~~~~~
# Validation/A2B_unit_test.C:90:9: error: ‘printf’ was not declared in this scope
#          printf("This test uses quadratic vector potentials, so the magnetic fields should agree to roundoff error.\\n");
#          ^~~~~~
# Validation/A2B_unit_test.C:90:9: note: suggested alternative: ‘int’
#          printf("This test uses quadratic vector potentials, so the magnetic fields should agree to roundoff error.\\n");
#          ^~~~~~
#          int
# Validation/A2B_unit_test.C:102:34: error: ‘Nxx’ was not declared in this scope
#                  if(indices[dim]%(Nxx[dim]+NGHOSTS)<NGHOSTS) {
#                                   ^~~
# Validation/A2B_unit_test.C:102:34: note: suggested alternative: ‘Nxx2’
#                  if(indices[dim]%(Nxx[dim]+NGHOSTS)<NGHOSTS) {
#                                   ^~~
#                                   Nxx2
# Validation/A2B_unit_test.C:109:60: error: ‘B_ANALYTICU0GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                                                             ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:109:55: error: ‘IDX4’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                                                        ^~~~
# Validation/A2B_unit_test.C:109:103: error: ‘BU0GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                                                                                                        ^~~~~
# Validation/A2B_unit_test.C:109:38: error: ‘fabs’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                                       ^~~~
# Validation/A2B_unit_test.C:109:28: error: ‘log10’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                             ^~~~~
# Validation/A2B_unit_test.C:110:60: error: ‘B_ANALYTICU1GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])+1.e-15)),
#                                                             ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:110:103: error: ‘BU1GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])+1.e-15)),
#                                                                                                        ^~~~~
# Validation/A2B_unit_test.C:111:60: error: ‘B_ANALYTICU2GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])+1.e-15))
#                                                             ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:111:103: error: ‘BU2GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])+1.e-15))
#                                                                                                        ^~~~~
# Validation/A2B_unit_test.C:118:5: error: ‘a’ was not declared in this scope
#      a = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:119:5: error: ‘b’ was not declared in this scope
#      b = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:120:5: error: ‘c’ was not declared in this scope
#      c = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:121:5: error: ‘g’ was not declared in this scope
#      g = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:122:5: error: ‘h’ was not declared in this scope
#      h = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:123:5: error: ‘l’ was not declared in this scope
#      l = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:124:5: error: ‘p’ was not declared in this scope
#      p = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:125:5: error: ‘q’ was not declared in this scope
#      q = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:126:5: error: ‘r’ was not declared in this scope
#      r = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:129:18: error: ‘Nxx_plus_2NGHOSTS’ was not declared in this scope
#      calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#                   ^~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:129:18: note: suggested alternative: ‘Nxx_plus_2NGHOSTS2’
#      calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#                   ^~~~~~~~~~~~~~~~~
#                   Nxx_plus_2NGHOSTS2
# Validation/A2B_unit_test.C:132:5: error: ‘calculate_exact_BU’ was not declared in this scope
#      calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#      ^~~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:132:5: note: suggested alternative: ‘calculate_AD’
#      calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#      ^~~~~~~~~~~~~~~~~~
#      calculate_AD
# Validation/A2B_unit_test.C:135:5: error: ‘driver_A_to_B’ was not declared in this scope
#      driver_A_to_B(&params,evol_gfs,auxevol_gfs);
#      ^~~~~~~~~~~~~
# Validation/A2B_unit_test.C:141:40: error: ‘Nxx’ was not declared in this scope
#      sprintf(filename,"out%d-numer.txt",Nxx[0]);
#                                         ^~~
# Validation/A2B_unit_test.C:141:40: note: suggested alternative: ‘Nxx2’
#      sprintf(filename,"out%d-numer.txt",Nxx[0]);
#                                         ^~~
#                                         Nxx2
# Validation/A2B_unit_test.C:141:5: error: ‘sprintf’ was not declared in this scope
#      sprintf(filename,"out%d-numer.txt",Nxx[0]);
#      ^~~~~~~
# Validation/A2B_unit_test.C:142:5: error: ‘FILE’ was not declared in this scope
#      FILE *out2D = fopen(filename, "w");
#      ^~~~
# Validation/A2B_unit_test.C:142:11: error: ‘out2D’ was not declared in this scope
#      FILE *out2D = fopen(filename, "w");
#            ^~~~~
# Validation/A2B_unit_test.C:142:19: error: ‘fopen’ was not declared in this scope
#      FILE *out2D = fopen(filename, "w");
#                    ^~~~~
# Validation/A2B_unit_test.C:157:42: error: ‘B_ANALYTICU0GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                           ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:157:37: error: ‘IDX4’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                      ^~~~
# Validation/A2B_unit_test.C:157:85: error: ‘BU0GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                                                                      ^~~~~
# Validation/A2B_unit_test.C:158:42: error: ‘B_ANALYTICU1GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                                           ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:158:85: error: ‘BU1GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                                                                                      ^~~~~
# Validation/A2B_unit_test.C:159:42: error: ‘B_ANALYTICU2GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                                           ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:159:85: error: ‘BU2GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                                                                                      ^~~~~
# Validation/A2B_unit_test.C:156:17: error: ‘fprintf’ was not declared in this scope
#                  fprintf(out2D,"%.16e\t%.16e\t%.16e\\n",
#                  ^~~~~~~
# Validation/A2B_unit_test.C:181:46: error: ‘B_ANALYTICU0GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                               ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:181:41: error: ‘IDX4’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                          ^~~~
# Validation/A2B_unit_test.C:181:89: error: ‘BU0GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                                                                          ^~~~~
# Validation/A2B_unit_test.C:182:46: error: ‘B_ANALYTICU1GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                                               ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:182:89: error: ‘BU1GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                                                                                          ^~~~~
# Validation/A2B_unit_test.C:183:46: error: ‘B_ANALYTICU2GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                                               ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:183:89: error: ‘BU2GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                                                                                          ^~~~~
# Validation/A2B_unit_test.C:180:21: error: ‘fprintf’ was not declared in this scope
#                      fprintf(out2D,"%.16e\t%.16e\t%.16e\\n",
#                      ^~~~~~~
# Validation/A2B_unit_test.C:190:5: error: ‘fclose’ was not declared in this scope
#      fclose(out2D);
#      ^~~~~~
# Validation/A2B_unit_test.C:190:5: note: suggested alternative: ‘class’
#      fclose(out2D);
#      ^~~~~~
#      class
# Finished executing in 0.2149806022644043 seconds.
# Most optimized compilation failed. Removing -march=native:
# Executing `gcc -Ofast -fopenmp -funroll-loops Validation/A2B_unit_test.C -o Validation/A2B_unit_test -lm`...
# Validation/A2B_unit_test.C:4:25: error: ‘paramstruct’ does not name a type; did you mean ‘struct’?
#  void calculate_AD(const paramstruct *restrict params,REAL *restrict in_gfs,REAL *restrict out_gfs) {
#                          ^~~~~~~~~~~
#                          struct
# Validation/A2B_unit_test.C:4:47: error: expected ‘,’ or ‘...’ before ‘params’
#  void calculate_AD(const paramstruct *restrict params,REAL *restrict in_gfs,REAL *restrict out_gfs) {
#                                                ^~~~~~
# In file included from Validation/A2B_unit_test.C:5:0:
# Validation/set_Cparameters.h: In function ‘void calculate_AD(const int*)’:
# Validation/set_Cparameters.h:1:18: error: ‘params’ was not declared in this scope
#  const int Nxx0 = params->Nxx0;
#                   ^~~~~~
# Validation/set_Cparameters.h:7:7: error: ‘REAL’ does not name a type
#  const REAL dxx0 = params->dxx0;
#        ^~~~
# Validation/set_Cparameters.h:8:7: error: ‘REAL’ does not name a type
#  const REAL dxx1 = params->dxx1;
#        ^~~~
# Validation/set_Cparameters.h:9:7: error: ‘REAL’ does not name a type
#  const REAL dxx2 = params->dxx2;
#        ^~~~
# Validation/set_Cparameters.h:10:7: error: ‘REAL’ does not name a type
#  const REAL invdx0 = params->invdx0;
#        ^~~~
# Validation/set_Cparameters.h:11:7: error: ‘REAL’ does not name a type
#  const REAL invdx1 = params->invdx1;
#        ^~~~
# Validation/set_Cparameters.h:12:7: error: ‘REAL’ does not name a type
#  const REAL invdx2 = params->invdx2;
#        ^~~~
# Validation/set_Cparameters.h:13:7: error: ‘REAL’ does not name a type
#  const REAL a = params->a;
#        ^~~~
# Validation/set_Cparameters.h:14:7: error: ‘REAL’ does not name a type
#  const REAL b = params->b;
#        ^~~~
# Validation/set_Cparameters.h:15:7: error: ‘REAL’ does not name a type
#  const REAL c = params->c;
#        ^~~~
# Validation/set_Cparameters.h:16:7: error: ‘REAL’ does not name a type
#  const REAL d = params->d;
#        ^~~~
# Validation/set_Cparameters.h:17:7: error: ‘REAL’ does not name a type
#  const REAL e = params->e;
#        ^~~~
# Validation/set_Cparameters.h:18:7: error: ‘REAL’ does not name a type
#  const REAL f = params->f;
#        ^~~~
# Validation/set_Cparameters.h:19:7: error: ‘REAL’ does not name a type
#  const REAL g = params->g;
#        ^~~~
# Validation/set_Cparameters.h:20:7: error: ‘REAL’ does not name a type
#  const REAL h = params->h;
#        ^~~~
# Validation/set_Cparameters.h:21:7: error: ‘REAL’ does not name a type
#  const REAL l = params->l;
#        ^~~~
# Validation/set_Cparameters.h:22:7: error: ‘REAL’ does not name a type
#  const REAL m = params->m;
#        ^~~~
# Validation/set_Cparameters.h:23:7: error: ‘REAL’ does not name a type
#  const REAL n = params->n;
#        ^~~~
# Validation/set_Cparameters.h:24:7: error: ‘REAL’ does not name a type
#  const REAL o = params->o;
#        ^~~~
# Validation/set_Cparameters.h:25:7: error: ‘REAL’ does not name a type
#  const REAL p = params->p;
#        ^~~~
# Validation/set_Cparameters.h:26:7: error: ‘REAL’ does not name a type
#  const REAL q = params->q;
#        ^~~~
# Validation/set_Cparameters.h:27:7: error: ‘REAL’ does not name a type
#  const REAL r = params->r;
#        ^~~~
# Validation/set_Cparameters.h:28:7: error: ‘REAL’ does not name a type
#  const REAL s = params->s;
#        ^~~~
# Validation/set_Cparameters.h:29:7: error: ‘REAL’ does not name a type
#  const REAL t = params->t;
#        ^~~~
# Validation/set_Cparameters.h:30:7: error: ‘REAL’ does not name a type
#  const REAL u = params->u;
#        ^~~~
# Validation/set_Cparameters.h:31:7: error: ‘REAL’ does not name a type
#  const REAL xmin = params->xmin;
#        ^~~~
# Validation/set_Cparameters.h:32:7: error: ‘REAL’ does not name a type
#  const REAL xmax = params->xmax;
#        ^~~~
# Validation/set_Cparameters.h:33:7: error: ‘REAL’ does not name a type
#  const REAL ymin = params->ymin;
#        ^~~~
# Validation/set_Cparameters.h:34:7: error: ‘REAL’ does not name a type
#  const REAL ymax = params->ymax;
#        ^~~~
# Validation/set_Cparameters.h:35:7: error: ‘REAL’ does not name a type
#  const REAL zmin = params->zmin;
#        ^~~~
# Validation/set_Cparameters.h:36:7: error: ‘REAL’ does not name a type
#  const REAL zmax = params->zmax;
#        ^~~~
# Validation/A2B_unit_test.C:7:9: error: ‘REAL’ was not declared in this scope
#          REAL xx0 = xx[0][i0];
#          ^~~~
# Validation/A2B_unit_test.C:8:14: error: expected ‘;’ before ‘xx1’
#          REAL xx1 = xx[1][i1];
#               ^~~
# Validation/A2B_unit_test.C:9:14: error: expected ‘;’ before ‘xx2’
#          REAL xx2 = xx[2][i2];
#               ^~~
# Validation/A2B_unit_test.C:20:42: error: ‘xx0’ was not declared in this scope
#                     const double tmp0 = ((xx0)*(xx0)*(xx0));
#                                           ^~~
# Validation/A2B_unit_test.C:20:42: note: suggested alternative: ‘Nxx0’
#                     const double tmp0 = ((xx0)*(xx0)*(xx0));
#                                           ^~~
#                                           Nxx0
# Validation/A2B_unit_test.C:21:42: error: ‘xx1’ was not declared in this scope
#                     const double tmp1 = ((xx1)*(xx1)*(xx1));
#                                           ^~~
# Validation/A2B_unit_test.C:21:42: note: suggested alternative: ‘Nxx1’
#                     const double tmp1 = ((xx1)*(xx1)*(xx1));
#                                           ^~~
#                                           Nxx1
# Validation/A2B_unit_test.C:22:42: error: ‘xx2’ was not declared in this scope
#                     const double tmp2 = ((xx2)*(xx2)*(xx2));
#                                           ^~~
# Validation/A2B_unit_test.C:22:42: note: suggested alternative: ‘Nxx2’
#                     const double tmp2 = ((xx2)*(xx2)*(xx2));
#                                           ^~~
#                                           Nxx2
# Validation/A2B_unit_test.C:26:20: error: ‘out_gfs’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                     ^~~~~~~
# Validation/A2B_unit_test.C:26:34: error: ‘AD0GF’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                   ^~~~~
# Validation/A2B_unit_test.C:26:28: error: ‘IDX4S’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                             ^~~~~
# Validation/A2B_unit_test.C:26:56: error: ‘a’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                         ^
# Validation/A2B_unit_test.C:26:65: error: ‘b’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                  ^
# Validation/A2B_unit_test.C:26:74: error: ‘c’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                           ^
# Validation/A2B_unit_test.C:26:83: error: ‘d’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                                    ^
# Validation/A2B_unit_test.C:26:92: error: ‘e’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                                             ^
# Validation/A2B_unit_test.C:26:101: error: ‘f’ was not declared in this scope
#                     out_gfs[IDX4S(AD0GF, i0, i1, i2)] = a*tmp0 + b*tmp1 + c*tmp2 + d*tmp3 + e*tmp4 + f;
#                                                                                                      ^
# Validation/A2B_unit_test.C:27:34: error: ‘AD1GF’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                   ^~~~~
# Validation/A2B_unit_test.C:27:56: error: ‘g’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                         ^
# Validation/A2B_unit_test.C:27:65: error: ‘h’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                  ^
# Validation/A2B_unit_test.C:27:74: error: ‘l’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                           ^
# Validation/A2B_unit_test.C:27:83: error: ‘m’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                                    ^
# Validation/A2B_unit_test.C:27:92: error: ‘n’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                                             ^
# Validation/A2B_unit_test.C:27:101: error: ‘o’ was not declared in this scope
#                     out_gfs[IDX4S(AD1GF, i0, i1, i2)] = g*tmp0 + h*tmp1 + l*tmp2 + m*tmp5 + n*tmp4 + o;
#                                                                                                      ^
# Validation/A2B_unit_test.C:28:34: error: ‘AD2GF’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                   ^~~~~
# Validation/A2B_unit_test.C:28:56: error: ‘p’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                         ^
# Validation/A2B_unit_test.C:28:65: error: ‘q’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                  ^
# Validation/A2B_unit_test.C:28:74: error: ‘r’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                           ^
# Validation/A2B_unit_test.C:28:83: error: ‘s’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                                    ^
# Validation/A2B_unit_test.C:28:92: error: ‘t’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                                             ^
# Validation/A2B_unit_test.C:28:101: error: ‘u’ was not declared in this scope
#                     out_gfs[IDX4S(AD2GF, i0, i1, i2)] = p*tmp0 + q*tmp1 + r*tmp2 + s*tmp5 + t*tmp3 + u;
#                                                                                                      ^
# Validation/A2B_unit_test.C:12:5: error: invalid controlling predicate
#      for(int i2=0; i2<Nxx_plus_2NGHOSTS2; i2++) {
#      ^~~
# In file included from Validation/A2B_unit_test.C:37:0:
# Validation/set_Cparameters_default.h: In function ‘int main(int, const char**)’:
# Validation/set_Cparameters_default.h:1:1: error: ‘params’ was not declared in this scope
#  params.Nxx0 = 64;
#  ^~~~~~
# Validation/A2B_unit_test.C:40:29: error: ‘atoi’ was not declared in this scope
#      int do_quadratic_test = atoi(argv[4]);
#                              ^~~~
# Validation/A2B_unit_test.C:40:29: note: suggested alternative: ‘auto’
#      int do_quadratic_test = atoi(argv[4]);
#                              ^~~~
#                              auto
# In file included from Validation/A2B_unit_test.C:44:0:
# Validation/free_parameters.h:7:45: error: ‘NGHOSTS’ was not declared in this scope
#  params.Nxx_plus_2NGHOSTS0 = params.Nxx0 + 2*NGHOSTS;
#                                              ^~~~~~~
# Validation/free_parameters.h:12:7: error: ‘REAL’ does not name a type
#  const REAL xxmin[3] = {-0.01,-0.01,-0.01};
#        ^~~~
# Validation/free_parameters.h:13:7: error: ‘REAL’ does not name a type
#  const REAL xxmax[3] = { 0.01, 0.01, 0.01};
#        ^~~~
# Validation/free_parameters.h:15:16: error: ‘xxmax’ was not declared in this scope
#  params.dxx0 = (xxmax[0] - xxmin[0]) / ((REAL)params.Nxx0);
#                 ^~~~~
# Validation/free_parameters.h:15:27: error: ‘xxmin’ was not declared in this scope
#  params.dxx0 = (xxmax[0] - xxmin[0]) / ((REAL)params.Nxx0);
#                            ^~~~~
# Validation/free_parameters.h:15:41: error: ‘REAL’ was not declared in this scope
#  params.dxx0 = (xxmax[0] - xxmin[0]) / ((REAL)params.Nxx0);
#                                          ^~~~
# Validation/free_parameters.h:15:46: error: expected ‘)’ before ‘params’
# ...
#                                                ^~~
#                                                Nxx2
# Validation/A2B_unit_test.C:60:11: error: ‘auxevol_gfs’ was not declared in this scope
#      REAL *auxevol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_AUXEVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#            ^~~~~~~~~~~
# Validation/A2B_unit_test.C:60:33: error: expected primary-expression before ‘)’ token
#      REAL *auxevol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_AUXEVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#                                  ^
# Validation/A2B_unit_test.C:61:11: error: ‘evol_gfs’ was not declared in this scope
#      REAL *evol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_EVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#            ^~~~~~~~
# Validation/A2B_unit_test.C:61:30: error: expected primary-expression before ‘)’ token
#      REAL *evol_gfs  = (REAL *)malloc(sizeof(REAL) * NUM_EVOL_GFS * Nxx_plus_2NGHOSTS[2] * Nxx_plus_2NGHOSTS[1] * Nxx_plus_2NGHOSTS[0]);
#                               ^
# Validation/A2B_unit_test.C:63:21: error: ‘Nxx_plus_2NGHOSTS’ was not declared in this scope
#      for(int i2=0;i2<Nxx_plus_2NGHOSTS[2];i2++) for(int i1=0;i1<Nxx_plus_2NGHOSTS[1];i1++) for(int i0=0;i0<Nxx_plus_2NGHOSTS[0];i0++) {
#                      ^~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:63:21: note: suggested alternative: ‘Nxx_plus_2NGHOSTS2’
#      for(int i2=0;i2<Nxx_plus_2NGHOSTS[2];i2++) for(int i1=0;i1<Nxx_plus_2NGHOSTS[1];i1++) for(int i0=0;i0<Nxx_plus_2NGHOSTS[0];i0++) {
#                      ^~~~~~~~~~~~~~~~~
#                      Nxx_plus_2NGHOSTS2
# Validation/A2B_unit_test.C:65:26: error: ‘GAMMADETGF’ was not declared in this scope
#          auxevol_gfs[IDX4(GAMMADETGF,i0,i1,i2)] = 1.0 - 1.0/(2.0+xx[0][i0]*xx[0][i0]+xx[1][i1]*xx[1][i1]+xx[2][i2]*xx[2][i2]);
#                           ^~~~~~~~~~
# Validation/A2B_unit_test.C:65:21: error: ‘IDX4’ was not declared in this scope
#          auxevol_gfs[IDX4(GAMMADETGF,i0,i1,i2)] = 1.0 - 1.0/(2.0+xx[0][i0]*xx[0][i0]+xx[1][i1]*xx[1][i1]+xx[2][i2]*xx[2][i2]);
#                      ^~~~
# Validation/A2B_unit_test.C:71:5: error: ‘d’ was not declared in this scope
#      d = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:71:18: error: ‘rand’ was not declared in this scope
#      d = (double)(rand()%20-10);
#                   ^~~~
# Validation/A2B_unit_test.C:72:5: error: ‘e’ was not declared in this scope
#      e = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:73:5: error: ‘f’ was not declared in this scope
#      f = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:74:5: error: ‘m’ was not declared in this scope
#      m = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:75:5: error: ‘n’ was not declared in this scope
#      n = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:76:5: error: ‘o’ was not declared in this scope
#      o = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:77:5: error: ‘s’ was not declared in this scope
#      s = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:78:5: error: ‘t’ was not declared in this scope
#      t = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:79:5: error: ‘u’ was not declared in this scope
#      u = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:82:22: error: ‘Nxx_plus_2NGHOSTS’ was not declared in this scope
#          calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#                       ^~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:82:22: note: suggested alternative: ‘Nxx_plus_2NGHOSTS2’
#          calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#                       ^~~~~~~~~~~~~~~~~
#                       Nxx_plus_2NGHOSTS2
# Validation/A2B_unit_test.C:85:9: error: ‘calculate_exact_BU’ was not declared in this scope
#          calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#          ^~~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:85:9: note: suggested alternative: ‘calculate_AD’
#          calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#          ^~~~~~~~~~~~~~~~~~
#          calculate_AD
# Validation/A2B_unit_test.C:88:9: error: ‘driver_A_to_B’ was not declared in this scope
#          driver_A_to_B(&params,evol_gfs,auxevol_gfs);
#          ^~~~~~~~~~~~~
# Validation/A2B_unit_test.C:90:9: error: ‘printf’ was not declared in this scope
#          printf("This test uses quadratic vector potentials, so the magnetic fields should agree to roundoff error.\\n");
#          ^~~~~~
# Validation/A2B_unit_test.C:90:9: note: suggested alternative: ‘int’
#          printf("This test uses quadratic vector potentials, so the magnetic fields should agree to roundoff error.\\n");
#          ^~~~~~
#          int
# Validation/A2B_unit_test.C:102:34: error: ‘Nxx’ was not declared in this scope
#                  if(indices[dim]%(Nxx[dim]+NGHOSTS)<NGHOSTS) {
#                                   ^~~
# Validation/A2B_unit_test.C:102:34: note: suggested alternative: ‘Nxx2’
#                  if(indices[dim]%(Nxx[dim]+NGHOSTS)<NGHOSTS) {
#                                   ^~~
#                                   Nxx2
# Validation/A2B_unit_test.C:109:60: error: ‘B_ANALYTICU0GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                                                             ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:109:55: error: ‘IDX4’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                                                        ^~~~
# Validation/A2B_unit_test.C:109:103: error: ‘BU0GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                                                                                                        ^~~~~
# Validation/A2B_unit_test.C:109:38: error: ‘fabs’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                                       ^~~~
# Validation/A2B_unit_test.C:109:28: error: ‘log10’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU0GF,i0,i1,i2)])+1.e-15)),
#                             ^~~~~
# Validation/A2B_unit_test.C:110:60: error: ‘B_ANALYTICU1GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])+1.e-15)),
#                                                             ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:110:103: error: ‘BU1GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU1GF,i0,i1,i2)])+1.e-15)),
#                                                                                                        ^~~~~
# Validation/A2B_unit_test.C:111:60: error: ‘B_ANALYTICU2GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])+1.e-15))
#                                                             ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:111:103: error: ‘BU2GF’ was not declared in this scope
#                         1.0-log10(2.0*fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])/(fabs(auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)])+fabs(auxevol_gfs[IDX4(BU2GF,i0,i1,i2)])+1.e-15))
#                                                                                                        ^~~~~
# Validation/A2B_unit_test.C:118:5: error: ‘a’ was not declared in this scope
#      a = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:119:5: error: ‘b’ was not declared in this scope
#      b = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:120:5: error: ‘c’ was not declared in this scope
#      c = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:121:5: error: ‘g’ was not declared in this scope
#      g = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:122:5: error: ‘h’ was not declared in this scope
#      h = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:123:5: error: ‘l’ was not declared in this scope
#      l = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:124:5: error: ‘p’ was not declared in this scope
#      p = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:125:5: error: ‘q’ was not declared in this scope
#      q = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:126:5: error: ‘r’ was not declared in this scope
#      r = (double)(rand()%20-10);
#      ^
# Validation/A2B_unit_test.C:129:18: error: ‘Nxx_plus_2NGHOSTS’ was not declared in this scope
#      calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#                   ^~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:129:18: note: suggested alternative: ‘Nxx_plus_2NGHOSTS2’
#      calculate_AD(Nxx_plus_2NGHOSTS,xx,evol_gfs);
#                   ^~~~~~~~~~~~~~~~~
#                   Nxx_plus_2NGHOSTS2
# Validation/A2B_unit_test.C:132:5: error: ‘calculate_exact_BU’ was not declared in this scope
#      calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#      ^~~~~~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:132:5: note: suggested alternative: ‘calculate_AD’
#      calculate_exact_BU(Nxx_plus_2NGHOSTS,xx,auxevol_gfs);
#      ^~~~~~~~~~~~~~~~~~
#      calculate_AD
# Validation/A2B_unit_test.C:135:5: error: ‘driver_A_to_B’ was not declared in this scope
#      driver_A_to_B(&params,evol_gfs,auxevol_gfs);
#      ^~~~~~~~~~~~~
# Validation/A2B_unit_test.C:141:40: error: ‘Nxx’ was not declared in this scope
#      sprintf(filename,"out%d-numer.txt",Nxx[0]);
#                                         ^~~
# Validation/A2B_unit_test.C:141:40: note: suggested alternative: ‘Nxx2’
#      sprintf(filename,"out%d-numer.txt",Nxx[0]);
#                                         ^~~
#                                         Nxx2
# Validation/A2B_unit_test.C:141:5: error: ‘sprintf’ was not declared in this scope
#      sprintf(filename,"out%d-numer.txt",Nxx[0]);
#      ^~~~~~~
# Validation/A2B_unit_test.C:142:5: error: ‘FILE’ was not declared in this scope
#      FILE *out2D = fopen(filename, "w");
#      ^~~~
# Validation/A2B_unit_test.C:142:11: error: ‘out2D’ was not declared in this scope
#      FILE *out2D = fopen(filename, "w");
#            ^~~~~
# Validation/A2B_unit_test.C:142:19: error: ‘fopen’ was not declared in this scope
#      FILE *out2D = fopen(filename, "w");
#                    ^~~~~
# Validation/A2B_unit_test.C:157:42: error: ‘B_ANALYTICU0GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                           ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:157:37: error: ‘IDX4’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                      ^~~~
# Validation/A2B_unit_test.C:157:85: error: ‘BU0GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                                                                      ^~~~~
# Validation/A2B_unit_test.C:158:42: error: ‘B_ANALYTICU1GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                                           ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:158:85: error: ‘BU1GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                                                                                      ^~~~~
# Validation/A2B_unit_test.C:159:42: error: ‘B_ANALYTICU2GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                                           ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:159:85: error: ‘BU2GF’ was not declared in this scope
#                          auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                                                                                      ^~~~~
# Validation/A2B_unit_test.C:156:17: error: ‘fprintf’ was not declared in this scope
#                  fprintf(out2D,"%.16e\t%.16e\t%.16e\\n",
#                  ^~~~~~~
# Validation/A2B_unit_test.C:181:46: error: ‘B_ANALYTICU0GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                               ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:181:41: error: ‘IDX4’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                          ^~~~
# Validation/A2B_unit_test.C:181:89: error: ‘BU0GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU0GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU0GF,i0,i1,i2)],
#                                                                                          ^~~~~
# Validation/A2B_unit_test.C:182:46: error: ‘B_ANALYTICU1GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                                               ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:182:89: error: ‘BU1GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU1GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU1GF,i0,i1,i2)],
#                                                                                          ^~~~~
# Validation/A2B_unit_test.C:183:46: error: ‘B_ANALYTICU2GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                                               ^~~~~~~~~~~~~~
# Validation/A2B_unit_test.C:183:89: error: ‘BU2GF’ was not declared in this scope
#                              auxevol_gfs[IDX4(B_ANALYTICU2GF,i0,i1,i2)]-auxevol_gfs[IDX4(BU2GF,i0,i1,i2)]
#                                                                                          ^~~~~
# Validation/A2B_unit_test.C:180:21: error: ‘fprintf’ was not declared in this scope
#                      fprintf(out2D,"%.16e\t%.16e\t%.16e\\n",
#                      ^~~~~~~
# Validation/A2B_unit_test.C:190:5: error: ‘fclose’ was not declared in this scope
#      fclose(out2D);
#      ^~~~~~
# Validation/A2B_unit_test.C:190:5: note: suggested alternative: ‘class’
#      fclose(out2D);
#      ^~~~~~
#      class
# Finished executing in 0.22315645217895508 seconds.
# Sorry, compilation failed
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /home/penelson/jup38/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# Now that we have shown that when we use a quadratic vector potential, we get roundoff-level agreement (which is to be expected, since the finite-differencing used approximates the underlying function with a quadratic), we will use do a convergence test to show that when we can't exactly model the function, the truncation error dominates and converges to zero at the expected rate. For this, we use cubic functions for the vector potential. In the code above, we output the difference beteween the numeric and exact magnetic fields at the overlapping, non-edge, non-vertex points of two separate grids. Here, we import that data and calculate the convergence in the usual way,
# $$
# k = \log_2 \left( \frac{F - F_1}{F - F_2} \right),
# $$
# where $k$ is the convergence order, $F$ is the exact solution, $F_1$ is the approximate solution on the coarser grid with resolution $\Delta x$, and $F_2$ is the approximate solution on the finer grid with resolution $\Delta x/2$.

# %%
import numpy as np
import matplotlib.pyplot as plt

Data1 = np.loadtxt("out1-numer.txt")
Data2 = np.loadtxt("out3-numer.txt")

convergence = np.log(np.divide(np.abs(Data1),np.abs(Data2)))/np.log(2)
print("Convergence test: All should be approximately 2\n")
print(convergence)
