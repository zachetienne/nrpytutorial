# %% [markdown]
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-59152712-8"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-59152712-8');
# </script>
#
# # LaTeX Interface Example: BSSN (Cartesian)
#
# ## Author: Ken Sible
#
# ### The following notebook will demonstrate parsing BSSN (Cartesian) and validating against NRPy+
#
# ### NRPy+ Source Code: [parse_latex.py](../edit/parse_latex.py) [\[**tutorial**\]](Tutorial-LaTeX_Parser_Interface.ipynb)

# %% [markdown]
# ### Introduction
#
# ## >> *Work-In-Progress Notebook* <<

# %% [markdown]
# <a id='top'></a>
#
# # Table of Contents
# $$\label{toc}$$
#
# - [Step 1](#step_1): Evolution Equation for $\partial_t \bar{\gamma}_{ij}$
# - [Step 2](#step_2): Evolution Equation for $\partial_t \phi$
# - [Step 3](#step_3): Evolution Equation for $\partial_t K$
# - [Step 4](#step_4): Evolution Equation for $\partial_t \bar{\Lambda}^i$
# - [Step 5](#step_5): Evolution Equation for $\partial_t \bar{A}_{ij}$
# - [Step 6](#step_6): Gauge Evolution Equation for $\partial_t \alpha$
# - [Step 7](#step_7): Gauge Evolution Equation for $\partial_t \beta$
# - [Step 8](#step_8): Gauge Evolution Equation for $\partial_t B$
# - [Step 9](#step_9): Hamiltonian Constraint Equation $\mathcal{H}$
# - [Step 10](#step_10): Momentum Constraint Equation $\mathcal{M}^i$
# - [Step 11](#step_11): Ricci Tensor Equation $\bar{R}_{ij}$
# - [Step 12](#step_12): Output Notebook to PDF

# %%
# %%latex
#
# \begin{align}
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#         + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\
#         &\qquad- 2 \bar{A}^{ij} (\partial_j \alpha - 6 \alpha \partial_j \phi)
#         + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#         - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#         - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#         + \alpha \bar{A}_{ij} K
#         + e^{{-4\phi}} \hat{X}_{ij} \\
#
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     \partial_t \beta^i &= \left[\beta^j \bar{D}_j \beta^i\right] + B^i \\
#
#     \partial_t B^i &= \left[\beta^j \bar{D}_j B^i\right] + \frac{3}{4} \left(\partial_t \bar{\Lambda}^i - \left[\beta^j \bar{D}_j \bar{\Lambda}^i\right]\right) - \eta B^i \\
#
#     \mathcal{H} &= \frac{2}{3} K^{{2}} - \bar{A}_{ij} \bar{A}^{ij} + e^{-4\phi} \left(\bar{R} - 8 \bar{D}^i \phi \bar{D}_i \phi - 8 \bar{D}^2 \phi\right) \\
#     \mathcal{M}^i &= e^{-4\phi} \left(\hat{D}_j \bar{A}^{ij} + 6 \bar{A}^{ij}\partial_j \phi - \frac{2}{3} \bar{\gamma}^{ij} \partial_j K + \bar{A}^{jk} \Delta^i_{jk} + \bar{A}^{ik} \Delta^j_{jk}\right) \\
#
#     \bar{R}_{ij} &= -\frac{1}{2} \bar{\gamma}^{kl} \hat{D}_k \hat{D}_l \bar{\gamma}_{ij}
#         + \frac{1}{2} (\bar{\gamma}_{ki} \hat{D}_j \bar{\Lambda}^k + \bar{\gamma}_{kj} \hat{D}_i \bar{\Lambda}^k)
#         + \frac{1}{2} \Delta^k (\Delta_{ijk} + \Delta_{jik}) \\
#         &\qquad+ \bar{\gamma}^{kl} (\Delta^m_{ki} \Delta_{jml} + \Delta^m_{kj} \Delta_{iml} + \Delta^m_{ik} \Delta_{mjl})
# \end{align}
# Out:
# \begin{align}
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#         + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\
#         &\qquad- 2 \bar{A}^{ij} (\partial_j \alpha - 6 \alpha \partial_j \phi)
#         + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#         - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#         - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#         + \alpha \bar{A}_{ij} K
#         + e^{{-4\phi}} \hat{X}_{ij} \\
#
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     \partial_t \beta^i &= \left[\beta^j \bar{D}_j \beta^i\right] + B^i \\
#
#     \partial_t B^i &= \left[\beta^j \bar{D}_j B^i\right] + \frac{3}{4} \left(\partial_t \bar{\Lambda}^i - \left[\beta^j \bar{D}_j \bar{\Lambda}^i\right]\right) - \eta B^i \\
#
#     \mathcal{H} &= \frac{2}{3} K^{{2}} - \bar{A}_{ij} \bar{A}^{ij} + e^{-4\phi} \left(\bar{R} - 8 \bar{D}^i \phi \bar{D}_i \phi - 8 \bar{D}^2 \phi\right) \\
#     \mathcal{M}^i &= e^{-4\phi} \left(\hat{D}_j \bar{A}^{ij} + 6 \bar{A}^{ij}\partial_j \phi - \frac{2}{3} \bar{\gamma}^{ij} \partial_j K + \bar{A}^{jk} \Delta^i_{jk} + \bar{A}^{ik} \Delta^j_{jk}\right) \\
#
#     \bar{R}_{ij} &= -\frac{1}{2} \bar{\gamma}^{kl} \hat{D}_k \hat{D}_l \bar{\gamma}_{ij}
#         + \frac{1}{2} (\bar{\gamma}_{ki} \hat{D}_j \bar{\Lambda}^k + \bar{\gamma}_{kj} \hat{D}_i \bar{\Lambda}^k)
#         + \frac{1}{2} \Delta^k (\Delta_{ijk} + \Delta_{jik}) \\
#         &\qquad+ \bar{\gamma}^{kl} (\Delta^m_{ki} \Delta_{jml} + \Delta^m_{kj} \Delta_{iml} + \Delta^m_{ik} \Delta_{mjl})
# \end{align}

# %%
from parse_latex import *
Parser.continue_parsing = False

import NRPy_param_funcs as par, reference_metric as rfm
import BSSN.BSSN_RHSs as Brhs, BSSN.BSSN_quantities as Bq
import BSSN.BSSN_gauge_RHSs as gaugerhs
import BSSN.BSSN_constraints as bssncon
from UnitTesting.assert_equal import assert_equal

par.set_parval_from_str('reference_metric::CoordSystem', 'Cartesian')
par.set_parval_from_str('BSSN.BSSN_quantities::LeaveRicciSymbolic', 'True')
rfm.reference_metric(); Brhs.BSSN_RHSs()
gaugerhs.BSSN_gauge_RHSs(); bssncon.BSSN_constraints()
par.set_parval_from_str('BSSN.BSSN_quantities::LeaveRicciSymbolic', 'False')
Bq.RicciBar__gammabarDD_dHatD__DGammaUDD__DGammaU()

# %% [markdown]
# We formatted the notebook in the following pedagogical scheme, shown below, to encourage a *learned* approach to parsing LaTeX.
# ```
# (1) attempt to parse equation
# (2) if ParseError or TensorError
#         debug error and goto (1)
# (3) change equation and goto (1)
# ```

# %% [markdown]
# <a id='step_1'></a>
#
# ## Step 1: Evolution Equation for $\partial_t \bar{\gamma}_{ij}$ [ [^](#top) ]

# %% [markdown]
# If we attempt to parse the first equation without any modification, then we receive a `ParseError` for indexing an `undefined tensor 'gammabarDD'`.

# %%
# %%parse_latex
#
# \begin{align}
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
# \end{align}
# Out:
# ParseError: \partial_t \bar{\gamma}_{ij} = \mathcal{L}_\beta \bar{\gamma}_{ij}
#                        ^
# cannot index undefined tensor 'gammabarDD' at position 29

# %% [markdown]
# The undefined tensor `gammabarDD` mentioned in the `ParseError` is a perturbation of the 3D Cartesian metric `gammahatDD`.
# $$ \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij} $$
#
# Hence, we must define the metric `gammahatDD` and the perturbation `hDD` before defining `gammabarDD` using the above equation.
#
# To define the variable `gammahatDD`,
# 1. define the Kronecker delta `deltaDD` using the `vardef` macro
# 1. parse the equation $\hat{\gamma}_{ij} = \delta_{ij}$ using the `parse` macro
# 1. assign the `-metric` option to `gammahatDD` using the `assign` macro
#
# ```
# % vardef -kronecker 'deltaDD'
# % parse \hat{\gamma}_{ij} = \delta_{ij}
# % assign -symbolic <H> -metric 'gammahatDD'
# ```
#
# The `vardef` macro can define a variable, including a derivative option and a (anti)symmetry option. The `parse` macro can parse an equation without rendering the equation LaTeX. The `assign` macro can assign a `vardef` option to an already existing variable in the namespace. Finally, the `-metric` symmetry option can assign the symmetry `-sym01` and generate the metric inverse `gammahatUU` and determinant `gammahatdet`.
#
# **Remark:** If a derivative option should also apply to the metric inverse and determinant, then that option should precede `-metric`. Moreover, you need not define a scalar quantity. However, should a scalar quantity require a `vardef` option, you may assign one using either the `vardef` or `assign` macro.
#
# To define the variable `gammabarDD`,
# 1. define the perturbation `hDD` using the `vardef` macro
# 1. parse the equation $\bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}$ using the `parse` macro
# 1. assign the `-metric` option to `gammabarDD` using the `assign` macro
#
# ```
# % vardef -numeric -sym01 'hDD'
# % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
# % assign -numeric -metric 'gammabarDD'
# ```
#
# In the `assign` macro for `gammahatDD`, we included a derivative priority `<H>`, but no such priority was included for `gammabarDD`, defaulting that to `<L>`. You may change the derivative type for a tensor occuring in a specific pattern using the `\vphantom` command. The derivative priority, high `<H>` or low `<L>` is with respect to that `\vphantom` command, of which an example shall occur shortly inside the Lie derivative.

# %%
# %%parse_latex
#
# \begin{align}
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
# \end{align}
# Out:
# ParseError: \mathcal{L}_\text{beta} \text{gammabar}_{i j} = \text{beta}^a \partial_a \text{gammabar}_{i j} + (\partial_i \text{beta}^a) \text{gammabar}_{a j} + (\partial_j \text{beta}^a) \text{gammabar}_{i a}
#                                                             ^
# cannot index undefined tensor 'betaU' at position 48

# %% [markdown]
# Next, we define the variable `betaU`, following the same approach from before. However, we require a different variable name than that used in the LaTeX representation, namely `betaU -> vetU`. The `srepl` macro can perform string replacement with the assumption that string `A` and string `B` are considered equal whenever they are equivalent syntactically (i.e. same [lexeme](https://en.wikipedia.org/wiki/Lexeme), same [token](https://en.wikipedia.org/wiki/Lexical_analysis#Tokenization)). So, for example, `S_{a b} T^{b c}` and `S_{ab}T^{bc}` are equal, according to the `srepl` macro. You can check syntactic equivalence using the code provided below
#
# ```
# lexer = Lexer()
# lexer.initialize(A)
# syntax_A = [(lexer.lexeme, token) for token in lexer.tokenize()]
# lexer.initialize(B)
# syntax_B = [(lexer.lexeme, token) for token in lexer.tokenize()]
# assert syntax_A == syntax_B
# ```
# The `-persist` option will apply the replacement rule `"..." -> "..."` to every subsequent input of the `parse` function. If you require a variable name longer than one Latin or Greek letter, you should surround that variable name in the `\text` command.
#
# ```
# % vardef -numeric 'vetU'
# % srepl "\beta" -> "\text{vet}"
# ```
# Next, we substitute a tensor identity for the contraction $\bar{D}_k \beta^k$, intended to **TODO**.
# ```
# % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
# ```

# %%
# %%parse_latex
#
# \begin{align}
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
# \end{align}
# Out:
# ParseError: cannot differentiate symbolically without specifying a basis

# %% [markdown]
# To perform symbolic differentiation, we define a three dimensional Cartesian basis $\{x,y,z\}$ using the `keydef` macro.

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
# \end{align}
# Out:
# ParseError: + \frac{2}{3} \bar{\gamma}_{ij} (\alpha \bar{A}^k_k - (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}}))
#                                                     ^
# cannot index undefined tensor 'AbarUD' at position 761

# %% [markdown]
# Next, we define the variable `aDD`, renamed from `AbarDD`, and raise the first index using the metric `gammabarUU` and the `parse` macro, which can parse an equation without rendering the equation in a `.tex` document or a Jupyter Notebook (useful for internal calculation).

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj} \\
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
# \end{align}
# Out:
# TensorError: unbalanced free index
#
# Tensor(gammabarDD_dD, i, j, t) = -2*Tensor(alpha)*Tensor(aDD, i, j) + 2*Tensor(alpha)*Tensor(aUD, k, k)*Tensor(gammabarDD, i, j)/3 - 2*Tensor(gammabarDD, i, j)*Tensor(vetU_dD, k, k)/3 + Tensor(gammabarDD_ldvet, i, j) - Tensor(vetU, k)*Tensor(gammabarDD, i, j)*Derivative(Tensor(gammahatdet), k)/(3*Tensor(gammahatdet))

# %% [markdown]
# Finally, we replace the partial derivative $\partial_t \bar{\gamma}$ on the LHS with the variable name `h_rhs` using the `srepl` macro, resolving the `TensorError` for an 'unbalanced free index,' which resulted from interpreting `t` as an index in the partial derivative on the LHS.

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD')

# %%
assert_equal(h_rhsDD, Brhs.h_rhsDD)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_2'></a>
#
# ## Step 2: Evolution Equation for $\partial_t \phi$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#             + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
# \end{align}
# Out:
# TensorError: unbalanced free index
#
# Tensor(phi_dD, t) = -Tensor(K)*Tensor(alpha)/6 + Tensor(phi_ldvet) + Tensor(vetU_dD, k, k)/6 + Tensor(vetU, k)*Derivative(Tensor(gammahatdet), k)/(12*Tensor(gammahatdet))

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#             + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs')

# %%
assert_equal(cf_rhs, Brhs.cf_rhs)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_3'></a>
#
# ## Step 3: Evolution Equation for $\partial_t K$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
# \end{align}
# Out:
# ParseError: - \text{cf}^{{2}} (\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi) \\
# ^
# cannot index undefined tensor 'aUU' at position 1849

# %% [markdown]
# First, we raise the second index of `aUD` (already computed) using the metric `gammabarUU` and the `parse` macro.
#
# ```
# % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
# ```

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k \\
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
# \end{align}
# Out:
# TensorError: unbalanced free index
#
# Tensor(trK_dD, t) = Tensor(alpha)*Tensor(trK)**2/3 + Tensor(alpha)*Tensor(aDD, i, j)*Tensor(aUU, i, j) - 2*Tensor(cf)**2*Tensor(alpha_cdbarU, i)*Tensor(phi_cdbarD, i) - Tensor(cf)**2*Tensor(alpha_cdbarUD, i, i) + Tensor(trK_ldvet)

# %% [markdown]
# Finally, we replace the partial derivative $\partial_t K$ on the LHS with the variable name `h_rhs` using the `srepl` macro
#
# ```
# % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
# ```

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs',
#  'aUU',
#  'trK_dupD',
#  'trK_ldvet',
#  'alpha_dD',
#  'alpha_cdbarD',
#  'alpha_cdbarU',
#  'alpha_cdbarU_dD',
#  'alpha_cdbarD_dD',
#  'alpha_dDD',
#  'gammabarUU_dD',
#  'gammabarDD_dD',
#  'hDD_dD',
#  'gammabardet_dD',
#  'GammabarUDD',
#  'alpha_cdbarUD',
#  'cf_dD',
#  'phi_cdbarD',
#  'trK_rhs')

# %%
assert_equal(trK_rhs, Brhs.trK_rhs)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_4'></a>
#
# ## Step 4: Evolution Equation for $\partial_t \bar{\Lambda}^i$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
# \end{align}
# Out:
# ParseError: \partial_t \bar{\Lambda}^i = \mathcal{L}_\text{vet} \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \text{vet}^i
#                        ^
# cannot index undefined tensor 'LambdabarU' at position 2081

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
# \end{align}
# Out:
# ParseError: + \frac{2}{3} \Delta^i (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}}) + \frac{1}{3} \bar{D}^i (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}}) \\%
#                           ^
# cannot index undefined tensor 'DeltaU' at position 2296

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
# \end{align}
# Out:
# TensorError: illegal bound index
#
# Tensor(DeltaU, k) = Tensor(gammabarUU, i, j)*Tensor(lambdaU_dD, i, t)*Tensor(DeltaUDD, k, i, j)

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
# \end{align}
# Out:
# ParseError: \qquad- 2 \text{a}^{ij} (\partial_j \alpha - 6 \alpha \partial_j \text{cf} \frac{-1}{2 \text{cf}})
#             ^
# unsupported macro '\qquad' at position 2791

# %% [markdown]
# We instruct the parser to ignore the formatting command `\qquad` and our custom line break `\\%` for equation formatting using the `ignore` macro.

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs',
#  'aUU',
#  'trK_dupD',
#  'trK_ldvet',
#  'alpha_dD',
#  'alpha_cdbarD',
#  'alpha_cdbarU',
#  'alpha_cdbarU_dD',
#  'alpha_cdbarD_dD',
#  'alpha_dDD',
#  'gammabarUU_dD',
#  'gammabarDD_dD',
#  'hDD_dD',
#  'gammabardet_dD',
#  'GammabarUDD',
#  'alpha_cdbarUD',
#  'cf_dD',
#  'phi_cdbarD',
#  'trK_rhs',
#  'lambdaU',
#  'GammahatUDD',
#  'DeltaUDD',
#  'DeltaDDD',
#  'DeltaU',
#  'lambdaU_dupD',
#  'lambdaU_ldvet',
#  'vetU_cdhatD',
#  'vetU_cdhatD_dD',
#  'vetU_dDD',
#  'vetU_cdhatDD',
#  'gammahatdet_dD_cdbarD',
#  'gammahatdet_dD_cdbarU',
#  'vetU_cdbarD',
#  'vetU_cdbarU',
#  'gammahatdet_dD',
#  'gammahatdet_cdbarD',
#  'gammahatdet_cdbarU',
#  'vetU_dD_cdbarD',
#  'vetU_dD_cdbarU',
#  'trK_dD',
#  'Lambdabar_rhsU')

# %%
assert_equal(Lambdabar_rhsU, Brhs.Lambdabar_rhsU)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_5'></a>
#
# ## Step 5: Evolution Equation for $\partial_t \bar{A}_{ij}$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
# \end{align}
# Out:
# ParseError: \hat{X}_{ij} = X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
# ^
# cannot index undefined tensor 'RbarDD' at position 3241

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
# \end{align}
# Out:
# TensorError: unbalanced free index
#
# Tensor(aDD_dD, i, j, t) = Tensor(alpha)*Tensor(trK)*Tensor(aDD, i, j) - 2*Tensor(alpha)*Tensor(aDD, i, k)*Tensor(aUD, k, j) + Tensor(cf)**2*Tensor(XhatDD, i, j) - 2*Tensor(aDD, i, j)*Tensor(vetU_dD, k, k)/3 + Tensor(aDD_ldvet, i, j) - Tensor(gammahatdet_dD, k)*Tensor(vetU, k)*Tensor(aDD, i, j)/(3*Tensor(gammahatdet))

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs',
#  'aUU',
#  'trK_dupD',
#  'trK_ldvet',
#  'alpha_dD',
#  'alpha_cdbarD',
#  'alpha_cdbarU',
#  'alpha_cdbarU_dD',
#  'alpha_cdbarD_dD',
#  'alpha_dDD',
#  'gammabarUU_dD',
#  'gammabarDD_dD',
#  'hDD_dD',
#  'gammabardet_dD',
#  'GammabarUDD',
#  'alpha_cdbarUD',
#  'cf_dD',
#  'phi_cdbarD',
#  'trK_rhs',
#  'lambdaU',
#  'GammahatUDD',
#  'DeltaUDD',
#  'DeltaDDD',
#  'DeltaU',
#  'lambdaU_dupD',
#  'lambdaU_ldvet',
#  'vetU_cdhatD',
#  'vetU_cdhatD_dD',
#  'vetU_dDD',
#  'vetU_cdhatDD',
#  'gammahatdet_dD_cdbarD',
#  'gammahatdet_dD_cdbarU',
#  'vetU_cdbarD',
#  'vetU_cdbarU',
#  'gammahatdet_dD',
#  'gammahatdet_cdbarD',
#  'gammahatdet_cdbarU',
#  'vetU_dD_cdbarD',
#  'vetU_dD_cdbarU',
#  'trK_dD',
#  'Lambdabar_rhsU',
#  'RbarDD',
#  'phi_cdbarD_dD',
#  'cf_dDD',
#  'phi_cdbarDD',
#  'alpha_cdbarDD',
#  'XDD',
#  'XhatDD',
#  'aDD_dupD',
#  'aDD_ldvet',
#  'a_rhsDD')

# %%
assert_equal(a_rhsDD, Brhs.a_rhsDD)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_6'></a>
#
# ## Step 6: Gauge Evolution Equation for $\partial_t \alpha$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
# \end{align}
# Out:
# TensorError: unbalanced free index
#
# Tensor(alpha_dD, t) = -2*Tensor(alpha)*Tensor(trK) + Tensor(alpha_ldvet)

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs',
#  'aUU',
#  'trK_dupD',
#  'trK_ldvet',
#  'alpha_dD',
#  'alpha_cdbarD',
#  'alpha_cdbarU',
#  'alpha_cdbarU_dD',
#  'alpha_cdbarD_dD',
#  'alpha_dDD',
#  'gammabarUU_dD',
#  'gammabarDD_dD',
#  'hDD_dD',
#  'gammabardet_dD',
#  'GammabarUDD',
#  'alpha_cdbarUD',
#  'cf_dD',
#  'phi_cdbarD',
#  'trK_rhs',
#  'lambdaU',
#  'GammahatUDD',
#  'DeltaUDD',
#  'DeltaDDD',
#  'DeltaU',
#  'lambdaU_dupD',
#  'lambdaU_ldvet',
#  'vetU_cdhatD',
#  'vetU_cdhatD_dD',
#  'vetU_dDD',
#  'vetU_cdhatDD',
#  'gammahatdet_dD_cdbarD',
#  'gammahatdet_dD_cdbarU',
#  'vetU_cdbarD',
#  'vetU_cdbarU',
#  'gammahatdet_dD',
#  'gammahatdet_cdbarD',
#  'gammahatdet_cdbarU',
#  'vetU_dD_cdbarD',
#  'vetU_dD_cdbarU',
#  'trK_dD',
#  'Lambdabar_rhsU',
#  'RbarDD',
#  'phi_cdbarD_dD',
#  'cf_dDD',
#  'phi_cdbarDD',
#  'alpha_cdbarDD',
#  'XDD',
#  'XhatDD',
#  'aDD_dupD',
#  'aDD_ldvet',
#  'a_rhsDD',
#  'alpha_dupD',
#  'alpha_ldvet',
#  'alpha_rhs')

# %%
assert_equal(alpha_rhs, gaugerhs.alpha_rhs)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_7'></a>
#
# ## Step 7: Gauge Evolution Equation for $\partial_t \beta$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
# \end{align}
# Out:
# ParseError: \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \text{a}^i_j = \bar{\gamma}^{ik} \text{a}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \text{h_rhs}_{ij} = \mathcal{L}_\text{vet} \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} (\alpha \text{a}^k_k - (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}}))
#         - 2 \alpha \text{a}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \text{cf_rhs} = -2 \text{cf} (\mathcal{L}_\text{vet}\phi+\frac{1}{6}((\partial_k\text{vet}^k+\frac{\partial_k\text{gammahatdet}\text{vet}^k}{2\text{gammahatdet}})-\alpha\text{trK})) \\
#
#     % parse \text{a}^{ij} = \bar{\gamma}^{jk} \text{a}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \text{trK_rhs} = \mathcal{L}_\text{vet} \text{trK}
#         + \frac{1}{3} \alpha \text{trK}^{{2}}
#         + \alpha \text{a}_{ij} \text{a}^{ij}
#         - \text{cf}^{{2}} (\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \text{Lambdabar_rhs}^i = \mathcal{L}_\text{vet} \text{lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \text{vet}^i
#             + \frac{2}{3} \Delta^i (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}}) + \frac{1}{3} \bar{D}^i (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})
#             - 2 \text{a}^{ij} (\partial_j \alpha - 6 \alpha \partial_j \text{cf} \frac{-1}{2 \text{cf}})
#             + 2 \alpha \text{a}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j \text{trK} \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} = -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} = X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \text{a_rhs}_{ij} = \mathcal{L}_\text{vet} \text{a}_{ij}
#             - \frac{2}{3} \text{a}_{ij} (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})
#             - 2 \alpha \text{a}_{ik} \text{a}^k_j
#             + \alpha \text{a}_{ij} \text{trK}
#             + \text{cf}^{{2}} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \text{alpha_rhs} = \mathcal{L}_\text{vet} \alpha - 2 \alpha \text{trK} \\
#
#     \partial_t \text{vet}^i = [\text{vet}^j \vphantom{upwind} \bar{D}_j \text{vet}^i] + B^i \\
# \end{align}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# cannot index undefined tensor 'BU' at position 3998

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
# \end{align}
# Out:
# TensorError: unbalanced free index
#
# Tensor(vetU_dD, i, t) = Tensor(betU, i) + Tensor(vetU, j)*Tensor(vetU_cdbarD, i, j)

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     % srepl "\partial_t \text{vet}" -> "\text{vet_rhs}"
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs',
#  'aUU',
#  'trK_dupD',
#  'trK_ldvet',
#  'alpha_dD',
#  'alpha_cdbarD',
#  'alpha_cdbarU',
#  'alpha_cdbarU_dD',
#  'alpha_cdbarD_dD',
#  'alpha_dDD',
#  'gammabarUU_dD',
#  'gammabarDD_dD',
#  'hDD_dD',
#  'gammabardet_dD',
#  'GammabarUDD',
#  'alpha_cdbarUD',
#  'cf_dD',
#  'phi_cdbarD',
#  'trK_rhs',
#  'lambdaU',
#  'GammahatUDD',
#  'DeltaUDD',
#  'DeltaDDD',
#  'DeltaU',
#  'lambdaU_dupD',
#  'lambdaU_ldvet',
#  'vetU_cdhatD',
#  'vetU_cdhatD_dD',
#  'vetU_dDD',
#  'vetU_cdhatDD',
#  'gammahatdet_dD_cdbarD',
#  'gammahatdet_dD_cdbarU',
#  'vetU_cdbarD',
#  'vetU_cdbarU',
#  'gammahatdet_dD',
#  'gammahatdet_cdbarD',
#  'gammahatdet_cdbarU',
#  'vetU_dD_cdbarD',
#  'vetU_dD_cdbarU',
#  'trK_dD',
#  'Lambdabar_rhsU',
#  'RbarDD',
#  'phi_cdbarD_dD',
#  'cf_dDD',
#  'phi_cdbarDD',
#  'alpha_cdbarDD',
#  'XDD',
#  'XhatDD',
#  'aDD_dupD',
#  'aDD_ldvet',
#  'a_rhsDD',
#  'alpha_dupD',
#  'alpha_ldvet',
#  'alpha_rhs',
#  'betU',
#  'vetU_dupD',
#  'vet_rhsU')

# %%
assert_equal(vet_rhsU, gaugerhs.vet_rhsU)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_8'></a>
#
# ## Step 8: Gauge Evolution Equation for $\partial_t B$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     % srepl "\partial_t \text{vet}" -> "\text{vet_rhs}"
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
#
#     \partial_t B^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j B^i\right]
#         + \frac{3}{4} \left(\partial_t \bar{\Lambda}^i - \left[\beta^j \vphantom{upwind} \bar{D}_j \bar{\Lambda}^i\right]\right)
#         - \eta B^i \\
# \end{align}
# Out:
# TensorError: unbalanced free index
#
# Tensor(betU_dD, i, t) = -Tensor(eta)*Tensor(betU, i) + 3*Tensor(Lambdabar_rhsU, i)/4 + Tensor(vetU, j)*Tensor(betU_cdbarD, i, j) - 3*Tensor(vetU, j)*Tensor(lambdaU_cdbarD, i, j)/4

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     % srepl "\partial_t \text{vet}" -> "\text{vet_rhs}"
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
#
#     % vardef -const 'eta'
#     % srepl "\partial_t \text{bet}" -> "\text{bet_rhs}"
#     \partial_t B^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j B^i\right]
#         + \frac{3}{4} \left(\partial_t \bar{\Lambda}^i - \left[\beta^j \vphantom{upwind} \bar{D}_j \bar{\Lambda}^i\right]\right)
#         - \eta B^i \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs',
#  'aUU',
#  'trK_dupD',
#  'trK_ldvet',
#  'alpha_dD',
#  'alpha_cdbarD',
#  'alpha_cdbarU',
#  'alpha_cdbarU_dD',
#  'alpha_cdbarD_dD',
#  'alpha_dDD',
#  'gammabarUU_dD',
#  'gammabarDD_dD',
#  'hDD_dD',
#  'gammabardet_dD',
#  'GammabarUDD',
#  'alpha_cdbarUD',
#  'cf_dD',
#  'phi_cdbarD',
#  'trK_rhs',
#  'lambdaU',
#  'GammahatUDD',
#  'DeltaUDD',
#  'DeltaDDD',
#  'DeltaU',
#  'lambdaU_dupD',
#  'lambdaU_ldvet',
#  'vetU_cdhatD',
#  'vetU_cdhatD_dD',
#  'vetU_dDD',
#  'vetU_cdhatDD',
#  'gammahatdet_dD_cdbarD',
#  'gammahatdet_dD_cdbarU',
#  'vetU_cdbarD',
#  'vetU_cdbarU',
#  'gammahatdet_dD',
#  'gammahatdet_cdbarD',
#  'gammahatdet_cdbarU',
#  'vetU_dD_cdbarD',
#  'vetU_dD_cdbarU',
#  'trK_dD',
#  'Lambdabar_rhsU',
#  'RbarDD',
#  'phi_cdbarD_dD',
#  'cf_dDD',
#  'phi_cdbarDD',
#  'alpha_cdbarDD',
#  'XDD',
#  'XhatDD',
#  'aDD_dupD',
#  'aDD_ldvet',
#  'a_rhsDD',
#  'alpha_dupD',
#  'alpha_ldvet',
#  'alpha_rhs',
#  'betU',
#  'vetU_dupD',
#  'vet_rhsU',
#  'betU_dupD',
#  'betU_cdbarD',
#  'lambdaU_cdbarD',
#  'bet_rhsU')

# %%
assert_equal(bet_rhsU, gaugerhs.bet_rhsU)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_9'></a>
#
# ## Step 9: Hamiltonian Constraint Equation $\mathcal{H}$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     % srepl "\partial_t \text{vet}" -> "\text{vet_rhs}"
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
#
#     % vardef -const 'eta'
#     % srepl "\partial_t \text{bet}" -> "\text{bet_rhs}"
#     \partial_t B^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j B^i\right]
#         + \frac{3}{4} \left(\partial_t \bar{\Lambda}^i - \left[\beta^j \vphantom{upwind} \bar{D}_j \bar{\Lambda}^i\right]\right)
#         - \eta B^i \\
#
#     \mathcal{H} &= \frac{2}{3} K^{{2}} - \bar{A}_{ij} \bar{A}^{ij}
#         + e^{-4\phi} \left(\bar{R} - 8 \bar{D}^i \phi \bar{D}_i \phi - 8 \bar{D}^2 \phi\right) \\
# \end{align}
# Out:
# ParseError: + \text{cf}^{{2}} (\bar{R} - 8 \bar{D}^i \phi \bar{D}_i \phi - 8 \bar{D}^2 \phi) \\
# ^
# unsupported operator '\mathcal' at position 4430

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     % srepl "\partial_t \text{vet}" -> "\text{vet_rhs}"
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
#
#     % vardef -const 'eta'
#     % srepl "\partial_t \text{bet}" -> "\text{bet_rhs}"
#     \partial_t B^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j B^i\right]
#         + \frac{3}{4} \left(\partial_t \bar{\Lambda}^i - \left[\beta^j \vphantom{upwind} \bar{D}_j \bar{\Lambda}^i\right]\right)
#         - \eta B^i \\
#
#     % parse \bar{R} = \bar{\gamma}^{ij} \bar{R}_{ij}
#     % srepl "\mathcal{<1>}" -> "<1>"
#     \mathcal{H} &= \frac{2}{3} K^{{2}} - \bar{A}_{ij} \bar{A}^{ij}
#         + e^{-4\phi} \left(\bar{R} - 8 \bar{D}^i \phi \bar{D}_i \phi - 8 \bar{D}^2 \phi\right) \\
# \end{align}
# Out:
# ParseError: \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \text{a}^i_j = \bar{\gamma}^{ik} \text{a}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \text{h_rhs}_{ij} = \mathcal{L}_\text{vet} \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} (\alpha \text{a}^k_k - (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}}))
#         - 2 \alpha \text{a}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \text{cf_rhs} = -2 \text{cf} (\mathcal{L}_\text{vet}\phi+\frac{1}{6}((\partial_k\text{vet}^k+\frac{\partial_k\text{gammahatdet}\text{vet}^k}{2\text{gammahatdet}})-\alpha\text{trK})) \\
#
#     % parse \text{a}^{ij} = \bar{\gamma}^{jk} \text{a}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \text{trK_rhs} = \mathcal{L}_\text{vet} \text{trK}
#         + \frac{1}{3} \alpha \text{trK}^{{2}}
#         + \alpha \text{a}_{ij} \text{a}^{ij}
#         - \text{cf}^{{2}} (\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \text{Lambdabar_rhs}^i = \mathcal{L}_\text{vet} \text{lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \text{vet}^i
#             + \frac{2}{3} \Delta^i (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}}) + \frac{1}{3} \bar{D}^i (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})
#             - 2 \text{a}^{ij} (\partial_j \alpha - 6 \alpha \partial_j \text{cf} \frac{-1}{2 \text{cf}})
#             + 2 \alpha \text{a}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j \text{trK} \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} = -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} = X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \text{a_rhs}_{ij} = \mathcal{L}_\text{vet} \text{a}_{ij}
#             - \frac{2}{3} \text{a}_{ij} (\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})
#             - 2 \alpha \text{a}_{ik} \text{a}^k_j
#             + \alpha \text{a}_{ij} \text{trK}
#             + \text{cf}^{{2}} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \text{alpha_rhs} = \mathcal{L}_\text{vet} \alpha - 2 \alpha \text{trK} \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     % srepl "\partial_t \text{vet}" -> "\text{vet_rhs}"
#     \text{vet_rhs}^i = [\text{vet}^j \vphantom{upwind} \bar{D}_j \text{vet}^i] + \text{bet}^i \\
#
#     % vardef -const 'eta'
#     % srepl "\partial_t \text{bet}" -> "\text{bet_rhs}"
#     \text{bet_rhs}^i = [\text{vet}^j \vphantom{upwind} \bar{D}_j \text{bet}^i]
#         + \frac{3}{4} (\text{Lambdabar_rhs}^i - [\text{vet}^j \vphantom{upwind} \bar{D}_j \text{lambda}^i])
#         - \eta \text{bet}^i \\
#
#     % parse \bar{R} = \bar{\gamma}^{ij} \bar{R}_{ij}
#     % srepl "\mathcal{<1>}" -> "<1>"
#     H = \frac{2}{3} \text{trK}^{{2}} - \text{a}_{ij} \text{a}^{ij}
#         + \text{cf}^{{2}} (\bar{R} - 8 \bar{D}^i \phi \bar{D}_i \phi - 8 \bar{D}^2 \phi) \\
# \end{align}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# expected token LETTER at position 4664

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     % srepl "\partial_t \text{vet}" -> "\text{vet_rhs}"
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
#
#     % vardef -const 'eta'
#     % srepl "\partial_t \text{bet}" -> "\text{bet_rhs}"
#     \partial_t B^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j B^i\right]
#         + \frac{3}{4} \left(\partial_t \bar{\Lambda}^i - \left[\beta^j \vphantom{upwind} \bar{D}_j \bar{\Lambda}^i\right]\right)
#         - \eta B^i \\
#
#     % parse \bar{R} = \bar{\gamma}^{ij} \bar{R}_{ij}
#     % srepl "\bar{D}^2" -> "\bar{D}^i \bar{D}_i", "\mathcal{<1>}" -> "<1>"
#     \mathcal{H} &= \frac{2}{3} K^{{2}} - \bar{A}_{ij} \bar{A}^{ij}
#         + e^{-4\phi} \left(\bar{R} - 8 \bar{D}^i \phi \bar{D}_i \phi - 8 \bar{D}^2 \phi\right) \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs',
#  'aUU',
#  'trK_dupD',
#  'trK_ldvet',
#  'alpha_dD',
#  'alpha_cdbarD',
#  'alpha_cdbarU',
#  'alpha_cdbarU_dD',
#  'alpha_cdbarD_dD',
#  'alpha_dDD',
#  'gammabarUU_dD',
#  'gammabarDD_dD',
#  'hDD_dD',
#  'gammabardet_dD',
#  'GammabarUDD',
#  'alpha_cdbarUD',
#  'cf_dD',
#  'phi_cdbarD',
#  'trK_rhs',
#  'lambdaU',
#  'GammahatUDD',
#  'DeltaUDD',
#  'DeltaDDD',
#  'DeltaU',
#  'lambdaU_dupD',
#  'lambdaU_ldvet',
#  'vetU_cdhatD',
#  'vetU_cdhatD_dD',
#  'vetU_dDD',
#  'vetU_cdhatDD',
#  'gammahatdet_dD_cdbarD',
#  'gammahatdet_dD_cdbarU',
#  'vetU_cdbarD',
#  'vetU_cdbarU',
#  'gammahatdet_dD',
#  'gammahatdet_cdbarD',
#  'gammahatdet_cdbarU',
#  'vetU_dD_cdbarD',
#  'vetU_dD_cdbarU',
#  'trK_dD',
#  'Lambdabar_rhsU',
#  'RbarDD',
#  'phi_cdbarD_dD',
#  'cf_dDD',
#  'phi_cdbarDD',
#  'alpha_cdbarDD',
#  'XDD',
#  'XhatDD',
#  'aDD_dupD',
#  'aDD_ldvet',
#  'a_rhsDD',
#  'alpha_dupD',
#  'alpha_ldvet',
#  'alpha_rhs',
#  'betU',
#  'vetU_dupD',
#  'vet_rhsU',
#  'betU_dupD',
#  'betU_cdbarD',
#  'lambdaU_cdbarD',
#  'bet_rhsU',
#  'Rbar',
#  'phi_cdbarU',
#  'phi_cdbarDU',
#  'H')

# %%
assert_equal(H, bssncon.H)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_10'></a>
#
# ## Step 10: Momentum Constraint Equation $\mathcal{M}^i$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     % srepl "\partial_t \text{vet}" -> "\text{vet_rhs}"
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
#
#     % vardef -const 'eta'
#     % srepl "\partial_t \text{bet}" -> "\text{bet_rhs}"
#     \partial_t B^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j B^i\right]
#         + \frac{3}{4} \left(\partial_t \bar{\Lambda}^i - \left[\beta^j \vphantom{upwind} \bar{D}_j \bar{\Lambda}^i\right]\right)
#         - \eta B^i \\
#
#     % parse \bar{R} = \bar{\gamma}^{ij} \bar{R}_{ij}
#     % srepl "\bar{D}^2" -> "\bar{D}^i \bar{D}_i", "\mathcal{<1>}" -> "<1>"
#     \mathcal{H} &= \frac{2}{3} K^{{2}} - \bar{A}_{ij} \bar{A}^{ij}
#         + e^{-4\phi} \left(\bar{R} - 8 \bar{D}^i \phi \bar{D}_i \phi - 8 \bar{D}^2 \phi\right) \\
#
#     % assign -numeric 'aUD', 'aUU'
#     \mathcal{M}^i &= e^{-4\phi} \left(\bar{D}_j \bar{A}^{ij} + 6 \bar{A}^{ij}\partial_j \phi
#         - \frac{2}{3} \bar{\gamma}^{ij} \partial_j K\right) \\
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs',
#  'aUU',
#  'trK_dupD',
#  'trK_ldvet',
#  'alpha_dD',
#  'alpha_cdbarD',
#  'alpha_cdbarU',
#  'alpha_cdbarU_dD',
#  'alpha_cdbarD_dD',
#  'alpha_dDD',
#  'gammabarUU_dD',
#  'gammabarDD_dD',
#  'hDD_dD',
#  'gammabardet_dD',
#  'GammabarUDD',
#  'alpha_cdbarUD',
#  'cf_dD',
#  'phi_cdbarD',
#  'trK_rhs',
#  'lambdaU',
#  'GammahatUDD',
#  'DeltaUDD',
#  'DeltaDDD',
#  'DeltaU',
#  'lambdaU_dupD',
#  'lambdaU_ldvet',
#  'vetU_cdhatD',
#  'vetU_cdhatD_dD',
#  'vetU_dDD',
#  'vetU_cdhatDD',
#  'gammahatdet_dD_cdbarD',
#  'gammahatdet_dD_cdbarU',
#  'vetU_cdbarD',
#  'vetU_cdbarU',
#  'gammahatdet_dD',
#  'gammahatdet_cdbarD',
#  'gammahatdet_cdbarU',
#  'vetU_dD_cdbarD',
#  'vetU_dD_cdbarU',
#  'trK_dD',
#  'Lambdabar_rhsU',
#  'RbarDD',
#  'phi_cdbarD_dD',
#  'cf_dDD',
#  'phi_cdbarDD',
#  'alpha_cdbarDD',
#  'XDD',
#  'XhatDD',
#  'aDD_dupD',
#  'aDD_ldvet',
#  'a_rhsDD',
#  'alpha_dupD',
#  'alpha_ldvet',
#  'alpha_rhs',
#  'betU',
#  'vetU_dupD',
#  'vet_rhsU',
#  'betU_dupD',
#  'betU_cdbarD',
#  'lambdaU_cdbarD',
#  'bet_rhsU',
#  'Rbar',
#  'phi_cdbarU',
#  'phi_cdbarDU',
#  'H',
#  'aUU_dD',
#  'aUD_dD',
#  'aDD_dD',
#  'aUU_cdbarD',
#  'MU')

# %%
assert_equal(MU, bssncon.MU)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_11'></a>
#
# ## Step 11: Ricci Tensor Equation $\bar{R}_{ij}$ [ [^](#top) ]

# %%
# %%parse_latex
#
# \begin{align}
#     % keydef basis [x, y, z]
#     % ignore "\\%", "\qquad"
#
#     % vardef -kronecker 'deltaDD'
#     % parse \hat{\gamma}_{ij} = \delta_{ij}
#     % assign -symbolic <H> -metric 'gammahatDD'
#     % vardef -numeric -sym01 'hDD'
#     % parse \bar{\gamma}_{ij} = h_{ij} + \hat{\gamma}_{ij}
#     % assign -numeric -metric 'gammabarDD'
#
#     % vardef -numeric 'vetU'
#     % srepl "\beta" -> "\text{vet}"
#     %% upwind pattern inside Lie derivative expansion
#     % srepl -persist "\text{vet}^<1> \partial_<1>" -> "\text{vet}^<1> \vphantom{upwind} \partial_<1>"
#     %% substitute tensor identity (see appropriate BSSN notebook)
#     % srepl -persist "\bar{D}_k \text{vet}^k" -> "(\partial_k \text{vet}^k + \frac{\partial_k \text{gammahatdet} \text{vet}^k}{2 \text{gammahatdet}})"
#
#     % vardef -numeric 'alpha'
#     % vardef -numeric -sym01 'aDD'
#     % srepl "\bar{A}" -> "\text{a}"
#     % parse \bar{A}^i_j = \bar{\gamma}^{ik} \bar{A}_{kj}
#     % srepl "\partial_t \bar{\gamma}" -> "\text{h_rhs}"
#
#     \partial_t \bar{\gamma}_{ij} &= \mathcal{L}_\beta \bar{\gamma}_{ij}
#         + \frac{2}{3} \bar{\gamma}_{ij} \left(\alpha \bar{A}^k{}_k - \bar{D}_k \beta^k\right)
#         - 2 \alpha \bar{A}_{ij} \\
#
#     % vardef -numeric 'cf', 'trK'
#     % srepl "K" -> "\text{trK}"
#     %% replace 'phi' with conformal factor cf = W = e^{{-2\phi}}
#     % srepl "e^{-4\phi}" -> "\text{cf}^{{2}}"
#     % srepl "\partial_t \phi = <1..> \\" -> "\text{cf_rhs} = -2 \text{cf} (<1..>) \\"
#     % srepl -persist "\partial_<1> \phi"       -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#     % srepl -persist "\partial_<1> \text{phi}" -> "\partial_<1> \text{cf} \frac{-1}{2 \text{cf}}"
#
#     \partial_t \phi &= \mathcal{L}_\beta \phi
#         + \frac{1}{6} \left(\bar{D}_k \beta^k - \alpha K \right) \\
#
#     % parse \bar{A}^{ij} = \bar{\gamma}^{jk} \bar{A}^i_k
#     % srepl "\partial_t \text{trK}" -> "\text{trK_rhs}"
#     \partial_t K &= \mathcal{L}_\beta K
#         + \frac{1}{3} \alpha K^{{2}}
#         + \alpha \bar{A}_{ij} \bar{A}^{ij}
#         - e^{-4\phi} \left(\bar{D}_i \bar{D}^i \alpha + 2 \bar{D}^i \alpha \bar{D}_i \phi\right) \\
#
#     % vardef -numeric 'lambdaU'
#     % srepl "\bar{\Lambda}" -> "\text{lambda}"
#     % parse \Delta^k_{ij} = \bar{\Gamma}^k_{ij} - \hat{\Gamma}^k_{ij}
#     % parse \Delta_{ijk}  = \bar{\gamma}_{il} \Delta^l_{jk}
#     % parse \Delta^k = \bar{\gamma}^{ij} \Delta^k_{ij}
#     % srepl "\partial_t \text{lambda}" -> "\text{Lambdabar_rhs}"
#     \partial_t \bar{\Lambda}^i &= \mathcal{L}_\beta \bar{\Lambda}^i + \bar{\gamma}^{jk} \hat{D}_j \hat{D}_k \beta^i
#             + \frac{2}{3} \Delta^i \bar{D}_k \beta^k + \frac{1}{3} \bar{D}^i \bar{D}_k \beta^k \\%
#             &\qquad- 2 \bar{A}^{ij} \left(\partial_j \alpha - 6 \alpha \partial_j \phi\right)
#             + 2 \alpha \bar{A}^{jk} \Delta^i_{jk} - \frac{4}{3} \alpha \bar{\gamma}^{ij} \partial_j K \\
#
#     % vardef -numeric -sym01 'RbarDD'
#     X_{ij} &= -2 \alpha \bar{D}_i \bar{D}_j \phi + 4 \alpha \bar{D}_i \phi \bar{D}_j \phi
#         + 2 \bar{D}_i \alpha \bar{D}_j \phi + 2 \bar{D}_j \alpha \bar{D}_i \phi
#         - \bar{D}_i \bar{D}_j \alpha + \alpha \bar{R}_{ij} \\
#     \hat{X}_{ij} &= X_{ij} - \frac{1}{3} \bar{\gamma}_{ij} \bar{\gamma}^{kl} X_{kl} \\
#     % srepl "\partial_t \text{a}" -> "\text{a_rhs}"
#     \partial_t \bar{A}_{ij} &= \mathcal{L}_\beta \bar{A}_{ij}
#             - \frac{2}{3} \bar{A}_{ij} \bar{D}_k \beta^k
#             - 2 \alpha \bar{A}_{ik} \bar{A}^k_j
#             + \alpha \bar{A}_{ij} K
#             + e^{-4\phi} \hat{X}_{ij} \\
#
#     % srepl "\partial_t \alpha" -> "\text{alpha_rhs}"
#     \partial_t \alpha &= \mathcal{L}_\beta \alpha - 2 \alpha K \\
#
#     % vardef -numeric 'betU'
#     % srepl "B" -> "\text{bet}"
#     % srepl "\partial_t \text{vet}" -> "\text{vet_rhs}"
#     \partial_t \beta^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j \beta^i\right] + B^i \\
#
#     % vardef -const 'eta'
#     % srepl "\partial_t \text{bet}" -> "\text{bet_rhs}"
#     \partial_t B^i &= \left[\beta^j \vphantom{upwind} \bar{D}_j B^i\right]
#         + \frac{3}{4} \left(\partial_t \bar{\Lambda}^i - \left[\beta^j \vphantom{upwind} \bar{D}_j \bar{\Lambda}^i\right]\right)
#         - \eta B^i \\
#
#     % parse \bar{R} = \bar{\gamma}^{ij} \bar{R}_{ij}
#     % srepl "\bar{D}^2" -> "\bar{D}^i \bar{D}_i", "\mathcal{<1>}" -> "<1>"
#     \mathcal{H} &= \frac{2}{3} K^{{2}} - \bar{A}_{ij} \bar{A}^{ij}
#         + e^{-4\phi} \left(\bar{R} - 8 \bar{D}^i \phi \bar{D}_i \phi - 8 \bar{D}^2 \phi\right) \\
#
#     % assign -numeric 'aUD', 'aUU'
#     \mathcal{M}^i &= e^{-4\phi} \left(\bar{D}_j \bar{A}^{ij} + 6 \bar{A}^{ij}\partial_j \phi
#         - \frac{2}{3} \bar{\gamma}^{ij} \partial_j K\right) \\
#
#     \bar{R}_{ij} &= -\frac{1}{2} \bar{\gamma}^{kl} \hat{D}_k \hat{D}_l \bar{\gamma}_{ij}
#             + \frac{1}{2} \left(\bar{\gamma}_{ki} \hat{D}_j \bar{\Lambda}^k + \bar{\gamma}_{kj} \hat{D}_i \bar{\Lambda}^k\right)
#             + \frac{1}{2} \Delta^k \left(\Delta_{ijk} + \Delta_{jik}\right) \\%
#             &\qquad+ \bar{\gamma}^{kl} \left(\Delta^m_{ki} \Delta_{jml} + \Delta^m_{kj} \Delta_{iml} + \Delta^m_{ik} \Delta_{mjl}\right)
# \end{align}
# Out:
# ('deltaDD',
#  'gammahatDD',
#  'epsilonUUU',
#  'gammahatdet',
#  'gammahatUU',
#  'hDD',
#  'gammabarDD',
#  'gammabardet',
#  'gammabarUU',
#  'vetU',
#  'aDD',
#  'aUD',
#  'gammabarDD_dupD',
#  'hDD_dupD',
#  'vetU_dD',
#  'gammabarDD_ldvet',
#  'h_rhsDD',
#  'cf_dupD',
#  'phi_ldvet',
#  'cf_rhs',
#  'aUU',
#  'trK_dupD',
#  'trK_ldvet',
#  'alpha_dD',
#  'alpha_cdbarD',
#  'alpha_cdbarU',
#  'alpha_cdbarU_dD',
#  'alpha_cdbarD_dD',
#  'alpha_dDD',
#  'gammabarUU_dD',
#  'gammabarDD_dD',
#  'hDD_dD',
#  'gammabardet_dD',
#  'GammabarUDD',
#  'alpha_cdbarUD',
#  'cf_dD',
#  'phi_cdbarD',
#  'trK_rhs',
#  'lambdaU',
#  'GammahatUDD',
#  'DeltaUDD',
#  'DeltaDDD',
#  'DeltaU',
#  'lambdaU_dupD',
#  'lambdaU_ldvet',
#  'vetU_cdhatD',
#  'vetU_cdhatD_dD',
#  'vetU_dDD',
#  'vetU_cdhatDD',
#  'gammahatdet_dD_cdbarD',
#  'gammahatdet_dD_cdbarU',
#  'vetU_cdbarD',
#  'vetU_cdbarU',
#  'gammahatdet_dD',
#  'gammahatdet_cdbarD',
#  'gammahatdet_cdbarU',
#  'vetU_dD_cdbarD',
#  'vetU_dD_cdbarU',
#  'trK_dD',
#  'Lambdabar_rhsU',
#  'RbarDD',
#  'phi_cdbarD_dD',
#  'cf_dDD',
#  'phi_cdbarDD',
#  'alpha_cdbarDD',
#  'XDD',
#  'XhatDD',
#  'aDD_dupD',
#  'aDD_ldvet',
#  'a_rhsDD',
#  'alpha_dupD',
#  'alpha_ldvet',
#  'alpha_rhs',
#  'betU',
#  'vetU_dupD',
#  'vet_rhsU',
#  'betU_dupD',
#  'betU_cdbarD',
#  'lambdaU_cdbarD',
#  'bet_rhsU',
#  'Rbar',
#  'phi_cdbarU',
#  'phi_cdbarDU',
#  'H',
#  'aUU_dD',
#  'aUD_dD',
#  'aDD_dD',
#  'aUU_cdbarD',
#  'MU',
#  'gammabarDD_cdhatD',
#  'gammabarDD_cdhatD_dD',
#  'gammabarDD_dDD',
#  'hDD_dDD',
#  'gammabarDD_cdhatDD',
#  'lambdaU_dD',
#  'lambdaU_cdhatD')

# %%
assert_equal(RbarDD, Bq.RbarDD)
# Out:
# Assertion Passed!

# %% [markdown]
# <a id='step_12'></a>
#
# ## Step 12: Output Notebook to PDF [ [^](#top) ]
#
# The following code cell converts this Jupyter notebook into a proper, clickable $\LaTeX$-formatted PDF file. After the cell is successfully run, the generated PDF may be found in the root NRPy+ tutorial directory, with filename
# [Tutorial-LaTeX_Interface_Example-BSSN_Cartesian.pdf](Tutorial-LaTeX_Interface_Example-BSSN_Cartesian.pdf) (Note that clicking on this link may not work; you may need to open the PDF file through another means.)

# %%
import cmdline_helper as cmd    # NRPy+: Multi-platform Python command-line interface
cmd.output_Jupyter_notebook_to_LaTeXed_PDF("Tutorial-LaTeX_Interface_Example-BSSN_Cartesian")
# Out:
# Created Tutorial-LaTeX_Interface_Example-BSSN_Cartesian.tex, and compiled
#     LaTeX file to PDF file Tutorial-LaTeX_Interface_Example-
#     BSSN_Cartesian.pdf
