# %% [markdown]
# # The Effective One-Body Cartesian Hamiltonian
#
# ### Authors: Tyler Knowles & Zach Etienne
#
# <font color='red'>**During development, all expressions generated in this module are being validated against a trusted code: the original LALSuite SEOBNRv3 code, and the Mathematica expressions for the LALSuite SEOBNRv3_opt code.**</font>
#
# This module documents and splits up the reduced spinning effective one-body Hamiltonian derived in [Barausse and Buonanno (2010)](https://arxiv.org/abs/0912.3517) and [Pan, Buonanno, Buchman, et. al (2010)](https://arxiv.org/abs/0912.3466) for use in efficient gravitational waveform generation software.  This Cartesian formulation is used to generate gravitational waveforms in LALSuite's SEOBNRv3 approximant.
#
# * Something to be checked: should the constants (like k0,...,k5) be symbols since we compute them?  Also, why are we *recomputing* them?  They're computed elsewhere and available in an array.

# %%
# import sympy as sp
# x,y,z,s1x,s1y,s1z,s2x,s2y,s2z = sp.symbols("x y z s1x s1y s1z s2x s2y s2z")
# blah = x+y
# g = sp.sin(blah)
# print(sp.mathematica_code(g))

# %%
import sympy as sp
m1,m2,x,y,z,px,py,pz,s1x,s1y,s1z,s2x,s2y,s2z,eta = sp.symbols("m1 m2 x y z px py pz s1x s1y s1z s2x s2y s2z eta",real=True)
c0k2,c1k2,c0k3,c1k3,c0k4,c1k4,c2k4,c0k5,c1k5,c2k5 = sp.symbols("c0k2 c1k2 c0k3 c1k3 c0k4 c1k4 c2k4 c0k5 c1k5 c2k5",real=True)
KK,k5l,b3,bb3,d1,d1v2,dheffSS,dheffSSv2 = sp.symbols("KK k5l b3 bb3 d1 d1v2 dheffSS dheffSSv2",real=True)
tortoise,copysignresult = sp.symbols("tortoise copysignresult",real=True)

sigmaKerr0 = s1x + s2x
sigmaKerr1 = s1y + s2y
sigmaKerr2 = s1z + s2z
invm1m2 = 1/(m1*m2)
m2overm1 = m2*m2*invm1m2
m1overm2 = m1*m1*invm1m2
sigmaStar0 = (m2overm1)*s1x + (m1overm2)*s2x
sigmaStar1 = (m2overm1)*s1y + (m1overm2)*s2y
sigmaStar2 = (m2overm1)*s1z + (m1overm2)*s2z
s1dots1 = s1x*s1x + s1y*s1y + s1z*s1z
s2dots2 = s2x*s2x + s2y*s2y + s2z*s2z
r2 = x*x + y*y + z*z
r = sp.sqrt(r2)
u = 1/r
u2 = u*u
u3 = u2*u
u4 = u2*u2
u5 = u4*u
etau3 = eta*u3
etau4 = eta*u4
nx = x*u
ny = y*u
nz = z*u
sKerrUSCOREx = sigmaKerr0
sKerrUSCOREy = sigmaKerr1
sKerrUSCOREz = sigmaKerr2
sStarUSCOREx = sigmaStar0
sStarUSCOREy = sigmaStar1
sStarUSCOREz = sigmaStar2
a2 = sKerrUSCOREx*sKerrUSCOREx + sKerrUSCOREy*sKerrUSCOREy + sKerrUSCOREz*sKerrUSCOREz
a4 = a2*a2
a = sp.sqrt(a2)
inva = 1/a
m1PlusetaKK = -1 + eta*KK
invm1PlusetaKK = 1/m1PlusetaKK
k0 = KK*(m1PlusetaKK - 1)
k1 = -2*(k0 + KK)*m1PlusetaKK
k2 = c0k2 + c1k2*a2
k3 = c0k3 + c1k3*a2
k4 = c0k4 + c1k4*a2 + c2k4*a4
k5 = c0k5 + c1k5*a2 + c2k5*a4
e3USCOREx = sKerrUSCOREx*inva
e3USCOREy = sKerrUSCOREy*inva
e3USCOREz = sKerrUSCOREz*inva
costheta = e3USCOREx*nx + e3USCOREy*ny + e3USCOREz*nz
xi2 = 1 - costheta*costheta
xiUSCOREx = -e3USCOREz*ny + e3USCOREy*nz
xiUSCOREy =  e3USCOREz*nx - e3USCOREx*nz
xiUSCOREz = -e3USCOREy*nx + e3USCOREx*ny
vx = -nz*xiUSCOREy + ny*xiUSCOREz
vy =  nz*xiUSCOREx - nx*xiUSCOREz
vz = -ny*xiUSCOREx + nx*xiUSCOREy
w2 = r2 + a2
rho2 = r2 + a2*costheta*costheta
bulk = invm1PlusetaKK*(invm1PlusetaKK + 2*u) + a2*u2
logu = sp.log( u )
logarg = k1*u + k2*u2 + k3*u3 + k4*u4 + k5*u5 + k5l*u5*logu
onepluslogarg = (1 + logarg)
invonepluslogarg = 1/onepluslogarg
logTerms = 1 + eta*k0 + eta*sp.log(onepluslogarg)
deltaU = bulk*logTerms

#deltaT = r2*deltaU
deltaT = sp.symbols('deltaT')

deltaUUSCOREupt7 = k5 + k5l*logu
deltaUUSCOREupt6 = 4*k4 + 5*deltaUUSCOREupt7*u
deltaUUSCOREupt5 = 3*k3 + u*deltaUUSCOREupt6
deltaUUSCOREupt4 = 2*k2 + u*deltaUUSCOREupt5
deltaUUSCOREupt3 = k1 + u*deltaUUSCOREupt4
deltaUUSCOREupt2 = invm1PlusetaKK + a2*u
deltaUUSCOREupt1 = bulk*eta*deltaUUSCOREupt3
deltaUUSCOREu = 2*deltaUUSCOREupt2*logTerms + deltaUUSCOREupt1*invonepluslogarg


#deltaTUSCOREr = 2*r*deltaU - deltaUUSCOREu
deltaTUSCOREr = sp.symbols('deltaTUSCOREr')

#Lambda = w2*w2 - a2*deltaT*xi2
Lambda = sp.symbols('Lambda')

rho2xi2Lambda = rho2*xi2*Lambda
invrho2xi2Lambda = 1/rho2xi2Lambda
invrho2 = xi2*Lambda*invrho2xi2Lambda
invxi2 = rho2*Lambda*invrho2xi2Lambda
invLambda = xi2*rho2*invrho2xi2Lambda
invLambdasq = invLambda*invLambda

rho2invLambda = rho2*invLambda
rho2invLambda = sp.symbols('rho2invLambda')

expnu = sp.sqrt(deltaT*rho2invLambda)
expMU = sp.sqrt(rho2)
expMUexpnu = expMU*expnu
expMUsq = expMU*expMU
expnusq = expnu*expnu
expMUsqexpnusq = expMUsq*expnusq
invexpnuexpMU = 1/expMUexpnu
invexpMU = expnu*invexpnuexpMU
invexpMUsq = invexpMU*invexpMU
expnuinvexpMU2 = expnu*invexpMUsq
invexpMUcubinvexpnu = invexpMUsq*invexpnuexpMU
DD = 1 +  sp.log(1 + 6*eta*u2 + 2*(26 - 3*eta)*etau3)
deltaR = deltaT*DD
qq = 2*eta*(4 - 3*eta)
ww = 2*a*r + b3*eta*a2*a*u + bb3*eta*a*u
B = sp.sqrt(deltaT)
sqrtdeltaT = B
sqrtdeltaR = sp.sqrt(deltaR)
deltaTsqrtdeltaR = deltaT*sqrtdeltaR
sqrtdeltaTdeltaTsqrtdeltaR = sqrtdeltaT*deltaTsqrtdeltaR
invdeltaTsqrtdeltaTsqrtdeltaR = 1./sqrtdeltaTdeltaTsqrtdeltaR

#invdeltaT = sqrtdeltaT*(sqrtdeltaR*invdeltaTsqrtdeltaTsqrtdeltaR)
invdeltaT = sp.symbols('invdeltaT')

invsqrtdeltaT = deltaTsqrtdeltaR*invdeltaTsqrtdeltaTsqrtdeltaR
invsqrtdeltaR = deltaT*sqrtdeltaT*invdeltaTsqrtdeltaTsqrtdeltaR
w = ww*invLambda
LambdaUSCOREr = 4*r*w2 - a2*deltaTUSCOREr*xi2
wwUSCOREr = 2*a - (a2*a*b3*eta)*u2 - bb3*eta*a*u2

BR = (-deltaT*invsqrtdeltaR + deltaTUSCOREr*sp.Rational(1,2))*invsqrtdeltaT
BR = sp.symbols('BR')

wr = (-LambdaUSCOREr*ww + Lambda*wwUSCOREr)*(invLambdasq)
nurpt2 = w2*(-4.*r*deltaT + w2*deltaTUSCOREr)
nurpt1 = nurpt2*invdeltaT
nur = r*invrho2 + sp.Rational(1,2)*invLambda*nurpt1
mur = r*invrho2 - invsqrtdeltaR
a2costheta = a2*costheta
wcospt2 = deltaT*ww
wcospt1 = invLambdasq*wcospt2
wcos  = -2*(a2costheta)*wcospt1
nucospt3 = invrho2*invLambda
nucospt2 = w2*nucospt3
nucospt1 = a2costheta*nucospt2
nucos = (w2 - deltaT)*nucospt1
mucos = a2costheta*invrho2
etaover12r = eta*sp.Rational(1,12)*u
csi = sp.sqrt(deltaT*deltaR)/w2
csi1  =  1 + (1-sp.Abs(1-tortoise)) * (csi - 1)
#csi2  =  1 + (sp.Rational(1,2)-copysign(0.5, 1.5-tortoise)) * (csi - 1)
csi2  =  1 + (sp.Rational(1,2)-copysignresult) * (csi - 1)
prT = (px*nx + py*ny + pz*nz)*csi2

prTtimesoneminuscsi1inv = prT*(1 - 1/csi1)
prTtimesoneminuscsi1inv = sp.symbols('prTtimesoneminuscsi1inv')

tmppx = px - nx*prTtimesoneminuscsi1inv
tmppy = py - ny*prTtimesoneminuscsi1inv
tmppz = pz - nz*prTtimesoneminuscsi1inv
pxir = (tmppx*xiUSCOREx + tmppy*xiUSCOREy + tmppz*xiUSCOREz)*r
pvr  = (tmppx*vx + tmppy*vy + tmppz*vz)*r
pvrsq = pvr*pvr
pn   =  tmppx*nx + tmppy*ny + tmppz*nz
pnsq = pn*pn
pr = pn
prsq = pr*pr
pf = pxir
pxirsq = pxir*pxir
ptheta2 = pvrsq*invxi2
prT4=prT*prT*prT*prT
Hnspt7 = deltaR*invrho2
Hnspt6 = rho2invLambda*invxi2
Hnspt5 = qq*u2
Hnspt4 = (1 + prT4*Hnspt5 + ptheta2*invrho2 + pf*pf*Hnspt6 + prsq*Hnspt7)
Hnspt3 = deltaT*Hnspt4
Hnspt2 = rho2*Hnspt3
Hnspt1 = pf*ww
Hns = sp.sqrt(Hnspt2*invLambda) + invLambda*Hnspt1
Qpt3 = deltaR*invrho2
Qpt2 = rho2invLambda*invxi2
Qpt1 = invrho2*invxi2
Q = 1 + pvrsq*Qpt1 + pxirsq*Qpt2 + pnsq*Qpt3
pn2 = prsq*deltaR*invrho2
pp  = Q - 1
sKerrmultfact = (-8 - 3*r*(12*pn2 - pp))
sStarmultfact = (14 + (- 30*pn2 + 4*pp)*r)
deltaSigmaStarUSCOREx1=etaover12r*(sKerrmultfact*sKerrUSCOREx + sStarmultfact*sStarUSCOREx)
deltaSigmaStarUSCOREy1=etaover12r*(sKerrmultfact*sKerrUSCOREy + sStarmultfact*sStarUSCOREy)
deltaSigmaStarUSCOREz1=etaover12r*(sKerrmultfact*sKerrUSCOREz + sStarmultfact*sStarUSCOREz)
pn2pp = pn2*pp
pp2 = pp*pp
pn2u2 = pn2*u2
ppu2 = pp*u2
pn2ppu2 = pn2pp*u2
sMultiplier1pt6 = -360*pn2*pn2 + 126*pn2pp + 3*pp2
sMultiplier1pt5 = -96*pn2pp + 23*pp2
sMultiplier1pt4 = -120*pp + 324*pn2 + sMultiplier1pt6*r
sMultiplier1pt3 = 206*pp - 282*pn2 + sMultiplier1pt5*r
sMultiplier1pt2 = 54 + sMultiplier1pt4*r
sMultiplier1pt1 = -706 + sMultiplier1pt3*r + sMultiplier1pt2*eta
sMultiplier1 = sMultiplier1pt1*eta*u2*sp.Rational(-1,72)
sMultiplier2pt6 = sp.Rational(45,8)*pn2*pn2u2 - sp.Rational(13,8)*pn2ppu2
sMultiplier2pt5 = pn2ppu2/4 - sp.Rational(5,16)*pp2*u2
sMultiplier2pt4 = sp.Rational(-49,8)*pn2u2 + sp.Rational(17,12)*ppu2 + sMultiplier2pt6*r
sMultiplier2pt3 = sp.Rational(-2,3)*pn2u2 - sp.Rational(109,36)*ppu2 + sMultiplier2pt5*r
sMultiplier2pt2 = sp.Rational(-7,3)*u2 + sMultiplier2pt4*r
sMultiplier2pt1 = sp.Rational(-56,9)*u2 + sMultiplier2pt3*r + sMultiplier2pt2*eta
sMultiplier2 = sMultiplier2pt1*eta
deltaSigmaStarUSCOREx2 = deltaSigmaStarUSCOREx1 + sMultiplier1*sigmaStar0 + sMultiplier2*sigmaKerr0
deltaSigmaStarUSCOREy2 = deltaSigmaStarUSCOREy1 + sMultiplier1*sigmaStar1 + sMultiplier2*sigmaKerr1
deltaSigmaStarUSCOREz2 = deltaSigmaStarUSCOREz1 + sMultiplier1*sigmaStar2 + sMultiplier2*sigmaKerr2
deltaSigmaStarUSCOREx3 = deltaSigmaStarUSCOREx2 + d1*sigmaStar0*etau3
deltaSigmaStarUSCOREy3 = deltaSigmaStarUSCOREy2 + d1*sigmaStar1*etau3
deltaSigmaStarUSCOREz3 = deltaSigmaStarUSCOREz2 + d1*sigmaStar2*etau3
deltaSigmaStarUSCOREx = deltaSigmaStarUSCOREx3 + d1v2*sigmaKerr0*etau3
deltaSigmaStarUSCOREy = deltaSigmaStarUSCOREy3 + d1v2*sigmaKerr1*etau3
deltaSigmaStarUSCOREz = deltaSigmaStarUSCOREz3 + d1v2*sigmaKerr2*etau3
sx = sStarUSCOREx + deltaSigmaStarUSCOREx
sy = sStarUSCOREy + deltaSigmaStarUSCOREy
sz = sStarUSCOREz + deltaSigmaStarUSCOREz
sxi = sx*xiUSCOREx + sy*xiUSCOREy + sz*xiUSCOREz
sv  = sx*vx + sy*vy + sz*vz
sn  = sx*nx + sy*ny + sz*nz
s3 = sx*e3USCOREx + sy*e3USCOREy + sz*e3USCOREz
sqrtQ = sp.sqrt(Q)
oneplus2sqrtQ = 1 + 2*sqrtQ
oneplus1sqrtQ = oneplus2sqrtQ - sqrtQ
twoB1psqrtQsqrtQ = (2*B*oneplus1sqrtQ*sqrtQ)
invtwoB1psqrtQsqrtQ = 1/twoB1psqrtQsqrtQ
expMUsqsqrtQplusQ = (expMUsq)*(sqrtQ + Q)
Hwrpt4a = pxirsq*sv
Hwrpt4 = expMUsqexpnusq*Hwrpt4a
Hwrpt3c = pxir*sxi
Hwrpt3b = pvr*Hwrpt3c
Hwrpt3a = expMUexpnu*Hwrpt3b
Hwrpt3 = B*Hwrpt3a
Hwrpt2g = sv*deltaR
Hwrpt2f = sn*sqrtdeltaR
Hwrpt2e = pvr*Hwrpt2f
Hwrpt2d = pnsq*Hwrpt2g
Hwrpt2c = pn*Hwrpt2e
Hwrpt2b = expMUsqsqrtQplusQ*sv
Hwrpt2a = xi2*(Hwrpt2b + Hwrpt2c - Hwrpt2d)
Hwrpt2 = deltaT*Hwrpt2a
Hwrpt1b = invtwoB1psqrtQsqrtQ*invxi2
Hwrpt1a = sqrtdeltaR*Hwrpt1b
Hwrpt1 = invexpMUcubinvexpnu*Hwrpt1a
Hwr = (Hwrpt4 - Hwrpt3 + Hwrpt2)*Hwrpt1
Hwcospt9 = pxir*sxi
Hwcospt8 = pvr*sv
Hwcospt7 = (B*Hwcospt8 - (expMUexpnu)*Hwcospt9)
Hwcospt6 = sqrtdeltaR*Hwcospt7
Hwcospt5 = (pvrsq - expMUsqsqrtQplusQ*xi2)
Hwcospt4 = pn*Hwcospt6
Hwcospt3 = -(expMUsqexpnusq*pxirsq) + deltaT*Hwcospt5
Hwcospt2 = sn*Hwcospt3 - B*Hwcospt4
Hwcospt1 = invexpMUcubinvexpnu*Hwcospt2
Hwcos = invtwoB1psqrtQsqrtQ*Hwcospt1
deltaTsqrtQ = deltaT*sqrtQ
invdeltatTsqrtQ = 1/deltaTsqrtQ
HSOLpt5 = (-B + (expMUexpnu))*pxir
HSOLpt4 = invexpMU*HSOLpt5
HSOLpt3 = expnusq*HSOLpt4
HSOLpt2 = (HSOLpt3*s3)
HSOLpt1 = HSOLpt2*invxi2
HSOL = HSOLpt1*invdeltatTsqrtQ
deltaTsqrtQplusQ = (deltaT*(sqrtQ + Q))
invdeltaTsqrtQplusQ = 1/deltaTsqrtQplusQ
HSONLmult2 = invxi2*invdeltaTsqrtQplusQ
HSONLmult = expnuinvexpMU2*HSONLmult2
HSONLpt1b = pn*xi2
HSONLpt1a = (mur*pvr - nur*pvr + (-mucos + nucos)*HSONLpt1b)
HSONLpt1 = mur*pvr - (mucos*HSONLpt1b) + sqrtQ*HSONLpt1a
HSONLpt2d = nur*pxir
HSONLpt2c = oneplus2sqrtQ*HSONLpt2d
HSONLpt2b = B*sxi
HSONLpt2a = expMUexpnu*HSONLpt2c
HSONLpt2 = (sv*HSONLpt2a + HSONLpt1*HSONLpt2b)
HSONLpt3c = sv*pxir
HSONLpt3b = oneplus1sqrtQ*HSONLpt3c
HSONLpt3a = expMUexpnu*HSONLpt3b
HSONLpt3 = -BR*HSONLpt3a + B*HSONLpt2
HSONLpt4e = sn*xi2
HSONLpt4d = oneplus2sqrtQ*HSONLpt4e
HSONLpt4c = pxir*HSONLpt4d
HSONLpt4b = nucos*HSONLpt4c
HSONLpt4a = expMUexpnu*HSONLpt4b
HSONLpt4 = (-(B*HSONLpt4a) + HSONLpt3*sqrtdeltaR)
HSONL = HSONLmult*HSONLpt4
Hs = w*s3 + Hwr*wr + Hwcos*wcos + HSOL + HSONL
Hsspt1 = sp.Rational(-1,2)*(sx*sx + sy*sy + sz*sz - 3*sn*sn)
Hss = u3*Hsspt1
sKerrdotsStar = (sKerrUSCOREx*sStarUSCOREx + sKerrUSCOREy*sStarUSCOREy + sKerrUSCOREz*sStarUSCOREz)
Hpt1 = etau4*(s1dots1 + s2dots2)
H = Hns + Hs + Hss + (dheffSS*sKerrdotsStar + dheffSSv2)*Hpt1
Hreal = sp.sqrt(1 + 2*eta*(H - 1))

#print(sp.mathematica_code(expnu))

# %%
from outputC import *
import time
start = time.time()

#outstring = "test"
outstring = outputC(pf,"pftest","returnstring","outCverbose=False,SIMD_enable=True,enable_TYPE=False,includebraces=False")

end = time.time()

print("Finished in " + str(end - start) + " seconds.")
# Out:
# Finished in 0.433350086212 seconds.

# %%
print("""(* Part 1: SIMD function definitions *)
MulSIMD[x_, y_] = x*y;
DivSIMD[x_, y_] = x/y;
AddSIMD[x_, y_] = x + y;
FusedMulAddSIMD[x_, y_, z_] = x*y + z;
FusedMulSubSIMD[x_, y_, z_] = x*y - z;
SqrtSIMD[x_] = Sqrt[x];
LogSIMD[x_] = Log[x];
SubSIMD[x_, y_] = x - y;
AbsSIMD[x_] = Abs[x];
PowSIMD[x_, y_] = x^y;

""")
print("(* Part 2: SEOBNR Hamiltonian *)")
print(outstring.replace("_Rational","Rational").replace("_Integer","Integer").replace("_","USCR")).replace("(","[").replace(")","]").replace(".000000000000000000000000000000000","").replace(".00000000000000000000000000000000","").replace("000000000000000000000000000000000","").replace("00000000000000000000000000000000","")
# replace(";","").
# Out:
# (* Part 1: SIMD function definitions *)
# MulSIMD[x_, y_] = x*y;
# DivSIMD[x_, y_] = x/y;
# AddSIMD[x_, y_] = x + y;
# FusedMulAddSIMD[x_, y_, z_] = x*y + z;
# FusedMulSubSIMD[x_, y_, z_] = x*y - z;
# SqrtSIMD[x_] = Sqrt[x];
# LogSIMD[x_] = Log[x];
# SubSIMD[x_, y_] = x - y;
# AbsSIMD[x_] = Abs[x];
# PowSIMD[x_, y_] = x^y;
#
#
# (* Part 2: SEOBNR Hamiltonian *)
# IntegerUSCR1 = 1;
# IntegerUSCRm1 = -1;
# tmp0 = SqrtSIMD[FusedMulAddSIMD[y, y, FusedMulAddSIMD[z, z, MulSIMD[x, x]]]];
# tmp1 = DivSIMD[IntegerUSCR1, tmp0];
# tmp2 = MulSIMD[prTtimesoneminuscsi1inv, tmp1];
# tmp3 = AddSIMD[s1y, s2y];
# tmp4 = AddSIMD[s1x, s2x];
# tmp5 = AddSIMD[s1z, s2z];
# tmp6 = DivSIMD[tmp1, SqrtSIMD[FusedMulAddSIMD[tmp4, tmp4, FusedMulAddSIMD[tmp5, tmp5, MulSIMD[tmp3, tmp3]]]]];
# tmp7 = MulSIMD[tmp6, z];
# tmp8 = MulSIMD[tmp5, tmp6];
# pftest = MulSIMD[tmp0, FusedMulAddSIMD[FusedMulAddSIMD[y, MulSIMD[tmp2, IntegerUSCRm1], py], FusedMulAddSIMD[tmp8, x, MulSIMD[tmp7, MulSIMD[tmp4, IntegerUSCRm1]]], FusedMulAddSIMD[FusedMulAddSIMD[z, MulSIMD[tmp2, IntegerUSCRm1], pz], FusedMulAddSIMD[x, MulSIMD[tmp6, MulSIMD[tmp3, IntegerUSCRm1]], MulSIMD[tmp6, MulSIMD[tmp4, y]]], MulSIMD[FusedMulAddSIMD[x, MulSIMD[tmp2, IntegerUSCRm1], px], FusedMulAddSIMD[y, MulSIMD[tmp8, IntegerUSCRm1], MulSIMD[tmp3, tmp7]]]]]];

# %%
bigstring = """
sigmaKerr0 = s1x + s2x
sigmaKerr1 = s1y + s2y
sigmaKerr2 = s1z + s2z
invm1m2 = 1/(m1*m2)
m2overm1 = m2*m2*invm1m2
m1overm2 = m1*m1*invm1m2
sigmaStar0 = (m2overm1)*s1x + (m1overm2)*s2x
sigmaStar1 = (m2overm1)*s1y + (m1overm2)*s2y
sigmaStar2 = (m2overm1)*s1z + (m1overm2)*s2z
s1dots1 = s1x*s1x + s1y*s1y + s1z*s1z
s2dots2 = s2x*s2x + s2y*s2y + s2z*s2z
r2 = x*x + y*y + z*z
r = sp.sqrt(r2)
u = 1/r
u2 = u*u
u3 = u2*u
u4 = u2*u2
u5 = u4*u
etau3 = eta*u3
etau4 = eta*u4
nx = x*u
ny = y*u
nz = z*u
sKerrUSCOREx = sigmaKerr0
sKerrUSCOREy = sigmaKerr1
sKerrUSCOREz = sigmaKerr2
sStarUSCOREx = sigmaStar0
sStarUSCOREy = sigmaStar1
sStarUSCOREz = sigmaStar2
a2 = sKerrUSCOREx*sKerrUSCOREx + sKerrUSCOREy*sKerrUSCOREy + sKerrUSCOREz*sKerrUSCOREz
a4 = a2*a2
a = sp.sqrt(a2)
inva = 1/a
m1PlusetaKK = -1 + eta*KK
invm1PlusetaKK = 1/m1PlusetaKK
k0 = KK*(m1PlusetaKK - 1)
k1 = -2*(k0 + KK)*m1PlusetaKK
k2 = c0k2 + c1k2*a2
k3 = c0k3 + c1k3*a2
k4 = c0k4 + c1k4*a2 + c2k4*a4
k5 = c0k5 + c1k5*a2 + c2k5*a4
e3USCOREx = sKerrUSCOREx*inva
e3USCOREy = sKerrUSCOREy*inva
e3USCOREz = sKerrUSCOREz*inva
costheta = e3USCOREx*nx + e3USCOREy*ny + e3USCOREz*nz
xi2 = 1 - costheta*costheta
xiUSCOREx = -e3USCOREz*ny + e3USCOREy*nz
xiUSCOREy =  e3USCOREz*nx - e3USCOREx*nz
xiUSCOREz = -e3USCOREy*nx + e3USCOREx*ny
vx = -nz*xiUSCOREy + ny*xiUSCOREz
vy =  nz*xiUSCOREx - nx*xiUSCOREz
vz = -ny*xiUSCOREx + nx*xiUSCOREy
w2 = r2 + a2
rho2 = r2 + a2*costheta*costheta
bulk = invm1PlusetaKK*(invm1PlusetaKK + 2*u) + a2*u2
logu = sp.log( u )
logarg = k1*u + k2*u2 + k3*u3 + k4*u4 + k5*u5 + k5l*u5*logu
onepluslogarg = (1 + logarg)
invonepluslogarg = 1/onepluslogarg
logTerms = 1 + eta*k0 + eta*sp.log(onepluslogarg)
deltaU = bulk*logTerms
deltaT = r2*deltaU
deltaUUSCOREupt7 = k5 + k5l*logu
deltaUUSCOREupt6 = 4*k4 + 5*deltaUUSCOREupt7*u
deltaUUSCOREupt5 = 3*k3 + u*deltaUUSCOREupt6
deltaUUSCOREupt4 = 2*k2 + u*deltaUUSCOREupt5
deltaUUSCOREupt3 = k1 + u*deltaUUSCOREupt4
deltaUUSCOREupt2 = invm1PlusetaKK + a2*u
deltaUUSCOREupt1 = bulk*eta*deltaUUSCOREupt3
deltaUUSCOREu = 2*deltaUUSCOREupt2*logTerms + deltaUUSCOREupt1*invonepluslogarg
deltaTUSCOREr = 2*r*deltaU - deltaUUSCOREu
Lambda = w2*w2 - a2*deltaT*xi2
rho2xi2Lambda = rho2*xi2*Lambda
invrho2xi2Lambda = 1/rho2xi2Lambda
invrho2 = xi2*Lambda*invrho2xi2Lambda
invxi2 = rho2*Lambda*invrho2xi2Lambda
invLambda = xi2*rho2*invrho2xi2Lambda
invLambdasq = invLambda*invLambda
rho2invLambda = rho2*invLambda
expnu = sp.sqrt(deltaT*rho2invLambda)
expMU = sp.sqrt(rho2)
expMUexpnu = expMU*expnu
expMUsq = expMU*expMU
expnusq = expnu*expnu
expMUsqexpnusq = expMUsq*expnusq
invexpnuexpMU = 1/expMUexpnu
invexpMU = expnu*invexpnuexpMU
invexpMUsq = invexpMU*invexpMU
expnuinvexpMU2 = expnu*invexpMUsq
invexpMUcubinvexpnu = invexpMUsq*invexpnuexpMU
DD = 1 +  sp.log(1 + 6*eta*u2 + 2*(26 - 3*eta)*etau3)
deltaR = deltaT*DD
qq = 2*eta*(4 - 3*eta)
ww = 2*a*r + b3*eta*a2*a*u + bb3*eta*a*u
B = sp.sqrt(deltaT)
sqrtdeltaT = B
sqrtdeltaR = sp.sqrt(deltaR)
deltaTsqrtdeltaR = deltaT*sqrtdeltaR
sqrtdeltaTdeltaTsqrtdeltaR = sqrtdeltaT*deltaTsqrtdeltaR
invdeltaTsqrtdeltaTsqrtdeltaR = 1./sqrtdeltaTdeltaTsqrtdeltaR
invdeltaT = sqrtdeltaT*(sqrtdeltaR*invdeltaTsqrtdeltaTsqrtdeltaR)
invsqrtdeltaT = deltaTsqrtdeltaR*invdeltaTsqrtdeltaTsqrtdeltaR
invsqrtdeltaR = deltaT*sqrtdeltaT*invdeltaTsqrtdeltaTsqrtdeltaR
w = ww*invLambda
LambdaUSCOREr = 4*r*w2 - a2*deltaTUSCOREr*xi2
wwUSCOREr = 2*a - (a2*a*b3*eta)*u2 - bb3*eta*a*u2
BR = (-deltaT*invsqrtdeltaR + deltaTUSCOREr*sp.Rational(1,2))*invsqrtdeltaT
wr = (-LambdaUSCOREr*ww + Lambda*wwUSCOREr)*(invLambdasq)
nurpt2 = w2*(-4.*r*deltaT + w2*deltaTUSCOREr)
nurpt1 = nurpt2*invdeltaT
nur = r*invrho2 + sp.Rational(1,2)*invLambda*nurpt1
mur = r*invrho2 - invsqrtdeltaR
a2costheta = a2*costheta
wcospt2 = deltaT*ww
wcospt1 = invLambdasq*wcospt2
wcos  = -2*(a2costheta)*wcospt1
nucospt3 = invrho2*invLambda
nucospt2 = w2*nucospt3
nucospt1 = a2costheta*nucospt2
nucos = (w2 - deltaT)*nucospt1
mucos = a2costheta*invrho2
etaover12r = eta*sp.Rational(1,12)*u
csi = sp.sqrt(deltaT*deltaR)/w2
csi1  =  1 + (1-sp.Abs(1-tortoise)) * (csi - 1)
#csi2  =  1 + (sp.Rational(1,2)-copysign(0.5, 1.5-tortoise)) * (csi - 1)
csi2  =  1 + (sp.Rational(1,2)-copysignresult) * (csi - 1)
prT = (px*nx + py*ny + pz*nz)*csi2
prTtimesoneminuscsi1inv = prT*(1 - 1/csi1)
tmppx = px - nx*prTtimesoneminuscsi1inv
tmppy = py - ny*prTtimesoneminuscsi1inv
tmppz = pz - nz*prTtimesoneminuscsi1inv
pxir = (tmppx*xiUSCOREx + tmppy*xiUSCOREy + tmppz*xiUSCOREz)*r
pvr  = (tmppx*vx + tmppy*vy + tmppz*vz)*r
pvrsq = pvr*pvr
pn   =  tmppx*nx + tmppy*ny + tmppz*nz
pnsq = pn*pn
pr = pn
prsq = pr*pr
pf = pxir
pxirsq = pxir*pxir
ptheta2 = pvrsq*invxi2
prT4=prT*prT*prT*prT
Hnspt7 = deltaR*invrho2
Hnspt6 = rho2invLambda*invxi2
Hnspt5 = qq*u2
Hnspt4 = (1 + prT4*Hnspt5 + ptheta2*invrho2 + pf*pf*Hnspt6 + prsq*Hnspt7)
Hnspt3 = deltaT*Hnspt4
Hnspt2 = rho2*Hnspt3
Hnspt1 = pf*ww
Hns = sp.sqrt(Hnspt2*invLambda) + invLambda*Hnspt1
Qpt3 = deltaR*invrho2
Qpt2 = rho2invLambda*invxi2
Qpt1 = invrho2*invxi2
Q = 1 + pvrsq*Qpt1 + pxirsq*Qpt2 + pnsq*Qpt3
pn2 = prsq*deltaR*invrho2
pp  = Q - 1
sKerrmultfact = (-8 - 3*r*(12*pn2 - pp))
sStarmultfact = (14 + (- 30*pn2 + 4*pp)*r)
deltaSigmaStarUSCOREx1=etaover12r*(sKerrmultfact*sKerrUSCOREx + sStarmultfact*sStarUSCOREx)
deltaSigmaStarUSCOREy1=etaover12r*(sKerrmultfact*sKerrUSCOREy + sStarmultfact*sStarUSCOREy)
deltaSigmaStarUSCOREz1=etaover12r*(sKerrmultfact*sKerrUSCOREz + sStarmultfact*sStarUSCOREz)
pn2pp = pn2*pp
pp2 = pp*pp
pn2u2 = pn2*u2
ppu2 = pp*u2
pn2ppu2 = pn2pp*u2
sMultiplier1pt6 = -360*pn2*pn2 + 126*pn2pp + 3*pp2
sMultiplier1pt5 = -96*pn2pp + 23*pp2
sMultiplier1pt4 = -120*pp + 324*pn2 + sMultiplier1pt6*r
sMultiplier1pt3 = 206*pp - 282*pn2 + sMultiplier1pt5*r
sMultiplier1pt2 = 54 + sMultiplier1pt4*r
sMultiplier1pt1 = -706 + sMultiplier1pt3*r + sMultiplier1pt2*eta
sMultiplier1 = sMultiplier1pt1*eta*u2*sp.Rational(-1,72)
sMultiplier2pt6 = sp.Rational(45,8)*pn2*pn2u2 - sp.Rational(13,8)*pn2ppu2
sMultiplier2pt5 = pn2ppu2/4 - sp.Rational(5,16)*pp2*u2
sMultiplier2pt4 = sp.Rational(-49,8)*pn2u2 + sp.Rational(17,12)*ppu2 + sMultiplier2pt6*r
sMultiplier2pt3 = sp.Rational(-2,3)*pn2u2 - sp.Rational(109,36)*ppu2 + sMultiplier2pt5*r
sMultiplier2pt2 = sp.Rational(-7,3)*u2 + sMultiplier2pt4*r
sMultiplier2pt1 = sp.Rational(-56,9)*u2 + sMultiplier2pt3*r + sMultiplier2pt2*eta
sMultiplier2 = sMultiplier2pt1*eta
deltaSigmaStarUSCOREx2 = deltaSigmaStarUSCOREx1 + sMultiplier1*sigmaStar0 + sMultiplier2*sigmaKerr0
deltaSigmaStarUSCOREy2 = deltaSigmaStarUSCOREy1 + sMultiplier1*sigmaStar1 + sMultiplier2*sigmaKerr1
deltaSigmaStarUSCOREz2 = deltaSigmaStarUSCOREz1 + sMultiplier1*sigmaStar2 + sMultiplier2*sigmaKerr2
deltaSigmaStarUSCOREx3 = deltaSigmaStarUSCOREx2 + d1*sigmaStar0*etau3
deltaSigmaStarUSCOREy3 = deltaSigmaStarUSCOREy2 + d1*sigmaStar1*etau3
deltaSigmaStarUSCOREz3 = deltaSigmaStarUSCOREz2 + d1*sigmaStar2*etau3
deltaSigmaStarUSCOREx = deltaSigmaStarUSCOREx3 + d1v2*sigmaKerr0*etau3
deltaSigmaStarUSCOREy = deltaSigmaStarUSCOREy3 + d1v2*sigmaKerr1*etau3
deltaSigmaStarUSCOREz = deltaSigmaStarUSCOREz3 + d1v2*sigmaKerr2*etau3
sx = sStarUSCOREx + deltaSigmaStarUSCOREx
sy = sStarUSCOREy + deltaSigmaStarUSCOREy
sz = sStarUSCOREz + deltaSigmaStarUSCOREz
sxi = sx*xiUSCOREx + sy*xiUSCOREy + sz*xiUSCOREz
sv  = sx*vx + sy*vy + sz*vz
sn  = sx*nx + sy*ny + sz*nz
s3 = sx*e3USCOREx + sy*e3USCOREy + sz*e3USCOREz
sqrtQ = sp.sqrt(Q)
oneplus2sqrtQ = 1 + 2*sqrtQ
oneplus1sqrtQ = oneplus2sqrtQ - sqrtQ
twoB1psqrtQsqrtQ = (2*B*oneplus1sqrtQ*sqrtQ)
invtwoB1psqrtQsqrtQ = 1/twoB1psqrtQsqrtQ
expMUsqsqrtQplusQ = (expMUsq)*(sqrtQ + Q)
Hwrpt4a = pxirsq*sv
Hwrpt4 = expMUsqexpnusq*Hwrpt4a
Hwrpt3c = pxir*sxi
Hwrpt3b = pvr*Hwrpt3c
Hwrpt3a = expMUexpnu*Hwrpt3b
Hwrpt3 = B*Hwrpt3a
Hwrpt2g = sv*deltaR
Hwrpt2f = sn*sqrtdeltaR
Hwrpt2e = pvr*Hwrpt2f
Hwrpt2d = pnsq*Hwrpt2g
Hwrpt2c = pn*Hwrpt2e
Hwrpt2b = expMUsqsqrtQplusQ*sv
Hwrpt2a = xi2*(Hwrpt2b + Hwrpt2c - Hwrpt2d)
Hwrpt2 = deltaT*Hwrpt2a
Hwrpt1b = invtwoB1psqrtQsqrtQ*invxi2
Hwrpt1a = sqrtdeltaR*Hwrpt1b
Hwrpt1 = invexpMUcubinvexpnu*Hwrpt1a
Hwr = (Hwrpt4 - Hwrpt3 + Hwrpt2)*Hwrpt1
Hwcospt9 = pxir*sxi
Hwcospt8 = pvr*sv
Hwcospt7 = (B*Hwcospt8 - (expMUexpnu)*Hwcospt9)
Hwcospt6 = sqrtdeltaR*Hwcospt7
Hwcospt5 = (pvrsq - expMUsqsqrtQplusQ*xi2)
Hwcospt4 = pn*Hwcospt6
Hwcospt3 = -(expMUsqexpnusq*pxirsq) + deltaT*Hwcospt5
Hwcospt2 = sn*Hwcospt3 - B*Hwcospt4
Hwcospt1 = invexpMUcubinvexpnu*Hwcospt2
Hwcos = invtwoB1psqrtQsqrtQ*Hwcospt1
deltaTsqrtQ = deltaT*sqrtQ
invdeltatTsqrtQ = 1/deltaTsqrtQ
HSOLpt5 = (-B + (expMUexpnu))*pxir
HSOLpt4 = invexpMU*HSOLpt5
HSOLpt3 = expnusq*HSOLpt4
HSOLpt2 = (HSOLpt3*s3)
HSOLpt1 = HSOLpt2*invxi2
HSOL = HSOLpt1*invdeltatTsqrtQ
deltaTsqrtQplusQ = (deltaT*(sqrtQ + Q))
invdeltaTsqrtQplusQ = 1/deltaTsqrtQplusQ
HSONLmult2 = invxi2*invdeltaTsqrtQplusQ
HSONLmult = expnuinvexpMU2*HSONLmult2
HSONLpt1b = pn*xi2
HSONLpt1a = (mur*pvr - nur*pvr + (-mucos + nucos)*HSONLpt1b)
HSONLpt1 = mur*pvr - (mucos*HSONLpt1b) + sqrtQ*HSONLpt1a
HSONLpt2d = nur*pxir
HSONLpt2c = oneplus2sqrtQ*HSONLpt2d
HSONLpt2b = B*sxi
HSONLpt2a = expMUexpnu*HSONLpt2c
HSONLpt2 = (sv*HSONLpt2a + HSONLpt1*HSONLpt2b)
HSONLpt3c = sv*pxir
HSONLpt3b = oneplus1sqrtQ*HSONLpt3c
HSONLpt3a = expMUexpnu*HSONLpt3b
HSONLpt3 = -BR*HSONLpt3a + B*HSONLpt2
HSONLpt4e = sn*xi2
HSONLpt4d = oneplus2sqrtQ*HSONLpt4e
HSONLpt4c = pxir*HSONLpt4d
HSONLpt4b = nucos*HSONLpt4c
HSONLpt4a = expMUexpnu*HSONLpt4b
HSONLpt4 = (-(B*HSONLpt4a) + HSONLpt3*sqrtdeltaR)
HSONL = HSONLmult*HSONLpt4
Hs = w*s3 + Hwr*wr + Hwcos*wcos + HSOL + HSONL
Hsspt1 = sp.Rational(-1,2)*(sx*sx + sy*sy + sz*sz - 3*sn*sn)
Hss = u3*Hsspt1
sKerrdotsStar = (sKerrUSCOREx*sStarUSCOREx + sKerrUSCOREy*sStarUSCOREy + sKerrUSCOREz*sStarUSCOREz)
Hpt1 = etau4*(s1dots1 + s2dots2)
H = Hns + Hs + Hss + (dheffSS*sKerrdotsStar + dheffSSv2)*Hpt1
Hreal = sp.sqrt(1 + 2*eta*(H - 1))
"""

# %%
from outputC import *

# Split bigstring by carriage returns:
blah = bigstring.splitlines()

# Create "lr" array, which will store each left-hand side and right-hand side as strings.
lr = []
# Loop over each line in bigstring
for i in range(len(blah)):
    # Ignore lines with 2 or fewer characters and those starting with #
    if len(blah[i]) > 2 and blah[i][0] != "#": 
        # Split each line by its equals sign.
        splitblah = blah[i].split("=") 
        # Append to the "lr" array, removing spaces, "sp." prefixes, and replacing Lambda->Lamb 
        #       (Lambda is a protected keyword):
        #lhs = 
        lr.append(lhrh(lhs=splitblah[0].replace(" ","").replace("Lambda","Lamb"), 
                       rhs=splitblah[1].replace(" ","").replace("sp.","").replace("Lambda","Lamb"))) 

# print(lr[1].lhs)

xx = sp.Symbol('xx')
func = []
lhss = []
rhss = []
for i in range(len(lr)):
    func.append(sp.sympify(sp.Function(lr[i].lhs)(xx)))
#     print(i,lr[i].rhs)
    lhss.append(sp.sympify(lr[i].lhs))
    rhss.append(sp.sympify(lr[i].rhs))

# Next get a list of all the "free symbols" in the RHS expressions.
full_symbol_list_with_dups = []
for i in range(len(lr)):
    for var in rhss[i].free_symbols:
        full_symbol_list_with_dups.append(var)

full_symbol_list = superfast_uniq(full_symbol_list_with_dups)

# Next declare independent variables:
# x,y,z,px,py,pz,s1x,s1y,s1z,s2x,s2y,s2z = sp.symbols("x y z px py pz s1x s1y s1z s2x s2y s2z",real=True)
# independent_variables = [x,y,z,px,py,pz,s1x,s1y,s1z,s2x,s2y,s2z]

# Next declare input constants:
m1,m2,eta = sp.symbols("m1 m2 eta",real=True)
c0k2,c1k2,c0k3,c1k3,c0k4,c1k4,c2k4,c0k5,c1k5,c2k5 = sp.symbols("c0k2 c1k2 c0k3 c1k3 c0k4 c1k4 c2k4 c0k5 c1k5 c2k5",real=True)
KK,k5l,b3,bb3,d1,d1v2,dheffSS,dheffSSv2 = sp.symbols("KK k5l b3 bb3 d1 d1v2 dheffSS dheffSSv2",real=True)
tortoise,copysignresult = sp.symbols("tortoise copysignresult",real=True)
input_constants = [m1,m2,eta,
                   c0k2,c1k2,c0k3,c1k3,c0k4,c1k4,c2k4,c0k5,c1k5,c2k5,
                   KK,k5l,b3,bb3,d1,d1v2,dheffSS,dheffSSv2,
                   tortoise,copysignresult]

# Derivatives of input constants will always be zero, so 
# print(full_symbol_list)
for inputconst in input_constants:
    for symbol in full_symbol_list:
        if str(symbol) == str(inputconst):
            full_symbol_list.remove(symbol)

full_function_list = []
for symb in full_symbol_list:
    func = sp.sympify(sp.Function(str(symb))(xx))
    full_function_list.append(func)
    for i in range(len(rhss)):
        for var in rhss[i].free_symbols:
            if str(var) == str(symb):
                rhss[i] = rhss[i].subs(var,func)

lhss_deriv = []
rhss_deriv = []
for i in range(len(rhss)):
    lhss_deriv.append(sp.sympify(str(lhss[i])+"prm"))
    newrhs = sp.sympify(str(sp.diff(rhss[i],xx)).replace("(xx)","").replace(", xx","prm").replace("Derivative",""))
    rhss_deriv.append(newrhs)
    #     rhss_deriv.append(sp.diff(rhss[i],xx))

def simplify_deriv(lhss_deriv,rhss_deriv):
    lhss_deriv_simp = []
    rhss_deriv_simp = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_simp.append(lhss_deriv[i])
        rhss_deriv_simp.append(rhss_deriv[i])
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == 0:
            for j in range(i+1,len(rhss_deriv_simp)):
                for var in rhss_deriv_simp[j].free_symbols:
                    if str(var) == str(lhss_deriv_simp[i]):
                        rhss_deriv_simp[j] = rhss_deriv_simp[j].subs(var,0)
    zero_elements_to_remove = []
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == sp.sympify(0):
            zero_elements_to_remove.append(i)
    count = 0
    for i in range(len(zero_elements_to_remove)):
        del lhss_deriv_simp[zero_elements_to_remove[i]+count]
        del rhss_deriv_simp[zero_elements_to_remove[i]+count]
        count -= 1
    return lhss_deriv_simp,rhss_deriv_simp

lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv,rhss_deriv)
lhss_deriv = lhss_deriv_simp
rhss_deriv = rhss_deriv_simp

def deriv_onevar(lhss_deriv,rhss_deriv,
                 xprm=0,yprm=0,zprm=0,pxprm=0,pyprm=0,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=0):
    
    lhss_deriv_new = []
    rhss_deriv_new = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_new.append(lhss_deriv[i])
        rhss_deriv_new.append(rhss_deriv[i])
    for i in range(len(rhss_deriv_new)):
        for var in rhss_deriv_new[i].free_symbols:
            if str(var)=="xprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,xprm)
            elif str(var)=="yprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,yprm)
            elif str(var)=="zprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,zprm)
            elif str(var)=="pxprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,pxprm)
            elif str(var)=="pyprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,pyprm)
            elif str(var)=="pzprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,pzprm)
            elif str(var)=="s1xprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,s1xprm)
            elif str(var)=="s1yprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,s1yprm)
            elif str(var)=="s1zprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,s1zprm)
            elif str(var)=="s2xprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,s2xprm)
            elif str(var)=="s2yprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,s2yprm)
            elif str(var)=="s2zprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,s2zprm)
    lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv_new,rhss_deriv_new)
    return lhss_deriv_simp,rhss_deriv_simp

lhss_deriv_x,rhss_deriv_x = deriv_onevar(lhss_deriv,rhss_deriv, \
                            xprm=1,yprm=0,zprm=0,pxprm=0,pyprm=0,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=0)
lhss_deriv_y,rhss_deriv_y = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=1,zprm=0,pxprm=0,pyprm=0,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=0)
lhss_deriv_z,rhss_deriv_z = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=1,pxprm=0,pyprm=0,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=0)
lhss_deriv_px,rhss_deriv_px = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=0,pxprm=1,pyprm=0,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=0)
lhss_deriv_py,rhss_deriv_py = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=0,pxprm=0,pyprm=1,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=0)
lhss_deriv_pz,rhss_deriv_pz = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=0,pxprm=0,pyprm=1,pzprm=1,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=0)
lhss_deriv_s1x,rhss_deriv_s1x = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=0,pxprm=0,pyprm=0,pzprm=0,s1xprm=1,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=0)
lhss_deriv_s1x,rhss_deriv_s1y = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=0,pxprm=0,pyprm=0,pzprm=0,s1xprm=0,s1yprm=1,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=0)
lhss_deriv_s1x,rhss_deriv_s1z = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=0,pxprm=0,pyprm=0,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=1,s2xprm=0,s2yprm=0,s2zprm=0)
lhss_deriv_s1x,rhss_deriv_s2x = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=0,pxprm=0,pyprm=0,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=1,s2yprm=0,s2zprm=0)
lhss_deriv_s1x,rhss_deriv_s2y = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=0,pxprm=0,pyprm=0,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=1,s2zprm=0)
lhss_deriv_s1x,rhss_deriv_s2z = deriv_onevar(lhss_deriv,rhss_deriv,
                            xprm=0,yprm=0,zprm=0,pxprm=0,pyprm=0,pzprm=0,s1xprm=0,s1yprm=0,s1zprm=0,s2xprm=0,s2yprm=0,s2zprm=1)

outstring = "/* SEOBNR Hamiltonian expression: */\n"
for i in range(len(lr)):
    outstring += outputC(sp.sympify(lr[i].rhs),lr[i].lhs,"returnstring","outCverbose=False,includebraces=False,CSE_enable=False")
outstring += "\n\n\n/* SEOBNR \partial_x H expression: */\n"
for i in range(len(lhss_deriv_x)):
    outstring += outputC(rhss_deriv_x[i],str(lhss_deriv_x[i]),"returnstring","outCverbose=False,includebraces=False,CSE_enable=False")
print(outstring)
# Out:
# /* SEOBNR Hamiltonian expression: */
# sigmaKerr0 = s1x + s2x;
# sigmaKerr1 = s1y + s2y;
# sigmaKerr2 = s1z + s2z;
# invm1m2 = 1/(m1*m2);
# m2overm1 = invm1m2*pow(m2, 2);
# m1overm2 = invm1m2*pow(m1, 2);
# sigmaStar0 = m1overm2*s2x + m2overm1*s1x;
# sigmaStar1 = m1overm2*s2y + m2overm1*s1y;
# sigmaStar2 = m1overm2*s2z + m2overm1*s1z;
# s1dots1 = pow(s1x, 2) + pow(s1y, 2) + pow(s1z, 2);
# s2dots2 = pow(s2x, 2) + pow(s2y, 2) + pow(s2z, 2);
# r2 = pow(x, 2) + pow(y, 2) + pow(z, 2);
# r = sqrt(r2);
# u = 1.0/r;
# u2 = pow(u, 2);
# u3 = u*u2;
# u4 = pow(u2, 2);
# u5 = u*u4;
# etau3 = eta*u3;
# etau4 = eta*u4;
# nx = u*x;
# ny = u*y;
# nz = u*z;
# sKerrUSCOREx = sigmaKerr0;
# sKerrUSCOREy = sigmaKerr1;
# sKerrUSCOREz = sigmaKerr2;
# sStarUSCOREx = sigmaStar0;
# sStarUSCOREy = sigmaStar1;
# sStarUSCOREz = sigmaStar2;
# a2 = pow(sKerrUSCOREx, 2) + pow(sKerrUSCOREy, 2) + pow(sKerrUSCOREz, 2);
# a4 = pow(a2, 2);
# a = sqrt(a2);
# inva = 1.0/a;
# m1PlusetaKK = KK*eta - 1;
# invm1PlusetaKK = 1.0/m1PlusetaKK;
# k0 = KK*(m1PlusetaKK - 1);
# k1 = m1PlusetaKK*(-2*KK - 2*k0);
# k2 = a2*c1k2 + c0k2;
# k3 = a2*c1k3 + c0k3;
# k4 = a2*c1k4 + a4*c2k4 + c0k4;
# k5 = a2*c1k5 + a4*c2k5 + c0k5;
# e3USCOREx = inva*sKerrUSCOREx;
# e3USCOREy = inva*sKerrUSCOREy;
# e3USCOREz = inva*sKerrUSCOREz;
# costheta = e3USCOREx*nx + e3USCOREy*ny + e3USCOREz*nz;
# xi2 = 1 - pow(costheta, 2);
# xiUSCOREx = e3USCOREy*nz - e3USCOREz*ny;
# xiUSCOREy = -e3USCOREx*nz + e3USCOREz*nx;
# xiUSCOREz = e3USCOREx*ny - e3USCOREy*nx;
# vx = ny*xiUSCOREz - nz*xiUSCOREy;
# vy = -nx*xiUSCOREz + nz*xiUSCOREx;
# vz = nx*xiUSCOREy - ny*xiUSCOREx;
# w2 = a2 + r2;
# rho2 = a2*pow(costheta, 2) + r2;
# bulk = a2*u2 + invm1PlusetaKK*(invm1PlusetaKK + 2*u);
# logu = log(u);
# logarg = k1*u + k2*u2 + k3*u3 + k4*u4 + k5*u5 + k5l*logu*u5;
# onepluslogarg = logarg + 1;
# invonepluslogarg = 1.0/onepluslogarg;
# logTerms = eta*k0 + eta*log(onepluslogarg) + 1;
# deltaU = bulk*logTerms;
# deltaT = deltaU*r2;
# deltaUUSCOREupt7 = k5 + k5l*logu;
# deltaUUSCOREupt6 = 5*deltaUUSCOREupt7*u + 4*k4;
# deltaUUSCOREupt5 = deltaUUSCOREupt6*u + 3*k3;
# deltaUUSCOREupt4 = deltaUUSCOREupt5*u + 2*k2;
# deltaUUSCOREupt3 = deltaUUSCOREupt4*u + k1;
# deltaUUSCOREupt2 = a2*u + invm1PlusetaKK;
# deltaUUSCOREupt1 = bulk*deltaUUSCOREupt3*eta;
# deltaUUSCOREu = deltaUUSCOREupt1*invonepluslogarg + 2*deltaUUSCOREupt2*logTerms;
# deltaTUSCOREr = 2*deltaU*r - deltaUUSCOREu;
# Lamb = -a2*deltaT*xi2 + pow(w2, 2);
# rho2xi2Lamb = Lamb*rho2*xi2;
# invrho2xi2Lamb = 1.0/rho2xi2Lamb;
# invrho2 = Lamb*invrho2xi2Lamb*xi2;
# invxi2 = Lamb*invrho2xi2Lamb*rho2;
# invLamb = invrho2xi2Lamb*rho2*xi2;
# invLambsq = pow(invLamb, 2);
# rho2invLamb = invLamb*rho2;
# expnu = sqrt(deltaT*rho2invLamb);
# expMU = sqrt(rho2);
# expMUexpnu = expMU*expnu;
# expMUsq = pow(expMU, 2);
# expnusq = pow(expnu, 2);
# expMUsqexpnusq = expMUsq*expnusq;
# invexpnuexpMU = 1.0/expMUexpnu;
# invexpMU = expnu*invexpnuexpMU;
# invexpMUsq = pow(invexpMU, 2);
# expnuinvexpMU2 = expnu*invexpMUsq;
# invexpMUcubinvexpnu = invexpMUsq*invexpnuexpMU;
# DD = log(6*eta*u2 + etau3*(52 - 6*eta) + 1) + 1;
# deltaR = DD*deltaT;
# qq = 2*eta*(4 - 3*eta);
# ww = a*a2*b3*eta*u + a*bb3*eta*u + 2*a*r;
# B = sqrt(deltaT);
# sqrtdeltaT = B;
# sqrtdeltaR = sqrt(deltaR);
# deltaTsqrtdeltaR = deltaT*sqrtdeltaR;
# sqrtdeltaTdeltaTsqrtdeltaR = deltaTsqrtdeltaR*sqrtdeltaT;
# invdeltaTsqrtdeltaTsqrtdeltaR = 1.0/sqrtdeltaTdeltaTsqrtdeltaR;
# invdeltaT = invdeltaTsqrtdeltaTsqrtdeltaR*sqrtdeltaR*sqrtdeltaT;
# invsqrtdeltaT = deltaTsqrtdeltaR*invdeltaTsqrtdeltaTsqrtdeltaR;
# invsqrtdeltaR = deltaT*invdeltaTsqrtdeltaTsqrtdeltaR*sqrtdeltaT;
# w = invLamb*ww;
# LambUSCOREr = -a2*deltaTUSCOREr*xi2 + 4*r*w2;
# wwUSCOREr = -a*a2*b3*eta*u2 - a*bb3*eta*u2 + 2*a;
# BR = invsqrtdeltaT*(-deltaT*invsqrtdeltaR + (1.0/2.0)*deltaTUSCOREr);
# wr = invLambsq*(Lamb*wwUSCOREr - LambUSCOREr*ww);
# nurpt2 = w2*(-4.0*deltaT*r + deltaTUSCOREr*w2);
# nurpt1 = invdeltaT*nurpt2;
# nur = (1.0/2.0)*invLamb*nurpt1 + invrho2*r;
# mur = invrho2*r - invsqrtdeltaR;
# a2costheta = a2*costheta;
# wcospt2 = deltaT*ww;
# wcospt1 = invLambsq*wcospt2;
# wcos = -2*a2costheta*wcospt1;
# nucospt3 = invLamb*invrho2;
# nucospt2 = nucospt3*w2;
# nucospt1 = a2costheta*nucospt2;
# nucos = nucospt1*(-deltaT + w2);
# mucos = a2costheta*invrho2;
# etaover12r = (1.0/12.0)*eta*u;
# csi = sqrt(deltaR*deltaT)/w2;
# csi1 = (1 - fabs(tortoise - 1))*(csi - 1) + 1;
# csi2 = (1.0/2.0 - copysignresult)*(csi - 1) + 1;
# prT = csi2*(nx*px + ny*py + nz*pz);
# prTtimesoneminuscsi1inv = prT*(1 - 1/csi1);
# tmppx = -nx*prTtimesoneminuscsi1inv + px;
# tmppy = -ny*prTtimesoneminuscsi1inv + py;
# tmppz = -nz*prTtimesoneminuscsi1inv + pz;
# pxir = r*(tmppx*xiUSCOREx + tmppy*xiUSCOREy + tmppz*xiUSCOREz);
# pvr = r*(tmppx*vx + tmppy*vy + tmppz*vz);
# pvrsq = pow(pvr, 2);
# pn = nx*tmppx + ny*tmppy + nz*tmppz;
# pnsq = pow(pn, 2);
# pr = pn;
# prsq = pow(pr, 2);
# pf = pxir;
# pxirsq = pow(pxir, 2);
# ptheta2 = invxi2*pvrsq;
# prT4 = pow(prT, 4);
# Hnspt7 = deltaR*invrho2;
# Hnspt6 = invxi2*rho2invLamb;
# Hnspt5 = qq*u2;
# Hnspt4 = Hnspt5*prT4 + Hnspt6*pow(pf, 2) + Hnspt7*prsq + invrho2*ptheta2 + 1;
# Hnspt3 = Hnspt4*deltaT;
# Hnspt2 = Hnspt3*rho2;
# Hnspt1 = pf*ww;
# Hns = Hnspt1*invLamb + sqrt(Hnspt2*invLamb);
# Qpt3 = deltaR*invrho2;
# Qpt2 = invxi2*rho2invLamb;
# Qpt1 = invrho2*invxi2;
# Q = Qpt1*pvrsq + Qpt2*pxirsq + Qpt3*pnsq + 1;
# pn2 = deltaR*invrho2*prsq;
# pp = Q - 1;
# sKerrmultfact = -3*r*(12*pn2 - pp) - 8;
# sStarmultfact = r*(-30*pn2 + 4*pp) + 14;
# deltaSigmaStarUSCOREx1 = etaover12r*(sKerrUSCOREx*sKerrmultfact + sStarUSCOREx*sStarmultfact);
# deltaSigmaStarUSCOREy1 = etaover12r*(sKerrUSCOREy*sKerrmultfact + sStarUSCOREy*sStarmultfact);
# deltaSigmaStarUSCOREz1 = etaover12r*(sKerrUSCOREz*sKerrmultfact + sStarUSCOREz*sStarmultfact);
# pn2pp = pn2*pp;
# pp2 = pow(pp, 2);
# pn2u2 = pn2*u2;
# ppu2 = pp*u2;
# pn2ppu2 = pn2pp*u2;
# sMultiplier1pt6 = -360*pow(pn2, 2) + 126*pn2pp + 3*pp2;
# sMultiplier1pt5 = -96*pn2pp + 23*pp2;
# sMultiplier1pt4 = 324*pn2 - 120*pp + r*sMultiplier1pt6;
# sMultiplier1pt3 = -282*pn2 + 206*pp + r*sMultiplier1pt5;
# sMultiplier1pt2 = r*sMultiplier1pt4 + 54;
# sMultiplier1pt1 = eta*sMultiplier1pt2 + r*sMultiplier1pt3 - 706;
# sMultiplier1 = -1.0/72.0*eta*sMultiplier1pt1*u2;
# sMultiplier2pt6 = (45.0/8.0)*pn2*pn2u2 - 13.0/8.0*pn2ppu2;
# sMultiplier2pt5 = (1.0/4.0)*pn2ppu2 - 5.0/16.0*pp2*u2;
# sMultiplier2pt4 = -49.0/8.0*pn2u2 + (17.0/12.0)*ppu2 + r*sMultiplier2pt6;
# sMultiplier2pt3 = -2.0/3.0*pn2u2 - 109.0/36.0*ppu2 + r*sMultiplier2pt5;
# sMultiplier2pt2 = r*sMultiplier2pt4 - 7.0/3.0*u2;
# sMultiplier2pt1 = eta*sMultiplier2pt2 + r*sMultiplier2pt3 - 56.0/9.0*u2;
# sMultiplier2 = eta*sMultiplier2pt1;
# deltaSigmaStarUSCOREx2 = deltaSigmaStarUSCOREx1 + sMultiplier1*sigmaStar0 + sMultiplier2*sigmaKerr0;
# deltaSigmaStarUSCOREy2 = deltaSigmaStarUSCOREy1 + sMultiplier1*sigmaStar1 + sMultiplier2*sigmaKerr1;
# deltaSigmaStarUSCOREz2 = deltaSigmaStarUSCOREz1 + sMultiplier1*sigmaStar2 + sMultiplier2*sigmaKerr2;
# deltaSigmaStarUSCOREx3 = d1*etau3*sigmaStar0 + deltaSigmaStarUSCOREx2;
# deltaSigmaStarUSCOREy3 = d1*etau3*sigmaStar1 + deltaSigmaStarUSCOREy2;
# deltaSigmaStarUSCOREz3 = d1*etau3*sigmaStar2 + deltaSigmaStarUSCOREz2;
# deltaSigmaStarUSCOREx = d1v2*etau3*sigmaKerr0 + deltaSigmaStarUSCOREx3;
# deltaSigmaStarUSCOREy = d1v2*etau3*sigmaKerr1 + deltaSigmaStarUSCOREy3;
# deltaSigmaStarUSCOREz = d1v2*etau3*sigmaKerr2 + deltaSigmaStarUSCOREz3;
# sx = deltaSigmaStarUSCOREx + sStarUSCOREx;
# sy = deltaSigmaStarUSCOREy + sStarUSCOREy;
# sz = deltaSigmaStarUSCOREz + sStarUSCOREz;
# sxi = sx*xiUSCOREx + sy*xiUSCOREy + sz*xiUSCOREz;
# sv = sx*vx + sy*vy + sz*vz;
# sn = nx*sx + ny*sy + nz*sz;
# s3 = e3USCOREx*sx + e3USCOREy*sy + e3USCOREz*sz;
# sqrtQ = sqrt(Q);
# oneplus2sqrtQ = 2*sqrtQ + 1;
# oneplus1sqrtQ = oneplus2sqrtQ - sqrtQ;
# twoB1psqrtQsqrtQ = 2*B*oneplus1sqrtQ*sqrtQ;
# invtwoB1psqrtQsqrtQ = 1.0/twoB1psqrtQsqrtQ;
# expMUsqsqrtQplusQ = expMUsq*(Q + sqrtQ);
# Hwrpt4a = pxirsq*sv;
# Hwrpt4 = Hwrpt4a*expMUsqexpnusq;
# Hwrpt3c = pxir*sxi;
# Hwrpt3b = Hwrpt3c*pvr;
# Hwrpt3a = Hwrpt3b*expMUexpnu;
# Hwrpt3 = B*Hwrpt3a;
# Hwrpt2g = deltaR*sv;
# Hwrpt2f = sn*sqrtdeltaR;
# Hwrpt2e = Hwrpt2f*pvr;
# Hwrpt2d = Hwrpt2g*pnsq;
# Hwrpt2c = Hwrpt2e*pn;
# Hwrpt2b = expMUsqsqrtQplusQ*sv;
# Hwrpt2a = xi2*(Hwrpt2b + Hwrpt2c - Hwrpt2d);
# Hwrpt2 = Hwrpt2a*deltaT;
# Hwrpt1b = invtwoB1psqrtQsqrtQ*invxi2;
# Hwrpt1a = Hwrpt1b*sqrtdeltaR;
# Hwrpt1 = Hwrpt1a*invexpMUcubinvexpnu;
# Hwr = Hwrpt1*(Hwrpt2 - Hwrpt3 + Hwrpt4);
# Hwcospt9 = pxir*sxi;
# Hwcospt8 = pvr*sv;
# Hwcospt7 = B*Hwcospt8 - Hwcospt9*expMUexpnu;
# Hwcospt6 = Hwcospt7*sqrtdeltaR;
# Hwcospt5 = -expMUsqsqrtQplusQ*xi2 + pvrsq;
# Hwcospt4 = Hwcospt6*pn;
# Hwcospt3 = Hwcospt5*deltaT - expMUsqexpnusq*pxirsq;
# Hwcospt2 = -B*Hwcospt4 + Hwcospt3*sn;
# Hwcospt1 = Hwcospt2*invexpMUcubinvexpnu;
# Hwcos = Hwcospt1*invtwoB1psqrtQsqrtQ;
# deltaTsqrtQ = deltaT*sqrtQ;
# invdeltatTsqrtQ = 1.0/deltaTsqrtQ;
# HSOLpt5 = pxir*(-B + expMUexpnu);
# HSOLpt4 = HSOLpt5*invexpMU;
# HSOLpt3 = HSOLpt4*expnusq;
# HSOLpt2 = HSOLpt3*s3;
# HSOLpt1 = HSOLpt2*invxi2;
# HSOL = HSOLpt1*invdeltatTsqrtQ;
# deltaTsqrtQplusQ = deltaT*(Q + sqrtQ);
# invdeltaTsqrtQplusQ = 1.0/deltaTsqrtQplusQ;
# HSONLmult2 = invdeltaTsqrtQplusQ*invxi2;
# HSONLmult = HSONLmult2*expnuinvexpMU2;
# HSONLpt1b = pn*xi2;
# HSONLpt1a = HSONLpt1b*(-mucos + nucos) + mur*pvr - nur*pvr;
# HSONLpt1 = HSONLpt1a*sqrtQ - HSONLpt1b*mucos + mur*pvr;
# HSONLpt2d = nur*pxir;
# HSONLpt2c = HSONLpt2d*oneplus2sqrtQ;
# HSONLpt2b = B*sxi;
# HSONLpt2a = HSONLpt2c*expMUexpnu;
# HSONLpt2 = HSONLpt1*HSONLpt2b + HSONLpt2a*sv;
# HSONLpt3c = pxir*sv;
# HSONLpt3b = HSONLpt3c*oneplus1sqrtQ;
# HSONLpt3a = HSONLpt3b*expMUexpnu;
# HSONLpt3 = B*HSONLpt2 - BR*HSONLpt3a;
# HSONLpt4e = sn*xi2;
# HSONLpt4d = HSONLpt4e*oneplus2sqrtQ;
# HSONLpt4c = HSONLpt4d*pxir;
# HSONLpt4b = HSONLpt4c*nucos;
# HSONLpt4a = HSONLpt4b*expMUexpnu;
# HSONLpt4 = -B*HSONLpt4a + HSONLpt3*sqrtdeltaR;
# HSONL = HSONLmult*HSONLpt4;
# Hs = HSOL + HSONL + Hwcos*wcos + Hwr*wr + s3*w;
# Hsspt1 = (3.0/2.0)*pow(sn, 2) - 1.0/2.0*pow(sx, 2) - 1.0/2.0*pow(sy, 2) - 1.0/2.0*pow(sz, 2);
# Hss = Hsspt1*u3;
# sKerrdotsStar = sKerrUSCOREx*sStarUSCOREx + sKerrUSCOREy*sStarUSCOREy + sKerrUSCOREz*sStarUSCOREz;
# Hpt1 = etau4*(s1dots1 + s2dots2);
# H = Hns + Hpt1*(dheffSS*sKerrdotsStar + dheffSSv2) + Hs + Hss;
# Hreal = sqrt(2*eta*(H - 1) + 1);
#
#
#
# /* SEOBNR \partial_x H expression: */
# r2prm = 2*x;
# rprm = (1.0/2.0)*r2prm/sqrt(r2);
# uprm = -rprm/pow(r, 2);
# u2prm = 2*u*uprm;
# u3prm = u*u2prm + u2*uprm;
# u4prm = 2*u2*u2prm;
# u5prm = u*u4prm + u4*uprm;
# etau3prm = eta*u3prm;
# etau4prm = eta*u4prm;
# nxprm = u + uprm*x;
# nyprm = uprm*y;
# nzprm = uprm*z;
# costhetaprm = e3USCOREx*nxprm + e3USCOREy*nyprm + e3USCOREz*nzprm;
# xi2prm = -2*costheta*costhetaprm;
# xiUSCORExprm = e3USCOREy*nzprm - e3USCOREz*nyprm;
# xiUSCOREyprm = -e3USCOREx*nzprm + e3USCOREz*nxprm;
# xiUSCOREzprm = e3USCOREx*nyprm - e3USCOREy*nxprm;
# vxprm = ny*xiUSCOREzprm + nyprm*xiUSCOREz - nz*xiUSCOREyprm - nzprm*xiUSCOREy;
# vyprm = -nx*xiUSCOREzprm - nxprm*xiUSCOREz + nz*xiUSCORExprm + nzprm*xiUSCOREx;
# vzprm = nx*xiUSCOREyprm + nxprm*xiUSCOREy - ny*xiUSCORExprm - nyprm*xiUSCOREx;
# w2prm = r2prm;
# rho2prm = 2*a2*costheta*costhetaprm + r2prm;
# bulkprm = a2*u2prm + 2*invm1PlusetaKK*uprm;
# loguprm = uprm/u;
# logargprm = k1*uprm + k2*u2prm + k3*u3prm + k4*u4prm + k5*u5prm + k5l*logu*u5prm + k5l*loguprm*u5;
# onepluslogargprm = logargprm;
# invonepluslogargprm = -onepluslogargprm/pow(onepluslogarg, 2);
# logTermsprm = eta*onepluslogargprm/onepluslogarg;
# deltaUprm = bulk*logTermsprm + bulkprm*logTerms;
# deltaTprm = deltaU*r2prm + deltaUprm*r2;
# deltaUUSCOREupt7prm = k5l*loguprm;
# deltaUUSCOREupt6prm = 5*deltaUUSCOREupt7*uprm + 5*deltaUUSCOREupt7prm*u;
# deltaUUSCOREupt5prm = deltaUUSCOREupt6*uprm + deltaUUSCOREupt6prm*u;
# deltaUUSCOREupt4prm = deltaUUSCOREupt5*uprm + deltaUUSCOREupt5prm*u;
# deltaUUSCOREupt3prm = deltaUUSCOREupt4*uprm + deltaUUSCOREupt4prm*u;
# deltaUUSCOREupt2prm = a2*uprm;
# deltaUUSCOREupt1prm = bulk*deltaUUSCOREupt3prm*eta + bulkprm*deltaUUSCOREupt3*eta;
# deltaUUSCOREuprm = deltaUUSCOREupt1*invonepluslogargprm + deltaUUSCOREupt1prm*invonepluslogarg + 2*deltaUUSCOREupt2*logTermsprm + 2*deltaUUSCOREupt2prm*logTerms;
# deltaTUSCORErprm = 2*deltaU*rprm - deltaUUSCOREuprm + 2*deltaUprm*r;
# Lambprm = -a2*deltaT*xi2prm - a2*deltaTprm*xi2 + 2*w2*w2prm;
# rho2xi2Lambprm = Lamb*rho2*xi2prm + Lamb*rho2prm*xi2 + Lambprm*rho2*xi2;
# invrho2xi2Lambprm = -rho2xi2Lambprm/pow(rho2xi2Lamb, 2);
# invrho2prm = Lamb*invrho2xi2Lamb*xi2prm + Lamb*invrho2xi2Lambprm*xi2 + Lambprm*invrho2xi2Lamb*xi2;
# invxi2prm = Lamb*invrho2xi2Lamb*rho2prm + Lamb*invrho2xi2Lambprm*rho2 + Lambprm*invrho2xi2Lamb*rho2;
# invLambprm = invrho2xi2Lamb*rho2*xi2prm + invrho2xi2Lamb*rho2prm*xi2 + invrho2xi2Lambprm*rho2*xi2;
# invLambsqprm = 2*invLamb*invLambprm;
# rho2invLambprm = invLamb*rho2prm + invLambprm*rho2;
# expnuprm = sqrt(deltaT*rho2invLamb)*((1.0/2.0)*deltaT*rho2invLambprm + (1.0/2.0)*deltaTprm*rho2invLamb)/(deltaT*rho2invLamb);
# expMUprm = (1.0/2.0)*rho2prm/sqrt(rho2);
# expMUexpnuprm = expMU*expnuprm + expMUprm*expnu;
# expMUsqprm = 2*expMU*expMUprm;
# expnusqprm = 2*expnu*expnuprm;
# expMUsqexpnusqprm = expMUsq*expnusqprm + expMUsqprm*expnusq;
# invexpnuexpMUprm = -expMUexpnuprm/pow(expMUexpnu, 2);
# invexpMUprm = expnu*invexpnuexpMUprm + expnuprm*invexpnuexpMU;
# invexpMUsqprm = 2*invexpMU*invexpMUprm;
# expnuinvexpMU2prm = expnu*invexpMUsqprm + expnuprm*invexpMUsq;
# invexpMUcubinvexpnuprm = invexpMUsq*invexpnuexpMUprm + invexpMUsqprm*invexpnuexpMU;
# DDprm = (6*eta*u2prm + etau3prm*(52 - 6*eta))/(6*eta*u2 + etau3*(52 - 6*eta) + 1);
# deltaRprm = DD*deltaTprm + DDprm*deltaT;
# wwprm = a*a2*b3*eta*uprm + a*bb3*eta*uprm + 2*a*rprm;
# Bprm = (1.0/2.0)*deltaTprm/sqrt(deltaT);
# sqrtdeltaTprm = Bprm;
# sqrtdeltaRprm = (1.0/2.0)*deltaRprm/sqrt(deltaR);
# deltaTsqrtdeltaRprm = deltaT*sqrtdeltaRprm + deltaTprm*sqrtdeltaR;
# sqrtdeltaTdeltaTsqrtdeltaRprm = deltaTsqrtdeltaR*sqrtdeltaTprm + deltaTsqrtdeltaRprm*sqrtdeltaT;
# invdeltaTsqrtdeltaTsqrtdeltaRprm = -1.0*sqrtdeltaTdeltaTsqrtdeltaRprm/pow(sqrtdeltaTdeltaTsqrtdeltaR, 2);
# invdeltaTprm = invdeltaTsqrtdeltaTsqrtdeltaR*sqrtdeltaR*sqrtdeltaTprm + invdeltaTsqrtdeltaTsqrtdeltaR*sqrtdeltaRprm*sqrtdeltaT + invdeltaTsqrtdeltaTsqrtdeltaRprm*sqrtdeltaR*sqrtdeltaT;
# invsqrtdeltaTprm = deltaTsqrtdeltaR*invdeltaTsqrtdeltaTsqrtdeltaRprm + deltaTsqrtdeltaRprm*invdeltaTsqrtdeltaTsqrtdeltaR;
# invsqrtdeltaRprm = deltaT*invdeltaTsqrtdeltaTsqrtdeltaR*sqrtdeltaTprm + deltaT*invdeltaTsqrtdeltaTsqrtdeltaRprm*sqrtdeltaT + deltaTprm*invdeltaTsqrtdeltaTsqrtdeltaR*sqrtdeltaT;
# wprm = invLamb*wwprm + invLambprm*ww;
# LambUSCORErprm = -a2*deltaTUSCOREr*xi2prm - a2*deltaTUSCORErprm*xi2 + 4*r*w2prm + 4*rprm*w2;
# wwUSCORErprm = -a*a2*b3*eta*u2prm - a*bb3*eta*u2prm;
# BRprm = invsqrtdeltaT*(-deltaT*invsqrtdeltaRprm + (1.0/2.0)*deltaTUSCORErprm - deltaTprm*invsqrtdeltaR) + invsqrtdeltaTprm*(-deltaT*invsqrtdeltaR + (1.0/2.0)*deltaTUSCOREr);
# wrprm = invLambsq*(Lamb*wwUSCORErprm - LambUSCOREr*wwprm - LambUSCORErprm*ww + Lambprm*wwUSCOREr) + invLambsqprm*(Lamb*wwUSCOREr - LambUSCOREr*ww);
# nurpt2prm = w2*(-4.0*deltaT*rprm + deltaTUSCOREr*w2prm + deltaTUSCORErprm*w2 - 4.0*deltaTprm*r) + w2prm*(-4.0*deltaT*r + deltaTUSCOREr*w2);
# nurpt1prm = invdeltaT*nurpt2prm + invdeltaTprm*nurpt2;
# nurprm = (1.0/2.0)*invLamb*nurpt1prm + (1.0/2.0)*invLambprm*nurpt1 + invrho2*rprm + invrho2prm*r;
# murprm = invrho2*rprm + invrho2prm*r - invsqrtdeltaRprm;
# a2costhetaprm = a2*costhetaprm;
# wcospt2prm = deltaT*wwprm + deltaTprm*ww;
# wcospt1prm = invLambsq*wcospt2prm + invLambsqprm*wcospt2;
# wcosprm = -2*a2costheta*wcospt1prm - 2*a2costhetaprm*wcospt1;
# nucospt3prm = invLamb*invrho2prm + invLambprm*invrho2;
# nucospt2prm = nucospt3*w2prm + nucospt3prm*w2;
# nucospt1prm = a2costheta*nucospt2prm + a2costhetaprm*nucospt2;
# nucosprm = nucospt1*(-deltaTprm + w2prm) + nucospt1prm*(-deltaT + w2);
# mucosprm = a2costheta*invrho2prm + a2costhetaprm*invrho2;
# etaover12rprm = (1.0/12.0)*eta*uprm;
# csiprm = -w2prm*sqrt(deltaR*deltaT)/pow(w2, 2) + sqrt(deltaR*deltaT)*((1.0/2.0)*deltaR*deltaTprm + (1.0/2.0)*deltaRprm*deltaT)/(deltaR*deltaT*w2);
# csi1prm = csiprm*(1 - fabs(tortoise - 1));
# csi2prm = csiprm*(1.0/2.0 - copysignresult);
# prTprm = csi2*(nxprm*px + nyprm*py + nzprm*pz) + csi2prm*(nx*px + ny*py + nz*pz);
# prTtimesoneminuscsi1invprm = prTprm*(1 - 1/csi1) + csi1prm*prT/pow(csi1, 2);
# tmppxprm = -nx*prTtimesoneminuscsi1invprm - nxprm*prTtimesoneminuscsi1inv;
# tmppyprm = -ny*prTtimesoneminuscsi1invprm - nyprm*prTtimesoneminuscsi1inv;
# tmppzprm = -nz*prTtimesoneminuscsi1invprm - nzprm*prTtimesoneminuscsi1inv;
# pxirprm = r*(tmppx*xiUSCORExprm + tmppxprm*xiUSCOREx + tmppy*xiUSCOREyprm + tmppyprm*xiUSCOREy + tmppz*xiUSCOREzprm + tmppzprm*xiUSCOREz) + rprm*(tmppx*xiUSCOREx + tmppy*xiUSCOREy + tmppz*xiUSCOREz);
# pvrprm = r*(tmppx*vxprm + tmppxprm*vx + tmppy*vyprm + tmppyprm*vy + tmppz*vzprm + tmppzprm*vz) + rprm*(tmppx*vx + tmppy*vy + tmppz*vz);
# pvrsqprm = 2*pvr*pvrprm;
# pnprm = nx*tmppxprm + nxprm*tmppx + ny*tmppyprm + nyprm*tmppy + nz*tmppzprm + nzprm*tmppz;
# pnsqprm = 2*pn*pnprm;
# prprm = pnprm;
# prsqprm = 2*pr*prprm;
# pfprm = pxirprm;
# pxirsqprm = 2*pxir*pxirprm;
# ptheta2prm = invxi2*pvrsqprm + invxi2prm*pvrsq;
# prT4prm = 4*pow(prT, 3)*prTprm;
# Hnspt7prm = deltaR*invrho2prm + deltaRprm*invrho2;
# Hnspt6prm = invxi2*rho2invLambprm + invxi2prm*rho2invLamb;
# Hnspt5prm = qq*u2prm;
# Hnspt4prm = Hnspt5*prT4prm + Hnspt5prm*prT4 + 2*Hnspt6*pf*pfprm + Hnspt6prm*pow(pf, 2) + Hnspt7*prsqprm + Hnspt7prm*prsq + invrho2*ptheta2prm + invrho2prm*ptheta2;
# Hnspt3prm = Hnspt4*deltaTprm + Hnspt4prm*deltaT;
# Hnspt2prm = Hnspt3*rho2prm + Hnspt3prm*rho2;
# Hnspt1prm = pf*wwprm + pfprm*ww;
# Hnsprm = Hnspt1*invLambprm + Hnspt1prm*invLamb + sqrt(Hnspt2*invLamb)*((1.0/2.0)*Hnspt2*invLambprm + (1.0/2.0)*Hnspt2prm*invLamb)/(Hnspt2*invLamb);
# Qpt3prm = deltaR*invrho2prm + deltaRprm*invrho2;
# Qpt2prm = invxi2*rho2invLambprm + invxi2prm*rho2invLamb;
# Qpt1prm = invrho2*invxi2prm + invrho2prm*invxi2;
# Qprm = Qpt1*pvrsqprm + Qpt1prm*pvrsq + Qpt2*pxirsqprm + Qpt2prm*pxirsq + Qpt3*pnsqprm + Qpt3prm*pnsq;
# pn2prm = deltaR*invrho2*prsqprm + deltaR*invrho2prm*prsq + deltaRprm*invrho2*prsq;
# ppprm = Qprm;
# sKerrmultfactprm = r*(-36*pn2prm + 3*ppprm) + rprm*(-36*pn2 + 3*pp);
# sStarmultfactprm = r*(-30*pn2prm + 4*ppprm) + rprm*(-30*pn2 + 4*pp);
# deltaSigmaStarUSCOREx1prm = etaover12r*(sKerrUSCOREx*sKerrmultfactprm + sStarUSCOREx*sStarmultfactprm) + etaover12rprm*(sKerrUSCOREx*sKerrmultfact + sStarUSCOREx*sStarmultfact);
# deltaSigmaStarUSCOREy1prm = etaover12r*(sKerrUSCOREy*sKerrmultfactprm + sStarUSCOREy*sStarmultfactprm) + etaover12rprm*(sKerrUSCOREy*sKerrmultfact + sStarUSCOREy*sStarmultfact);
# deltaSigmaStarUSCOREz1prm = etaover12r*(sKerrUSCOREz*sKerrmultfactprm + sStarUSCOREz*sStarmultfactprm) + etaover12rprm*(sKerrUSCOREz*sKerrmultfact + sStarUSCOREz*sStarmultfact);
# pn2ppprm = pn2*ppprm + pn2prm*pp;
# pp2prm = 2*pp*ppprm;
# pn2u2prm = pn2*u2prm + pn2prm*u2;
# ppu2prm = pp*u2prm + ppprm*u2;
# pn2ppu2prm = pn2pp*u2prm + pn2ppprm*u2;
# sMultiplier1pt6prm = -720*pn2*pn2prm + 126*pn2ppprm + 3*pp2prm;
# sMultiplier1pt5prm = -96*pn2ppprm + 23*pp2prm;
# sMultiplier1pt4prm = 324*pn2prm - 120*ppprm + r*sMultiplier1pt6prm + rprm*sMultiplier1pt6;
# sMultiplier1pt3prm = -282*pn2prm + 206*ppprm + r*sMultiplier1pt5prm + rprm*sMultiplier1pt5;
# sMultiplier1pt2prm = r*sMultiplier1pt4prm + rprm*sMultiplier1pt4;
# sMultiplier1pt1prm = eta*sMultiplier1pt2prm + r*sMultiplier1pt3prm + rprm*sMultiplier1pt3;
# sMultiplier1prm = -1.0/72.0*eta*sMultiplier1pt1*u2prm - 1.0/72.0*eta*sMultiplier1pt1prm*u2;
# sMultiplier2pt6prm = (45.0/8.0)*pn2*pn2u2prm - 13.0/8.0*pn2ppu2prm + (45.0/8.0)*pn2prm*pn2u2;
# sMultiplier2pt5prm = (1.0/4.0)*pn2ppu2prm - 5.0/16.0*pp2*u2prm - 5.0/16.0*pp2prm*u2;
# sMultiplier2pt4prm = -49.0/8.0*pn2u2prm + (17.0/12.0)*ppu2prm + r*sMultiplier2pt6prm + rprm*sMultiplier2pt6;
# sMultiplier2pt3prm = -2.0/3.0*pn2u2prm - 109.0/36.0*ppu2prm + r*sMultiplier2pt5prm + rprm*sMultiplier2pt5;
# sMultiplier2pt2prm = r*sMultiplier2pt4prm + rprm*sMultiplier2pt4 - 7.0/3.0*u2prm;
# sMultiplier2pt1prm = eta*sMultiplier2pt2prm + r*sMultiplier2pt3prm + rprm*sMultiplier2pt3 - 56.0/9.0*u2prm;
# sMultiplier2prm = eta*sMultiplier2pt1prm;
# deltaSigmaStarUSCOREx2prm = deltaSigmaStarUSCOREx1prm + sMultiplier1prm*sigmaStar0 + sMultiplier2prm*sigmaKerr0;
# deltaSigmaStarUSCOREy2prm = deltaSigmaStarUSCOREy1prm + sMultiplier1prm*sigmaStar1 + sMultiplier2prm*sigmaKerr1;
# deltaSigmaStarUSCOREz2prm = deltaSigmaStarUSCOREz1prm + sMultiplier1prm*sigmaStar2 + sMultiplier2prm*sigmaKerr2;
# deltaSigmaStarUSCOREx3prm = d1*etau3prm*sigmaStar0 + deltaSigmaStarUSCOREx2prm;
# deltaSigmaStarUSCOREy3prm = d1*etau3prm*sigmaStar1 + deltaSigmaStarUSCOREy2prm;
# deltaSigmaStarUSCOREz3prm = d1*etau3prm*sigmaStar2 + deltaSigmaStarUSCOREz2prm;
# deltaSigmaStarUSCORExprm = d1v2*etau3prm*sigmaKerr0 + deltaSigmaStarUSCOREx3prm;
# deltaSigmaStarUSCOREyprm = d1v2*etau3prm*sigmaKerr1 + deltaSigmaStarUSCOREy3prm;
# deltaSigmaStarUSCOREzprm = d1v2*etau3prm*sigmaKerr2 + deltaSigmaStarUSCOREz3prm;
# sxprm = deltaSigmaStarUSCORExprm;
# syprm = deltaSigmaStarUSCOREyprm;
# szprm = deltaSigmaStarUSCOREzprm;
# sxiprm = sx*xiUSCORExprm + sxprm*xiUSCOREx + sy*xiUSCOREyprm + syprm*xiUSCOREy + sz*xiUSCOREzprm + szprm*xiUSCOREz;
# svprm = sx*vxprm + sxprm*vx + sy*vyprm + syprm*vy + sz*vzprm + szprm*vz;
# snprm = nx*sxprm + nxprm*sx + ny*syprm + nyprm*sy + nz*szprm + nzprm*sz;
# s3prm = e3USCOREx*sxprm + e3USCOREy*syprm + e3USCOREz*szprm;
# sqrtQprm = (1.0/2.0)*Qprm/sqrt(Q);
# oneplus2sqrtQprm = 2*sqrtQprm;
# oneplus1sqrtQprm = oneplus2sqrtQprm - sqrtQprm;
# twoB1psqrtQsqrtQprm = 2*B*oneplus1sqrtQ*sqrtQprm + 2*B*oneplus1sqrtQprm*sqrtQ + 2*Bprm*oneplus1sqrtQ*sqrtQ;
# invtwoB1psqrtQsqrtQprm = -twoB1psqrtQsqrtQprm/pow(twoB1psqrtQsqrtQ, 2);
# expMUsqsqrtQplusQprm = expMUsq*(Qprm + sqrtQprm) + expMUsqprm*(Q + sqrtQ);
# Hwrpt4aprm = pxirsq*svprm + pxirsqprm*sv;
# Hwrpt4prm = Hwrpt4a*expMUsqexpnusqprm + Hwrpt4aprm*expMUsqexpnusq;
# Hwrpt3cprm = pxir*sxiprm + pxirprm*sxi;
# Hwrpt3bprm = Hwrpt3c*pvrprm + Hwrpt3cprm*pvr;
# Hwrpt3aprm = Hwrpt3b*expMUexpnuprm + Hwrpt3bprm*expMUexpnu;
# Hwrpt3prm = B*Hwrpt3aprm + Bprm*Hwrpt3a;
# Hwrpt2gprm = deltaR*svprm + deltaRprm*sv;
# Hwrpt2fprm = sn*sqrtdeltaRprm + snprm*sqrtdeltaR;
# Hwrpt2eprm = Hwrpt2f*pvrprm + Hwrpt2fprm*pvr;
# Hwrpt2dprm = Hwrpt2g*pnsqprm + Hwrpt2gprm*pnsq;
# Hwrpt2cprm = Hwrpt2e*pnprm + Hwrpt2eprm*pn;
# Hwrpt2bprm = expMUsqsqrtQplusQ*svprm + expMUsqsqrtQplusQprm*sv;
# Hwrpt2aprm = xi2*(Hwrpt2bprm + Hwrpt2cprm - Hwrpt2dprm) + xi2prm*(Hwrpt2b + Hwrpt2c - Hwrpt2d);
# Hwrpt2prm = Hwrpt2a*deltaTprm + Hwrpt2aprm*deltaT;
# Hwrpt1bprm = invtwoB1psqrtQsqrtQ*invxi2prm + invtwoB1psqrtQsqrtQprm*invxi2;
# Hwrpt1aprm = Hwrpt1b*sqrtdeltaRprm + Hwrpt1bprm*sqrtdeltaR;
# Hwrpt1prm = Hwrpt1a*invexpMUcubinvexpnuprm + Hwrpt1aprm*invexpMUcubinvexpnu;
# Hwrprm = Hwrpt1*(Hwrpt2prm - Hwrpt3prm + Hwrpt4prm) + Hwrpt1prm*(Hwrpt2 - Hwrpt3 + Hwrpt4);
# Hwcospt9prm = pxir*sxiprm + pxirprm*sxi;
# Hwcospt8prm = pvr*svprm + pvrprm*sv;
# Hwcospt7prm = B*Hwcospt8prm + Bprm*Hwcospt8 - Hwcospt9*expMUexpnuprm - Hwcospt9prm*expMUexpnu;
# Hwcospt6prm = Hwcospt7*sqrtdeltaRprm + Hwcospt7prm*sqrtdeltaR;
# Hwcospt5prm = -expMUsqsqrtQplusQ*xi2prm - expMUsqsqrtQplusQprm*xi2 + pvrsqprm;
# Hwcospt4prm = Hwcospt6*pnprm + Hwcospt6prm*pn;
# Hwcospt3prm = Hwcospt5*deltaTprm + Hwcospt5prm*deltaT - expMUsqexpnusq*pxirsqprm - expMUsqexpnusqprm*pxirsq;
# Hwcospt2prm = -B*Hwcospt4prm - Bprm*Hwcospt4 + Hwcospt3*snprm + Hwcospt3prm*sn;
# Hwcospt1prm = Hwcospt2*invexpMUcubinvexpnuprm + Hwcospt2prm*invexpMUcubinvexpnu;
# Hwcosprm = Hwcospt1*invtwoB1psqrtQsqrtQprm + Hwcospt1prm*invtwoB1psqrtQsqrtQ;
# deltaTsqrtQprm = deltaT*sqrtQprm + deltaTprm*sqrtQ;
# invdeltatTsqrtQprm = -deltaTsqrtQprm/pow(deltaTsqrtQ, 2);
# HSOLpt5prm = pxir*(-Bprm + expMUexpnuprm) + pxirprm*(-B + expMUexpnu);
# HSOLpt4prm = HSOLpt5*invexpMUprm + HSOLpt5prm*invexpMU;
# HSOLpt3prm = HSOLpt4*expnusqprm + HSOLpt4prm*expnusq;
# HSOLpt2prm = HSOLpt3*s3prm + HSOLpt3prm*s3;
# HSOLpt1prm = HSOLpt2*invxi2prm + HSOLpt2prm*invxi2;
# HSOLprm = HSOLpt1*invdeltatTsqrtQprm + HSOLpt1prm*invdeltatTsqrtQ;
# deltaTsqrtQplusQprm = deltaT*(Qprm + sqrtQprm) + deltaTprm*(Q + sqrtQ);
# invdeltaTsqrtQplusQprm = -deltaTsqrtQplusQprm/pow(deltaTsqrtQplusQ, 2);
# HSONLmult2prm = invdeltaTsqrtQplusQ*invxi2prm + invdeltaTsqrtQplusQprm*invxi2;
# HSONLmultprm = HSONLmult2*expnuinvexpMU2prm + HSONLmult2prm*expnuinvexpMU2;
# HSONLpt1bprm = pn*xi2prm + pnprm*xi2;
# HSONLpt1aprm = HSONLpt1b*(-mucosprm + nucosprm) + HSONLpt1bprm*(-mucos + nucos) + mur*pvrprm + murprm*pvr - nur*pvrprm - nurprm*pvr;
# HSONLpt1prm = HSONLpt1a*sqrtQprm + HSONLpt1aprm*sqrtQ - HSONLpt1b*mucosprm - HSONLpt1bprm*mucos + mur*pvrprm + murprm*pvr;
# HSONLpt2dprm = nur*pxirprm + nurprm*pxir;
# HSONLpt2cprm = HSONLpt2d*oneplus2sqrtQprm + HSONLpt2dprm*oneplus2sqrtQ;
# HSONLpt2bprm = B*sxiprm + Bprm*sxi;
# HSONLpt2aprm = HSONLpt2c*expMUexpnuprm + HSONLpt2cprm*expMUexpnu;
# HSONLpt2prm = HSONLpt1*HSONLpt2bprm + HSONLpt1prm*HSONLpt2b + HSONLpt2a*svprm + HSONLpt2aprm*sv;
# HSONLpt3cprm = pxir*svprm + pxirprm*sv;
# HSONLpt3bprm = HSONLpt3c*oneplus1sqrtQprm + HSONLpt3cprm*oneplus1sqrtQ;
# HSONLpt3aprm = HSONLpt3b*expMUexpnuprm + HSONLpt3bprm*expMUexpnu;
# HSONLpt3prm = B*HSONLpt2prm - BR*HSONLpt3aprm - BRprm*HSONLpt3a + Bprm*HSONLpt2;
# HSONLpt4eprm = sn*xi2prm + snprm*xi2;
# HSONLpt4dprm = HSONLpt4e*oneplus2sqrtQprm + HSONLpt4eprm*oneplus2sqrtQ;
# HSONLpt4cprm = HSONLpt4d*pxirprm + HSONLpt4dprm*pxir;
# HSONLpt4bprm = HSONLpt4c*nucosprm + HSONLpt4cprm*nucos;
# HSONLpt4aprm = HSONLpt4b*expMUexpnuprm + HSONLpt4bprm*expMUexpnu;
# HSONLpt4prm = -B*HSONLpt4aprm - Bprm*HSONLpt4a + HSONLpt3*sqrtdeltaRprm + HSONLpt3prm*sqrtdeltaR;
# HSONLprm = HSONLmult*HSONLpt4prm + HSONLmultprm*HSONLpt4;
# Hsprm = HSOLprm + HSONLprm + Hwcos*wcosprm + Hwcosprm*wcos + Hwr*wrprm + Hwrprm*wr + s3*wprm + s3prm*w;
# Hsspt1prm = 3*sn*snprm - sx*sxprm - sy*syprm - sz*szprm;
# Hssprm = Hsspt1*u3prm + Hsspt1prm*u3;
# Hpt1prm = etau4prm*(s1dots1 + s2dots2);
# Hprm = Hnsprm + Hpt1prm*(dheffSS*sKerrdotsStar + dheffSSv2) + Hsprm + Hssprm;
# Hrealprm = Hprm*eta/sqrt(2*eta*(H - 1) + 1);
