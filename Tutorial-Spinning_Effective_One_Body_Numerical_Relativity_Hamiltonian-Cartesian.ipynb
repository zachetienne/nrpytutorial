# %% [markdown]
# # The Effective One-Body Cartesian Hamiltonian
#
# ### Author: Tyler Knowles
#
# <font color='red'>**During development, all expressions generated in this module are being validated against a trusted code: the original LALSuite SEOBNRv3 code, and the Mathematica expressions for the LALSuite SEOBNRv3_opt code.**</font>
#
# This module documents and splits up the reduced spinning effective one-body Hamiltonian derived in [Barausse and Buonanno (2010)](https://arxiv.org/abs/0912.3517) and [Pan, Buonanno, Buchman, et. al (2010)](https://arxiv.org/abs/0912.3466) for use in efficient gravitational waveform generation software.  This Cartesian formulation is used to generate gravitational waveforms in LALSuite's SEOBNRv3 approximant.
#
# * Something to be checked: should the constants (like k0,...,k5) be symbols since we compute them?  Also, why are we *recomputing* them?  They're computed elsewhere and available in an array.

# %%
import sympy as sp
x,y,z,s1x,s1y,s1z,s2x,s2y,s2z = sp.symbols("x y z s1x s1y s1z s2x s2y s2z")
blah = x+y
g = sp.sin(blah)
print(sp.mathematica_code(g))
# Out:
# Sin[x + y]

# %%
import sympy as sp
m1,m2,x,y,z,px,py,pz,s1x,s1y,s1z,s2x,s2y,s2z,eta = sp.symbols("m1 m2 x y z px py pz s1x s1y s1z s2x s2y s2z eta",real=True)
c0k2,c1k2,c0k3,c1k3,c0k4,c1k4,c2k4,c0k5,c1k5,c2k5 = sp.symbols("c0k2 c1k2 c0k3 c1k3 c0k4 c1k4 c2k4 c0k5 c1k5 c2k5",real=True)
KK,k5l,b3,bb3,d1,d1v2,dheffSS,dheffSSv2 = sp.symbols("KK k5l b3 bb3 d1 d1v2 dheffSS dheffSSv2",real=True)
tortoise,copysignresult = sp.symbols("tortoise copysignresult",real=True)

sigmaKerr0 = s1x + s2x
sigmaKerr1 = s1y + s2y
sigmaKerr2 = s1z + s2z
invm1m2 = 1/(m1*m2)
m2overm1 = m2*m2*invm1m2
m1overm2 = m1*m1*invm1m2
sigmaStar0 = (m2overm1)*s1x + (m1overm2)*s2x
sigmaStar1 = (m2overm1)*s1y + (m1overm2)*s2y
sigmaStar2 = (m2overm1)*s1z + (m1overm2)*s2z
s1dots1 = s1x*s1x + s1y*s1y + s1z*s1z
s2dots2 = s2x*s2x + s2y*s2y + s2z*s2z
r2 = x*x + y*y + z*z
r = sp.sqrt(r2)
u = 1/r
u2 = u*u
u3 = u2*u
u4 = u2*u2
u5 = u4*u
etau3 = eta*u3
etau4 = eta*u4
nx = x*u
ny = y*u
nz = z*u
sKerrUSCOREx = sigmaKerr0
sKerrUSCOREy = sigmaKerr1
sKerrUSCOREz = sigmaKerr2
sStarUSCOREx = sigmaStar0
sStarUSCOREy = sigmaStar1
sStarUSCOREz = sigmaStar2
a2 = sKerrUSCOREx*sKerrUSCOREx + sKerrUSCOREy*sKerrUSCOREy + sKerrUSCOREz*sKerrUSCOREz
a4 = a2*a2
a = sp.sqrt(a2)
inva = 1/a
m1PlusetaKK = -1 + eta*KK
invm1PlusetaKK = 1/m1PlusetaKK
k0 = KK*(m1PlusetaKK - 1)
k1 = -2*(k0 + KK)*m1PlusetaKK
k2 = c0k2 + c1k2*a2
k3 = c0k3 + c1k3*a2
k4 = c0k4 + c1k4*a2 + c2k4*a4
k5 = c0k5 + c1k5*a2 + c2k5*a4
e3USCOREx = sKerrUSCOREx*inva
e3USCOREy = sKerrUSCOREy*inva
e3USCOREz = sKerrUSCOREz*inva
costheta = e3USCOREx*nx + e3USCOREy*ny + e3USCOREz*nz
xi2 = 1 - costheta*costheta
xiUSCOREx = -e3USCOREz*ny + e3USCOREy*nz
xiUSCOREy =  e3USCOREz*nx - e3USCOREx*nz
xiUSCOREz = -e3USCOREy*nx + e3USCOREx*ny
vx = -nz*xiUSCOREy + ny*xiUSCOREz
vy =  nz*xiUSCOREx - nx*xiUSCOREz
vz = -ny*xiUSCOREx + nx*xiUSCOREy
w2 = r2 + a2
rho2 = r2 + a2*costheta*costheta
bulk = invm1PlusetaKK*(invm1PlusetaKK + 2*u) + a2*u2
logu = sp.log( u )
logarg = k1*u + k2*u2 + k3*u3 + k4*u4 + k5*u5 + k5l*u5*logu
onepluslogarg = (1 + logarg)
invonepluslogarg = 1/onepluslogarg
logTerms = 1 + eta*k0 + eta*sp.log(onepluslogarg)
deltaU = bulk*logTerms
deltaT = r2*deltaU
deltaUUSCOREupt7 = k5 + k5l*logu
deltaUUSCOREupt6 = 4*k4 + 5*deltaUUSCOREupt7*u
deltaUUSCOREupt5 = 3*k3 + u*deltaUUSCOREupt6
deltaUUSCOREupt4 = 2*k2 + u*deltaUUSCOREupt5
deltaUUSCOREupt3 = k1 + u*deltaUUSCOREupt4
deltaUUSCOREupt2 = invm1PlusetaKK + a2*u
deltaUUSCOREupt1 = bulk*eta*deltaUUSCOREupt3
deltaUUSCOREu = 2*deltaUUSCOREupt2*logTerms + deltaUUSCOREupt1*invonepluslogarg
deltaTUSCOREr = 2*r*deltaU - deltaUUSCOREu
Lambda = w2*w2 - a2*deltaT*xi2
# print(sp.mathematica_code(Lambda))




rho2xi2Lambda = rho2*xi2*Lambda
invrho2xi2Lambda = 1/rho2xi2Lambda
invrho2 = xi2*Lambda*invrho2xi2Lambda
invxi2 = rho2*Lambda*invrho2xi2Lambda
invLambda = xi2*rho2*invrho2xi2Lambda
invLambdasq = invLambda*invLambda
rho2invLambda = rho2*invLambda
expnu = sp.sqrt(deltaT*rho2invLambda)
expMU = sp.sqrt(rho2)
expMUexpnu = expMU*expnu
expMUsq = expMU*expMU
expnusq = expnu*expnu
expMUsqexpnusq = expMUsq*expnusq
invexpnuexpMU = 1/expMUexpnu
invexpMU = expnu*invexpnuexpMU
invexpMUsq = invexpMU*invexpMU
expnuinvexpMU2 = expnu*invexpMUsq
invexpMUcubinvexpnu = invexpMUsq*invexpnuexpMU
DD = 1 +  sp.log(1 + 6*eta*u2 + 2*(26 - 3*eta)*etau3)
deltaR = deltaT*DD
qq = 2*eta*(4 - 3*eta)
ww = 2*a*r + b3*eta*a2*a*u + bb3*eta*a*u
B = sp.sqrt(deltaT)
sqrtdeltaT = B
sqrtdeltaR = sp.sqrt(deltaR)
deltaTsqrtdeltaR = deltaT*sqrtdeltaR
sqrtdeltaTdeltaTsqrtdeltaR = sqrtdeltaT*deltaTsqrtdeltaR
invdeltaTsqrtdeltaTsqrtdeltaR = 1./sqrtdeltaTdeltaTsqrtdeltaR
invdeltaT = sqrtdeltaT*(sqrtdeltaR*invdeltaTsqrtdeltaTsqrtdeltaR)
invsqrtdeltaT = deltaTsqrtdeltaR*invdeltaTsqrtdeltaTsqrtdeltaR
invsqrtdeltaR = deltaT*sqrtdeltaT*invdeltaTsqrtdeltaTsqrtdeltaR
w = ww*invLambda
LambdaUSCOREr = 4*r*w2 - a2*deltaTUSCOREr*xi2
wwUSCOREr = 2*a - (a2*a*b3*eta)*u2 - bb3*eta*a*u2
BR = (-deltaT*invsqrtdeltaR + deltaTUSCOREr*sp.Rational(1,2))*invsqrtdeltaT
wr = (-LambdaUSCOREr*ww + Lambda*wwUSCOREr)*(invLambdasq)
nurpt2 = w2*(-4.*r*deltaT + w2*deltaTUSCOREr)
nurpt1 = nurpt2*invdeltaT
nur = r*invrho2 + sp.Rational(1,2)*invLambda*nurpt1
mur = r*invrho2 - invsqrtdeltaR
a2costheta = a2*costheta
wcospt2 = deltaT*ww
wcospt1 = invLambdasq*wcospt2
wcos  = -2*(a2costheta)*wcospt1
nucospt3 = invrho2*invLambda
nucospt2 = w2*nucospt3
nucospt1 = a2costheta*nucospt2
nucos = (w2 - deltaT)*nucospt1
mucos = a2costheta*invrho2
etaover12r = eta*sp.Rational(1,12)*u
csi = sp.sqrt(deltaT*deltaR)/w2
csi1  =  1 + (1-sp.Abs(1-tortoise)) * (csi - 1)
#csi2  =  1 + (sp.Rational(1,2)-copysign(0.5, 1.5-tortoise)) * (csi - 1)
csi2  =  1 + (sp.Rational(1,2)-copysignresult) * (csi - 1)
prT = (px*nx + py*ny + pz*nz)*csi2
prTtimesoneminuscsi1inv = prT*(1 - 1/csi1)
tmppx = px - nx*prTtimesoneminuscsi1inv
tmppy = py - ny*prTtimesoneminuscsi1inv
tmppz = pz - nz*prTtimesoneminuscsi1inv
pxir = (tmppx*xiUSCOREx + tmppy*xiUSCOREy + tmppz*xiUSCOREz)*r
pvr  = (tmppx*vx + tmppy*vy + tmppz*vz)*r
pvrsq = pvr*pvr
pn   =  tmppx*nx + tmppy*ny + tmppz*nz
pnsq = pn*pn
pr = pn
prsq = pr*pr
pf = pxir
pxirsq = pxir*pxir
ptheta2 = pvrsq*invxi2
prT4=prT*prT*prT*prT
Hnspt7 = deltaR*invrho2
Hnspt6 = rho2invLambda*invxi2
Hnspt5 = qq*u2
Hnspt4 = (1 + prT4*Hnspt5 + ptheta2*invrho2 + pf*pf*Hnspt6 + prsq*Hnspt7)
Hnspt3 = deltaT*Hnspt4
Hnspt2 = rho2*Hnspt3
Hnspt1 = pf*ww
Hns = sp.sqrt(Hnspt2*invLambda) + invLambda*Hnspt1
Qpt3 = deltaR*invrho2
Qpt2 = rho2invLambda*invxi2
Qpt1 = invrho2*invxi2
Q = 1 + pvrsq*Qpt1 + pxirsq*Qpt2 + pnsq*Qpt3
pn2 = prsq*deltaR*invrho2
pp  = Q - 1
sKerrmultfact = (-8 - 3*r*(12*pn2 - pp))
sStarmultfact = (14 + (- 30*pn2 + 4*pp)*r)
deltaSigmaStarUSCOREx1=etaover12r*(sKerrmultfact*sKerrUSCOREx + sStarmultfact*sStarUSCOREx)
deltaSigmaStarUSCOREy1=etaover12r*(sKerrmultfact*sKerrUSCOREy + sStarmultfact*sStarUSCOREy)
deltaSigmaStarUSCOREz1=etaover12r*(sKerrmultfact*sKerrUSCOREz + sStarmultfact*sStarUSCOREz)
pn2pp = pn2*pp
pp2 = pp*pp
pn2u2 = pn2*u2
ppu2 = pp*u2
pn2ppu2 = pn2pp*u2
sMultiplier1pt6 = -360*pn2*pn2 + 126*pn2pp + 3*pp2
sMultiplier1pt5 = -96*pn2pp + 23*pp2
sMultiplier1pt4 = -120*pp + 324*pn2 + sMultiplier1pt6*r
sMultiplier1pt3 = 206*pp - 282*pn2 + sMultiplier1pt5*r
sMultiplier1pt2 = 54 + sMultiplier1pt4*r
sMultiplier1pt1 = -706 + sMultiplier1pt3*r + sMultiplier1pt2*eta
sMultiplier1 = sMultiplier1pt1*eta*u2*sp.Rational(-1,72)
sMultiplier2pt6 = sp.Rational(45,8)*pn2*pn2u2 - sp.Rational(13,8)*pn2ppu2
sMultiplier2pt5 = pn2ppu2/4 - sp.Rational(5,16)*pp2*u2
sMultiplier2pt4 = sp.Rational(-49,8)*pn2u2 + sp.Rational(17,12)*ppu2 + sMultiplier2pt6*r
sMultiplier2pt3 = sp.Rational(-2,3)*pn2u2 - sp.Rational(109,36)*ppu2 + sMultiplier2pt5*r
sMultiplier2pt2 = sp.Rational(-7,3)*u2 + sMultiplier2pt4*r
sMultiplier2pt1 = sp.Rational(-56,9)*u2 + sMultiplier2pt3*r + sMultiplier2pt2*eta
sMultiplier2 = sMultiplier2pt1*eta
deltaSigmaStarUSCOREx2 = deltaSigmaStarUSCOREx1 + sMultiplier1*sigmaStar0 + sMultiplier2*sigmaKerr0
deltaSigmaStarUSCOREy2 = deltaSigmaStarUSCOREy1 + sMultiplier1*sigmaStar1 + sMultiplier2*sigmaKerr1
deltaSigmaStarUSCOREz2 = deltaSigmaStarUSCOREz1 + sMultiplier1*sigmaStar2 + sMultiplier2*sigmaKerr2
deltaSigmaStarUSCOREx3 = deltaSigmaStarUSCOREx2 + d1*sigmaStar0*etau3
deltaSigmaStarUSCOREy3 = deltaSigmaStarUSCOREy2 + d1*sigmaStar1*etau3
deltaSigmaStarUSCOREz3 = deltaSigmaStarUSCOREz2 + d1*sigmaStar2*etau3
deltaSigmaStarUSCOREx = deltaSigmaStarUSCOREx3 + d1v2*sigmaKerr0*etau3
deltaSigmaStarUSCOREy = deltaSigmaStarUSCOREy3 + d1v2*sigmaKerr1*etau3
deltaSigmaStarUSCOREz = deltaSigmaStarUSCOREz3 + d1v2*sigmaKerr2*etau3
sx = sStarUSCOREx + deltaSigmaStarUSCOREx
sy = sStarUSCOREy + deltaSigmaStarUSCOREy
sz = sStarUSCOREz + deltaSigmaStarUSCOREz
sxi = sx*xiUSCOREx + sy*xiUSCOREy + sz*xiUSCOREz
sv  = sx*vx + sy*vy + sz*vz
sn  = sx*nx + sy*ny + sz*nz
s3 = sx*e3USCOREx + sy*e3USCOREy + sz*e3USCOREz
sqrtQ = sp.sqrt(Q)
oneplus2sqrtQ = 1 + 2*sqrtQ
oneplus1sqrtQ = oneplus2sqrtQ - sqrtQ
twoB1psqrtQsqrtQ = (2*B*oneplus1sqrtQ*sqrtQ)
invtwoB1psqrtQsqrtQ = 1/twoB1psqrtQsqrtQ
expMUsqsqrtQplusQ = (expMUsq)*(sqrtQ + Q)
Hwrpt4a = pxirsq*sv
Hwrpt4 = expMUsqexpnusq*Hwrpt4a
Hwrpt3c = pxir*sxi
Hwrpt3b = pvr*Hwrpt3c
Hwrpt3a = expMUexpnu*Hwrpt3b
Hwrpt3 = B*Hwrpt3a
Hwrpt2g = sv*deltaR
Hwrpt2f = sn*sqrtdeltaR
Hwrpt2e = pvr*Hwrpt2f
Hwrpt2d = pnsq*Hwrpt2g
Hwrpt2c = pn*Hwrpt2e
Hwrpt2b = expMUsqsqrtQplusQ*sv
Hwrpt2a = xi2*(Hwrpt2b + Hwrpt2c - Hwrpt2d)
Hwrpt2 = deltaT*Hwrpt2a
Hwrpt1b = invtwoB1psqrtQsqrtQ*invxi2
Hwrpt1a = sqrtdeltaR*Hwrpt1b
Hwrpt1 = invexpMUcubinvexpnu*Hwrpt1a
Hwr = (Hwrpt4 - Hwrpt3 + Hwrpt2)*Hwrpt1
Hwcospt9 = pxir*sxi
Hwcospt8 = pvr*sv
Hwcospt7 = (B*Hwcospt8 - (expMUexpnu)*Hwcospt9)
Hwcospt6 = sqrtdeltaR*Hwcospt7
Hwcospt5 = (pvrsq - expMUsqsqrtQplusQ*xi2)
Hwcospt4 = pn*Hwcospt6
Hwcospt3 = -(expMUsqexpnusq*pxirsq) + deltaT*Hwcospt5
Hwcospt2 = sn*Hwcospt3 - B*Hwcospt4
Hwcospt1 = invexpMUcubinvexpnu*Hwcospt2
Hwcos = invtwoB1psqrtQsqrtQ*Hwcospt1
deltaTsqrtQ = deltaT*sqrtQ
invdeltatTsqrtQ = 1/deltaTsqrtQ
HSOLpt5 = (-B + (expMUexpnu))*pxir
HSOLpt4 = invexpMU*HSOLpt5
HSOLpt3 = expnusq*HSOLpt4
HSOLpt2 = (HSOLpt3*s3)
HSOLpt1 = HSOLpt2*invxi2
HSOL = HSOLpt1*invdeltatTsqrtQ
deltaTsqrtQplusQ = (deltaT*(sqrtQ + Q))
invdeltaTsqrtQplusQ = 1/deltaTsqrtQplusQ
HSONLmult2 = invxi2*invdeltaTsqrtQplusQ
HSONLmult = expnuinvexpMU2*HSONLmult2
HSONLpt1b = pn*xi2
HSONLpt1a = (mur*pvr - nur*pvr + (-mucos + nucos)*HSONLpt1b)
HSONLpt1 = mur*pvr - (mucos*HSONLpt1b) + sqrtQ*HSONLpt1a
HSONLpt2d = nur*pxir
HSONLpt2c = oneplus2sqrtQ*HSONLpt2d
HSONLpt2b = B*sxi
HSONLpt2a = expMUexpnu*HSONLpt2c
HSONLpt2 = (sv*HSONLpt2a + HSONLpt1*HSONLpt2b)
HSONLpt3c = sv*pxir
HSONLpt3b = oneplus1sqrtQ*HSONLpt3c
HSONLpt3a = expMUexpnu*HSONLpt3b
HSONLpt3 = -BR*HSONLpt3a + B*HSONLpt2
HSONLpt4e = sn*xi2
HSONLpt4d = oneplus2sqrtQ*HSONLpt4e
HSONLpt4c = pxir*HSONLpt4d
HSONLpt4b = nucos*HSONLpt4c
HSONLpt4a = expMUexpnu*HSONLpt4b
HSONLpt4 = (-(B*HSONLpt4a) + HSONLpt3*sqrtdeltaR)
HSONL = HSONLmult*HSONLpt4
Hs = w*s3 + Hwr*wr + Hwcos*wcos + HSOL + HSONL
Hsspt1 = sp.Rational(-1,2)*(sx*sx + sy*sy + sz*sz - 3*sn*sn)
Hss = u3*Hsspt1
sKerrdotsStar = (sKerrUSCOREx*sStarUSCOREx + sKerrUSCOREy*sStarUSCOREy + sKerrUSCOREz*sStarUSCOREz)
Hpt1 = etau4*(s1dots1 + s2dots2)
H = Hns + Hs + Hss + (dheffSS*sKerrdotsStar + dheffSSv2)*Hpt1
Hreal = sp.sqrt(1 + 2*eta*(H - 1))

# %%
from outputC import *
import time
start = time.time()

outstring = outputC(Hreal,"Hreal","returnstring","outCverbose=False,SIMD_enable=True,enable_TYPE=False,includebraces=False")

end = time.time()

print("Finished in " + str(end - start) + " seconds.")
# Out:
# Finished in 59.4827418327 seconds.

# %%
print("""
MulSIMD[x_, y_] = x*y;
DivSIMD[x_, y_] = x/y;
AddSIMD[x_, y_] = x + y;
FusedMulAddSIMD[x_, y_, z_] = x*y + z;
FusedMulSubSIMD[x_, y_, z_] = x*y - z;
SqrtSIMD[x_] = Sqrt[x];
LogSIMD[x_] = Log[x];
SubSIMD[x_, y_] = x - y;
AbsSIMD[x_] = Abs[x];
PowSIMD[x_, y_] = x^y;
""")
print(outstring.replace("_Rational","Rational").replace("_Integer","Integer").replace("_","USCR")).replace("(","[").replace(")","]")
# replace(";","").
# Out:
# MulSIMD[x_, y_] = x*y;
# DivSIMD[x_, y_] = x/y;
# AddSIMD[x_, y_] = x + y;
# FusedMulAddSIMD[x_, y_, z_] = x*y + z;
# FusedMulSubSIMD[x_, y_, z_] = x*y - z;
# SqrtSIMD[x_] = Sqrt[x];
# LogSIMD[x_] = Log[x];
# SubSIMD[x_, y_] = x - y;
# AbsSIMD[x_] = Abs[x];
# PowSIMD[x_, y_] = x^y;
#
# IntegerUSCR1 = 1.000000000000000000000000000000000;
# IntegerUSCR11 = 11.00000000000000000000000000000000;
# IntegerUSCR120 = 120.0000000000000000000000000000000;
# IntegerUSCR126 = 126.0000000000000000000000000000000;
# IntegerUSCR14 = 14.00000000000000000000000000000000;
# IntegerUSCR2 = 2.000000000000000000000000000000000;
# IntegerUSCR204 = 204.0000000000000000000000000000000;
# IntegerUSCR206 = 206.0000000000000000000000000000000;
# IntegerUSCR23 = 23.00000000000000000000000000000000;
# IntegerUSCR26 = 26.00000000000000000000000000000000;
# IntegerUSCR3 = 3.000000000000000000000000000000000;
# IntegerUSCR360 = 360.0000000000000000000000000000000;
# IntegerUSCR4 = 4.000000000000000000000000000000000;
# IntegerUSCR5 = 5.000000000000000000000000000000000;
# IntegerUSCR52 = 52.00000000000000000000000000000000;
# IntegerUSCR54 = 54.00000000000000000000000000000000;
# IntegerUSCR6 = 6.000000000000000000000000000000000;
# IntegerUSCR76 = 76.00000000000000000000000000000000;
# IntegerUSCR96 = 96.00000000000000000000000000000000;
# IntegerUSCRm1 = -1.000000000000000000000000000000000;
# IntegerUSCRm2 = -2.000000000000000000000000000000000;
# IntegerUSCRm706 = -706.0000000000000000000000000000000;
# IntegerUSCRm8 = -8.000000000000000000000000000000000;
# RationalUSCR17USCR12 = 1.416666666666666666666666666666667;
# RationalUSCR1USCR12 = 0.08333333333333333333333333333333333;
# RationalUSCR1USCR2 = 0.5000000000000000000000000000000000;
# RationalUSCR1USCR4 = 0.2500000000000000000000000000000000;
# RationalUSCR1USCR72 = 0.01388888888888888888888888888888889;
# RationalUSCR3USCR2 = 1.500000000000000000000000000000000;
# RationalUSCR45USCR8 = 5.625000000000000000000000000000000;
# RationalUSCRm109USCR36 = -3.027777777777777777777777777777778;
# RationalUSCRm13USCR8 = -1.625000000000000000000000000000000;
# RationalUSCRm1USCR2 = -0.5000000000000000000000000000000000;
# RationalUSCRm2USCR3 = -0.6666666666666666666666666666666667;
# RationalUSCRm49USCR8 = -6.125000000000000000000000000000000;
# RationalUSCRm56USCR9 = -6.222222222222222222222222222222222;
# RationalUSCRm5USCR16 = -0.3125000000000000000000000000000000;
# RationalUSCRm7USCR3 = -2.333333333333333333333333333333333;
# tmp0 = FusedMulAddSIMD[y, y, FusedMulAddSIMD[z, z, MulSIMD[x, x]]];
# tmp1 = MulSIMD[tmp0, tmp0];
# tmp2 = DivSIMD[IntegerUSCR1, tmp1];
# tmp3 = AddSIMD[s1x, s2x];
# tmp4 = DivSIMD[m2, m1];
# tmp5 = DivSIMD[m1, m2];
# tmp6 = FusedMulAddSIMD[tmp5, s2x, MulSIMD[tmp4, s1x]];
# tmp7 = AddSIMD[s1y, s2y];
# tmp8 = FusedMulAddSIMD[tmp5, s2y, MulSIMD[tmp4, s1y]];
# tmp9 = AddSIMD[s1z, s2z];
# tmp10 = FusedMulAddSIMD[tmp5, s2z, MulSIMD[tmp4, s1z]];
# tmp11 = SqrtSIMD[tmp0];
# tmp12 = DivSIMD[IntegerUSCR1, tmp11];
# tmp13 = MulSIMD[tmp12, z];
# tmp14 = FusedMulAddSIMD[tmp7, tmp7, FusedMulAddSIMD[tmp9, tmp9, MulSIMD[tmp3, tmp3]]];
# tmp15 = SqrtSIMD[tmp14];
# tmp16 = DivSIMD[IntegerUSCR1, tmp15];
# tmp17 = MulSIMD[tmp16, tmp7];
# tmp18 = MulSIMD[tmp12, y];
# tmp19 = MulSIMD[tmp16, tmp9];
# tmp20 = FusedMulAddSIMD[tmp19, MulSIMD[tmp18, IntegerUSCRm1], MulSIMD[tmp13, tmp17]];
# tmp21 = MulSIMD[tmp12, x];
# tmp22 = AddSIMD[tmp0, tmp14];
# tmp23 = DivSIMD[IntegerUSCR1, tmp0];
# tmp24 = MulSIMD[KK, eta];
# tmp25 = AddSIMD[tmp24, IntegerUSCRm1];
# tmp26 = DivSIMD[IntegerUSCR1, tmp25];
# tmp27 = MulSIMD[tmp12, IntegerUSCR2];
# tmp28 = FusedMulAddSIMD[tmp26, AddSIMD[tmp26, tmp27], MulSIMD[tmp14, tmp23]];
# tmp29 = MulSIMD[eta, IntegerUSCR6];
# tmp30 = PowSIMD[tmp0, RationalUSCR3USCR2];
# tmp31 = DivSIMD[IntegerUSCR1, tmp30];
# tmp32 = MulSIMD[tmp31, eta];
# tmp33 = AddSIMD[IntegerUSCR1, LogSIMD[FusedMulAddSIMD[tmp23, tmp29, FusedMulAddSIMD[tmp32, SubSIMD[IntegerUSCR52, tmp29], IntegerUSCR1]]]];
# tmp34 = AddSIMD[tmp24, IntegerUSCRm2];
# tmp35 = PowSIMD[tmp0, -5/2];
# tmp36 = MulSIMD[k5l, LogSIMD[tmp12]];
# tmp37 = MulSIMD[KK, IntegerUSCR2];
# tmp38 = MulSIMD[tmp25, FusedMulAddSIMD[tmp37, MulSIMD[tmp34, IntegerUSCRm1], MulSIMD[tmp37, IntegerUSCRm1]]];
# tmp39 = MulSIMD[tmp14, c1k2];
# tmp40 = MulSIMD[tmp14, c1k3];
# tmp41 = MulSIMD[tmp14, c1k4];
# tmp42 = MulSIMD[tmp14, tmp14];
# tmp43 = MulSIMD[tmp42, c2k4];
# tmp44 = MulSIMD[tmp14, c1k5];
# tmp45 = MulSIMD[tmp42, c2k5];
# tmp46 = FusedMulAddSIMD[tmp35, tmp36, FusedMulAddSIMD[tmp31, AddSIMD[tmp40, c0k3], FusedMulAddSIMD[tmp23, AddSIMD[tmp39, c0k2], FusedMulAddSIMD[tmp2, AddSIMD[tmp43, AddSIMD[tmp41, c0k4]], FusedMulAddSIMD[tmp12, tmp38, FusedMulAddSIMD[tmp35, AddSIMD[tmp45, AddSIMD[tmp44, c0k5]], IntegerUSCR1]]]]]];
# tmp47 = FusedMulAddSIMD[tmp24, tmp34, FusedMulAddSIMD[eta, LogSIMD[tmp46], IntegerUSCR1]];
# tmp48 = MulSIMD[tmp47, tmp47];
# tmp49 = AddSIMD[IntegerUSCRm1, DivSIMD[MulSIMD[AbsSIMD[tmp28], MulSIMD[tmp0, SqrtSIMD[MulSIMD[tmp33, tmp48]]]], tmp22]];
# tmp50 = FusedMulAddSIMD[tmp49, SubSIMD[RationalUSCR1USCR2, copysignresult], IntegerUSCR1];
# tmp51 = FusedMulAddSIMD[tmp18, py, FusedMulAddSIMD[tmp21, px, MulSIMD[tmp13, pz]]];
# tmp52 = MulSIMD[tmp51, MulSIMD[tmp50, AddSIMD[IntegerUSCR1, DivSIMD[IntegerUSCRm1, FusedMulAddSIMD[tmp49, SubSIMD[IntegerUSCR1, AbsSIMD[AddSIMD[tortoise, IntegerUSCRm1]]], IntegerUSCR1]]]]];
# tmp53 = FusedMulAddSIMD[tmp52, MulSIMD[tmp21, IntegerUSCRm1], px];
# tmp54 = MulSIMD[tmp16, tmp3];
# tmp55 = FusedMulAddSIMD[tmp54, MulSIMD[tmp13, IntegerUSCRm1], MulSIMD[tmp19, tmp21]];
# tmp56 = FusedMulAddSIMD[tmp52, MulSIMD[tmp18, IntegerUSCRm1], py];
# tmp57 = FusedMulAddSIMD[tmp21, MulSIMD[tmp17, IntegerUSCRm1], MulSIMD[tmp18, tmp54]];
# tmp58 = FusedMulAddSIMD[tmp52, MulSIMD[tmp13, IntegerUSCRm1], pz];
# tmp59 = FusedMulAddSIMD[tmp55, tmp56, FusedMulAddSIMD[tmp57, tmp58, MulSIMD[tmp20, tmp53]]];
# tmp60 = MulSIMD[tmp15, IntegerUSCR2];
# tmp61 = MulSIMD[tmp12, eta];
# tmp62 = MulSIMD[b3, PowSIMD[tmp14, RationalUSCR3USCR2]];
# tmp63 = MulSIMD[tmp15, bb3];
# tmp64 = FusedMulAddSIMD[tmp61, tmp62, FusedMulAddSIMD[tmp61, tmp63, MulSIMD[tmp11, tmp60]]];
# tmp65 = MulSIMD[tmp28, tmp47];
# tmp66 = MulSIMD[tmp0, tmp65];
# tmp67 = FusedMulAddSIMD[tmp17, tmp18, FusedMulAddSIMD[tmp21, tmp54, MulSIMD[tmp13, tmp19]]];
# tmp68 = MulSIMD[tmp67, tmp67];
# tmp69 = SubSIMD[IntegerUSCR1, tmp68];
# tmp70 = MulSIMD[tmp14, tmp69];
# tmp71 = FusedMulAddSIMD[tmp70, MulSIMD[tmp66, IntegerUSCRm1], MulSIMD[tmp22, tmp22]];
# tmp72 = DivSIMD[IntegerUSCR1, tmp71];
# tmp73 = MulSIMD[tmp64, tmp72];
# tmp74 = MulSIMD[eta, IntegerUSCR2];
# tmp75 = FusedMulAddSIMD[tmp14, tmp68, tmp0];
# tmp76 = DivSIMD[IntegerUSCR1, tmp75];
# tmp77 = FusedMulAddSIMD[tmp18, tmp56, FusedMulAddSIMD[tmp21, tmp53, MulSIMD[tmp13, tmp58]]];
# tmp78 = MulSIMD[tmp77, tmp77];
# tmp79 = MulSIMD[tmp33, tmp65];
# tmp80 = MulSIMD[tmp78, MulSIMD[tmp76, tmp79]];
# tmp81 = MulSIMD[tmp0, tmp80];
# tmp82 = DivSIMD[IntegerUSCR1, tmp69];
# tmp83 = FusedMulAddSIMD[tmp55, MulSIMD[tmp13, IntegerUSCRm1], MulSIMD[tmp18, tmp57]];
# tmp84 = FusedMulAddSIMD[tmp57, MulSIMD[tmp21, IntegerUSCRm1], MulSIMD[tmp13, tmp20]];
# tmp85 = FusedMulAddSIMD[tmp21, tmp55, MulSIMD[tmp20, MulSIMD[tmp18, IntegerUSCRm1]]];
# tmp86 = FusedMulAddSIMD[tmp56, tmp84, FusedMulAddSIMD[tmp58, tmp85, MulSIMD[tmp53, tmp83]]];
# tmp87 = MulSIMD[tmp0, MulSIMD[tmp86, tmp86]];
# tmp88 = MulSIMD[tmp82, MulSIMD[tmp76, tmp87]];
# tmp89 = MulSIMD[tmp59, tmp59];
# tmp90 = MulSIMD[tmp72, tmp82];
# tmp91 = MulSIMD[tmp89, MulSIMD[tmp75, MulSIMD[tmp0, tmp90]]];
# tmp92 = AddSIMD[tmp88, AddSIMD[tmp81, tmp91]];
# tmp93 = AddSIMD[tmp92, IntegerUSCR1];
# tmp94 = MulSIMD[tmp65, tmp72];
# tmp95 = SqrtSIMD[tmp75];
# tmp96 = MulSIMD[tmp11, tmp95];
# tmp97 = MulSIMD[tmp23, tmp92];
# tmp98 = MulSIMD[tmp75, tmp75];
# tmp99 = DivSIMD[IntegerUSCR1, tmp98];
# tmp100 = MulSIMD[MulSIMD[tmp33, tmp33], MulSIMD[MulSIMD[tmp28, tmp28], MulSIMD[tmp99, MulSIMD[tmp48, MulSIMD[tmp77, MulSIMD[tmp77, MulSIMD[tmp77, tmp77]]]]]]];
# tmp101 = MulSIMD[tmp80, tmp92];
# tmp102 = MulSIMD[tmp92, tmp92];
# tmp103 = MulSIMD[eta, FusedMulAddSIMD[tmp23, RationalUSCRm56USCR9, FusedMulAddSIMD[eta, FusedMulAddSIMD[tmp23, RationalUSCRm7USCR3, MulSIMD[tmp11, FusedMulAddSIMD[tmp80, RationalUSCRm49USCR8, FusedMulAddSIMD[tmp97, RationalUSCR17USCR12, MulSIMD[tmp11, FusedMulAddSIMD[tmp101, RationalUSCRm13USCR8, MulSIMD[tmp100, MulSIMD[tmp0, RationalUSCR45USCR8]]]]]]]], MulSIMD[tmp11, FusedMulAddSIMD[tmp80, RationalUSCRm2USCR3, FusedMulAddSIMD[tmp97, RationalUSCRm109USCR36, MulSIMD[tmp11, FusedMulAddSIMD[tmp23, MulSIMD[tmp102, RationalUSCRm5USCR16], MulSIMD[tmp101, RationalUSCR1USCR4]]]]]]]]];
# tmp104 = SubSIMD[IntegerUSCRm8, MulSIMD[SubSIMD[FusedMulSubSIMD[tmp81, IntegerUSCR11, tmp91], tmp88], MulSIMD[tmp11, IntegerUSCR3]]];
# tmp105 = FusedMulAddSIMD[tmp11, FusedMulAddSIMD[tmp91, IntegerUSCR4, FusedMulSubSIMD[tmp88, IntegerUSCR4, MulSIMD[tmp81, IntegerUSCR26]]], IntegerUSCR14];
# tmp106 = MulSIMD[tmp61, RationalUSCR1USCR12];
# tmp107 = MulSIMD[tmp32, d1];
# tmp108 = MulSIMD[tmp32, d1v2];
# tmp109 = MulSIMD[tmp81, tmp92];
# tmp110 = MulSIMD[tmp23, eta];
# tmp111 = MulSIMD[FusedMulAddSIMD[tmp11, FusedMulAddSIMD[tmp91, IntegerUSCR206, FusedMulAddSIMD[tmp88, IntegerUSCR206, FusedMulSubSIMD[tmp11, FusedMulSubSIMD[tmp102, IntegerUSCR23, MulSIMD[tmp109, IntegerUSCR96]], MulSIMD[tmp81, IntegerUSCR76]]]], FusedMulAddSIMD[eta, FusedMulAddSIMD[tmp11, SubSIMD[FusedMulAddSIMD[tmp81, IntegerUSCR204, FusedMulSubSIMD[tmp11, FusedMulAddSIMD[tmp109, IntegerUSCR126, FusedMulSubSIMD[tmp102, IntegerUSCR3, MulSIMD[tmp100, MulSIMD[tmp1, IntegerUSCR360]]]], MulSIMD[tmp91, IntegerUSCR120]]], MulSIMD[tmp88, IntegerUSCR120]], IntegerUSCR54], IntegerUSCRm706]], MulSIMD[tmp110, RationalUSCR1USCR72]];
# tmp112 = FusedMulAddSIMD[tmp108, tmp3, FusedMulAddSIMD[tmp107, tmp6, FusedMulAddSIMD[tmp106, FusedMulAddSIMD[tmp105, tmp6, MulSIMD[tmp104, tmp3]], FusedMulAddSIMD[tmp103, tmp3, FusedMulAddSIMD[tmp6, MulSIMD[tmp111, IntegerUSCRm1], tmp6]]]]];
# tmp113 = FusedMulAddSIMD[tmp108, tmp7, FusedMulAddSIMD[tmp107, tmp8, FusedMulAddSIMD[tmp106, FusedMulAddSIMD[tmp105, tmp8, MulSIMD[tmp104, tmp7]], FusedMulAddSIMD[tmp103, tmp7, FusedMulAddSIMD[tmp8, MulSIMD[tmp111, IntegerUSCRm1], tmp8]]]]];
# tmp114 = FusedMulAddSIMD[tmp108, tmp9, FusedMulAddSIMD[tmp106, FusedMulAddSIMD[tmp104, tmp9, MulSIMD[tmp10, tmp105]], FusedMulAddSIMD[tmp103, tmp9, FusedMulAddSIMD[tmp10, tmp107, FusedMulAddSIMD[tmp111, MulSIMD[tmp10, IntegerUSCRm1], tmp10]]]]];
# tmp115 = FusedMulAddSIMD[tmp113, tmp17, FusedMulAddSIMD[tmp114, tmp19, MulSIMD[tmp112, tmp54]]];
# tmp116 = SqrtSIMD[tmp93];
# tmp117 = DivSIMD[IntegerUSCR1, tmp116];
# tmp118 = SqrtSIMD[tmp65];
# tmp119 = MulSIMD[tmp11, tmp118];
# tmp120 = SqrtSIMD[tmp94];
# tmp121 = MulSIMD[tmp120, tmp75];
# tmp122 = MulSIMD[tmp11, tmp121];
# tmp123 = MulSIMD[tmp112, tmp21];
# tmp124 = MulSIMD[tmp113, tmp18];
# tmp125 = MulSIMD[tmp114, tmp13];
# tmp126 = AddSIMD[tmp124, AddSIMD[tmp123, tmp125]];
# tmp127 = MulSIMD[tmp94, MulSIMD[tmp89, MulSIMD[tmp1, tmp98]]];
# tmp128 = AddSIMD[tmp116, IntegerUSCR1];
# tmp129 = AddSIMD[tmp128, tmp92];
# tmp130 = MulSIMD[tmp129, tmp75];
# tmp131 = FusedMulAddSIMD[tmp113, tmp55, FusedMulAddSIMD[tmp114, tmp57, MulSIMD[tmp112, tmp20]]];
# tmp132 = MulSIMD[tmp121, MulSIMD[tmp0, tmp59]];
# tmp133 = FusedMulAddSIMD[tmp113, tmp84, FusedMulAddSIMD[tmp114, tmp85, MulSIMD[tmp112, tmp83]]];
# tmp134 = MulSIMD[tmp0, tmp86];
# tmp135 = SqrtSIMD[tmp79];
# tmp136 = MulSIMD[tmp135, tmp77];
# tmp137 = MulSIMD[tmp14, tmp67];
# tmp138 = DivSIMD[IntegerUSCR1, tmp118];
# tmp139 = DivSIMD[DivSIMD[MulSIMD[tmp99, MulSIMD[tmp138, DivSIMD[tmp117, MulSIMD[tmp71, tmp71]]]], tmp120], tmp128];
# tmp140 = FusedMulAddSIMD[tmp116, IntegerUSCR2, IntegerUSCR1];
# tmp141 = MulSIMD[tmp22, tmp72];
# tmp142 = MulSIMD[tmp141, SubSIMD[tmp22, tmp66]];
# tmp143 = MulSIMD[tmp118, tmp59];
# tmp144 = MulSIMD[tmp47, FusedMulAddSIMD[tmp26, IntegerUSCR2, MulSIMD[tmp14, tmp27]]];
# tmp145 = MulSIMD[tmp11, tmp65];
# tmp146 = MulSIMD[FusedMulAddSIMD[tmp12, FusedMulAddSIMD[tmp39, IntegerUSCR2, FusedMulAddSIMD[c0k2, IntegerUSCR2, MulSIMD[tmp12, FusedMulAddSIMD[tmp40, IntegerUSCR3, FusedMulAddSIMD[c0k3, IntegerUSCR3, MulSIMD[tmp12, FusedMulAddSIMD[tmp43, IntegerUSCR4, FusedMulAddSIMD[tmp41, IntegerUSCR4, FusedMulAddSIMD[c0k4, IntegerUSCR4, MulSIMD[tmp12, FusedMulAddSIMD[tmp45, IntegerUSCR5, FusedMulAddSIMD[tmp44, IntegerUSCR5, FusedMulAddSIMD[c0k5, IntegerUSCR5, MulSIMD[tmp36, IntegerUSCR5]]]]]]]]]]]]]], tmp38], MulSIMD[eta, DivSIMD[tmp28, tmp46]]];
# tmp147 = DivSIMD[1.0, tmp135];
# tmp148 = MulSIMD[tmp11, tmp76];
# tmp149 = FusedMulAddSIMD[tmp145, IntegerUSCR2, FusedMulSubSIMD[tmp144, IntegerUSCRm1, tmp146]];
# tmp150 = DivSIMD[DivSIMD[IntegerUSCR1, tmp47], tmp28];
# tmp151 = FusedMulAddSIMD[tmp23, MulSIMD[tmp150, MulSIMD[tmp141, MulSIMD[0.5, FusedMulAddSIMD[tmp65, MulSIMD[tmp30, MulSIMD[4.0, IntegerUSCRm1]], MulSIMD[tmp149, tmp22]]]]], tmp148];
# tmp152 = MulSIMD[tmp137, tmp76];
# tmp153 = MulSIMD[tmp69, tmp77];
# tmp154 = MulSIMD[tmp11, tmp86];
# tmp155 = MulSIMD[tmp154, FusedMulAddSIMD[tmp147, MulSIMD[tmp12, IntegerUSCRm1], tmp148]];
# tmp156 = MulSIMD[tmp12, tmp82];
# Hreal = SqrtSIMD[FusedMulAddSIMD[tmp74, FusedMulAddSIMD[FusedMulAddSIMD[tmp69, MulSIMD[tmp66, FusedMulAddSIMD[tmp134, MulSIMD[tmp126, tmp136], FusedMulAddSIMD[tmp79, MulSIMD[tmp78, MulSIMD[tmp133, MulSIMD[tmp0, IntegerUSCRm1]]], MulSIMD[tmp130, tmp133]]]], FusedMulAddSIMD[tmp86, MulSIMD[tmp143, MulSIMD[tmp131, MulSIMD[tmp121, MulSIMD[tmp1, IntegerUSCRm1]]]], MulSIMD[tmp127, tmp133]]], MulSIMD[FusedMulAddSIMD[tmp71, FusedMulAddSIMD[tmp62, MulSIMD[tmp110, IntegerUSCRm1], FusedMulAddSIMD[tmp63, MulSIMD[tmp110, IntegerUSCRm1], tmp60]], MulSIMD[tmp64, FusedMulSubSIMD[tmp149, tmp70, MulSIMD[tmp22, MulSIMD[tmp11, IntegerUSCR4]]]]], MulSIMD[tmp156, MulSIMD[tmp139, MulSIMD[tmp135, RationalUSCR1USCR2]]]], FusedMulAddSIMD[FusedMulAddSIMD[FusedMulAddSIMD[tmp133, MulSIMD[tmp118, tmp134], MulSIMD[tmp132, MulSIMD[tmp131, IntegerUSCRm1]]], MulSIMD[tmp136, MulSIMD[tmp118, MulSIMD[tmp0, IntegerUSCRm1]]], MulSIMD[tmp126, FusedMulAddSIMD[tmp66, FusedMulAddSIMD[tmp69, MulSIMD[tmp130, IntegerUSCRm1], tmp87], MulSIMD[tmp127, IntegerUSCRm1]]]], MulSIMD[tmp65, MulSIMD[tmp64, MulSIMD[tmp139, MulSIMD[tmp137, IntegerUSCRm1]]]], FusedMulAddSIMD[FusedMulAddSIMD[dheffSS, FusedMulAddSIMD[tmp3, tmp6, FusedMulAddSIMD[tmp7, tmp8, MulSIMD[tmp10, tmp9]]], dheffSSv2], MulSIMD[eta, MulSIMD[tmp2, FusedMulAddSIMD[s2y, s2y, FusedMulAddSIMD[s2x, s2x, FusedMulAddSIMD[s1z, s1z, FusedMulAddSIMD[s1y, s1y, FusedMulAddSIMD[s2z, s2z, MulSIMD[s1x, s1x]]]]]]]], FusedMulAddSIMD[tmp96, SqrtSIMD[MulSIMD[tmp94, FusedMulAddSIMD[MulSIMD[tmp50, MulSIMD[tmp50, MulSIMD[tmp50, tmp50]]], MulSIMD[SubSIMD[IntegerUSCR4, MulSIMD[eta, IntegerUSCR3]], MulSIMD[tmp74, MulSIMD[tmp23, MulSIMD[tmp51, MulSIMD[tmp51, MulSIMD[tmp51, tmp51]]]]]], tmp93]]], FusedMulAddSIMD[tmp96, MulSIMD[tmp90, MulSIMD[tmp59, MulSIMD[tmp117, MulSIMD[tmp115, SubSIMD[tmp122, tmp119]]]]], FusedMulAddSIMD[tmp59, MulSIMD[tmp11, tmp73], FusedMulAddSIMD[tmp31, FusedMulAddSIMD[MulSIMD[tmp113, tmp113], RationalUSCRm1USCR2, FusedMulAddSIMD[MulSIMD[tmp112, tmp112], RationalUSCRm1USCR2, FusedMulAddSIMD[MulSIMD[tmp114, tmp114], RationalUSCRm1USCR2, MulSIMD[FusedMulAddSIMD[tmp124, IntegerUSCR3, FusedMulAddSIMD[tmp125, IntegerUSCR3, MulSIMD[tmp123, IntegerUSCR3]]], MulSIMD[tmp126, RationalUSCR1USCR2]]]]], FusedMulAddSIMD[tmp115, tmp73, AddSIMD[IntegerUSCRm1, DivSIMD[MulSIMD[FusedMulAddSIMD[tmp69, MulSIMD[tmp30, MulSIMD[tmp143, MulSIMD[tmp142, MulSIMD[tmp140, MulSIMD[tmp137, MulSIMD[tmp126, MulSIMD[tmp120, IntegerUSCRm1]]]]]]], MulSIMD[tmp135, MulSIMD[tmp11, FusedMulAddSIMD[FusedMulAddSIMD[tmp146, RationalUSCRm1USCR2, FusedMulAddSIMD[tmp144, RationalUSCRm1USCR2, FusedMulAddSIMD[tmp147, MulSIMD[tmp145, IntegerUSCRm1], tmp145]]], MulSIMD[tmp59, MulSIMD[tmp138, MulSIMD[tmp133, MulSIMD[tmp128, MulSIMD[tmp122, MulSIMD[1.0, IntegerUSCRm1]]]]]], MulSIMD[tmp119, FusedMulAddSIMD[tmp140, MulSIMD[tmp133, MulSIMD[tmp132, tmp151]], MulSIMD[tmp131, MulSIMD[tmp119, FusedMulAddSIMD[tmp116, FusedMulAddSIMD[tmp153, FusedMulSubSIMD[tmp142, tmp152, tmp152], FusedMulAddSIMD[tmp154, MulSIMD[tmp151, IntegerUSCRm1], tmp155]], FusedMulAddSIMD[tmp153, MulSIMD[tmp152, IntegerUSCRm1], tmp155]]]]]]]]]], MulSIMD[tmp156, MulSIMD[tmp150, DivSIMD[tmp120, tmp95]]]], tmp129]]]]]]]]]], IntegerUSCR1]];
