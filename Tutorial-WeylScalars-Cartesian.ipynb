# %% [markdown]
# # The Weyl scalar $\psi_4$ in Cartesian coordinates
# ### This tutorial primarily concerns rewriting the arbitrary Weyl scalar code in a format that better facilitates an analytic comparison with Einstein Toolkit's $\text{WeylScal4}$ thorn.
# To that end, we use the same physical quantities as the Einstein Toolkit in place of conformal, rescaled quantities. Instead of calling BSSN_RHSs(), which in turn calls reference_metric(), we simply declare the metric $\gamma_{ij}$ and extrinsic curvature $K_{ij}$ (along with various traces, inverses, and determinants) as gridfunctions themselves.

# %%
# Step 1: import all needed modules from NRPy+:
import NRPy_param_funcs as par
import indexedexp as ixp
import grid as gri
import finite_difference as fin
import reference_metric as rfm
from outputC import *
#import BSSN.BSSN_RHSs as bssn
import sympy as sp

# %%
# Step 2: Initialize WeylScalar parameters
thismodule = __name__
# Current option: Approx_QuasiKinnersley = choice made in Baker, Campanelli, and Lousto. PRD 65, 044001 (2002)
par.initialize_param(par.glb_param("char", thismodule, "TetradChoice", "Approx_QuasiKinnersley"))

# %% [markdown]
# ### Defining the Levi-Civita Symbol
#
# Next we declare a function that defines the rank-3 Levi-Civita symbol, $\epsilon_{ijk}$, applying the algorithm in the [Wikipedia article on the Levi-Civita symbol](https://en.wikipedia.org/wiki/Levi-Civita_symbol), but exploiting properties of computer integer arithmetic as outlined [here](https://codegolf.stackexchange.com/questions/160359/levi-civita-symbol).
#
# In short, the Levi-Civita symbol $\epsilon_{ijk}$ is set to 1 for even permutations of the indices, -1 for odd permutations, or zero if any indices are repeated.

# %%
# Step 3: Define the rank-3 version of the Levi-Civita symbol. Amongst
#         other uses, this is needed for the construction of the approximate 
#         quasi-Kinnersley tetrad.
def define_LeviCivitaSymbol_rank3(DIM=-1):
    if DIM == -1:
        DIM = par.parval_from_str("DIM")

    LeviCivitaSymbol = ixp.zerorank3()

    for i in range(DIM):
        for j in range(DIM):
            for k in range(DIM):
                # From https://codegolf.stackexchange.com/questions/160359/levi-civita-symbol :
                LeviCivitaSymbol[i][j][k] = (i - j) * (j - k) * (k - i) / 2
    return LeviCivitaSymbol

# %% [markdown]
# ## Defining the Approximate Quasi-Kinnersley Tetrad
#
# To define the Weyl scalars, first a tetrad must be chosen. Below, for compatibility with the [WeylScal4 diagnostic module](https://bitbucket.org/einsteintoolkit/einsteinanalysis/src/master/WeylScal4/), we implement the approximate  quasi-Kinnersley tetrad of the BCL paper.
#
# We begin with the vectors given in eqs. 5.6 and 5.7 of the BCL paper,
# \begin{align}
#     v_1^a &= [-y,x,0] \\
#     v_2^a &= [x,y,z] \\
#     v_3^a &= {\rm det}(g)^{1/2} g^{ad} \epsilon_{dbc} v_1^b v_2^c,
# \end{align}
# and carry out the Gram-Schmidt orthonormalization process. Note that these vectors are initially orthogonal to each other; one is in the $\phi$ direction, one is in $r$, and the third is the cross product of the first two. The vectors $w_i^a$ are placeholders in the code; the final product of the orthonormalization is the vectors $e_i^a$. So,
# \begin{align}
# e_1^a &= \frac{v_1^a}{\omega_{11}} \\
# e_2^a &= \frac{v_2^a - \omega_{12} e_1^a}{\omega_{22}} \\
# e_3^a &= \frac{v_3^a - \omega_{13} e_1^a - \omega_{23} e_2^a}{\omega_{33}}, \\
# \end{align}
# where $\omega_{ij} = v_i^a v_j^b \gamma_{ab}$ needs to be updated between steps (to save resources, we can get away with only calculating components as needed), and uses $e_i^a$ instead of $v_i^a$ if it has been calculated. Recall that $\gamma_{ab}$ was declared as a gridfunction above.
#
# Once we have orthogonal, normalized vectors, we can contruct the tetrad itself, again drawing on eqs. 5.6. We can draw on SymPy's built-in tools for complex numbers to build the complex vectors $m^a$ and $\bar{m}^a$:
# \begin{align}
#     l^a &= \frac{1}{\sqrt{2}} e_2^a \\
#     n^a &= \frac{-1}{\sqrt{2}} e_2^a \\
#     m^a &= \frac{1}{\sqrt{2}} (e_3^a + i e_1^a) \\
#     \bar{m}^a &= \frac{1}{\sqrt{2}} (e_3^a - i e_1^a)
# \end{align}
#
# We will also assume that $n^0 = \frac{1}{\sqrt{2}}$ and that $m^0 = \bar{m}^0 = 0$. This last assumption in particular will significantly reduce the terms needed to find $\psi_4$.

# %%
# Step 1: Call BSSN_RHSs. This module computes many different quantities related to the metric,
#         many of which will be essential here. We must first change to our desired coordinate
#         system, however.
par.set_parval_from_str("reference_metric::CoordSystem","Cartesian")
#bssn.BSSN_RHSs() 
rfm.reference_metric()
# We do not need the barred or hatted quantities calculated when using Cartesian coordinates.
# Instead, we declare the PHYSICAL metric and extrinsic curvature as grid functions.
gammaDD = ixp.register_gridfunctions_for_single_rank2("EVOL","gammaDD", "sym12")
kDD = ixp.register_gridfunctions_for_single_rank2("EVOL","kDD", "sym12")
detgamma = gri.register_gridfunctions("AUX",["detgamma"]) # Should this be its own gridfunction, or the dummydet from below?
gammaUU, dummydet = ixp.symm_matrix_inverter3x3(gammaDD)


# Step 2a: Set spatial dimension (must be 3 for BSSN)
DIM = 3
par.set_parval_from_str("grid::DIM",DIM)

# Step 2b: Set the coordinate system to Cartesian
x = rfm.xxCart[0]
y = rfm.xxCart[1]
z = rfm.xxCart[2]

# Step 2c: Set which tetrad is used; at the moment, only one supported option
TetradChoice = par.parval_from_str("TetradChoice")

if TetradChoice == "Approx_QuasiKinnersley":
    # Eqs 5.6 in https://arxiv.org/pdf/gr-qc/0104063.pdf
    xmoved = x# - xorig
    ymoved = y# - yorig
    zmoved = z# - zorig

    # Step 3a: Choose 3 orthogonal vectors. Here, we choose one in the azimuthal 
    #          direction, one in the radial direction, and the cross product of the two. 
    # Eqs 5.7
    v1U = ixp.zerorank1()
    v2U = ixp.zerorank1()
    v3U = ixp.zerorank1()
    v1U[0] = -ymoved
    v1U[1] = xmoved# + offset
    v1U[2] = 0
    v2U[0] = xmoved# + offset
    v2U[1] = ymoved
    v2U[2] = zmoved
    LeviCivitaSymbol_rank3 = define_LeviCivitaSymbol_rank3()
    for a in range(DIM):
        for b in range(DIM):
            for c in range(DIM):
                for d in range(DIM):
                    v3U[a] += sp.sqrt(detgamma) * gammaUU[a][d] * LeviCivitaSymbol_rank3[d][b][c] * v1U[b] *v2U[c]

    # Step 3b: Gram-Schmidt orthonormalization of the vectors.
    # The w_i^a vectors here are used to temporarily hold values on the way to the final vectors e_i^a

    w1U = ixp.zerorank1()
    for a in range(DIM):
        w1U[a] = v1U[a]
    omega11 = 0
    for a in range(DIM):
        for b in range(DIM):
            omega11 += w1U[a] * w1U[b] * gammaDD[a][b]
    e1U = ixp.zerorank1()
    for a in range(DIM):
        e1U[a] = w1U[a] / sp.sqrt(omega11)

    omega12 = 0
    for a in range(DIM):
        for b in range(DIM):
            omega12 += e1U[a] * v2U[b] * gammaDD[a][b]
    w2U = ixp.zerorank1()
    for a in range(DIM):
        w2U[a] = v2U[a] - omega12*e1U[a]
    omega22 = 0
    for a in range(DIM):
        for b in range(DIM):
            omega22 += w2U[a] * w2U[b] *gammaDD[a][b]
    e2U = ixp.zerorank1()
    for a in range(DIM):
        e2U[a] = w2U[a] / sp.sqrt(omega22)

    omega13 = 0
    for a in range(DIM):
        for b in range(DIM):
            omega13 += e1U[a] * v3U[b] * gammaDD[a][b]
    omega23 = 0
    for a in range(DIM):
        for b in range(DIM):
            omega23 += e2U[a] * v3U[b] * gammaDD[a][b]
    w3U = ixp.zerorank1()
    for a in range(DIM):
        w3U[a] = v3U[a] - omega13*e1U[a] - omega23*e2U[a]
    omega33 = 0
    for a in range(DIM):
        for b in range(DIM):
            omega33 += w3U[a] * w3U[b] * gammaDD[a][b]
    e3U = ixp.zerorank1()
    for a in range(DIM):
        e3U[a] = w3U[a] / sp.sqrt(omega33)
        
    # Step 3c: Construct the tetrad itself.
    # Eqs. 5.6
    isqrt2 = 1/sp.sqrt(2)
    ltetU = ixp.zerorank1()
    ntetU = ixp.zerorank1()
    mtetU = ixp.zerorank1()
    mtetccU = ixp.zerorank1()
    for i in range(DIM):
        ltetU[i] = isqrt2 * e2U[i]
        ntetU[i] = -isqrt2 * e2U[i]
        mtetU[i] = isqrt2 * (e3U[i] + sp.I*e1U[i])
        mtetccU[i] = isqrt2 * (e3U[i] - sp.I*e1U[i])
    nn = isqrt2

else:
    print("Error: TetradChoice == "+par.parval_from_str("TetradChoice")+" unsupported!")
    exit(1)

# %% [markdown]
# ## Building the Riemann and extrinsic curvature tensors
# Now that we have the tetrad in place, we can contract it with the Weyl tensor to obtain the Weyl scalars. Naturally, we must first construct the Weyl tensor to do that. We will first build the Riemann curvature tensor,
# \begin{align}
# R_{abcd} = \frac{1}{2} (\gamma_{ad,cb}+\gamma_{bc,da}-\gamma_{ac,bd}-\gamma_{bd,ac}) + \gamma_{je} \Gamma^{j}_{bc}\Gamma^{e}_{ad} - \gamma_{je} \Gamma^{j}_{bd} \Gamma^{e}_{ac}
# \end{align}
# since several terms in our expression for $\psi_4$ are contractions of this tensor.
# To do this, we need second derivatives of the metric tensor, $\gamma_{ab,cd}$, using the finite differencing functionality in NRPy+.
#
# We also need the extrinsic curvature tensor $K_{ij}$; in the Cartesian case, we simply declared $K_{ij}$ as a gridfunction above.

# %%
#Step 4a: Declare and construct the second derivative of the metric.
#gammabarDD_dDD = ixp.zerorank4()
#for i in range(DIM):
#    for j in range(DIM):
#        for k in range(DIM):
#            for l in range(DIM):
#                gammabarDD_dDD[i][j][k][l] = bssn.hDD_dDD[i][j][k][l]*rfm.ReDD[i][j] + \
#                                             bssn.hDD_dD[i][j][k]*rfm.ReDDdD[i][j][l] + \
#                                             bssn.hDD_dD[i][j][l]*rfm.ReDDdD[i][j][k] + \
#                                             bssn.hDD[i][j]*rfm.ReDDdDD[i][j][k][l] + \
#                                             rfm.ghatDDdDD[i][j][k][l]
gammaDD_dD = ixp.declarerank3("gammaDD_dD","sym12")

# Define the Christoffel symbols
GammaUDD = ixp.zerorank3(DIM)
for i in range(DIM):
    for k in range(DIM):
        for l in range(DIM):
            for m in range(DIM):
                GammaUDD[i][k][l] += (sp.Rational(1,2))*gammaUU[i][m]*\
                                     (gammaDD_dD[m][k][l] + gammaDD_dD[m][l][k] - gammaDD_dD[k][l][m])


# Step 4b: Declare and construct the Riemann curvature tensor:
gammaDD_dDD = ixp.declarerank4("gammaDD_dDD","sym12_sym34")
RiemannDDDD = ixp.zerorank4()
for a in range(DIM):
    for b in range(DIM):
        for c in range(DIM):
            for d in range(DIM):
                RiemannDDDD[a][b][c][d] = (gammaDD_dDD[a][d][c][b] + \
                                           gammaDD_dDD[b][c][d][a] - \
                                           gammaDD_dDD[a][c][b][d] - \
                                           gammaDD_dDD[b][d][a][c]) / 2
                for e in range(DIM):
                    for j in range(DIM):
                        RiemannDDDD[a][b][c][d] +=  gammaDD[j][e] * GammaUDD[j][b][c] * GammaUDD[e][a][d] - \
                                                    gammaDD[j][e] * GammaUDD[j][b][d] * GammaUDD[e][a][c]

                        
# Step 4c: We also need the extrinsic curvature tensor $K_{ij}$. This can be built from quantities from BSSN_RHSs
# For Cartesian coordinates, we already made this a gridfunction.
#extrinsicKDD = ixp.zerorank2()
#for i in range(DIM):
#    for j in range(DIM):
#        extrinsicKDD[i][j] = (bssn.AbarDD[i][j] + sp.Rational(1,3)*gammaDD[i][j]*bssn.trK)/bssn.exp_m4phi
# We will, however, need to calculate the trace of K seperately:
trK = sp.sympify(0)
for i in range(DIM):
    for j in range(DIM):
        trK += gammaUU[i][j] * kDD[i][j]

# %% [markdown]
# # Putting it all together: calculating $\psi_4$
# We do not not need to explicitly build the Weyl tensor itself, because the BCL paper shows that, for the Weyl tensor $C_{ijkl}$,
# \begin{align}
# \psi_4 =&  C_{ijkl} n^i \bar{m}^j n^k \bar{m}^l\\
# =& (R_{ijkl} + 2K_{i[k}K_{l]j}) n^i \bar{m}^j n^k \bar{m}^l \\
# &- 8 (K_{j[k,l]} + \Gamma^p_{j[k} K_{l]p}) n^{[0} \bar{m}^{j]} n^k \bar{m}^l \\
# &+ 4 (R_{jl} - K_{jp} K^p_l + KK_{jl}) n^{[0} \bar{m}^{j]} n^{[0} \bar{m}^{l]}.
# \end{align}
# Note here the brackets around pairs of indices. This indicates the antisymmetric part of a tensor; that is for some arbitrary tensor $A_{ij}$, $A_{[ij]} = \frac{1}{2}(A_{ij}-A_{ji})$. This applies identically for indices belonging to separate tensors as well as superscripts in place of subscripts.
#
# To make it easier to track the construction of this expression, we will break it down into three parts, by first defining each of the parenthetical terms above separately. That is, let
# \begin{align}
# \text{GaussDDDD[i][j][k][l]} =& R_{ijkl} + 2K_{i[k}K_{l]j},
# \end{align}

# %%
# Step 5: Build the formula for \psi_4.
# Gauss equation: involving the Riemann tensor and extrinsic curvature.
GaussDDDD = ixp.zerorank4()
for i in range(DIM):
    for j in range(DIM):
        for k in range(DIM):
            for l in range(DIM):
                GaussDDDD[i][j][k][l] = RiemannDDDD[i][j][k][l] + kDD[i][k]*kDD[l][j] - kDD[i][l]*kDD[k][j]

# %% [markdown]
# \begin{align}
# \text{CodazziDDD[j][k][l]} =& -2 (K_{j[k,l]} + \Gamma^p_{j[k} K_{l]p}),
# \end{align}

# %%
# Codazzi equation: involving partial derivatives of the extrinsic curvature. 
# We will first need to declare derivatives of kDD
kDD_dD = ixp.declarerank3("kDD_dD","sym12")
CodazziDDD = ixp.zerorank3()
for j in range(DIM):
    for k in range(DIM):
        for l in range(DIM):
            CodazziDDD[j][k][l] = kDD_dD[j][l][k] - kDD_dD[j][k][l]
            for p in range(DIM):
                CodazziDDD[j][k][l] += GammaUDD[p][j][l]*kDD[k][p] - GammaUDD[p][j][k]*kDD[l][p]

# %% [markdown]
# and
# \begin{align}
# \text{RojoDD[j][l]} = & R_{jl} - K_{jp} K^p_l + KK_{jl} \\
# = & \gamma^{pd} R_{jpld} - K_{jp} K^p_l + KK_{jl},
# \end{align}

# %%
# Another piece. While not associated with any particular equation,
# this is still useful for organizational purposes.
RojoDD = ixp.zerorank2()
for j in range(DIM):
    for l in range(DIM):
        RojoDD[j][l] = trK*kDD[j][l]
        for p in range(DIM):
            for d in range(DIM):
                RojoDD[j][l] += gammaUU[p][d]*RiemannDDDD[j][p][l][d] - kDD[j][p]*gammaUU[p][d]*kDD[d][l]

# %% [markdown]
# where these quantities are so named because of their relation to the Gauss-Codazzi equations. Then, we simply contract these with the tetrad we chose earlier to arrive at an expression for $\psi_4$. The barred Christoffel symbols and barred Ricci tensor have already been calculated by BSSN_RHSs.py, so we use those values. So, our expression for $\psi_4$ has become
# \begin{align}
# \psi_4 =& (\text{Gauss[i][j][k][l]}) n^i \bar{m}^j n^k \bar{m}^l \\
# &+2 (\text{CodazziDDD[j][k][l]}) n^{0} \bar{m}^{j} n^k \bar{m}^l \\
# &+ (\text{RojoDD[j][l]}) n^{0} \bar{m}^{j} n^{0} \bar{m}^{l}.
# \end{align}

# %%
#mtetccU[i] = isqrt2 * (e3U[i] - sp.I*e1U[i])
#full: mtetccU[j] * mtetccU[l]
#real: isqrt2*isqrt2*(e3U[j]*e3U[l]-e1U[j]*e1U[l])
#imag: isqrt2*isqrt2*(-e3U[j]*e1U[l]-e1U[j]*e3U[l])
# Now we can calculate $\psi_4$ itself!
psi4 = sp.sympify(0)
for l in range(DIM):
    for j in range(DIM):
        psi4 += RojoDD[j][l] * nn * nn * isqrt2*isqrt2*(e3U[j]*e3U[l]-e1U[j]*e1U[l])
        for k in range(DIM):
            psi4 += 2 * CodazziDDD[j][k][l] * ntetU[k] * nn * isqrt2*isqrt2*(e3U[j]*e3U[l]-e1U[j]*e1U[l])
            for i in range(DIM):
                psi4 += GaussDDDD[i][j][k][l] * ntetU[i] * ntetU[k] * isqrt2*isqrt2*(e3U[j]*e3U[l]-e1U[j]*e1U[l])

cse_output = sp.cse(psi4,sp.numbered_symbols("tmp"))
#for commonsubexpression in cse_output:
#    print("hello?",commonsubexpression)
for commonsubexpression in cse_output[0]:
    print((str(commonsubexpression[0])+" = "+str(commonsubexpression[1])+";").replace("**","^").replace("_d","d"))
for i,result in enumerate(cse_output[1]):
   print(("psi4rPy = "+str(result)+";").replace("**","^").replace("_d","d"))
# These replace commands are used to allow us to validate against Einstein Toolkit's WeylScal4 thorn in Mathematica.
# Specifically, the first changes exponentiation to Mathematica's format, and the second strips the underscores
# that have a very specific meaning in Mathematica and thus cannot be used in variable names.
# Out:
# tmp0 = 2*kDDdD022;
# tmp1 = 2*kDDdD220;
# tmp2 = gammaDD11*gammaDD22;
# tmp3 = gammaDD01*gammaDD12;
# tmp4 = 2*gammaDD02;
# tmp5 = gammaDD12^2;
# tmp6 = gammaDD01^2;
# tmp7 = gammaDD02^2;
# tmp8 = 1/(gammaDD00*tmp2 - gammaDD00*tmp5 - gammaDD11*tmp7 - gammaDD22*tmp6 + tmp3*tmp4);
# tmp9 = tmp8*(-gammaDD02*gammaDD11 + tmp3);
# tmp10 = tmp9/2;
# tmp11 = tmp8*(tmp2 - tmp5);
# tmp12 = tmp11/2;
# tmp13 = gammaDDdD012 - gammaDDdD021 + gammaDDdD120;
# tmp14 = tmp8*(-gammaDD01*gammaDD22 + gammaDD02*gammaDD12);
# tmp15 = tmp14/2;
# tmp16 = gammaDDdD002*tmp12 + gammaDDdD220*tmp10 + tmp13*tmp15;
# tmp17 = 2*tmp16;
# tmp18 = kDD02*tmp17;
# tmp19 = tmp8*(-gammaDD00*gammaDD12 + gammaDD01*gammaDD02);
# tmp20 = tmp19/2;
# tmp21 = tmp8*(gammaDD00*gammaDD22 - tmp7);
# tmp22 = tmp21/2;
# tmp23 = gammaDDdD002*tmp15 + gammaDDdD220*tmp20 + tmp13*tmp22;
# tmp24 = 2*kDD12;
# tmp25 = tmp23*tmp24;
# tmp26 = tmp8*(gammaDD00*gammaDD11 - tmp6);
# tmp27 = tmp26/2;
# tmp28 = gammaDDdD002*tmp10 + gammaDDdD220*tmp27 + tmp13*tmp20;
# tmp29 = 2*kDD22;
# tmp30 = tmp28*tmp29;
# tmp31 = 2*gammaDDdD122 - gammaDDdD221;
# tmp32 = 2*gammaDDdD022 - gammaDDdD220;
# tmp33 = gammaDDdD222*tmp10 + tmp12*tmp32 + tmp15*tmp31;
# tmp34 = 2*kDD00;
# tmp35 = tmp33*tmp34;
# tmp36 = gammaDDdD222*tmp20 + tmp15*tmp32 + tmp22*tmp31;
# tmp37 = 2*kDD01;
# tmp38 = tmp36*tmp37;
# tmp39 = gammaDDdD222*tmp27 + tmp10*tmp32 + tmp20*tmp31;
# tmp40 = 2*kDD02;
# tmp41 = tmp39*tmp40;
# tmp42 = xx2^2;
# tmp43 = xx1^2;
# tmp44 = xx0^2;
# tmp45 = xx0*xx1;
# tmp46 = 2*gammaDD01;
# tmp47 = gammaDD00*tmp43 + gammaDD11*tmp44 - tmp45*tmp46;
# tmp48 = 1/sqrt(tmp47);
# tmp49 = tmp48*xx1;
# tmp50 = tmp48*xx0;
# tmp51 = gammaDD12*tmp50;
# tmp52 = gammaDD01*tmp48;
# tmp53 = gammaDD00*tmp49;
# tmp54 = gammaDD02*tmp49;
# tmp55 = gammaDD11*tmp49*xx0 - tmp43*tmp52 + tmp44*tmp52 + tmp51*xx2 - tmp53*xx0 - tmp54*xx2;
# tmp56 = tmp49*tmp55 + xx0;
# tmp57 = tmp56^2;
# tmp58 = tmp56*xx2;
# tmp59 = -tmp50*tmp55 + xx1;
# tmp60 = tmp59^2;
# tmp61 = gammaDD12*xx2;
# tmp62 = tmp56*tmp59;
# tmp63 = gammaDD00*tmp57 + gammaDD11*tmp60 + gammaDD22*tmp42 + tmp4*tmp58 + tmp46*tmp62 + 2*tmp59*tmp61;
# tmp64 = 1/sqrt(tmp63);
# tmp65 = 1.0*sqrt(detgamma);
# tmp66 = tmp65*xx2;
# tmp67 = tmp66*xx1;
# tmp68 = tmp65*tmp9;
# tmp69 = tmp66*xx0;
# tmp70 = tmp11*tmp69 + tmp14*tmp67 - tmp43*tmp68 - tmp44*tmp68;
# tmp71 = tmp64*tmp70;
# tmp72 = tmp19*tmp65;
# tmp73 = tmp14*tmp69 + tmp21*tmp67 - tmp43*tmp72 - tmp44*tmp72;
# tmp74 = tmp26*tmp65;
# tmp75 = -tmp43*tmp74 - tmp44*tmp74 + tmp68*xx0*xx2 + tmp72*xx1*xx2;
# tmp76 = tmp64*xx2;
# tmp77 = tmp56*tmp64;
# tmp78 = gammaDD01*tmp73;
# tmp79 = gammaDD11*tmp73;
# tmp80 = tmp59*tmp64;
# tmp81 = tmp64*(gammaDD00*tmp70*tmp77 + gammaDD01*tmp59*tmp71 + gammaDD02*tmp71*xx2 + gammaDD02*tmp75*tmp77 + gammaDD12*tmp75*tmp80 + gammaDD22*tmp75*tmp76 + tmp61*tmp64*tmp73 + tmp77*tmp78 + tmp79*tmp80);
# tmp82 = tmp75 - tmp81*xx2;
# tmp83 = tmp82^2;
# tmp84 = -tmp49*tmp78 + tmp50*tmp79 + tmp51*tmp75 + tmp52*tmp70*xx0 - tmp53*tmp70 - tmp54*tmp75;
# tmp85 = tmp49*tmp84 - tmp56*tmp81 + tmp70;
# tmp86 = tmp85^2;
# tmp87 = -tmp50*tmp84 - tmp59*tmp81 + tmp73;
# tmp88 = tmp87^2;
# tmp89 = tmp82*tmp85;
# tmp90 = tmp82*tmp87;
# tmp91 = 2*tmp90;
# tmp92 = tmp85*tmp87;
# tmp93 = 1/(gammaDD00*tmp86 + gammaDD11*tmp88 + gammaDD12*tmp91 + gammaDD22*tmp83 + tmp4*tmp89 + tmp46*tmp92);
# tmp94 = tmp83*tmp93;
# tmp95 = tmp77/4;
# tmp96 = 2*kDDdD122;
# tmp97 = 2*kDDdD221;
# tmp98 = gammaDDdD012 + gammaDDdD021 - gammaDDdD120;
# tmp99 = gammaDDdD112*tmp15 + gammaDDdD221*tmp10 + tmp12*tmp98;
# tmp100 = tmp40*tmp99;
# tmp101 = gammaDDdD112*tmp22 + gammaDDdD221*tmp20 + tmp15*tmp98;
# tmp102 = tmp101*tmp24;
# tmp103 = gammaDDdD112*tmp20 + gammaDDdD221*tmp27 + tmp10*tmp98;
# tmp104 = tmp103*tmp29;
# tmp105 = tmp33*tmp37;
# tmp106 = 2*kDD11;
# tmp107 = tmp106*tmp36;
# tmp108 = tmp24*tmp39;
# tmp109 = tmp80/4;
# tmp110 = 1/tmp47;
# tmp111 = -tmp110*tmp43 + tmp86*tmp93;
# tmp112 = 2*kDDdD002;
# tmp113 = 2*kDDdD020;
# tmp114 = kDD00*tmp17;
# tmp115 = tmp23*tmp37;
# tmp116 = tmp28*tmp40;
# tmp117 = -gammaDDdD001 + 2*gammaDDdD010;
# tmp118 = -gammaDDdD002 + 2*gammaDDdD020;
# tmp119 = gammaDDdD000*tmp12 + tmp10*tmp118 + tmp117*tmp15;
# tmp120 = tmp119*tmp40;
# tmp121 = gammaDDdD000*tmp15 + tmp117*tmp22 + tmp118*tmp20;
# tmp122 = tmp121*tmp24;
# tmp123 = gammaDDdD000*tmp10 + tmp117*tmp20 + tmp118*tmp27;
# tmp124 = tmp123*tmp29;
# tmp125 = tmp76/4;
# tmp126 = -tmp110*tmp44 + tmp88*tmp93;
# tmp127 = 2*kDDdD112;
# tmp128 = 2*kDDdD121;
# tmp129 = tmp37*tmp99;
# tmp130 = tmp101*tmp106;
# tmp131 = tmp103*tmp24;
# tmp132 = -gammaDDdD112 + 2*gammaDDdD121;
# tmp133 = 2*gammaDDdD011 - gammaDDdD110;
# tmp134 = gammaDDdD111*tmp15 + tmp10*tmp132 + tmp12*tmp133;
# tmp135 = tmp134*tmp40;
# tmp136 = gammaDDdD111*tmp22 + tmp132*tmp20 + tmp133*tmp15;
# tmp137 = tmp136*tmp24;
# tmp138 = gammaDDdD111*tmp20 + tmp10*tmp133 + tmp132*tmp27;
# tmp139 = tmp138*tmp29;
# tmp140 = 2*kDDdD001;
# tmp141 = 2*kDDdD010;
# tmp142 = -gammaDDdD012 + gammaDDdD021 + gammaDDdD120;
# tmp143 = gammaDDdD001*tmp12 + gammaDDdD110*tmp15 + tmp10*tmp142;
# tmp144 = tmp143*tmp34;
# tmp145 = gammaDDdD001*tmp15 + gammaDDdD110*tmp22 + tmp142*tmp20;
# tmp146 = tmp145*tmp37;
# tmp147 = gammaDDdD001*tmp10 + gammaDDdD110*tmp20 + tmp142*tmp27;
# tmp148 = tmp147*tmp40;
# tmp149 = tmp119*tmp37;
# tmp150 = tmp106*tmp121;
# tmp151 = tmp123*tmp24;
# tmp152 = 2*kDDdD011;
# tmp153 = 2*kDDdD110;
# tmp154 = tmp143*tmp37;
# tmp155 = tmp106*tmp145;
# tmp156 = tmp147*tmp24;
# tmp157 = tmp134*tmp34;
# tmp158 = tmp136*tmp37;
# tmp159 = tmp138*tmp40;
# tmp160 = kDD02^2;
# tmp161 = kDD00*kDD22;
# tmp162 = gammaDDdDD0022/2;
# tmp163 = gammaDDdDD2200/2;
# tmp164 = gammaDD00*tmp16^2;
# tmp165 = gammaDD11*tmp23^2;
# tmp166 = gammaDD22*tmp28^2;
# tmp167 = gammaDD01*tmp16;
# tmp168 = 2*tmp23;
# tmp169 = tmp167*tmp168;
# tmp170 = gammaDD02*tmp16;
# tmp171 = 2*tmp170*tmp28;
# tmp172 = gammaDD12*tmp28;
# tmp173 = tmp168*tmp172;
# tmp174 = gammaDD00*tmp119;
# tmp175 = tmp174*tmp33;
# tmp176 = gammaDD01*tmp121;
# tmp177 = tmp176*tmp33;
# tmp178 = gammaDD01*tmp119;
# tmp179 = tmp178*tmp36;
# tmp180 = gammaDD02*tmp123;
# tmp181 = tmp180*tmp33;
# tmp182 = gammaDD02*tmp119;
# tmp183 = tmp182*tmp39;
# tmp184 = gammaDD11*tmp121;
# tmp185 = tmp184*tmp36;
# tmp186 = gammaDD12*tmp123;
# tmp187 = tmp186*tmp36;
# tmp188 = gammaDD12*tmp121;
# tmp189 = tmp188*tmp39;
# tmp190 = gammaDD22*tmp123;
# tmp191 = tmp190*tmp39;
# tmp192 = gammaDDdDD0202 - tmp162 - tmp163 + tmp164 + tmp165 + tmp166 + tmp169 + tmp171 + tmp173 - tmp175 - tmp177 - tmp179 - tmp181 - tmp183 - tmp185 - tmp187 - tmp189 - tmp191;
# tmp193 = -tmp160 + tmp161 + tmp192;
# tmp194 = 1/tmp63;
# tmp195 = tmp194*tmp57;
# tmp196 = tmp94/4;
# tmp197 = kDD12^2;
# tmp198 = kDD11*kDD22;
# tmp199 = gammaDDdDD1122/2;
# tmp200 = gammaDDdDD2211/2;
# tmp201 = gammaDD00*tmp99^2;
# tmp202 = gammaDD11*tmp101^2;
# tmp203 = gammaDD22*tmp103^2;
# tmp204 = gammaDD01*tmp99;
# tmp205 = 2*tmp101;
# tmp206 = tmp204*tmp205;
# tmp207 = gammaDD02*tmp99;
# tmp208 = 2*tmp103*tmp207;
# tmp209 = gammaDD12*tmp103;
# tmp210 = tmp205*tmp209;
# tmp211 = gammaDD00*tmp134;
# tmp212 = tmp211*tmp33;
# tmp213 = gammaDD01*tmp136;
# tmp214 = tmp213*tmp33;
# tmp215 = gammaDD01*tmp134;
# tmp216 = tmp215*tmp36;
# tmp217 = gammaDD02*tmp138;
# tmp218 = tmp217*tmp33;
# tmp219 = gammaDD02*tmp134;
# tmp220 = tmp219*tmp39;
# tmp221 = gammaDD11*tmp136;
# tmp222 = tmp221*tmp36;
# tmp223 = gammaDD12*tmp138;
# tmp224 = tmp223*tmp36;
# tmp225 = gammaDD12*tmp136;
# tmp226 = tmp225*tmp39;
# tmp227 = gammaDD22*tmp138;
# tmp228 = tmp227*tmp39;
# tmp229 = gammaDDdDD1212 - tmp199 - tmp200 + tmp201 + tmp202 + tmp203 + tmp206 + tmp208 + tmp210 - tmp212 - tmp214 - tmp216 - tmp218 - tmp220 - tmp222 - tmp224 - tmp226 - tmp228;
# tmp230 = -tmp197 + tmp198 + tmp229;
# tmp231 = tmp194*tmp60;
# tmp232 = kDD01*kDD22;
# tmp233 = kDD02*kDD12;
# tmp234 = gammaDDdDD0122/2;
# tmp235 = gammaDDdDD0212/2;
# tmp236 = gammaDDdDD1202/2;
# tmp237 = gammaDDdDD2201/2;
# tmp238 = gammaDD00*tmp16*tmp99;
# tmp239 = tmp204*tmp23;
# tmp240 = tmp101*tmp167;
# tmp241 = tmp207*tmp28;
# tmp242 = tmp103*tmp170;
# tmp243 = gammaDD11*tmp101*tmp23;
# tmp244 = tmp101*tmp172;
# tmp245 = tmp209*tmp23;
# tmp246 = gammaDD22*tmp103*tmp28;
# tmp247 = gammaDD00*tmp143;
# tmp248 = tmp247*tmp33;
# tmp249 = gammaDD01*tmp145;
# tmp250 = tmp249*tmp33;
# tmp251 = gammaDD01*tmp143;
# tmp252 = tmp251*tmp36;
# tmp253 = gammaDD02*tmp147;
# tmp254 = tmp253*tmp33;
# tmp255 = gammaDD02*tmp143;
# tmp256 = tmp255*tmp39;
# tmp257 = gammaDD11*tmp145;
# tmp258 = tmp257*tmp36;
# tmp259 = gammaDD12*tmp147;
# tmp260 = tmp259*tmp36;
# tmp261 = gammaDD12*tmp145;
# tmp262 = tmp261*tmp39;
# tmp263 = gammaDD22*tmp147;
# tmp264 = tmp263*tmp39;
# tmp265 = -tmp234 + tmp235 + tmp236 - tmp237 + tmp238 + tmp239 + tmp240 + tmp241 + tmp242 + tmp243 + tmp244 + tmp245 + tmp246 - tmp248 - tmp250 - tmp252 - tmp254 - tmp256 - tmp258 - tmp260 - tmp262 - tmp264;
# tmp266 = tmp232 - tmp233 + tmp265;
# tmp267 = tmp194/2;
# tmp268 = tmp267*tmp62;
# tmp269 = tmp194*tmp42;
# tmp270 = tmp269/4;
# tmp271 = kDD01^2;
# tmp272 = kDD00*kDD11;
# tmp273 = gammaDDdDD0011/2;
# tmp274 = gammaDDdDD1100/2;
# tmp275 = gammaDD00*tmp143^2;
# tmp276 = gammaDD11*tmp145^2;
# tmp277 = gammaDD22*tmp147^2;
# tmp278 = 2*tmp145;
# tmp279 = tmp251*tmp278;
# tmp280 = 2*tmp147*tmp255;
# tmp281 = tmp259*tmp278;
# tmp282 = tmp134*tmp174;
# tmp283 = tmp134*tmp176;
# tmp284 = tmp136*tmp178;
# tmp285 = tmp134*tmp180;
# tmp286 = tmp138*tmp182;
# tmp287 = tmp136*tmp184;
# tmp288 = tmp136*tmp186;
# tmp289 = tmp138*tmp188;
# tmp290 = tmp138*tmp190;
# tmp291 = gammaDDdDD0101 - tmp273 - tmp274 + tmp275 + tmp276 + tmp277 + tmp279 + tmp280 + tmp281 - tmp282 - tmp283 - tmp284 - tmp285 - tmp286 - tmp287 - tmp288 - tmp289 - tmp290;
# tmp292 = -tmp271/4 + tmp272/4 + tmp291/4;
# tmp293 = tmp111*tmp194;
# tmp294 = tmp126*tmp194;
# tmp295 = tmp59*xx2;
# tmp296 = kDD00*kDD12;
# tmp297 = kDD01*kDD02;
# tmp298 = gammaDDdDD0012/2;
# tmp299 = gammaDDdDD0102/2;
# tmp300 = gammaDDdDD0201/2;
# tmp301 = gammaDDdDD1200/2;
# tmp302 = tmp16*tmp247;
# tmp303 = tmp16*tmp249;
# tmp304 = tmp23*tmp251;
# tmp305 = tmp16*tmp253;
# tmp306 = tmp255*tmp28;
# tmp307 = tmp23*tmp257;
# tmp308 = tmp23*tmp259;
# tmp309 = tmp261*tmp28;
# tmp310 = tmp263*tmp28;
# tmp311 = tmp174*tmp99;
# tmp312 = tmp176*tmp99;
# tmp313 = tmp101*tmp178;
# tmp314 = tmp180*tmp99;
# tmp315 = tmp103*tmp182;
# tmp316 = tmp101*tmp184;
# tmp317 = tmp101*tmp186;
# tmp318 = tmp103*tmp188;
# tmp319 = tmp103*tmp190;
# tmp320 = -tmp298 + tmp299 + tmp300 - tmp301 + tmp302 + tmp303 + tmp304 + tmp305 + tmp306 + tmp307 + tmp308 + tmp309 + tmp310 - tmp311 - tmp312 - tmp313 - tmp314 - tmp315 - tmp316 - tmp317 - tmp318 - tmp319;
# tmp321 = tmp296/2 - tmp297/2 + tmp320/2;
# tmp322 = kDD02*kDD11;
# tmp323 = kDD01*kDD12;
# tmp324 = gammaDDdDD0112/2;
# tmp325 = gammaDDdDD0211/2;
# tmp326 = gammaDDdDD1102/2;
# tmp327 = gammaDDdDD1201/2;
# tmp328 = tmp247*tmp99;
# tmp329 = tmp249*tmp99;
# tmp330 = tmp101*tmp251;
# tmp331 = tmp253*tmp99;
# tmp332 = tmp103*tmp255;
# tmp333 = tmp101*tmp257;
# tmp334 = tmp101*tmp259;
# tmp335 = tmp103*tmp261;
# tmp336 = tmp103*tmp263;
# tmp337 = tmp16*tmp211;
# tmp338 = tmp215*tmp23;
# tmp339 = tmp16*tmp213;
# tmp340 = tmp219*tmp28;
# tmp341 = tmp16*tmp217;
# tmp342 = tmp221*tmp23;
# tmp343 = tmp225*tmp28;
# tmp344 = tmp223*tmp23;
# tmp345 = tmp227*tmp28;
# tmp346 = tmp324 - tmp325 - tmp326 + tmp327 + tmp328 + tmp329 + tmp330 + tmp331 + tmp332 + tmp333 + tmp334 + tmp335 + tmp336 - tmp337 - tmp338 - tmp339 - tmp340 - tmp341 - tmp342 - tmp343 - tmp344 - tmp345;
# tmp347 = tmp322/2 - tmp323/2 + tmp346/2;
# tmp348 = kDD02*tmp10;
# tmp349 = kDD12*tmp20;
# tmp350 = tmp11/4;
# tmp351 = tmp21/4;
# tmp352 = tmp26/4;
# tmp353 = kDD00*tmp11;
# tmp354 = kDD11*tmp21;
# tmp355 = kDD22*tmp26;
# tmp356 = tmp14*tmp37/4 + tmp19*tmp24/4 + tmp353/4 + tmp354/4 + tmp355/4 + tmp40*tmp9/4;
# tmp357 = kDD01*tmp15;
# tmp358 = tmp89*tmp93;
# tmp359 = tmp90*tmp93;
# tmp360 = 2*kDDdD120;
# tmp361 = tmp34*tmp99;
# tmp362 = tmp101*tmp37;
# tmp363 = tmp103*tmp40;
# tmp364 = -tmp360 - tmp361 - tmp362 - tmp363;
# tmp365 = 2*kDDdD021;
# tmp366 = kDD01*tmp17;
# tmp367 = tmp106*tmp23;
# tmp368 = tmp24*tmp28;
# tmp369 = tmp365 + tmp366 + tmp367 + tmp368;
# tmp370 = tmp109*tmp358;
# tmp371 = 2*kDDdD012;
# tmp372 = tmp143*tmp40;
# tmp373 = tmp145*tmp24;
# tmp374 = tmp147*tmp29;
# tmp375 = -tmp371 - tmp372 - tmp373 - tmp374;
# tmp376 = -tmp365 - tmp366 - tmp367 - tmp368;
# tmp377 = tmp360 + tmp361 + tmp362 + tmp363;
# tmp378 = tmp359*tmp95;
# tmp379 = tmp371 + tmp372 + tmp373 + tmp374;
# tmp380 = tmp110*tmp45 + tmp92*tmp93;
# tmp381 = tmp125*tmp380;
# tmp382 = -gammaDDdDD0202 + tmp162 + tmp163 - tmp164 - tmp165 - tmp166 - tmp169 - tmp171 - tmp173 + tmp175 + tmp177 + tmp179 + tmp181 + tmp183 + tmp185 + tmp187 + tmp189 + tmp191;
# tmp383 = tmp267*tmp58;
# tmp384 = -gammaDDdDD1212 + tmp199 + tmp200 - tmp201 - tmp202 - tmp203 - tmp206 - tmp208 - tmp210 + tmp212 + tmp214 + tmp216 + tmp218 + tmp220 + tmp222 + tmp224 + tmp226 + tmp228;
# tmp385 = tmp267*tmp295;
# tmp386 = tmp234 - tmp235 - tmp236 + tmp237 - tmp238 - tmp239 - tmp240 - tmp241 - tmp242 - tmp243 - tmp244 - tmp245 - tmp246 + tmp248 + tmp250 + tmp252 + tmp254 + tmp256 + tmp258 + tmp260 + tmp262 + tmp264;
# tmp387 = -tmp232 + tmp233 + tmp386;
# tmp388 = tmp298 - tmp299 - tmp300 + tmp301 - tmp302 - tmp303 - tmp304 - tmp305 - tmp306 - tmp307 - tmp308 - tmp309 - tmp310 + tmp311 + tmp312 + tmp313 + tmp314 + tmp315 + tmp316 + tmp317 + tmp318 + tmp319;
# tmp389 = -tmp296 + tmp297 + tmp388;
# tmp390 = -tmp324 + tmp325 + tmp326 - tmp327 - tmp328 - tmp329 - tmp330 - tmp331 - tmp332 - tmp333 - tmp334 - tmp335 - tmp336 + tmp337 + tmp338 + tmp339 + tmp340 + tmp341 + tmp342 + tmp343 + tmp344 + tmp345;
# tmp391 = -tmp322 + tmp323 + tmp390;
# tmp392 = -gammaDDdDD0101 + tmp273 + tmp274 - tmp275 - tmp276 - tmp277 - tmp279 - tmp280 - tmp281 + tmp282 + tmp283 + tmp284 + tmp285 + tmp286 + tmp287 + tmp288 + tmp289 + tmp290;
# tmp393 = tmp380/2;
# tmp394 = tmp194*tmp393;
# tmp395 = tmp14/4;
# tmp396 = tmp9/4;
# tmp397 = tmp19/4;
# tmp398 = kDD02/4;
# tmp399 = kDD12/4;
# tmp400 = kDD01/4;
# psi4iPy = -tmp109*tmp111*(tmp140 - tmp141 - tmp144 - tmp146 - tmp148 + tmp149 + tmp150 + tmp151) - tmp109*tmp359*(-tmp127 + tmp128 + tmp129 + tmp130 + tmp131 - tmp135 - tmp137 - tmp139) - tmp109*tmp380*(tmp152 - tmp153 + tmp154 + tmp155 + tmp156 - tmp157 - tmp158 - tmp159) - tmp109*tmp94*(-tmp100 - tmp102 - tmp104 + tmp105 + tmp107 + tmp108 - tmp96 + tmp97) - tmp111*tmp125*(tmp112 - tmp113 - tmp114 - tmp115 - tmp116 + tmp120 + tmp122 + tmp124) + tmp111*tmp193*tmp270 + tmp111*(-kDD00^2*tmp350 - kDD00*tmp348 + kDD00*tmp356 - kDD00*tmp357 - tmp160*tmp352 + tmp192*tmp352 - tmp20*tmp297 + tmp20*tmp320 - tmp271*tmp351 + tmp291*tmp351) - tmp125*tmp126*(tmp127 - tmp128 - tmp129 - tmp130 - tmp131 + tmp135 + tmp137 + tmp139) - tmp125*tmp358*(tmp0 - tmp1 + tmp18 + tmp25 + tmp30 - tmp35 - tmp38 - tmp41) - tmp125*tmp359*(tmp100 + tmp102 + tmp104 - tmp105 - tmp107 - tmp108 + tmp96 - tmp97) + tmp126*tmp230*tmp270 - tmp126*tmp95*(-tmp152 + tmp153 - tmp154 - tmp155 - tmp156 + tmp157 + tmp158 + tmp159) + tmp126*(-kDD11^2*tmp351 - kDD11*tmp349 + kDD11*tmp356 - kDD11*tmp357 - tmp10*tmp323 + tmp10*tmp346 - tmp197*tmp352 + tmp229*tmp352 - tmp271*tmp350 + tmp291*tmp350) + tmp193*tmp195*tmp196 + tmp195*tmp321*tmp359 + tmp196*tmp230*tmp231 + tmp231*tmp347*tmp358 + tmp266*tmp268*tmp94 + tmp266*tmp269*tmp393 + tmp268*tmp358*tmp389 + tmp268*tmp359*tmp391 + tmp292*tmp293*tmp60 + tmp292*tmp294*tmp57 + tmp293*tmp295*tmp321 + tmp294*tmp347*tmp58 + tmp295*tmp391*tmp394 + tmp358*tmp383*(tmp160 - tmp161 + tmp382) + tmp358*tmp385*tmp387 - tmp358*tmp95*(-tmp112 + tmp113 + tmp114 + tmp115 + tmp116 - tmp120 - tmp122 - tmp124) + 2*tmp358*(kDD02*tmp356 - tmp160*tmp396 - tmp161*tmp396 - tmp232*tmp397 - tmp233*tmp397 - tmp296*tmp395 - tmp297*tmp395 - tmp323*tmp351 + tmp346*tmp351 - tmp353*tmp398 - tmp355*tmp398 + tmp382*tmp396 + tmp386*tmp397 + tmp388*tmp395) + tmp359*tmp383*tmp387 + tmp359*tmp385*(tmp197 - tmp198 + tmp384) - tmp370*(tmp364 + tmp369) - tmp370*(tmp369 + tmp375) - tmp378*(tmp375 + tmp377) - tmp378*(tmp376 + tmp377) - tmp380*tmp95*(-tmp140 + tmp141 + tmp144 + tmp146 + tmp148 - tmp149 - tmp150 - tmp151) + 2*tmp380*(kDD01*tmp356 - tmp233*tmp352 + tmp265*tmp352 - tmp271*tmp395 - tmp272*tmp395 - tmp296*tmp396 - tmp297*tmp396 - tmp322*tmp397 - tmp323*tmp397 - tmp353*tmp400 - tmp354*tmp400 + tmp388*tmp396 + tmp390*tmp397 + tmp392*tmp395) - tmp381*(tmp364 + tmp379) - tmp381*(tmp376 + tmp379) + tmp389*tmp394*tmp58 + tmp394*tmp62*(tmp271 - tmp272 + tmp392) + tmp91*tmp93*(kDD12*tmp356 - tmp197*tmp397 - tmp198*tmp397 - tmp232*tmp396 - tmp233*tmp396 - tmp297*tmp350 + tmp320*tmp350 - tmp322*tmp395 - tmp323*tmp395 - tmp354*tmp399 - tmp355*tmp399 + tmp384*tmp397 + tmp386*tmp396 + tmp390*tmp395) - tmp94*tmp95*(-tmp0 + tmp1 - tmp18 - tmp25 - tmp30 + tmp35 + tmp38 + tmp41) + tmp94*(-kDD22^2*tmp352 - kDD22*tmp348 - kDD22*tmp349 + kDD22*tmp356 - tmp15*tmp233 + tmp15*tmp265 - tmp160*tmp350 + tmp192*tmp350 - tmp197*tmp351 + tmp229*tmp351);
